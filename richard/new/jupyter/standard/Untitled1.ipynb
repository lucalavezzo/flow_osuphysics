# %%
exp = 'simple_training_example_ring_v1'
dirName = "PPO_WaveAttenuationPOEnv-v0_0_2020-03-23_12-23-23vhhlmj8e"
varNames = 'episode_reward_mean episode_reward_min episode_reward_max'
fullName = "/users/PYS1027/chnrhughes/ray_results/" + exp + '/' + dirName + '/progress.csv ' + varNames

pythonName = "/users/PYS1027/chnrhughes/work/flowtest/flow/flow/visualize/plot_ray_results\.py "

command = 

# %matplotlib notebook
# if this doesn't display anything, try with "%matplotlib inline" instead
# %run /users/PYS1027/chnrhughes/work/flowtest/flow/flow/visualize/plot_ray_results.py $fullName
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
exp = 'simple_training_example_ring_v1'
dirName = "PPO_WaveAttenuationPOEnv-v0_0_2020-03-23_12-23-23vhhlmj8e"
varNames = 'episode_reward_mean episode_reward_min episode_reward_max'
fullName = "/users/PYS1027/chnrhughes/ray_results/" + exp + '/' + dirName + '/progress.csv ' + varNames

# %matplotlib notebook
# if this doesn't display anything, try with "%matplotlib inline" instead
# %run /users/PYS1027/chnrhughes/work/flowtest/flow/flow/visualize/plot_ray_results.py \
/users/PYS1027/chnrhughes/ray_results/
simple_training_example_ring_v1/PPO_WaveAttenuationPOEnv-v0_0_2020-03-23_12-23-23vhhlmj8e/progress.csv \
 episode_reward_mean episode_reward_min episode_reward_max
# Out:
#   File "<ipython-input-5-cf173b8c56f8>", line 9
#     simple_training_example_ring_v1/PPO_WaveAttenuationPOEnv-v0_0_2020-03-23_12-23-23vhhlmj8e/progress.csv \
#                                                                         ^
# SyntaxError: invalid token
