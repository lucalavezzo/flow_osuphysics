# %%
# %matplotlib notebook
# if this doesn't display anything, try with "%matplotlib inline" instead
# %run /users/PYS1027/chnrhughes/work/flowtest/flow/flow/visualize/plot_ray_results.py \
 /users/PYS1027/chnrhughes/ray_results/training_example/PPO_WaveAttenuationPOEnv-v0_0_2020-03-23_10-20-58zzsxex87/progress.csv \
 episode_reward_mean episode_reward_min episode_reward_max
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
# if this doesn't display anything, try with "%matplotlib inline" instead
# %run /users/PYS1027/chnrhughes/work/flowtest/flow/flow/visualize/plot_ray_results.py \
/users/PYS1027/chnrhughes/ray_results/simple_training_example_ring/PPO_WaveAttenuationPOEnv-v0_0_2020-03-23_10-32-18okjg861_/progress.csv \
 episode_reward_mean episode_reward_min episode_reward_max
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
# if this doesn't display anything, try with "%matplotlib inline" instead
# %run /users/PYS1027/chnrhughes/work/flowtest/flow/flow/visualize/plot_ray_results.py \
/users/PYS1027/chnrhughes/ray_results/simple_training_example_ring/PPO_WaveAttenuationPOEnv-v0_0_2020-03-23_10-45-47hdufyn8x/progress.csv \
 episode_reward_mean episode_reward_min episode_reward_max
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
# if this doesn't display anything, try with "%matplotlib inline" instead
# %run /users/PYS1027/chnrhughes/work/flowtest/flow/flow/visualize/plot_ray_results.py \
/users/PYS1027/chnrhughes/ray_results/simple_training_example_ring_v1/PPO_WaveAttenuationPOEnv-v0_0_2020-03-23_11-12-42hon095ox/progress.csv \
 episode_reward_mean episode_reward_min episode_reward_max
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
# if this doesn't display anything, try with "%matplotlib inline" instead
# %run /users/PYS1027/chnrhughes/work/flowtest/flow/flow/visualize/plot_ray_results.py \
/users/PYS1027/chnrhughes/ray_results/simple_training_example_ring_v1/PPO_WaveAttenuationPOEnv-v0_0_2020-03-23_12-23-23vhhlmj8e/progress.csv \
 episode_reward_mean episode_reward_min episode_reward_max
# Out:
# <img src="data:image/png;base64,..." width="640">
