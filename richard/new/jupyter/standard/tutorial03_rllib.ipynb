# %% [markdown]
# # Tutorial 03: Running RLlib Experiments
#
# This tutorial walks you through the process of running traffic simulations in Flow with trainable RLlib-powered agents. Autonomous agents will learn to maximize a certain reward over the rollouts, using the [**RLlib**](https://ray.readthedocs.io/en/latest/rllib.html) library ([citation](https://arxiv.org/abs/1712.09381)) ([installation instructions](https://flow.readthedocs.io/en/latest/flow_setup.html#optional-install-ray-rllib)). Simulations of this form will depict the propensity of RL agents to influence the traffic of a human fleet in order to make the whole fleet more efficient (for some given metrics).
#
# In this tutorial, we simulate an initially perturbed single lane ring road, where we introduce a single autonomous vehicle. We witness that, after some training, that the autonomous vehicle learns to dissipate the formation and propagation of "phantom jams" which form when only human driver dynamics are involved.
#
# ## 1. Components of a Simulation
# All simulations, both in the presence and absence of RL, require two components: a *network*, and an *environment*. Networks describe the features of the transportation network used in simulation. This includes the positions and properties of nodes and edges constituting the lanes and junctions, as well as properties of the vehicles, traffic lights, inflows, etc... in the network. Environments, on the other hand, initialize, reset, and advance simulations, and act as the primary interface between the reinforcement learning algorithm and the network. Moreover, custom environments may be used to modify the dynamical features of an network. Finally, in the RL case, it is in the *environment* that the state/action spaces and the reward function are defined.
#
# ## 2. Setting up a Network
# Flow contains a plethora of pre-designed networks used to replicate highways, intersections, and merges in both closed and open settings. All these networks are located in flow/networks. For this tutorial, which involves a single lane ring road, we will use the network `RingNetwork`.
#
# ### 2.1 Setting up Network Parameters
#
# The network mentioned at the start of this section, as well as all other networks in Flow, are parameterized by the following arguments:
# * name
# * vehicles
# * net_params
# * initial_config
#
# These parameters are explained in detail in `tutorial01_sumo.ipynb`. Moreover, all parameters excluding vehicles (covered in section 2.2) do not change from the previous tutorial. Accordingly, we specify them nearly as we have before, and leave further explanations of the parameters to `tutorial01_sumo.ipynb`.
#
# We begin by choosing the network the experiment will be trained on. We use one of Flow's builtin networks, located in `flow.networks`. A list of all available networks can be found by running the script below.

# %%
import flow.networks as networks

print(networks.__all__)
# Out:
# ['Network', 'BayBridgeNetwork', 'BayBridgeTollNetwork', 'BottleneckNetwork', 'FigureEightNetwork', 'TrafficLightGridNetwork', 'HighwayNetwork', 'RingNetwork', 'MergeNetwork', 'MultiRingNetwork', 'MiniCityNetwork', 'HighwayRampsNetwork']

# %% [markdown]
# In this tutorial, we choose to use the ring road network. The network class is then:

# %%
from flow.networks import RingNetwork

# ring road network class
network_name = RingNetwork

# %% [markdown]
# One key difference between SUMO and RLlib experiments is that, in RLlib experiments, the network classes do not need to be defined; instead users should simply name the network class they wish to use. Later on, an environment setup module will import the correct network class based on the provided names.

# %%
# input parameter classes to the network class
from flow.core.params import NetParams, InitialConfig

# name of the network
name = "training_example"

# network-specific parameters
from flow.networks.ring import ADDITIONAL_NET_PARAMS
net_params = NetParams(additional_params=ADDITIONAL_NET_PARAMS)

# initial configuration to vehicles
initial_config = InitialConfig(spacing="uniform", perturbation=1)

# %% [markdown]
# ### 2.2 Adding Trainable Autonomous Vehicles
# The `Vehicles` class stores state information on all vehicles in the network. This class is used to identify the dynamical features of a vehicle and whether it is controlled by a reinforcement learning agent. Morover, information pertaining to the observations and reward function can be collected from various `get` methods within this class.
#
# The dynamics of vehicles in the `Vehicles` class can either be depicted by sumo or by the dynamical methods located in flow/controllers. For human-driven vehicles, we use the IDM model for acceleration behavior, with exogenous gaussian acceleration noise with std 0.2 m/s2 to induce perturbations that produce stop-and-go behavior. In addition, we use the `ContinousRouter` routing controller so that the vehicles may maintain their routes closed networks.
#
# As we have done in `tutorial01_sumo.ipynb`, human-driven vehicles are defined in the `VehicleParams` class as follows:

# %%
# vehicles class
from flow.core.params import VehicleParams

# vehicles dynamics models
from flow.controllers import IDMController, ContinuousRouter

vehicles = VehicleParams()
vehicles.add("human",
             acceleration_controller=(IDMController, {}),
             routing_controller=(ContinuousRouter, {}),
             num_vehicles=21)

# %% [markdown]
# The above addition to the `Vehicles` class only accounts for 21 of the 22 vehicles that are placed in the network. We now add an additional trainable autuonomous vehicle whose actions are dictated by an RL agent. This is done by specifying an `RLController` as the acceleraton controller to the vehicle.

# %%
from flow.controllers import RLController

# %% [markdown]
# Note that this controller serves primarirly as a placeholder that marks the vehicle as a component of the RL agent, meaning that lane changing and routing actions can also be specified by the RL agent to this vehicle.
#
# We finally add the vehicle as follows, while again using the `ContinuousRouter` to perpetually maintain the vehicle within the network.

# %%
vehicles.add(veh_id="rl",
             acceleration_controller=(RLController, {}),
             routing_controller=(ContinuousRouter, {}),
             num_vehicles=1)

# %% [markdown]
# ## 3. Setting up an Environment
#
# Several environments in Flow exist to train RL agents of different forms (e.g. autonomous vehicles, traffic lights) to perform a variety of different tasks. The use of an environment allows us to view the cumulative reward simulation rollouts receive, along with to specify the state/action spaces.
#
# Sumo envrionments in Flow are parametrized by three components:
# * `SumoParams`
# * `EnvParams`
# * `Network`
#
# ### 3.1 SumoParams
# `SumoParams` specifies simulation-specific variables. These variables include the length of any simulation step and whether to render the GUI when running the experiment. For this example, we consider a simulation step length of 0.1s and deactivate the GUI.
#
# **Note** For training purposes, it is highly recommanded to deactivate the GUI in order to avoid global slow down. In such case, one just needs to specify the following: `render=False`

# %%
from flow.core.params import SumoParams

sim_params = SumoParams(sim_step=0.1, render=False)

# %% [markdown]
# ### 3.2 EnvParams
#
# `EnvParams` specifies environment and experiment-specific parameters that either affect the training process or the dynamics of various components within the network. For the environment `WaveAttenuationPOEnv`, these parameters are used to dictate bounds on the accelerations of the autonomous vehicles, as well as the range of ring lengths (and accordingly network densities) the agent is trained on.
#
# Finally, it is important to specify here the *horizon* of the experiment, which is the duration of one episode (during which the RL-agent acquire data).

# %%
from flow.core.params import EnvParams

# Define horizon as a variable to ensure consistent use across notebook
HORIZON=100

env_params = EnvParams(
    # length of one rollout
    horizon=HORIZON,

    additional_params={
        # maximum acceleration of autonomous vehicles
        "max_accel": 1,
        # maximum deceleration of autonomous vehicles
        "max_decel": 1,
        # bounds on the ranges of ring road lengths the autonomous vehicle 
        # is trained on
        "ring_length": [220, 270],
    },
)

# %% [markdown]
# ### 3.3 Initializing a Gym Environment
#
# Now, we have to specify our Gym Environment and the algorithm that our RL agents will use. Similar to the network, we choose to use on of Flow's builtin environments, a list of which is provided by the script below.

# %%
import flow.envs as flowenvs

print(flowenvs.__all__)
# Out:
# ['Env', 'AccelEnv', 'LaneChangeAccelEnv', 'LaneChangeAccelPOEnv', 'TrafficLightGridTestEnv', 'MergePOEnv', 'BottleneckEnv', 'BottleneckAccelEnv', 'WaveAttenuationEnv', 'WaveAttenuationPOEnv', 'TrafficLightGridEnv', 'TrafficLightGridPOEnv', 'BottleneckDesiredVelocityEnv', 'TestEnv', 'BayBridgeEnv', 'BottleNeckAccelEnv', 'DesiredVelocityEnv', 'PO_TrafficLightGridEnv', 'GreenWaveTestEnv']

# %% [markdown]
# We will use the environment "WaveAttenuationPOEnv", which is used to train autonomous vehicles to attenuate the formation and propagation of waves in a partially observable variable density ring road. To create the Gym Environment, the only necessary parameters are the environment name plus the previously defined variables. These are defined as follows:

# %%
from flow.envs import WaveAttenuationPOEnv

env_name = WaveAttenuationPOEnv

# %% [markdown]
# ### 3.4 Setting up Flow Parameters
#
# RLlib experiments both generate a `params.json` file for each experiment run. For RLlib experiments, the parameters defining the Flow network and environment must be stored as well. As such, in this section we define the dictionary `flow_params`, which contains the variables required by the utility function `make_create_env`. `make_create_env` is a higher-order function which returns a function `create_env` that initializes a Gym environment corresponding to the Flow network specified.

# %%
# Creating flow_params. Make sure the dictionary keys are as specified. 
flow_params = dict(
    # name of the experiment
    exp_tag=name,
    # name of the flow environment the experiment is running on
    env_name=env_name,
    # name of the network class the experiment uses
    network=network_name,
    # simulator that is used by the experiment
    simulator='traci',
    # simulation-related parameters
    sim=sim_params,
    # environment related parameters (see flow.core.params.EnvParams)
    env=env_params,
    # network-related parameters (see flow.core.params.NetParams and
    # the network's documentation or ADDITIONAL_NET_PARAMS component)
    net=net_params,
    # vehicles to be placed in the network at the start of a rollout 
    # (see flow.core.vehicles.Vehicles)
    veh=vehicles,
    # (optional) parameters affecting the positioning of vehicles upon 
    # initialization/reset (see flow.core.params.InitialConfig)
    initial=initial_config
)

# %% [markdown]
# ## 4 Running RL experiments in Ray
#
# ### 4.1 Import
#
# First, we must import modules required to run experiments in Ray. The `json` package is required to store the Flow experiment parameters in the `params.json` file, as is `FlowParamsEncoder`. Ray-related imports are required: the PPO algorithm agent, `ray.tune`'s experiment runner, and environment helper methods `register_env` and `make_create_env`.

# %%
import json

import ray
try:
    from ray.rllib.agents.agent import get_agent_class
except ImportError:
    from ray.rllib.agents.registry import get_agent_class
from ray.tune import run_experiments
from ray.tune.registry import register_env

from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder
# Out:
# WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# ### 4.2 Initializing Ray
# Here, we initialize Ray and experiment-based constant variables specifying parallelism in the experiment as well as experiment batch size in terms of number of rollouts.

# %%
# number of parallel workers
N_CPUS = 2
# number of rollouts per training iteration
N_ROLLOUTS = 1

ray.init(num_cpus=N_CPUS)
# Out:
# 2020-03-22 14:46:05,082	INFO node.py:498 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2020-03-22_14-46-05_082210_449311/logs.
# 2020-03-22 14:46:05,205	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:45391 to respond...
# 2020-03-22 14:46:05,357	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:42169 to respond...
# 2020-03-22 14:46:05,358	INFO services.py:809 -- Starting Redis shard with 10.0 GB max memory.
# 2020-03-22 14:46:05,400	INFO node.py:512 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2020-03-22_14-46-05_082210_449311/logs.
# 2020-03-22 14:46:05,402	WARNING services.py:1301 -- Warning: Capping object memory store to 20.0GB. To increase this further, specify `object_store_memory` when calling ray.init() or ray start.
# 2020-03-22 14:46:05,403	INFO services.py:1475 -- Starting the Plasma object store with 20.0 GB memory using /dev/shm.
# {'node_ip_address': '10.4.2.25',
#  'object_store_address': '/tmp/ray/session_2020-03-22_14-46-05_082210_449311/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2020-03-22_14-46-05_082210_449311/sockets/raylet',
#  'redis_address': '10.4.2.25:45391',
#  'session_dir': '/tmp/ray/session_2020-03-22_14-46-05_082210_449311',
#  'webui_url': None}

# %% [markdown]
# ### 4.3 Configuration and Setup
# Here, we copy and modify the default configuration for the [PPO algorithm](https://arxiv.org/abs/1707.06347). The agent has the number of parallel workers specified, a batch size corresponding to `N_ROLLOUTS` rollouts (each of which has length `HORIZON` steps), a discount rate $\gamma$ of 0.999, two hidden layers of size 16, uses Generalized Advantage Estimation, $\lambda$ of 0.97, and other parameters as set below.
#
# Once `config` contains the desired parameters, a JSON string corresponding to the `flow_params` specified in section 3 is generated. The `FlowParamsEncoder` maps objects to string representations so that the experiment can be reproduced later. That string representation is stored within the `env_config` section of the `config` dictionary. Later, `config` is written out to the file `params.json`.
#
# Next, we call `make_create_env` and pass in the `flow_params` to return a function we can use to register our Flow environment with Gym.

# %%
# The algorithm or model to train. This may refer to "
#      "the name of a built-on algorithm (e.g. RLLib's DQN "
#      "or PPO), or a user-defined trainable function or "
#      "class registered in the tune registry.")
alg_run = "PPO"

agent_cls = get_agent_class(alg_run)
config = agent_cls._default_config.copy()
config["num_workers"] = N_CPUS - 1  # number of parallel workers
config["train_batch_size"] = HORIZON * N_ROLLOUTS  # batch size
config["gamma"] = 0.999  # discount rate
config["model"].update({"fcnet_hiddens": [16, 16]})  # size of hidden layers in network
config["use_gae"] = True  # using generalized advantage estimation
config["lambda"] = 0.97  
config["sgd_minibatch_size"] = min(16 * 1024, config["train_batch_size"])  # stochastic gradient descent
config["kl_target"] = 0.02  # target KL divergence
config["num_sgd_iter"] = 10  # number of SGD iterations
config["horizon"] = HORIZON  # rollout horizon

# save the flow params for replay
flow_json = json.dumps(flow_params, cls=FlowParamsEncoder, sort_keys=True,
                       indent=4)  # generating a string version of flow_params
config['env_config']['flow_params'] = flow_json  # adding the flow_params to config dict
config['env_config']['run'] = alg_run

# Call the utility function make_create_env to be able to 
# register the Flow env for this experiment
create_env, gym_name = make_create_env(params=flow_params, version=0)

# Register as rllib env with Gym
register_env(gym_name, create_env)

# %% [markdown]
# ### 4.4 Running Experiments
#
# Here, we use the `run_experiments` function from `ray.tune`. The function takes a dictionary with one key, a name corresponding to the experiment, and one value, itself a dictionary containing parameters for training.

# %%
trials = run_experiments({
    flow_params["exp_tag"]: {
        "run": alg_run,
        "env": gym_name,
        "config": {
            **config
        },
        "checkpoint_freq": 1,  # number of iterations between checkpoints
        "checkpoint_at_end": True,  # generate a checkpoint at the end
        "max_failures": 999,
        "stop": {  # stopping conditions
            "training_iteration": 10,  # number of iterations to stop after
        },
    },
})
# Out:
# 2020-03-22 14:59:15,799	INFO trial_runner.py:176 -- Starting a new experiment.
# 2020-03-22 14:59:15,809	WARNING signature.py:108 -- The function with_updates has a **kwargs argument, which is currently not supported.
# 2020-03-22 14:59:15,834	WARNING logger.py:227 -- Could not instantiate <class 'ray.tune.logger.TFLogger'> - skipping.
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/2 CPUs, 0/0 GPUs
# Memory usage on this node: 10.3/201.2 GB
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 2/2 CPUs, 0/0 GPUs
# Memory usage on this node: 10.3/201.2 GB
# Result logdir: /users/PYS1027/chnrhughes/ray_results/training_example
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - PPO_WaveAttenuationPOEnv-v0_0:	RUNNING
#
# (pid=455536) 2020-03-22 14:59:17.791185: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=455536) 2020-03-22 14:59:17.791259: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=455536) 2020-03-22 14:59:17.791268: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# (pid=455536) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=455536) Instructions for updating:
# (pid=455536) non-resource variables are not supported in the long term
# (pid=455536) 2020-03-22 14:59:20,825	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# (pid=455536) 2020-03-22 14:59:21,979	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# (pid=455536) 2020-03-22 14:59:21.980114: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# (pid=455536) 2020-03-22 14:59:21.989967: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2400000000 Hz
# (pid=455536) 2020-03-22 14:59:21.990429: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2b94410 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# (pid=455536) 2020-03-22 14:59:21.990464: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# (pid=455536) 2020-03-22 14:59:21.992397: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=455536) 2020-03-22 14:59:21.992418: E tensorflow/stream_executor/cuda/cuda_driver.cc:351] failed call to cuInit: UNKNOWN ERROR (303)
# (pid=455536) 2020-03-22 14:59:21.992435: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p0078.ten.osc.edu): /proc/driver/nvidia/version does not exist
# (pid=455536) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=455536) Instructions for updating:
# (pid=455536) Use keras.layers.Dense instead.
# (pid=455536) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=455536) Instructions for updating:
# (pid=455536) Use keras.layers.Dense instead.
# (pid=455536) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=455536) Instructions for updating:
# (pid=455536) Please use `layer.__call__` method instead.
# (pid=455536) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=455536) Instructions for updating:
# (pid=455536) Please use `layer.__call__` method instead.
# (pid=455536) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=455536) Instructions for updating:
# (pid=455536) Use `tf.cast` instead.
# (pid=455536) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=455536) Instructions for updating:
# (pid=455536) Use `tf.cast` instead.
# (pid=455536) 2020-03-22 14:59:22,101	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=455536)
# (pid=455536) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=455536)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 1) dtype=float32>,
# (pid=455536)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=455536)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 2) dtype=float32>,
# (pid=455536)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=455536)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 3) dtype=float32>,
# (pid=455536)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 3) dtype=float32>,
# (pid=455536)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 1) dtype=float32>,
# (pid=455536)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=455536)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=455536)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=455536)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=455536)
# (pid=455536) 2020-03-22 14:59:22,631	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x2aaf73d5c3c8>}
# (pid=455536) 2020-03-22 14:59:22,631	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x2aaf73d5c128>}
# (pid=455536) 2020-03-22 14:59:22,632	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x2ab518655f98>}
# (pid=455536) 2020-03-22 14:59:22,658	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# (pid=455728) 2020-03-22 14:59:24.258189: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=455728) 2020-03-22 14:59:24.258273: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=455728) 2020-03-22 14:59:24.258283: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# (pid=455536) 2020-03-22 14:59:24,395	WARNING util.py:47 -- Install gputil for GPU system monitoring.
# (pid=455536) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/policy/tf_policy.py:570: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=455536) Instructions for updating:
# (pid=455536) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=455536) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/policy/tf_policy.py:570: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=455536) Instructions for updating:
# (pid=455536) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=455728) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=455728) Instructions for updating:
# (pid=455728) non-resource variables are not supported in the long term
# (pid=455728) 2020-03-22 14:59:28,022	INFO rollout_worker.py:319 -- Creating policy evaluation worker 1 on CPU (please ignore any CUDA init errors)
# (pid=455728) 2020-03-22 14:59:28.024220: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# (pid=455728) 2020-03-22 14:59:28.033009: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2400000000 Hz
# (pid=455728) 2020-03-22 14:59:28.033174: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3d07db0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# (pid=455728) 2020-03-22 14:59:28.033201: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# (pid=455728) 2020-03-22 14:59:28.035044: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=455728) 2020-03-22 14:59:28.035065: E tensorflow/stream_executor/cuda/cuda_driver.cc:351] failed call to cuInit: UNKNOWN ERROR (303)
# (pid=455728) 2020-03-22 14:59:28.035082: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p0078.ten.osc.edu): /proc/driver/nvidia/version does not exist
# (pid=455728) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=455728) Instructions for updating:
# (pid=455728) Use keras.layers.Dense instead.
# (pid=455728) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=455728) Instructions for updating:
# (pid=455728) Use keras.layers.Dense instead.
# (pid=455728) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=455728) Instructions for updating:
# (pid=455728) Please use `layer.__call__` method instead.
# (pid=455728) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=455728) Instructions for updating:
# (pid=455728) Please use `layer.__call__` method instead.
# (pid=455728) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=455728) Instructions for updating:
# (pid=455728) Use `tf.cast` instead.
# (pid=455728) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=455728) Instructions for updating:
# (pid=455728) Use `tf.cast` instead.
# (pid=455728) 2020-03-22 14:59:28,133	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=455728)
# (pid=455728) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=455728)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 1) dtype=float32>,
# (pid=455728)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=455728)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 2) dtype=float32>,
# (pid=455728)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=455728)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 3) dtype=float32>,
# (pid=455728)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 3) dtype=float32>,
# (pid=455728)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 1) dtype=float32>,
# (pid=455728)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=455728)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=455728)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=455728)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=455728)
# (pid=455728) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/policy/tf_policy.py:570: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=455728) Instructions for updating:
# (pid=455728) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=455728) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/policy/tf_policy.py:570: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=455728) Instructions for updating:
# (pid=455728) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=455728)
# (pid=455728) -----------------------
# (pid=455728) ring length: 255
# (pid=455728) v_max: 4.902299776966978
# (pid=455728) -----------------------
# (pid=455728) 2020-03-22 14:59:28,710	INFO rollout_worker.py:451 -- Generating sample batch of size 200
# (pid=455728) 2020-03-22 14:59:29,861	INFO sampler.py:304 -- Raw obs from env: { 0: { 'agent0': np.ndarray((3,), dtype=float64, min=0.0, max=0.048, mean=0.016)}}
# (pid=455728) 2020-03-22 14:59:29,861	INFO sampler.py:305 -- Info return from env: {0: {'agent0': None}}
# (pid=455728) 2020-03-22 14:59:29,862	INFO sampler.py:403 -- Preprocessed obs: np.ndarray((3,), dtype=float64, min=0.0, max=0.048, mean=0.016)
# (pid=455728) 2020-03-22 14:59:29,862	INFO sampler.py:407 -- Filtered obs: np.ndarray((3,), dtype=float64, min=0.0, max=0.048, mean=0.016)
# (pid=455728) 2020-03-22 14:59:29,862	INFO sampler.py:521 -- Inputs to compute_actions():
# (pid=455728)
# (pid=455728) { 'default_policy': [ { 'data': { 'agent_id': 'agent0',
# (pid=455728)                                   'env_id': 0,
# (pid=455728)                                   'info': None,
# (pid=455728)                                   'obs': np.ndarray((3,), dtype=float64, min=0.0, max=0.048, mean=0.016),
# (pid=455728)                                   'prev_action': np.ndarray((1,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=455728)                                   'prev_reward': 0.0,
# (pid=455728)                                   'rnn_state': []},
# (pid=455728)                         'type': 'PolicyEvalData'}]}
# (pid=455728)
# (pid=455728) 2020-03-22 14:59:29,863	INFO tf_run_builder.py:92 -- Executing TF run without tracing. To dump TF timeline traces to disk, set the TF_TIMELINE_DIR environment variable.
# (pid=455728) 2020-03-22 14:59:29,894	INFO sampler.py:548 -- Outputs of compute_actions():
# (pid=455728)
# (pid=455728) { 'default_policy': ( np.ndarray((1, 1), dtype=float32, min=-0.075, max=-0.075, mean=-0.075),
# (pid=455728)                       [],
# (pid=455728)                       { 'action_prob': np.ndarray((1,), dtype=float32, min=0.398, max=0.398, mean=0.398),
# (pid=455728)                         'behaviour_logits': np.ndarray((1, 2), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=455728)                         'vf_preds': np.ndarray((1,), dtype=float32, min=-0.0, max=-0.0, mean=-0.0)})}
# (pid=455728)
# (pid=455728)
# (pid=455728) -----------------------
# (pid=455728) ring length: 259
# (pid=455728) v_max: 5.092292348291853
# (pid=455728) -----------------------
# (pid=455728) 2020-03-22 14:59:30,264	INFO sample_batch_builder.py:161 -- Trajectory fragment after postprocess_trajectory():
# (pid=455728)
# (pid=455728) { 'agent0': { 'data': { 'action_prob': np.ndarray((100,), dtype=float32, min=0.02, max=0.399, mean=0.277),
# (pid=455728)                         'actions': np.ndarray((100, 1), dtype=float32, min=-2.456, max=1.892, mean=-0.069),
# (pid=455728)                         'advantages': np.ndarray((100,), dtype=float32, min=-73.473, max=-1.186, mean=-44.161),
# (pid=455728)                         'agent_index': np.ndarray((100,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=455728)                         'behaviour_logits': np.ndarray((100, 2), dtype=float32, min=-0.0, max=0.001, mean=0.0),
# (pid=455728)                         'dones': np.ndarray((100,), dtype=bool, min=0.0, max=1.0, mean=0.01),
# (pid=455728)                         'eps_id': np.ndarray((100,), dtype=int64, min=469706670.0, max=469706670.0, mean=469706670.0),
# (pid=455728)                         'infos': np.ndarray((100,), dtype=object, head={}),
# (pid=455728)                         'new_obs': np.ndarray((100, 3), dtype=float32, min=0.0, max=0.23, mean=0.085),
# (pid=455728)                         'obs': np.ndarray((100, 3), dtype=float32, min=0.0, max=0.23, mean=0.084),
# (pid=455728)                         'prev_actions': np.ndarray((100, 1), dtype=float32, min=-2.456, max=1.892, mean=-0.065),
# (pid=455728)                         'prev_rewards': np.ndarray((100,), dtype=float32, min=-3.947, max=0.604, mean=-2.029),
# (pid=455728)                         'rewards': np.ndarray((100,), dtype=float32, min=-3.947, max=0.604, mean=-2.041),
# (pid=455728)                         't': np.ndarray((100,), dtype=int64, min=0.0, max=99.0, mean=49.5),
# (pid=455728)                         'unroll_id': np.ndarray((100,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=455728)                         'value_targets': np.ndarray((100,), dtype=float32, min=-73.473, max=-1.188, mean=-44.162),
# (pid=455728)                         'vf_preds': np.ndarray((100,), dtype=float32, min=-0.003, max=-0.0, mean=-0.002)},
# (pid=455728)               'type': 'SampleBatch'}}
# (pid=455728)
# (pid=455728)
# (pid=455728) -----------------------
# (pid=455728) ring length: 232
# (pid=455728) v_max: 3.8087690783250063
# (pid=455728) -----------------------
# (pid=455536) 2020-03-22 14:59:32,926	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/default_model/fc1/kernel:0' shape=(3, 16) dtype=float32_ref>
# (pid=455536) 2020-03-22 14:59:32,927	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/default_model/fc1/bias:0' shape=(16,) dtype=float32_ref>
# (pid=455536) 2020-03-22 14:59:32,927	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/default_model/fc2/kernel:0' shape=(16, 16) dtype=float32_ref>
# (pid=455536) 2020-03-22 14:59:32,927	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/default_model/fc2/bias:0' shape=(16,) dtype=float32_ref>
# (pid=455536) 2020-03-22 14:59:32,927	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/default_model/fc_out/kernel:0' shape=(16, 2) dtype=float32_ref>
# (pid=455536) 2020-03-22 14:59:32,927	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/default_model/fc_out/bias:0' shape=(2,) dtype=float32_ref>
# (pid=455536) 2020-03-22 14:59:32,927	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/value_function/fc1/kernel:0' shape=(3, 16) dtype=float32_ref>
# (pid=455536) 2020-03-22 14:59:32,927	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/value_function/fc1/bias:0' shape=(16,) dtype=float32_ref>
# (pid=455536) 2020-03-22 14:59:32,927	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/value_function/fc2/kernel:0' shape=(16, 16) dtype=float32_ref>
# (pid=455536) 2020-03-22 14:59:32,927	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/value_function/fc2/bias:0' shape=(16,) dtype=float32_ref>
# (pid=455536) 2020-03-22 14:59:32,927	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/value_function/fc_out/kernel:0' shape=(16, 1) dtype=float32_ref>
# (pid=455536) 2020-03-22 14:59:32,927	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/value_function/fc_out/bias:0' shape=(1,) dtype=float32_ref>
# (pid=455536) 2020-03-22 14:59:32,928	INFO multi_gpu_impl.py:146 -- Training on concatenated sample batches:
# (pid=455536)
# (pid=455536) { 'inputs': [ np.ndarray((200, 1), dtype=float32, min=-3.318, max=2.02, mean=-0.028),
# (pid=455536)               np.ndarray((200,), dtype=float32, min=-3.964, max=0.604, mean=-1.981),
# (pid=455536)               np.ndarray((200, 3), dtype=float32, min=0.0, max=0.259, mean=0.088),
# (pid=455536)               np.ndarray((200, 1), dtype=float32, min=-3.318, max=2.02, mean=-0.029),
# (pid=455536)               np.ndarray((200,), dtype=float32, min=-1.713, max=2.534, mean=-0.0),
# (pid=455536)               np.ndarray((200, 2), dtype=float32, min=-0.0, max=0.001, mean=0.0),
# (pid=455536)               np.ndarray((200,), dtype=float32, min=-73.473, max=-0.284, mean=-43.948),
# (pid=455536)               np.ndarray((200,), dtype=float32, min=-0.003, max=-0.0, mean=-0.002)],
# (pid=455536)   'placeholders': [ <tf.Tensor 'default_policy/action:0' shape=(?, 1) dtype=float32>,
# (pid=455536)                     <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=455536)                     <tf.Tensor 'default_policy/observation:0' shape=(?, 3) dtype=float32>,
# (pid=455536)                     <tf.Tensor 'default_policy/actions:0' shape=(?, 1) dtype=float32>,
# (pid=455536)                     <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=455536)                     <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 2) dtype=float32>,
# (pid=455536)                     <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=455536)                     <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>],
# (pid=455536)   'state_inputs': []}
# (pid=455536)
# (pid=455536) 2020-03-22 14:59:32,929	INFO multi_gpu_impl.py:191 -- Divided 200 rollout sequences, each of length 1, among 1 devices.
# (pid=455728) 2020-03-22 14:59:32,924	INFO rollout_worker.py:485 -- Completed sample batch:
# (pid=455728)
# (pid=455728) { 'data': { 'action_prob': np.ndarray((200,), dtype=float32, min=0.002, max=0.399, mean=0.285),
# (pid=455728)             'actions': np.ndarray((200, 1), dtype=float32, min=-3.318, max=2.02, mean=-0.029),
# (pid=455728)             'advantages': np.ndarray((200,), dtype=float32, min=-73.473, max=-0.281, mean=-43.946),
# (pid=455728)             'agent_index': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=455728)             'behaviour_logits': np.ndarray((200, 2), dtype=float32, min=-0.0, max=0.001, mean=0.0),
# (pid=455728)             'dones': np.ndarray((200,), dtype=bool, min=0.0, max=1.0, mean=0.01),
# (pid=455728)             'eps_id': np.ndarray((200,), dtype=int64, min=150930694.0, max=469706670.0, mean=310318682.0),
# (pid=455728)             'infos': np.ndarray((200,), dtype=object, head={}),
# (pid=455728)             'new_obs': np.ndarray((200, 3), dtype=float32, min=0.0, max=0.259, mean=0.089),
# (pid=455728)             'obs': np.ndarray((200, 3), dtype=float32, min=0.0, max=0.259, mean=0.088),
# (pid=455728)             'prev_actions': np.ndarray((200, 1), dtype=float32, min=-3.318, max=2.02, mean=-0.028),
# (pid=455728)             'prev_rewards': np.ndarray((200,), dtype=float32, min=-3.964, max=0.604, mean=-1.981),
# (pid=455728)             'rewards': np.ndarray((200,), dtype=float32, min=-3.964, max=0.604, mean=-1.989),
# (pid=455728)             't': np.ndarray((200,), dtype=int64, min=0.0, max=99.0, mean=49.5),
# (pid=455728)             'unroll_id': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=455728)             'value_targets': np.ndarray((200,), dtype=float32, min=-73.473, max=-0.284, mean=-43.948),
# (pid=455728)             'vf_preds': np.ndarray((200,), dtype=float32, min=-0.003, max=-0.0, mean=-0.002)},
# (pid=455728)   'type': 'SampleBatch'}
# (pid=455728)
# Result for PPO_WaveAttenuationPOEnv-v0_0:
#   custom_metrics: {}
#   date: 2020-03-22_14-59-33
#   done: false
#   episode_len_mean: 100.0
#   episode_reward_max: -193.59221580682464
#   episode_reward_mean: -198.86328224758324
#   episode_reward_min: -204.13434868834182
#   episodes_this_iter: 2
#   episodes_total: 2
#   experiment_id: 72c8564d6e124054a5640296b125d1ca
#   hostname: p0078.ten.osc.edu
#   info:
#     grad_time_ms: 349.69
#     learner:
#       default_policy:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 4.999999873689376e-05
#         entropy: 1.4180394411087036
#         entropy_coeff: 0.0
#         kl: 4.824995812668931e-06
#         policy_loss: -0.00023160502314567566
#         total_loss: 2228.04248046875
#         vf_explained_var: -0.00011980533599853516
#         vf_loss: 2228.04248046875
#     load_time_ms: 56.32
#     num_steps_sampled: 200
#     num_steps_trained: 200
#     sample_time_ms: 8059.293
#     update_time_ms: 434.001
#   iterations_since_restore: 1
#   node_ip: 10.4.2.25
#   num_healthy_workers: 1
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 2.984615384615385
#     ram_util_percent: 5.392307692307693
#   pid: 455536
#   policy_reward_mean: {}
#   sampler_perf:
#     mean_env_wait_ms: 8.773790663154564
#     mean_inference_ms: 0.6507546154420767
#     mean_processing_ms: 11.523563470413436
#   time_since_restore: 8.972515344619751
#   time_this_iter_s: 8.972515344619751
#   time_total_s: 8.972515344619751
#   timestamp: 1584903573
#   timesteps_since_restore: 200
#   timesteps_this_iter: 200
#   timesteps_total: 200
#   training_iteration: 1
#   trial_id: 39f96f22
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 2/2 CPUs, 0/0 GPUs
# Memory usage on this node: 10.9/201.2 GB
# Result logdir: /users/PYS1027/chnrhughes/ray_results/training_example
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - PPO_WaveAttenuationPOEnv-v0_0:	RUNNING, [2 CPUs, 0 GPUs], [pid=455536], 8 s, 1 iter, 200 ts, -199 rew
#
# (pid=455728)
# (pid=455728) -----------------------
# (pid=455728) ring length: 254
# (pid=455728) v_max: 4.854791141191876
# (pid=455728) -----------------------
# (pid=455728)
# (pid=455728) -----------------------
# (pid=455728) ring length: 226
# (pid=455728) v_max: 3.5232840694769565
# (pid=455728) -----------------------
# (pid=455728)
# (pid=455728) -----------------------
# (pid=455728) ring length: 260
# (pid=455728) v_max: 5.139779427502188
# (pid=455728) -----------------------
# (pid=455728)
# (pid=455728) -----------------------
# (pid=455728) ring length: 268
# (pid=455728) v_max: 5.5194978538368025
# (pid=455728) -----------------------
# Result for PPO_WaveAttenuationPOEnv-v0_0:
#   custom_metrics: {}
#   date: 2020-03-22_14-59-39
#   done: false
#   episode_len_mean: 100.0
#   episode_reward_max: -179.7186358535194
#   episode_reward_mean: -191.59585384818715
#   episode_reward_min: -204.13434868834182
#   episodes_this_iter: 2
#   episodes_total: 6
#   experiment_id: 72c8564d6e124054a5640296b125d1ca
#   hostname: p0078.ten.osc.edu
#   info:
#     grad_time_ms: 136.847
#     learner:
#       default_policy:
#         cur_kl_coeff: 0.05000000074505806
#         cur_lr: 4.999999873689376e-05
#         entropy: 1.4176819324493408
#         entropy_coeff: 0.0
#         kl: 4.091858727406361e-07
#         policy_loss: -2.4393200874328613e-05
#         total_loss: 1896.863525390625
#         vf_explained_var: -0.0001589059829711914
#         vf_loss: 1896.863525390625
#     load_time_ms: 19.527
#     num_steps_sampled: 600
#     num_steps_trained: 600
#     sample_time_ms: 4719.983
#     update_time_ms: 145.819
#   iterations_since_restore: 3
#   node_ip: 10.4.2.25
#   num_healthy_workers: 1
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 1.8
#     ram_util_percent: 5.4
#   pid: 455536
#   policy_reward_mean: {}
#   sampler_perf:
#     mean_env_wait_ms: 6.5748320303048
#     mean_inference_ms: 0.6087438892541862
#     mean_processing_ms: 11.538306706231594
#   time_since_restore: 15.146613121032715
#   time_this_iter_s: 3.0910356044769287
#   time_total_s: 15.146613121032715
#   timestamp: 1584903579
#   timesteps_since_restore: 600
#   timesteps_this_iter: 200
#   timesteps_total: 600
#   training_iteration: 3
#   trial_id: 39f96f22
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 2/2 CPUs, 0/0 GPUs
# Memory usage on this node: 10.9/201.2 GB
# Result logdir: /users/PYS1027/chnrhughes/ray_results/training_example
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - PPO_WaveAttenuationPOEnv-v0_0:	RUNNING, [2 CPUs, 0 GPUs], [pid=455536], 15 s, 3 iter, 600 ts, -192 rew
#
# (pid=455728)
# (pid=455728) -----------------------
# (pid=455728) ring length: 252
# (pid=455728) v_max: 4.759762049824181
# (pid=455728) -----------------------
# (pid=455728)
# (pid=455728) -----------------------
# (pid=455728) ring length: 225
# (pid=455728) v_max: 3.4756971311168834
# (pid=455728) -----------------------
# 2020-03-22 14:59:42,704	ERROR trial_runner.py:550 -- Error processing event.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/ray/tune/trial_runner.py", line 498, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/usr/local/lib/python3.5/dist-packages/ray/tune/ray_trial_executor.py", line 342, in fetch_result
#     result = ray.get(trial_future[0])
#   File "/usr/local/lib/python3.5/dist-packages/ray/worker.py", line 2247, in get
#     raise value
# ray.exceptions.RayTaskError: ray_PPO:train() (pid=455536, host=p0078.ten.osc.edu)
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/agents/trainer.py", line 369, in train
#     raise e
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/agents/trainer.py", line 358, in train
#     result = Trainable.train(self)
#   File "/usr/local/lib/python3.5/dist-packages/ray/tune/trainable.py", line 171, in train
#     result = self._train()
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/agents/trainer_template.py", line 126, in _train
#     fetches = self.optimizer.step()
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/optimizers/multi_gpu_optimizer.py", line 140, in step
#     self.num_envs_per_worker, self.train_batch_size)
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/optimizers/rollout.py", line 29, in collect_samples
#     next_sample = ray_get_and_free(fut_sample)
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/utils/memory.py", line 33, in ray_get_and_free
#     result = ray.get(object_ids)
# ray.exceptions.RayTaskError: ray_RolloutWorker:sample() (pid=455728, host=p0078.ten.osc.edu)
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/evaluation/rollout_worker.py", line 453, in sample
#     batches = [self.input_reader.next()]
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/evaluation/sampler.py", line 56, in next
#     batches = [self.get_data()]
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/evaluation/sampler.py", line 97, in get_data
#     item = next(self.rollout_provider)
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/evaluation/sampler.py", line 313, in _env_runner
#     soft_horizon)
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/evaluation/sampler.py", line 473, in _process_observations
#     resetted_obs = base_env.try_reset(env_id)
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/env/base_env.py", line 336, in try_reset
#     return {_DUMMY_AGENT_ID: self.vector_env.reset_at(env_id)}
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/env/vector_env.py", line 104, in reset_at
#     return self.envs[index].reset()
#   File "/users/PYS1027/chnrhughes/work/flowtest/flow/flow/envs/ring/wave_attenuation.py", line 210, in reset
#     observation = super().reset()
#   File "/users/PYS1027/chnrhughes/work/flowtest/flow/flow/envs/base.py", line 528, in reset
#     raise FatalFlowError(msg=msg)
# flow.utils.exceptions.FatalFlowError:
# Not enough vehicles have spawned! Bad start?
# Missing vehicles / initial state:
# - rl_0: ('rl', 'left', 0, 44.914105410475486, 0)
#
#
#
# 2020-03-22 14:59:42,711	INFO trial_runner.py:587 -- Attempting to recover trial state from last checkpoint.
# 2020-03-22 14:59:42,714	WARNING signature.py:108 -- The function with_updates has a **kwargs argument, which is currently not supported.
# (pid=455536) 2020-03-22 14:59:42,698	INFO trainer.py:366 -- Worker crashed during call to train(). To attempt to continue training without the failed worker, set `'ignore_worker_failures': True`.
# (pid=456160) 2020-03-22 14:59:44.501240: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=456160) 2020-03-22 14:59:44.501312: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=456160) 2020-03-22 14:59:44.501322: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# (pid=456160) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=456160) Instructions for updating:
# (pid=456160) non-resource variables are not supported in the long term
# (pid=456160) 2020-03-22 14:59:47,214	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# (pid=456160) 2020-03-22 14:59:48,346	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# (pid=456160) 2020-03-22 14:59:48.347292: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# (pid=456160) 2020-03-22 14:59:48.354523: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2400000000 Hz
# (pid=456160) 2020-03-22 14:59:48.354909: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x394a1d0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# (pid=456160) 2020-03-22 14:59:48.354946: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# (pid=456160) 2020-03-22 14:59:48.356536: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=456160) 2020-03-22 14:59:48.356556: E tensorflow/stream_executor/cuda/cuda_driver.cc:351] failed call to cuInit: UNKNOWN ERROR (303)
# (pid=456160) 2020-03-22 14:59:48.356571: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p0078.ten.osc.edu): /proc/driver/nvidia/version does not exist
# (pid=456160) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=456160) Instructions for updating:
# (pid=456160) Use keras.layers.Dense instead.
# (pid=456160) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=456160) Instructions for updating:
# (pid=456160) Use keras.layers.Dense instead.
# (pid=456160) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=456160) Instructions for updating:
# (pid=456160) Please use `layer.__call__` method instead.
# (pid=456160) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=456160) Instructions for updating:
# (pid=456160) Please use `layer.__call__` method instead.
# (pid=456160) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=456160) Instructions for updating:
# (pid=456160) Use `tf.cast` instead.
# (pid=456160) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=456160) Instructions for updating:
# (pid=456160) Use `tf.cast` instead.
# (pid=456160) 2020-03-22 14:59:48,452	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=456160)
# (pid=456160) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=456160)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 1) dtype=float32>,
# (pid=456160)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=456160)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 2) dtype=float32>,
# (pid=456160)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=456160)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 3) dtype=float32>,
# (pid=456160)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 3) dtype=float32>,
# (pid=456160)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 1) dtype=float32>,
# (pid=456160)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=456160)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=456160)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=456160)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=456160)
# (pid=456160) 2020-03-22 14:59:49,002	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x2b8b30d6d3c8>}
# (pid=456160) 2020-03-22 14:59:49,003	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x2b8b30d6d128>}
# (pid=456160) 2020-03-22 14:59:49,003	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x2b90d1669f98>}
# (pid=456160) 2020-03-22 14:59:49,033	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# 2020-03-22 14:59:50,704	WARNING util.py:145 -- The `get_current_ip` operation took 7.97641134262085 seconds to complete, which may be a performance bottleneck.
# 2020-03-22 14:59:50,761	WARNING util.py:145 -- The `process_trial` operation took 8.057918548583984 seconds to complete, which may be a performance bottleneck.
# (pid=456160) 2020-03-22 14:59:50,700	WARNING util.py:47 -- Install gputil for GPU system monitoring.
# (pid=456160) 2020-03-22 14:59:50,702	WARNING trainable.py:126 -- Getting current IP.
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 2/2 CPUs, 0/0 GPUs
# Memory usage on this node: 10.7/201.2 GB
# Result logdir: /users/PYS1027/chnrhughes/ray_results/training_example
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - PPO_WaveAttenuationPOEnv-v0_0:	RUNNING, 1 failures: /users/PYS1027/chnrhughes/ray_results/training_example/PPO_WaveAttenuationPOEnv-v0_0_2020-03-22_14-59-15tb_5w9r1/error_2020-03-22_14-59-42.txt, [2 CPUs, 0 GPUs], [pid=455536], 15 s, 3 iter, 600 ts, -192 rew
#
# (pid=456160) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/policy/tf_policy.py:570: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=456160) Instructions for updating:
# (pid=456160) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=456160) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/policy/tf_policy.py:570: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=456160) Instructions for updating:
# (pid=456160) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=456425) 2020-03-22 14:59:50.785922: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=456425) 2020-03-22 14:59:50.785991: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=456425) 2020-03-22 14:59:50.786001: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# (pid=456425) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=456425) Instructions for updating:
# (pid=456425) non-resource variables are not supported in the long term
# (pid=456425) 2020-03-22 14:59:54,378	INFO rollout_worker.py:319 -- Creating policy evaluation worker 1 on CPU (please ignore any CUDA init errors)
# (pid=456425) 2020-03-22 14:59:54.379586: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# (pid=456425) 2020-03-22 14:59:54.388260: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2400000000 Hz
# (pid=456425) 2020-03-22 14:59:54.388421: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3b9f690 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# (pid=456425) 2020-03-22 14:59:54.388447: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# (pid=456425) 2020-03-22 14:59:54.390310: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=456425) 2020-03-22 14:59:54.390330: E tensorflow/stream_executor/cuda/cuda_driver.cc:351] failed call to cuInit: UNKNOWN ERROR (303)
# (pid=456425) 2020-03-22 14:59:54.390345: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p0078.ten.osc.edu): /proc/driver/nvidia/version does not exist
# (pid=456425) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=456425) Instructions for updating:
# (pid=456425) Use keras.layers.Dense instead.
# (pid=456425) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=456425) Instructions for updating:
# (pid=456425) Use keras.layers.Dense instead.
# (pid=456425) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=456425) Instructions for updating:
# (pid=456425) Please use `layer.__call__` method instead.
# (pid=456425) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=456425) Instructions for updating:
# (pid=456425) Please use `layer.__call__` method instead.
# (pid=456425) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=456425) Instructions for updating:
# (pid=456425) Use `tf.cast` instead.
# (pid=456425) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=456425) Instructions for updating:
# (pid=456425) Use `tf.cast` instead.
# (pid=456425) 2020-03-22 14:59:54,488	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=456425)
# (pid=456425) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=456425)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 1) dtype=float32>,
# (pid=456425)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=456425)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 2) dtype=float32>,
# (pid=456425)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=456425)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 3) dtype=float32>,
# (pid=456425)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 3) dtype=float32>,
# (pid=456425)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 1) dtype=float32>,
# (pid=456425)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=456425)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=456425)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=456425)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=456425)
# ...
# (pid=456686) 2020-03-22 15:00:15,170	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/default_model/fc_out/kernel:0' shape=(16, 2) dtype=float32_ref>
# (pid=456686) 2020-03-22 15:00:15,170	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/default_model/fc_out/bias:0' shape=(2,) dtype=float32_ref>
# (pid=456686) 2020-03-22 15:00:15,170	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/value_function/fc1/kernel:0' shape=(3, 16) dtype=float32_ref>
# (pid=456686) 2020-03-22 15:00:15,170	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/value_function/fc1/bias:0' shape=(16,) dtype=float32_ref>
# (pid=456686) 2020-03-22 15:00:15,170	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/value_function/fc2/kernel:0' shape=(16, 16) dtype=float32_ref>
# (pid=456686) 2020-03-22 15:00:15,170	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/value_function/fc2/bias:0' shape=(16,) dtype=float32_ref>
# (pid=456686) 2020-03-22 15:00:15,170	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/value_function/fc_out/kernel:0' shape=(16, 1) dtype=float32_ref>
# (pid=456686) 2020-03-22 15:00:15,170	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/value_function/fc_out/bias:0' shape=(1,) dtype=float32_ref>
# (pid=456964) 2020-03-22 15:00:15,166	INFO rollout_worker.py:485 -- Completed sample batch:
# (pid=456964)
# (pid=456964) { 'data': { 'action_prob': np.ndarray((200,), dtype=float32, min=0.009, max=0.401, mean=0.274),
# (pid=456964)             'actions': np.ndarray((200, 1), dtype=float32, min=-2.719, max=2.745, mean=-0.087),
# (pid=456964)             'advantages': np.ndarray((200,), dtype=float32, min=-81.61, max=0.454, mean=-47.506),
# (pid=456964)             'agent_index': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=456964)             'behaviour_logits': np.ndarray((200, 2), dtype=float32, min=-0.004, max=0.007, mean=0.001),
# (pid=456964)             'dones': np.ndarray((200,), dtype=bool, min=0.0, max=1.0, mean=0.01),
# (pid=456964)             'eps_id': np.ndarray((200,), dtype=int64, min=1744077210.0, max=1994017011.0, mean=1869047110.5),
# (pid=456964)             'infos': np.ndarray((200,), dtype=object, head={}),
# (pid=456964)             'new_obs': np.ndarray((200, 3), dtype=float32, min=0.0, max=0.252, mean=0.083),
# (pid=456964)             'obs': np.ndarray((200, 3), dtype=float32, min=0.0, max=0.252, mean=0.082),
# (pid=456964)             'prev_actions': np.ndarray((200, 1), dtype=float32, min=-2.719, max=2.745, mean=-0.086),
# (pid=456964)             'prev_rewards': np.ndarray((200,), dtype=float32, min=-3.983, max=0.523, mean=-2.182),
# (pid=456964)             'rewards': np.ndarray((200,), dtype=float32, min=-3.983, max=0.523, mean=-2.185),
# (pid=456964)             't': np.ndarray((200,), dtype=int64, min=0.0, max=99.0, mean=49.5),
# (pid=456964)             'unroll_id': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=456964)             'value_targets': np.ndarray((200,), dtype=float32, min=-81.614, max=0.443, mean=-47.515),
# (pid=456964)             'vf_preds': np.ndarray((200,), dtype=float32, min=-0.012, max=-0.004, mean=-0.009)},
# (pid=456964)   'type': 'SampleBatch'}
# (pid=456964)
# (pid=456686) 2020-03-22 15:00:15,171	INFO multi_gpu_impl.py:146 -- Training on concatenated sample batches:
# (pid=456686)
# (pid=456686) { 'inputs': [ np.ndarray((200, 1), dtype=float32, min=-2.719, max=2.745, mean=-0.086),
# (pid=456686)               np.ndarray((200,), dtype=float32, min=-3.983, max=0.523, mean=-2.182),
# (pid=456686)               np.ndarray((200, 3), dtype=float32, min=0.0, max=0.252, mean=0.082),
# (pid=456686)               np.ndarray((200, 1), dtype=float32, min=-2.719, max=2.745, mean=-0.087),
# (pid=456686)               np.ndarray((200,), dtype=float32, min=-1.662, max=2.337, mean=0.0),
# (pid=456686)               np.ndarray((200, 2), dtype=float32, min=-0.004, max=0.007, mean=0.001),
# (pid=456686)               np.ndarray((200,), dtype=float32, min=-81.614, max=0.443, mean=-47.515),
# (pid=456686)               np.ndarray((200,), dtype=float32, min=-0.012, max=-0.004, mean=-0.009)],
# (pid=456686)   'placeholders': [ <tf.Tensor 'default_policy/action:0' shape=(?, 1) dtype=float32>,
# (pid=456686)                     <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=456686)                     <tf.Tensor 'default_policy/observation:0' shape=(?, 3) dtype=float32>,
# (pid=456686)                     <tf.Tensor 'default_policy/actions:0' shape=(?, 1) dtype=float32>,
# (pid=456686)                     <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=456686)                     <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 2) dtype=float32>,
# (pid=456686)                     <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=456686)                     <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>],
# (pid=456686)   'state_inputs': []}
# (pid=456686)
# (pid=456686) 2020-03-22 15:00:15,171	INFO multi_gpu_impl.py:191 -- Divided 200 rollout sequences, each of length 1, among 1 devices.
# Result for PPO_WaveAttenuationPOEnv-v0_0:
#   custom_metrics: {}
#   date: 2020-03-22_15-00-15
#   done: false
#   episode_len_mean: 100.0
#   episode_reward_max: -211.76223869583583
#   episode_reward_mean: -218.47828088606076
#   episode_reward_min: -225.19432307628566
#   episodes_this_iter: 2
#   episodes_total: 8
#   experiment_id: 72c8564d6e124054a5640296b125d1ca
#   hostname: p0078.ten.osc.edu
#   info:
#     grad_time_ms: 326.705
#     learner:
#       default_policy:
#         cur_kl_coeff: 0.02500000037252903
#         cur_lr: 4.999999873689376e-05
#         entropy: 1.4163920879364014
#         entropy_coeff: 0.0
#         kl: 6.941557330719661e-06
#         policy_loss: -0.0007098913192749023
#         total_loss: 2677.89111328125
#         vf_explained_var: -0.00024753808975219727
#         vf_loss: 2677.89208984375
#     load_time_ms: 47.1
#     num_steps_sampled: 800
#     num_steps_trained: 800
#     sample_time_ms: 7883.462
#     update_time_ms: 400.911
#   iterations_since_restore: 1
#   node_ip: 10.4.2.25
#   num_healthy_workers: 1
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 3.223076923076923
#     ram_util_percent: 5.392307692307693
#   pid: 456686
#   policy_reward_mean: {}
#   sampler_perf:
#     mean_env_wait_ms: 9.029969647156065
#     mean_inference_ms: 0.6786792432490866
#     mean_processing_ms: 11.516996877110419
#   time_since_restore: 8.697113275527954
#   time_this_iter_s: 8.697113275527954
#   time_total_s: 23.84372639656067
#   timestamp: 1584903615
#   timesteps_since_restore: 200
#   timesteps_this_iter: 200
#   timesteps_total: 800
#   training_iteration: 4
#   trial_id: 39f96f22
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 2/2 CPUs, 0/0 GPUs
# Memory usage on this node: 10.9/201.2 GB
# Result logdir: /users/PYS1027/chnrhughes/ray_results/training_example
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - PPO_WaveAttenuationPOEnv-v0_0:	RUNNING, 2 failures: /users/PYS1027/chnrhughes/ray_results/training_example/PPO_WaveAttenuationPOEnv-v0_0_2020-03-22_14-59-15tb_5w9r1/error_2020-03-22_14-59-59.txt, [2 CPUs, 0 GPUs], [pid=456686], 23 s, 4 iter, 800 ts, -218 rew
#
# (pid=456964)
# (pid=456964) -----------------------
# (pid=456964) ring length: 247
# (pid=456964) v_max: 4.522125250095652
# (pid=456964) -----------------------
# (pid=456964)
# (pid=456964) -----------------------
# (pid=456964) ring length: 233
# (pid=456964) v_max: 3.856343201216534
# (pid=456964) -----------------------
# (pid=456964)
# (pid=456964) -----------------------
# (pid=456964) ring length: 242
# (pid=456964) v_max: 4.2844067680020546
# (pid=456964) -----------------------
# (pid=456964)
# (pid=456964) -----------------------
# (pid=456964) ring length: 229
# (pid=456964) v_max: 3.666034803266416
# (pid=456964) -----------------------
# Result for PPO_WaveAttenuationPOEnv-v0_0:
#   custom_metrics: {}
#   date: 2020-03-22_15-00-21
#   done: false
#   episode_len_mean: 100.0
#   episode_reward_max: -211.76223869583583
#   episode_reward_mean: -216.08618761968657
#   episode_reward_min: -225.19432307628566
#   episodes_this_iter: 2
#   episodes_total: 12
#   experiment_id: 72c8564d6e124054a5640296b125d1ca
#   hostname: p0078.ten.osc.edu
#   info:
#     grad_time_ms: 126.685
#     learner:
#       default_policy:
#         cur_kl_coeff: 0.05000000074505806
#         cur_lr: 4.999999873689376e-05
#         entropy: 1.415597677230835
#         entropy_coeff: 0.0
#         kl: 1.9961594261985738e-06
#         policy_loss: -0.00030867941677570343
#         total_loss: 2585.96435546875
#         vf_explained_var: -0.00031960010528564453
#         vf_loss: 2585.96484375
#     load_time_ms: 16.366
#     num_steps_sampled: 1200
#     num_steps_trained: 1200
#     sample_time_ms: 4669.752
#     update_time_ms: 134.741
#   iterations_since_restore: 3
#   node_ip: 10.4.2.25
#   num_healthy_workers: 1
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 1.04
#     ram_util_percent: 5.4
#   pid: 456686
#   policy_reward_mean: {}
#   sampler_perf:
#     mean_env_wait_ms: 6.715340365459564
#     mean_inference_ms: 0.6434101923868364
#     mean_processing_ms: 11.565473427000141
#   time_since_restore: 14.888190269470215
#   time_this_iter_s: 3.091970205307007
#   time_total_s: 30.03480339050293
#   timestamp: 1584903621
#   timesteps_since_restore: 600
#   timesteps_this_iter: 200
#   timesteps_total: 1200
#   training_iteration: 6
#   trial_id: 39f96f22
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 2/2 CPUs, 0/0 GPUs
# Memory usage on this node: 10.9/201.2 GB
# Result logdir: /users/PYS1027/chnrhughes/ray_results/training_example
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - PPO_WaveAttenuationPOEnv-v0_0:	RUNNING, 2 failures: /users/PYS1027/chnrhughes/ray_results/training_example/PPO_WaveAttenuationPOEnv-v0_0_2020-03-22_14-59-15tb_5w9r1/error_2020-03-22_14-59-59.txt, [2 CPUs, 0 GPUs], [pid=456686], 30 s, 6 iter, 1200 ts, -216 rew
#
# (pid=456964)
# (pid=456964) -----------------------
# (pid=456964) ring length: 259
# (pid=456964) v_max: 5.092292348291853
# (pid=456964) -----------------------
# (pid=456964)
# (pid=456964) -----------------------
# (pid=456964) ring length: 253
# (pid=456964) v_max: 4.807278529691987
# (pid=456964) -----------------------
# (pid=456964)
# (pid=456964) -----------------------
# (pid=456964) ring length: 270
# (pid=456964) v_max: 5.6143732387852054
# (pid=456964) -----------------------
# (pid=456964)
# (pid=456964) -----------------------
# (pid=456964) ring length: 259
# (pid=456964) v_max: 5.092292348291853
# (pid=456964) -----------------------
# Result for PPO_WaveAttenuationPOEnv-v0_0:
#   custom_metrics: {}
#   date: 2020-03-22_15-00-28
#   done: false
#   episode_len_mean: 100.0
#   episode_reward_max: -177.8949183305609
#   episode_reward_mean: -208.79760872020702
#   episode_reward_min: -225.19432307628566
#   episodes_this_iter: 2
#   episodes_total: 16
#   experiment_id: 72c8564d6e124054a5640296b125d1ca
#   hostname: p0078.ten.osc.edu
#   info:
#     grad_time_ms: 86.638
#     learner:
#       default_policy:
#         cur_kl_coeff: 0.012500000186264515
#         cur_lr: 4.999999873689376e-05
#         entropy: 1.4144377708435059
#         entropy_coeff: 0.0
#         kl: 7.256865330873552e-08
#         policy_loss: -4.16487455368042e-05
#         total_loss: 2063.20263671875
#         vf_explained_var: -0.0006217360496520996
#         vf_loss: 2063.20263671875
#     load_time_ms: 10.203
#     num_steps_sampled: 1600
#     num_steps_trained: 1600
#     sample_time_ms: 4035.932
#     update_time_ms: 81.506
#   iterations_since_restore: 5
#   node_ip: 10.4.2.25
#   num_healthy_workers: 1
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 1.1999999999999997
#     ram_util_percent: 5.4
#   pid: 456686
#   policy_reward_mean: {}
#   sampler_perf:
#     mean_env_wait_ms: 5.796396534622799
#     mean_inference_ms: 0.6194493750759568
#     mean_processing_ms: 11.615971365118304
#   time_since_restore: 21.122711658477783
#   time_this_iter_s: 3.0720298290252686
#   time_total_s: 36.2693247795105
#   timestamp: 1584903628
#   timesteps_since_restore: 1000
#   timesteps_this_iter: 200
#   timesteps_total: 1600
#   training_iteration: 8
#   trial_id: 39f96f22
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 2/2 CPUs, 0/0 GPUs
# Memory usage on this node: 10.9/201.2 GB
# Result logdir: /users/PYS1027/chnrhughes/ray_results/training_example
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - PPO_WaveAttenuationPOEnv-v0_0:	RUNNING, 2 failures: /users/PYS1027/chnrhughes/ray_results/training_example/PPO_WaveAttenuationPOEnv-v0_0_2020-03-22_14-59-15tb_5w9r1/error_2020-03-22_14-59-59.txt, [2 CPUs, 0 GPUs], [pid=456686], 36 s, 8 iter, 1600 ts, -209 rew
#
# (pid=456964)
# (pid=456964) -----------------------
# (pid=456964) ring length: 255
# (pid=456964) v_max: 4.902299776966978
# (pid=456964) -----------------------
# (pid=456964)
# (pid=456964) -----------------------
# (pid=456964) ring length: 239
# (pid=456964) v_max: 4.141741239205832
# (pid=456964) -----------------------
# (pid=456964)
# (pid=456964) -----------------------
# (pid=456964) ring length: 241
# (pid=456964) v_max: 4.236854288051661
# (pid=456964) -----------------------
# (pid=456964)
# (pid=456964) -----------------------
# (pid=456964) ring length: 252
# (pid=456964) v_max: 4.759762049824181
# (pid=456964) -----------------------
# Result for PPO_WaveAttenuationPOEnv-v0_0:
#   custom_metrics: {}
#   date: 2020-03-22_15-00-34
#   done: true
#   episode_len_mean: 100.0
#   episode_reward_max: -177.8949183305609
#   episode_reward_mean: -206.64369757682258
#   episode_reward_min: -225.19432307628566
#   episodes_this_iter: 2
#   episodes_total: 20
#   experiment_id: 72c8564d6e124054a5640296b125d1ca
#   hostname: p0078.ten.osc.edu
#   info:
#     grad_time_ms: 68.977
#     learner:
#       default_policy:
#         cur_kl_coeff: 0.0031250000465661287
#         cur_lr: 4.999999873689376e-05
#         entropy: 1.4143848419189453
#         entropy_coeff: 0.0
#         kl: 1.8227100326839718e-06
#         policy_loss: -0.00019688531756401062
#         total_loss: 2199.75
#         vf_explained_var: -0.0005328655242919922
#         vf_loss: 2199.750244140625
#     load_time_ms: 7.572
#     num_steps_sampled: 2000
#     num_steps_trained: 2000
#     sample_time_ms: 3754.301
#     update_time_ms: 58.669
#   iterations_since_restore: 7
#   node_ip: 10.4.2.25
#   num_healthy_workers: 1
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 1.2399999999999998
#     ram_util_percent: 5.4
#   pid: 456686
#   policy_reward_mean: {}
#   sampler_perf:
#     mean_env_wait_ms: 5.284599493689709
#     mean_inference_ms: 0.6072603107182192
#     mean_processing_ms: 11.626382869029404
#   time_since_restore: 27.28406858444214
#   time_this_iter_s: 3.072533369064331
#   time_total_s: 42.43068170547485
#   timestamp: 1584903634
#   timesteps_since_restore: 1400
#   timesteps_this_iter: 200
#   timesteps_total: 2000
#   training_iteration: 10
#   trial_id: 39f96f22
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/2 CPUs, 0/0 GPUs
# Memory usage on this node: 10.9/201.2 GB
# Result logdir: /users/PYS1027/chnrhughes/ray_results/training_example
# Number of trials: 1 ({'TERMINATED': 1})
# TERMINATED trials:
#  - PPO_WaveAttenuationPOEnv-v0_0:	TERMINATED, 2 failures: /users/PYS1027/chnrhughes/ray_results/training_example/PPO_WaveAttenuationPOEnv-v0_0_2020-03-22_14-59-15tb_5w9r1/error_2020-03-22_14-59-59.txt, [2 CPUs, 0 GPUs], [pid=456686], 42 s, 10 iter, 2000 ts, -207 rew
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/2 CPUs, 0/0 GPUs
# Memory usage on this node: 10.9/201.2 GB
# Result logdir: /users/PYS1027/chnrhughes/ray_results/training_example
# Number of trials: 1 ({'TERMINATED': 1})
# TERMINATED trials:
#  - PPO_WaveAttenuationPOEnv-v0_0:	TERMINATED, 2 failures: /users/PYS1027/chnrhughes/ray_results/training_example/PPO_WaveAttenuationPOEnv-v0_0_2020-03-22_14-59-15tb_5w9r1/error_2020-03-22_14-59-59.txt, [2 CPUs, 0 GPUs], [pid=456686], 42 s, 10 iter, 2000 ts, -207 rew

# %% [markdown]
# ### 4.5 Visualizing the results
#
# The simulation results are saved within the `ray_results/training_example` directory (we defined `training_example` at the start of this tutorial). The `ray_results` folder is by default located at your root `~/ray_results`.
#
# You can run `tensorboard --logdir=~/ray_results/training_example` (install it with `pip install tensorboard`) to visualize the different data outputted by your simulation.
#
# For more instructions about visualizing, please see `tutorial05_visualize.ipynb`.

# %% [markdown]
# ### 4.6 Restart from a checkpoint / Transfer learning
#
# If you wish to do transfer learning, or to resume a previous training, you will need to start the simulation from a previous checkpoint. To do that, you can add a `restore` parameter in the `run_experiments` argument, as follows:
#
# ```python
# trials = run_experiments({
#     flow_params["exp_tag"]: {
#         "run": alg_run,
#         "env": gym_name,
#         "config": {
#             **config
#         },
#         "restore": "/ray_results/experiment/dir/checkpoint_50/checkpoint-50"
#         "checkpoint_freq": 1,
#         "checkpoint_at_end": True,
#         "max_failures": 999,
#         "stop": {
#             "training_iteration": 1,
#         },
#     },
# })
# ```
#
# The `"restore"` path should be such that the `[restore]/.tune_metadata` file exists.
#
# There is also a `"resume"` parameter that you can set to `True` if you just wish to continue the training from a previously saved checkpoint, in case you are still training on the same experiment.
