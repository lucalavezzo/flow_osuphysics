# %% [markdown]
# # Tutorial 03: Running RLlib Experiments
#
# This tutorial walks you through the process of running traffic simulations in Flow with trainable RLlib-powered agents. Autonomous agents will learn to maximize a certain reward over the rollouts, using the [**RLlib**](https://ray.readthedocs.io/en/latest/rllib.html) library ([citation](https://arxiv.org/abs/1712.09381)) ([installation instructions](https://flow.readthedocs.io/en/latest/flow_setup.html#optional-install-ray-rllib)). Simulations of this form will depict the propensity of RL agents to influence the traffic of a human fleet in order to make the whole fleet more efficient (for some given metrics).
#
# In this tutorial, we simulate an initially perturbed single lane ring road, where we introduce a single autonomous vehicle. We witness that, after some training, that the autonomous vehicle learns to dissipate the formation and propagation of "phantom jams" which form when only human driver dynamics are involved.
#
# ## 1. Components of a Simulation
# All simulations, both in the presence and absence of RL, require two components: a *network*, and an *environment*. Networks describe the features of the transportation network used in simulation. This includes the positions and properties of nodes and edges constituting the lanes and junctions, as well as properties of the vehicles, traffic lights, inflows, etc... in the network. Environments, on the other hand, initialize, reset, and advance simulations, and act as the primary interface between the reinforcement learning algorithm and the network. Moreover, custom environments may be used to modify the dynamical features of an network. Finally, in the RL case, it is in the *environment* that the state/action spaces and the reward function are defined.
#
# ## 2. Setting up a Network
# Flow contains a plethora of pre-designed networks used to replicate highways, intersections, and merges in both closed and open settings. All these networks are located in flow/networks. For this tutorial, which involves a single lane ring road, we will use the network `RingNetwork`.
#
# ### 2.1 Setting up Network Parameters
#
# The network mentioned at the start of this section, as well as all other networks in Flow, are parameterized by the following arguments:
# * name
# * vehicles
# * net_params
# * initial_config
#
# These parameters are explained in detail in `tutorial01_sumo.ipynb`. Moreover, all parameters excluding vehicles (covered in section 2.2) do not change from the previous tutorial. Accordingly, we specify them nearly as we have before, and leave further explanations of the parameters to `tutorial01_sumo.ipynb`.
#
# We begin by choosing the network the experiment will be trained on. We use one of Flow's builtin networks, located in `flow.networks`. A list of all available networks can be found by running the script below.

# %%
import flow.networks as networks

print(networks.__all__)
# Out:
# ['Network', 'BayBridgeNetwork', 'BayBridgeTollNetwork', 'BottleneckNetwork', 'FigureEightNetwork', 'TrafficLightGridNetwork', 'HighwayNetwork', 'RingNetwork', 'MergeNetwork', 'MultiRingNetwork', 'MiniCityNetwork', 'HighwayRampsNetwork']

# %% [markdown]
# In this tutorial, we choose to use the ring road network. The network class is then:

# %%
from flow.networks import RingNetwork

# ring road network class
network_name = RingNetwork

# %% [markdown]
# One key difference between SUMO and RLlib experiments is that, in RLlib experiments, the network classes do not need to be defined; instead users should simply name the network class they wish to use. Later on, an environment setup module will import the correct network class based on the provided names.

# %%
# input parameter classes to the network class
from flow.core.params import NetParams, InitialConfig

# name of the network
name = "training_example"

# network-specific parameters
from flow.networks.ring import ADDITIONAL_NET_PARAMS
net_params = NetParams(additional_params=ADDITIONAL_NET_PARAMS)

# initial configuration to vehicles
initial_config = InitialConfig(spacing="uniform", perturbation=1)

# %% [markdown]
# ### 2.2 Adding Trainable Autonomous Vehicles
# The `Vehicles` class stores state information on all vehicles in the network. This class is used to identify the dynamical features of a vehicle and whether it is controlled by a reinforcement learning agent. Morover, information pertaining to the observations and reward function can be collected from various `get` methods within this class.
#
# The dynamics of vehicles in the `Vehicles` class can either be depicted by sumo or by the dynamical methods located in flow/controllers. For human-driven vehicles, we use the IDM model for acceleration behavior, with exogenous gaussian acceleration noise with std 0.2 m/s2 to induce perturbations that produce stop-and-go behavior. In addition, we use the `ContinousRouter` routing controller so that the vehicles may maintain their routes closed networks.
#
# As we have done in `tutorial01_sumo.ipynb`, human-driven vehicles are defined in the `VehicleParams` class as follows:

# %%
# vehicles class
from flow.core.params import VehicleParams

# vehicles dynamics models
from flow.controllers import IDMController, ContinuousRouter

vehicles = VehicleParams()
vehicles.add("human",
             acceleration_controller=(IDMController, {}),
             routing_controller=(ContinuousRouter, {}),
             num_vehicles=21)

# %% [markdown]
# The above addition to the `Vehicles` class only accounts for 21 of the 22 vehicles that are placed in the network. We now add an additional trainable autuonomous vehicle whose actions are dictated by an RL agent. This is done by specifying an `RLController` as the acceleraton controller to the vehicle.

# %%
from flow.controllers import RLController

# %% [markdown]
# Note that this controller serves primarirly as a placeholder that marks the vehicle as a component of the RL agent, meaning that lane changing and routing actions can also be specified by the RL agent to this vehicle.
#
# We finally add the vehicle as follows, while again using the `ContinuousRouter` to perpetually maintain the vehicle within the network.

# %%
vehicles.add(veh_id="rl",
             acceleration_controller=(RLController, {}),
             routing_controller=(ContinuousRouter, {}),
             num_vehicles=1)
        

vehicles.add(veh_id="rl2",
             acceleration_controller=(RLController, {}),
             routing_controller=(ContinuousRouter, {}),
             num_vehicles=1)

# %% [markdown]
# ## 3. Setting up an Environment
#
# Several environments in Flow exist to train RL agents of different forms (e.g. autonomous vehicles, traffic lights) to perform a variety of different tasks. The use of an environment allows us to view the cumulative reward simulation rollouts receive, along with to specify the state/action spaces.
#
# Sumo envrionments in Flow are parametrized by three components:
# * `SumoParams`
# * `EnvParams`
# * `Network`
#
# ### 3.1 SumoParams
# `SumoParams` specifies simulation-specific variables. These variables include the length of any simulation step and whether to render the GUI when running the experiment. For this example, we consider a simulation step length of 0.1s and deactivate the GUI.
#
# **Note** For training purposes, it is highly recommanded to deactivate the GUI in order to avoid global slow down. In such case, one just needs to specify the following: `render=False`

# %%
from flow.core.params import SumoParams

sim_params = SumoParams(sim_step=0.1, render=False)

# %% [markdown]
# ### 3.2 EnvParams
#
# `EnvParams` specifies environment and experiment-specific parameters that either affect the training process or the dynamics of various components within the network. For the environment `WaveAttenuationPOEnv`, these parameters are used to dictate bounds on the accelerations of the autonomous vehicles, as well as the range of ring lengths (and accordingly network densities) the agent is trained on.
#
# Finally, it is important to specify here the *horizon* of the experiment, which is the duration of one episode (during which the RL-agent acquire data).

# %%
from flow.core.params import EnvParams

# Define horizon as a variable to ensure consistent use across notebook
HORIZON=100

env_params = EnvParams(
    # length of one rollout
    horizon=HORIZON,

    additional_params={
        # maximum acceleration of autonomous vehicles
        "max_accel": 1,
        # maximum deceleration of autonomous vehicles
        "max_decel": 1,
        # bounds on the ranges of ring road lengths the autonomous vehicle 
        # is trained on
        "ring_length": [220, 270],
    },
)

# %% [markdown]
# ### 3.3 Initializing a Gym Environment
#
# Now, we have to specify our Gym Environment and the algorithm that our RL agents will use. Similar to the network, we choose to use on of Flow's builtin environments, a list of which is provided by the script below.

# %%
import flow.envs as flowenvs

print(flowenvs.__all__)
# Out:
# ['Env', 'AccelEnv', 'LaneChangeAccelEnv', 'LaneChangeAccelPOEnv', 'TrafficLightGridTestEnv', 'MergePOEnv', 'BottleneckEnv', 'BottleneckAccelEnv', 'WaveAttenuationEnv', 'WaveAttenuationPOEnv', 'TrafficLightGridEnv', 'TrafficLightGridPOEnv', 'BottleneckDesiredVelocityEnv', 'TestEnv', 'BayBridgeEnv', 'BottleNeckAccelEnv', 'DesiredVelocityEnv', 'PO_TrafficLightGridEnv', 'GreenWaveTestEnv']

# %% [markdown]
# We will use the environment "WaveAttenuationPOEnv", which is used to train autonomous vehicles to attenuate the formation and propagation of waves in a partially observable variable density ring road. To create the Gym Environment, the only necessary parameters are the environment name plus the previously defined variables. These are defined as follows:

# %%
from flow.envs import WaveAttenuationPOEnv

env_name = WaveAttenuationPOEnv

# %% [markdown]
# ### 3.4 Setting up Flow Parameters
#
# RLlib experiments both generate a `params.json` file for each experiment run. For RLlib experiments, the parameters defining the Flow network and environment must be stored as well. As such, in this section we define the dictionary `flow_params`, which contains the variables required by the utility function `make_create_env`. `make_create_env` is a higher-order function which returns a function `create_env` that initializes a Gym environment corresponding to the Flow network specified.

# %%
# Creating flow_params. Make sure the dictionary keys are as specified. 
flow_params = dict(
    # name of the experiment
    exp_tag=name,
    # name of the flow environment the experiment is running on
    env_name=env_name,
    # name of the network class the experiment uses
    network=network_name,
    # simulator that is used by the experiment
    simulator='traci',
    # simulation-related parameters
    sim=sim_params,
    # environment related parameters (see flow.core.params.EnvParams)
    env=env_params,
    # network-related parameters (see flow.core.params.NetParams and
    # the network's documentation or ADDITIONAL_NET_PARAMS component)
    net=net_params,
    # vehicles to be placed in the network at the start of a rollout 
    # (see flow.core.vehicles.Vehicles)
    veh=vehicles,
    # (optional) parameters affecting the positioning of vehicles upon 
    # initialization/reset (see flow.core.params.InitialConfig)
    initial=initial_config
)

# %% [markdown]
# ## 4 Running RL experiments in Ray
#
# ### 4.1 Import
#
# First, we must import modules required to run experiments in Ray. The `json` package is required to store the Flow experiment parameters in the `params.json` file, as is `FlowParamsEncoder`. Ray-related imports are required: the PPO algorithm agent, `ray.tune`'s experiment runner, and environment helper methods `register_env` and `make_create_env`.

# %%
import json

import ray
try:
    from ray.rllib.agents.agent import get_agent_class
except ImportError:
    from ray.rllib.agents.registry import get_agent_class
from ray.tune import run_experiments
from ray.tune.registry import register_env

from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder
# Out:
# WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %% [markdown]
# ### 4.2 Initializing Ray
# Here, we initialize Ray and experiment-based constant variables specifying parallelism in the experiment as well as experiment batch size in terms of number of rollouts.

# %%
# number of parallel workers
N_CPUS = 2
# number of rollouts per training iteration
N_ROLLOUTS = 1

ray.init(num_cpus=N_CPUS)
# Out:
# 2020-03-20 13:11:52,887	INFO node.py:498 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2020-03-20_13-11-52_887289_423917/logs.
# 2020-03-20 13:11:53,004	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:35766 to respond...
# 2020-03-20 13:11:53,122	INFO services.py:409 -- Waiting for redis server at 127.0.0.1:14894 to respond...
# 2020-03-20 13:11:53,124	INFO services.py:809 -- Starting Redis shard with 10.0 GB max memory.
# 2020-03-20 13:11:53,146	INFO node.py:512 -- Process STDOUT and STDERR is being redirected to /tmp/ray/session_2020-03-20_13-11-52_887289_423917/logs.
# 2020-03-20 13:11:53,147	WARNING services.py:1301 -- Warning: Capping object memory store to 20.0GB. To increase this further, specify `object_store_memory` when calling ray.init() or ray start.
# 2020-03-20 13:11:53,148	INFO services.py:1475 -- Starting the Plasma object store with 20.0 GB memory using /dev/shm.
# {'node_ip_address': '10.4.3.16',
#  'object_store_address': '/tmp/ray/session_2020-03-20_13-11-52_887289_423917/sockets/plasma_store',
#  'raylet_socket_name': '/tmp/ray/session_2020-03-20_13-11-52_887289_423917/sockets/raylet',
#  'redis_address': '10.4.3.16:35766',
#  'session_dir': '/tmp/ray/session_2020-03-20_13-11-52_887289_423917',
#  'webui_url': None}

# %% [markdown]
# ### 4.3 Configuration and Setup
# Here, we copy and modify the default configuration for the [PPO algorithm](https://arxiv.org/abs/1707.06347). The agent has the number of parallel workers specified, a batch size corresponding to `N_ROLLOUTS` rollouts (each of which has length `HORIZON` steps), a discount rate $\gamma$ of 0.999, two hidden layers of size 16, uses Generalized Advantage Estimation, $\lambda$ of 0.97, and other parameters as set below.
#
# Once `config` contains the desired parameters, a JSON string corresponding to the `flow_params` specified in section 3 is generated. The `FlowParamsEncoder` maps objects to string representations so that the experiment can be reproduced later. That string representation is stored within the `env_config` section of the `config` dictionary. Later, `config` is written out to the file `params.json`.
#
# Next, we call `make_create_env` and pass in the `flow_params` to return a function we can use to register our Flow environment with Gym.

# %%
# The algorithm or model to train. This may refer to "
#      "the name of a built-on algorithm (e.g. RLLib's DQN "
#      "or PPO), or a user-defined trainable function or "
#      "class registered in the tune registry.")
alg_run = "PPO"

agent_cls = get_agent_class(alg_run)
config = agent_cls._default_config.copy()
config["num_workers"] = N_CPUS - 1  # number of parallel workers
config["train_batch_size"] = HORIZON * N_ROLLOUTS  # batch size
config["gamma"] = 0.999  # discount rate
config["model"].update({"fcnet_hiddens": [16, 16]})  # size of hidden layers in network
config["use_gae"] = True  # using generalized advantage estimation
config["lambda"] = 0.97  
config["sgd_minibatch_size"] = min(16 * 1024, config["train_batch_size"])  # stochastic gradient descent
config["kl_target"] = 0.02  # target KL divergence
config["num_sgd_iter"] = 10  # number of SGD iterations
config["horizon"] = HORIZON  # rollout horizon

# save the flow params for replay
flow_json = json.dumps(flow_params, cls=FlowParamsEncoder, sort_keys=True,
                       indent=4)  # generating a string version of flow_params
config['env_config']['flow_params'] = flow_json  # adding the flow_params to config dict
config['env_config']['run'] = alg_run

# Call the utility function make_create_env to be able to 
# register the Flow env for this experiment
create_env, gym_name = make_create_env(params=flow_params, version=0)

# Register as rllib env with Gym
register_env(gym_name, create_env)

# %% [markdown]
# ### 4.4 Running Experiments
#
# Here, we use the `run_experiments` function from `ray.tune`. The function takes a dictionary with one key, a name corresponding to the experiment, and one value, itself a dictionary containing parameters for training.

# %%
trials = run_experiments({
    flow_params["exp_tag"]: {
        "run": alg_run,
        "env": gym_name,
        "config": {
            **config
        },
        "checkpoint_freq": 1,  # number of iterations between checkpoints
        "checkpoint_at_end": True,  # generate a checkpoint at the end
        "max_failures": 999,
        "stop": {  # stopping conditions
            "training_iteration": 1,  # number of iterations to stop after
        },
    },
})
# Out:
# 2020-03-20 13:12:17,155	INFO trial_runner.py:176 -- Starting a new experiment.
# 2020-03-20 13:12:17,161	WARNING signature.py:108 -- The function with_updates has a **kwargs argument, which is currently not supported.
# 2020-03-20 13:12:17,169	WARNING logger.py:227 -- Could not instantiate <class 'ray.tune.logger.TFLogger'> - skipping.
# 2020-03-20 13:12:17,170	ERROR log_sync.py:34 -- Log sync requires cluster to be setup with `ray up`.
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/2 CPUs, 0/0 GPUs
# Memory usage on this node: 13.1/201.2 GB
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 2/2 CPUs, 0/0 GPUs
# Memory usage on this node: 13.1/201.2 GB
# Result logdir: /users/PYS1027/chnrhughes/ray_results/training_example
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - PPO_WaveAttenuationPOEnv-v0_0:	RUNNING
#
# (pid=424329) 2020-03-20 13:12:18.473467: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=424329) 2020-03-20 13:12:18.473543: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=424329) 2020-03-20 13:12:18.473554: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# (pid=424329) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=424329) Instructions for updating:
# (pid=424329) non-resource variables are not supported in the long term
# (pid=424329) 2020-03-20 13:12:20,885	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# (pid=424329) 2020-03-20 13:12:22,041	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# (pid=424329) 2020-03-20 13:12:22.041948: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# (pid=424329) 2020-03-20 13:12:22.049061: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2400000000 Hz
# (pid=424329) 2020-03-20 13:12:22.049413: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7290000 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# (pid=424329) 2020-03-20 13:12:22.049443: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# (pid=424329) 2020-03-20 13:12:22.051052: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=424329) 2020-03-20 13:12:22.051073: E tensorflow/stream_executor/cuda/cuda_driver.cc:351] failed call to cuInit: UNKNOWN ERROR (303)
# (pid=424329) 2020-03-20 13:12:22.051096: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p0127.ten.osc.edu): /proc/driver/nvidia/version does not exist
# (pid=424329) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=424329) Instructions for updating:
# (pid=424329) Use keras.layers.Dense instead.
# (pid=424329) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=424329) Instructions for updating:
# (pid=424329) Use keras.layers.Dense instead.
# (pid=424329) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=424329) Instructions for updating:
# (pid=424329) Please use `layer.__call__` method instead.
# (pid=424329) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=424329) Instructions for updating:
# (pid=424329) Please use `layer.__call__` method instead.
# (pid=424329) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=424329) Instructions for updating:
# (pid=424329) Use `tf.cast` instead.
# (pid=424329) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=424329) Instructions for updating:
# (pid=424329) Use `tf.cast` instead.
# (pid=424329) 2020-03-20 13:12:22,147	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=424329)
# (pid=424329) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=424329)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 2) dtype=float32>,
# (pid=424329)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=424329)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 4) dtype=float32>,
# (pid=424329)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=424329)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 3) dtype=float32>,
# (pid=424329)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 3) dtype=float32>,
# (pid=424329)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 2) dtype=float32>,
# (pid=424329)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=424329)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=424329)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=424329)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=424329)
# (pid=424329) 2020-03-20 13:12:22,696	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x2ad545841a20>}
# (pid=424329) 2020-03-20 13:12:22,696	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x2ad545841780>}
# (pid=424329) 2020-03-20 13:12:22,696	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x2ad545841630>}
# (pid=424329) 2020-03-20 13:12:22,721	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# (pid=424328) 2020-03-20 13:12:24.094326: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=424328) 2020-03-20 13:12:24.094404: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=424328) 2020-03-20 13:12:24.094414: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# (pid=424329) 2020-03-20 13:12:24,365	WARNING util.py:47 -- Install gputil for GPU system monitoring.
# (pid=424329) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/policy/tf_policy.py:570: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=424329) Instructions for updating:
# (pid=424329) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=424329) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/policy/tf_policy.py:570: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=424329) Instructions for updating:
# (pid=424329) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=424328) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=424328) Instructions for updating:
# (pid=424328) non-resource variables are not supported in the long term
# (pid=424328) 2020-03-20 13:12:27,574	INFO rollout_worker.py:319 -- Creating policy evaluation worker 1 on CPU (please ignore any CUDA init errors)
# (pid=424328) 2020-03-20 13:12:27.576071: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# (pid=424328) 2020-03-20 13:12:27.584654: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2400000000 Hz
# (pid=424328) 2020-03-20 13:12:27.584855: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x6dc4d90 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# (pid=424328) 2020-03-20 13:12:27.584889: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# (pid=424328) 2020-03-20 13:12:27.586712: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=424328) 2020-03-20 13:12:27.586733: E tensorflow/stream_executor/cuda/cuda_driver.cc:351] failed call to cuInit: UNKNOWN ERROR (303)
# (pid=424328) 2020-03-20 13:12:27.586750: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p0127.ten.osc.edu): /proc/driver/nvidia/version does not exist
# (pid=424328) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=424328) Instructions for updating:
# (pid=424328) Use keras.layers.Dense instead.
# (pid=424328) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=424328) Instructions for updating:
# (pid=424328) Use keras.layers.Dense instead.
# (pid=424328) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=424328) Instructions for updating:
# (pid=424328) Please use `layer.__call__` method instead.
# (pid=424328) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=424328) Instructions for updating:
# (pid=424328) Please use `layer.__call__` method instead.
# (pid=424328) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=424328) Instructions for updating:
# (pid=424328) Use `tf.cast` instead.
# (pid=424328) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=424328) Instructions for updating:
# (pid=424328) Use `tf.cast` instead.
# (pid=424328) 2020-03-20 13:12:27,686	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=424328)
# (pid=424328) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=424328)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 2) dtype=float32>,
# (pid=424328)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=424328)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 4) dtype=float32>,
# (pid=424328)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=424328)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 3) dtype=float32>,
# (pid=424328)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 3) dtype=float32>,
# (pid=424328)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 2) dtype=float32>,
# (pid=424328)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=424328)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=424328)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=424328)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=424328)
# (pid=424328) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/policy/tf_policy.py:570: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=424328) Instructions for updating:
# (pid=424328) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=424328) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/policy/tf_policy.py:570: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=424328) Instructions for updating:
# (pid=424328) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=424328)
# (pid=424328) -----------------------
# (pid=424328) ring length: 251
# (pid=424328) v_max: 4.180652396980301
# (pid=424328) -----------------------
# (pid=424328) 2020-03-20 13:12:28,238	INFO rollout_worker.py:451 -- Generating sample batch of size 200
# (pid=424328) 2020-03-20 13:12:29,415	INFO sampler.py:304 -- Raw obs from env: { 0: { 'agent0': np.ndarray((3,), dtype=float64, min=0.0, max=0.046, mean=0.015)}}
# (pid=424328) 2020-03-20 13:12:29,415	INFO sampler.py:305 -- Info return from env: {0: {'agent0': None}}
# (pid=424328) 2020-03-20 13:12:29,416	INFO sampler.py:403 -- Preprocessed obs: np.ndarray((3,), dtype=float64, min=0.0, max=0.046, mean=0.015)
# (pid=424328) 2020-03-20 13:12:29,416	INFO sampler.py:407 -- Filtered obs: np.ndarray((3,), dtype=float64, min=0.0, max=0.046, mean=0.015)
# (pid=424328) 2020-03-20 13:12:29,417	INFO sampler.py:521 -- Inputs to compute_actions():
# (pid=424328)
# (pid=424328) { 'default_policy': [ { 'data': { 'agent_id': 'agent0',
# (pid=424328)                                   'env_id': 0,
# (pid=424328)                                   'info': None,
# (pid=424328)                                   'obs': np.ndarray((3,), dtype=float64, min=0.0, max=0.046, mean=0.015),
# (pid=424328)                                   'prev_action': np.ndarray((2,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=424328)                                   'prev_reward': 0.0,
# (pid=424328)                                   'rnn_state': []},
# (pid=424328)                         'type': 'PolicyEvalData'}]}
# (pid=424328)
# (pid=424328) 2020-03-20 13:12:29,417	INFO tf_run_builder.py:92 -- Executing TF run without tracing. To dump TF timeline traces to disk, set the TF_TIMELINE_DIR environment variable.
# (pid=424328) 2020-03-20 13:12:29,449	INFO sampler.py:548 -- Outputs of compute_actions():
# (pid=424328)
# (pid=424328) { 'default_policy': ( np.ndarray((1, 2), dtype=float32, min=-0.102, max=0.66, mean=0.279),
# (pid=424328)                       [],
# (pid=424328)                       { 'action_prob': np.ndarray((1,), dtype=float32, min=0.127, max=0.127, mean=0.127),
# (pid=424328)                         'behaviour_logits': np.ndarray((1, 4), dtype=float32, min=-0.0, max=0.0, mean=-0.0),
# (pid=424328)                         'vf_preds': np.ndarray((1,), dtype=float32, min=-0.001, max=-0.001, mean=-0.001)})}
# (pid=424328)
# (pid=424328)
# (pid=424328) -----------------------
# (pid=424328) ring length: 258
# (pid=424328) v_max: 4.498356881565
# (pid=424328) -----------------------
# (pid=424328) 2020-03-20 13:12:29,839	INFO sample_batch_builder.py:161 -- Trajectory fragment after postprocess_trajectory():
# (pid=424328)
# (pid=424328) { 'agent0': { 'data': { 'action_prob': np.ndarray((100,), dtype=float32, min=0.001, max=0.154, mean=0.072),
# (pid=424328)                         'actions': np.ndarray((100, 2), dtype=float32, min=-3.021, max=2.209, mean=-0.101),
# (pid=424328)                         'advantages': np.ndarray((100,), dtype=float32, min=-75.928, max=-1.508, mean=-50.559),
# (pid=424328)                         'agent_index': np.ndarray((100,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=424328)                         'behaviour_logits': np.ndarray((100, 4), dtype=float32, min=-0.001, max=0.001, mean=-0.0),
# (pid=424328)                         'dones': np.ndarray((100,), dtype=bool, min=0.0, max=1.0, mean=0.01),
# (pid=424328)                         'eps_id': np.ndarray((100,), dtype=int64, min=1358668456.0, max=1358668456.0, mean=1358668456.0),
# (pid=424328)                         'infos': np.ndarray((100,), dtype=object, head={}),
# (pid=424328)                         'new_obs': np.ndarray((100, 3), dtype=float32, min=0.0, max=0.209, mean=0.082),
# (pid=424328)                         'obs': np.ndarray((100, 3), dtype=float32, min=0.0, max=0.209, mean=0.081),
# (pid=424328)                         'prev_actions': np.ndarray((100, 2), dtype=float32, min=-3.021, max=2.209, mean=-0.097),
# (pid=424328)                         'prev_rewards': np.ndarray((100,), dtype=float32, min=-3.825, max=0.0, mean=-2.263),
# (pid=424328)                         'rewards': np.ndarray((100,), dtype=float32, min=-3.825, max=-0.145, mean=-2.278),
# (pid=424328)                         't': np.ndarray((100,), dtype=int64, min=0.0, max=99.0, mean=49.5),
# (pid=424328)                         'unroll_id': np.ndarray((100,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=424328)                         'value_targets': np.ndarray((100,), dtype=float32, min=-75.928, max=-1.51, mean=-50.56),
# (pid=424328)                         'vf_preds': np.ndarray((100,), dtype=float32, min=-0.002, max=-0.001, mean=-0.001)},
# (pid=424328)               'type': 'SampleBatch'}}
# (pid=424328)
# (pid=424328)
# (pid=424328) -----------------------
# (pid=424328) ring length: 225
# (pid=424328) v_max: 2.999750077051092
# (pid=424328) -----------------------
# 2020-03-20 13:12:32,525	ERROR trial_runner.py:550 -- Error processing event.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/ray/tune/trial_runner.py", line 498, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/usr/local/lib/python3.5/dist-packages/ray/tune/ray_trial_executor.py", line 342, in fetch_result
#     result = ray.get(trial_future[0])
#   File "/usr/local/lib/python3.5/dist-packages/ray/worker.py", line 2247, in get
#     raise value
# ray.exceptions.RayTaskError: ray_PPO:train() (pid=424329, host=p0127.ten.osc.edu)
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/agents/trainer.py", line 369, in train
#     raise e
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/agents/trainer.py", line 358, in train
#     result = Trainable.train(self)
#   File "/usr/local/lib/python3.5/dist-packages/ray/tune/trainable.py", line 171, in train
#     result = self._train()
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/agents/trainer_template.py", line 126, in _train
#     fetches = self.optimizer.step()
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/optimizers/multi_gpu_optimizer.py", line 140, in step
#     self.num_envs_per_worker, self.train_batch_size)
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/optimizers/rollout.py", line 29, in collect_samples
#     next_sample = ray_get_and_free(fut_sample)
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/utils/memory.py", line 33, in ray_get_and_free
#     result = ray.get(object_ids)
# ray.exceptions.RayTaskError: ray_RolloutWorker:sample() (pid=424328, host=p0127.ten.osc.edu)
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/evaluation/rollout_worker.py", line 453, in sample
#     batches = [self.input_reader.next()]
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/evaluation/sampler.py", line 56, in next
#     batches = [self.get_data()]
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/evaluation/sampler.py", line 97, in get_data
#     item = next(self.rollout_provider)
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/evaluation/sampler.py", line 313, in _env_runner
#     soft_horizon)
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/evaluation/sampler.py", line 473, in _process_observations
#     resetted_obs = base_env.try_reset(env_id)
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/env/base_env.py", line 336, in try_reset
#     return {_DUMMY_AGENT_ID: self.vector_env.reset_at(env_id)}
#   File "/usr/local/lib/python3.5/dist-packages/ray/rllib/env/vector_env.py", line 104, in reset_at
#     return self.envs[index].reset()
#   File "/users/PYS1027/chnrhughes/work/flowtest/flow/flow/envs/ring/wave_attenuation.py", line 210, in reset
#     observation = super().reset()
#   File "/users/PYS1027/chnrhughes/work/flowtest/flow/flow/envs/base.py", line 528, in reset
#     raise FatalFlowError(msg=msg)
# flow.utils.exceptions.FatalFlowError:
# Not enough vehicles have spawned! Bad start?
# Missing vehicles / initial state:
# - human_5: ('human', 'bottom', 0, 49.32593967655412, 0)
# - human_4: ('human', 'bottom', 0, 36.962702026608, 0)
#
#
#
# 2020-03-20 13:12:32,529	INFO trial_runner.py:587 -- Attempting to recover trial state from last checkpoint.
# 2020-03-20 13:12:32,532	WARNING signature.py:108 -- The function with_updates has a **kwargs argument, which is currently not supported.
# (pid=424329) 2020-03-20 13:12:32,520	INFO trainer.py:366 -- Worker crashed during call to train(). To attempt to continue training without the failed worker, set `'ignore_worker_failures': True`.
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 2/2 CPUs, 0/0 GPUs
# Memory usage on this node: 13.6/201.2 GB
# Result logdir: /users/PYS1027/chnrhughes/ray_results/training_example
# Number of trials: 1 ({'RUNNING': 1})
# RUNNING trials:
#  - PPO_WaveAttenuationPOEnv-v0_0:	RUNNING, 1 failures: /users/PYS1027/chnrhughes/ray_results/training_example/PPO_WaveAttenuationPOEnv-v0_0_2020-03-20_13-12-17wfb54obv/error_2020-03-20_13-12-32.txt
#
# (pid=425025) 2020-03-20 13:12:34.187507: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=425025) 2020-03-20 13:12:34.187594: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=425025) 2020-03-20 13:12:34.187604: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# (pid=425025) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=425025) Instructions for updating:
# (pid=425025) non-resource variables are not supported in the long term
# (pid=425025) 2020-03-20 13:12:36,688	WARNING ppo.py:143 -- FYI: By default, the value function will not share layers with the policy model ('vf_share_layers': False).
# (pid=425025) 2020-03-20 13:12:37,815	INFO rollout_worker.py:319 -- Creating policy evaluation worker 0 on CPU (please ignore any CUDA init errors)
# (pid=425025) 2020-03-20 13:12:37.816890: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# (pid=425025) 2020-03-20 13:12:37.826949: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2400000000 Hz
# (pid=425025) 2020-03-20 13:12:37.827288: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7603410 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# (pid=425025) 2020-03-20 13:12:37.827321: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# (pid=425025) 2020-03-20 13:12:37.829296: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=425025) 2020-03-20 13:12:37.829318: E tensorflow/stream_executor/cuda/cuda_driver.cc:351] failed call to cuInit: UNKNOWN ERROR (303)
# (pid=425025) 2020-03-20 13:12:37.829337: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p0127.ten.osc.edu): /proc/driver/nvidia/version does not exist
# (pid=425025) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=425025) Instructions for updating:
# (pid=425025) Use keras.layers.Dense instead.
# (pid=425025) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=425025) Instructions for updating:
# (pid=425025) Use keras.layers.Dense instead.
# (pid=425025) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=425025) Instructions for updating:
# (pid=425025) Please use `layer.__call__` method instead.
# (pid=425025) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=425025) Instructions for updating:
# (pid=425025) Please use `layer.__call__` method instead.
# (pid=425025) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=425025) Instructions for updating:
# (pid=425025) Use `tf.cast` instead.
# (pid=425025) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=425025) Instructions for updating:
# (pid=425025) Use `tf.cast` instead.
# (pid=425025) 2020-03-20 13:12:37,935	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=425025)
# (pid=425025) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=425025)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 2) dtype=float32>,
# (pid=425025)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=425025)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 4) dtype=float32>,
# (pid=425025)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=425025)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 3) dtype=float32>,
# (pid=425025)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 3) dtype=float32>,
# (pid=425025)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 2) dtype=float32>,
# (pid=425025)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=425025)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=425025)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=425025)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=425025)
# (pid=425025) 2020-03-20 13:12:38,453	INFO rollout_worker.py:742 -- Built policy map: {'default_policy': <ray.rllib.policy.tf_policy_template.PPOTFPolicy object at 0x2af2639199b0>}
# (pid=425025) 2020-03-20 13:12:38,453	INFO rollout_worker.py:743 -- Built preprocessor map: {'default_policy': <ray.rllib.models.preprocessors.NoPreprocessor object at 0x2af263919710>}
# (pid=425025) 2020-03-20 13:12:38,453	INFO rollout_worker.py:356 -- Built filter map: {'default_policy': <ray.rllib.utils.filter.NoFilter object at 0x2af2639195c0>}
# (pid=425025) 2020-03-20 13:12:38,474	INFO multi_gpu_optimizer.py:93 -- LocalMultiGPUOptimizer devices ['/cpu:0']
# (pid=425286) 2020-03-20 13:12:40.075797: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=425286) 2020-03-20 13:12:40.075870: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=425286) 2020-03-20 13:12:40.075880: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# (pid=425025) 2020-03-20 13:12:40,141	WARNING util.py:47 -- Install gputil for GPU system monitoring.
# (pid=425025) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/policy/tf_policy.py:570: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=425025) Instructions for updating:
# (pid=425025) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=425025) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/policy/tf_policy.py:570: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=425025) Instructions for updating:
# (pid=425025) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=425286) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# (pid=425286) Instructions for updating:
# (pid=425286) non-resource variables are not supported in the long term
# (pid=425286) 2020-03-20 13:12:43,560	INFO rollout_worker.py:319 -- Creating policy evaluation worker 1 on CPU (please ignore any CUDA init errors)
# (pid=425286) 2020-03-20 13:12:43.562006: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# (pid=425286) 2020-03-20 13:12:43.572708: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2400000000 Hz
# (pid=425286) 2020-03-20 13:12:43.572876: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x744c100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# (pid=425286) 2020-03-20 13:12:43.572928: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# (pid=425286) 2020-03-20 13:12:43.574825: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# (pid=425286) 2020-03-20 13:12:43.574845: E tensorflow/stream_executor/cuda/cuda_driver.cc:351] failed call to cuInit: UNKNOWN ERROR (303)
# (pid=425286) 2020-03-20 13:12:43.574865: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p0127.ten.osc.edu): /proc/driver/nvidia/version does not exist
# (pid=425286) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=425286) Instructions for updating:
# (pid=425286) Use keras.layers.Dense instead.
# (pid=425286) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/fcnet_v1.py:48: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# (pid=425286) Instructions for updating:
# (pid=425286) Use keras.layers.Dense instead.
# (pid=425286) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=425286) Instructions for updating:
# (pid=425286) Please use `layer.__call__` method instead.
# (pid=425286) WARNING:tensorflow:From /users/PYS1027/chnrhughes/.local/lib/python3.5/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# (pid=425286) Instructions for updating:
# (pid=425286) Please use `layer.__call__` method instead.
# (pid=425286) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=425286) Instructions for updating:
# (pid=425286) Use `tf.cast` instead.
# (pid=425286) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/models/tf/tf_action_dist.py:138: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# (pid=425286) Instructions for updating:
# (pid=425286) Use `tf.cast` instead.
# (pid=425286) 2020-03-20 13:12:43,681	INFO dynamic_tf_policy.py:324 -- Initializing loss function with dummy input:
# (pid=425286)
# (pid=425286) { 'action_prob': <tf.Tensor 'default_policy/action_prob:0' shape=(?,) dtype=float32>,
# (pid=425286)   'actions': <tf.Tensor 'default_policy/actions:0' shape=(?, 2) dtype=float32>,
# (pid=425286)   'advantages': <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=425286)   'behaviour_logits': <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 4) dtype=float32>,
# (pid=425286)   'dones': <tf.Tensor 'default_policy/dones:0' shape=(?,) dtype=bool>,
# (pid=425286)   'new_obs': <tf.Tensor 'default_policy/new_obs:0' shape=(?, 3) dtype=float32>,
# (pid=425286)   'obs': <tf.Tensor 'default_policy/observation:0' shape=(?, 3) dtype=float32>,
# (pid=425286)   'prev_actions': <tf.Tensor 'default_policy/action:0' shape=(?, 2) dtype=float32>,
# (pid=425286)   'prev_rewards': <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=425286)   'rewards': <tf.Tensor 'default_policy/rewards:0' shape=(?,) dtype=float32>,
# (pid=425286)   'value_targets': <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=425286)   'vf_preds': <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>}
# (pid=425286)
# (pid=425286) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/policy/tf_policy.py:570: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=425286) Instructions for updating:
# (pid=425286) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=425286) WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/ray/rllib/policy/tf_policy.py:570: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# (pid=425286) Instructions for updating:
# (pid=425286) Prefer Variable.assign which has equivalent behavior in 2.X.
# (pid=425286)
# (pid=425286) -----------------------
# (pid=425286) ring length: 255
# (pid=425286) v_max: 4.362213816451154
# (pid=425286) -----------------------
# (pid=425286) 2020-03-20 13:12:44,233	INFO rollout_worker.py:451 -- Generating sample batch of size 200
# (pid=425286) 2020-03-20 13:12:45,375	INFO sampler.py:304 -- Raw obs from env: { 0: { 'agent0': np.ndarray((3,), dtype=float64, min=0.0, max=0.051, mean=0.017)}}
# (pid=425286) 2020-03-20 13:12:45,375	INFO sampler.py:305 -- Info return from env: {0: {'agent0': None}}
# (pid=425286) 2020-03-20 13:12:45,375	INFO sampler.py:403 -- Preprocessed obs: np.ndarray((3,), dtype=float64, min=0.0, max=0.051, mean=0.017)
# (pid=425286) 2020-03-20 13:12:45,375	INFO sampler.py:407 -- Filtered obs: np.ndarray((3,), dtype=float64, min=0.0, max=0.051, mean=0.017)
# (pid=425286) 2020-03-20 13:12:45,376	INFO sampler.py:521 -- Inputs to compute_actions():
# (pid=425286)
# (pid=425286) { 'default_policy': [ { 'data': { 'agent_id': 'agent0',
# (pid=425286)                                   'env_id': 0,
# (pid=425286)                                   'info': None,
# (pid=425286)                                   'obs': np.ndarray((3,), dtype=float64, min=0.0, max=0.051, mean=0.017),
# (pid=425286)                                   'prev_action': np.ndarray((2,), dtype=float32, min=0.0, max=0.0, mean=0.0),
# (pid=425286)                                   'prev_reward': 0.0,
# (pid=425286)                                   'rnn_state': []},
# (pid=425286)                         'type': 'PolicyEvalData'}]}
# (pid=425286)
# (pid=425286) 2020-03-20 13:12:45,376	INFO tf_run_builder.py:92 -- Executing TF run without tracing. To dump TF timeline traces to disk, set the TF_TIMELINE_DIR environment variable.
# (pid=425286) 2020-03-20 13:12:45,407	INFO sampler.py:548 -- Outputs of compute_actions():
# (pid=425286)
# (pid=425286) { 'default_policy': ( np.ndarray((1, 2), dtype=float32, min=-1.599, max=1.328, mean=-0.135),
# (pid=425286)                       [],
# (pid=425286)                       { 'action_prob': np.ndarray((1,), dtype=float32, min=0.018, max=0.018, mean=0.018),
# (pid=425286)                         'behaviour_logits': np.ndarray((1, 4), dtype=float32, min=-0.0, max=0.0, mean=0.0),
# (pid=425286)                         'vf_preds': np.ndarray((1,), dtype=float32, min=-0.001, max=-0.001, mean=-0.001)})}
# (pid=425286)
# (pid=425286)
# (pid=425286) -----------------------
# (pid=425286) ring length: 246
# (pid=425286) v_max: 3.953647285580593
# (pid=425286) -----------------------
# (pid=425286) 2020-03-20 13:12:45,796	INFO sample_batch_builder.py:161 -- Trajectory fragment after postprocess_trajectory():
# (pid=425286)
# (pid=425286) { 'agent0': { 'data': { 'action_prob': np.ndarray((100,), dtype=float32, min=0.002, max=0.159, mean=0.08),
# (pid=425286)                         'actions': np.ndarray((100, 2), dtype=float32, min=-2.511, max=2.81, mean=0.08),
# (pid=425286)                         'advantages': np.ndarray((100,), dtype=float32, min=-70.512, max=-3.432, mean=-45.923),
# (pid=425286)                         'agent_index': np.ndarray((100,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=425286)                         'behaviour_logits': np.ndarray((100, 4), dtype=float32, min=-0.002, max=0.001, mean=-0.0),
# (pid=425286)                         'dones': np.ndarray((100,), dtype=bool, min=0.0, max=1.0, mean=0.01),
# (pid=425286)                         'eps_id': np.ndarray((100,), dtype=int64, min=1718079389.0, max=1718079389.0, mean=1718079389.0),
# (pid=425286)                         'infos': np.ndarray((100,), dtype=object, head={}),
# (pid=425286)                         'new_obs': np.ndarray((100, 3), dtype=float32, min=0.0, max=0.202, mean=0.08),
# (pid=425286)                         'obs': np.ndarray((100, 3), dtype=float32, min=0.0, max=0.202, mean=0.079),
# (pid=425286)                         'prev_actions': np.ndarray((100, 2), dtype=float32, min=-2.511, max=2.81, mean=0.069),
# (pid=425286)                         'prev_rewards': np.ndarray((100,), dtype=float32, min=-3.983, max=0.346, mean=-2.071),
# (pid=425286)                         'rewards': np.ndarray((100,), dtype=float32, min=-3.983, max=0.346, mean=-2.106),
# (pid=425286)                         't': np.ndarray((100,), dtype=int64, min=0.0, max=99.0, mean=49.5),
# (pid=425286)                         'unroll_id': np.ndarray((100,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=425286)                         'value_targets': np.ndarray((100,), dtype=float32, min=-70.513, max=-3.434, mean=-45.924),
# (pid=425286)                         'vf_preds': np.ndarray((100,), dtype=float32, min=-0.002, max=-0.001, mean=-0.001)},
# (pid=425286)               'type': 'SampleBatch'}}
# (pid=425286)
# (pid=425286)
# (pid=425286) -----------------------
# (pid=425286) ring length: 238
# (pid=425286) v_max: 3.5903355955997784
# (pid=425286) -----------------------
# (pid=425025) 2020-03-20 13:12:48,499	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/default_model/fc1/kernel:0' shape=(3, 16) dtype=float32_ref>
# (pid=425025) 2020-03-20 13:12:48,499	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/default_model/fc1/bias:0' shape=(16,) dtype=float32_ref>
# (pid=425025) 2020-03-20 13:12:48,499	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/default_model/fc2/kernel:0' shape=(16, 16) dtype=float32_ref>
# (pid=425025) 2020-03-20 13:12:48,500	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/default_model/fc2/bias:0' shape=(16,) dtype=float32_ref>
# (pid=425025) 2020-03-20 13:12:48,500	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/default_model/fc_out/kernel:0' shape=(16, 4) dtype=float32_ref>
# (pid=425025) 2020-03-20 13:12:48,500	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/default_model/fc_out/bias:0' shape=(4,) dtype=float32_ref>
# (pid=425025) 2020-03-20 13:12:48,500	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/value_function/fc1/kernel:0' shape=(3, 16) dtype=float32_ref>
# (pid=425025) 2020-03-20 13:12:48,500	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/value_function/fc1/bias:0' shape=(16,) dtype=float32_ref>
# (pid=425025) 2020-03-20 13:12:48,500	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/value_function/fc2/kernel:0' shape=(16, 16) dtype=float32_ref>
# (pid=425025) 2020-03-20 13:12:48,500	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/value_function/fc2/bias:0' shape=(16,) dtype=float32_ref>
# (pid=425025) 2020-03-20 13:12:48,500	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/value_function/fc_out/kernel:0' shape=(16, 1) dtype=float32_ref>
# (pid=425025) 2020-03-20 13:12:48,500	INFO tf_policy.py:355 -- Optimizing variable <tf.Variable 'default_policy/value_function/fc_out/bias:0' shape=(1,) dtype=float32_ref>
# (pid=425025) 2020-03-20 13:12:48,501	INFO multi_gpu_impl.py:146 -- Training on concatenated sample batches:
# (pid=425025)
# (pid=425025) { 'inputs': [ np.ndarray((200, 2), dtype=float32, min=-3.379, max=2.901, mean=0.048),
# (pid=425025)               np.ndarray((200,), dtype=float32, min=-3.983, max=0.346, mean=-2.128),
# (pid=425025)               np.ndarray((200, 3), dtype=float32, min=-0.001, max=0.202, mean=0.077),
# (pid=425025)               np.ndarray((200, 2), dtype=float32, min=-3.379, max=2.901, mean=0.045),
# (pid=425025)               np.ndarray((200,), dtype=float32, min=-1.614, max=2.399, mean=-0.0),
# (pid=425025)               np.ndarray((200, 4), dtype=float32, min=-0.002, max=0.001, mean=-0.0),
# (pid=425025)               np.ndarray((200,), dtype=float32, min=-76.268, max=-3.19, mean=-46.872),
# (pid=425025)               np.ndarray((200,), dtype=float32, min=-0.002, max=-0.001, mean=-0.001)],
# (pid=425025)   'placeholders': [ <tf.Tensor 'default_policy/action:0' shape=(?, 2) dtype=float32>,
# (pid=425025)                     <tf.Tensor 'default_policy/prev_reward:0' shape=(?,) dtype=float32>,
# (pid=425025)                     <tf.Tensor 'default_policy/observation:0' shape=(?, 3) dtype=float32>,
# (pid=425025)                     <tf.Tensor 'default_policy/actions:0' shape=(?, 2) dtype=float32>,
# (pid=425025)                     <tf.Tensor 'default_policy/advantages:0' shape=(?,) dtype=float32>,
# (pid=425025)                     <tf.Tensor 'default_policy/behaviour_logits:0' shape=(?, 4) dtype=float32>,
# (pid=425025)                     <tf.Tensor 'default_policy/value_targets:0' shape=(?,) dtype=float32>,
# (pid=425025)                     <tf.Tensor 'default_policy/vf_preds:0' shape=(?,) dtype=float32>],
# (pid=425025)   'state_inputs': []}
# (pid=425025)
# (pid=425025) 2020-03-20 13:12:48,501	INFO multi_gpu_impl.py:191 -- Divided 200 rollout sequences, each of length 1, among 1 devices.
# (pid=425286) 2020-03-20 13:12:48,483	INFO rollout_worker.py:485 -- Completed sample batch:
# (pid=425286)
# (pid=425286) { 'data': { 'action_prob': np.ndarray((200,), dtype=float32, min=0.001, max=0.159, mean=0.076),
# (pid=425286)             'actions': np.ndarray((200, 2), dtype=float32, min=-3.379, max=2.901, mean=0.045),
# (pid=425286)             'advantages': np.ndarray((200,), dtype=float32, min=-76.268, max=-3.188, mean=-46.871),
# (pid=425286)             'agent_index': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=425286)             'behaviour_logits': np.ndarray((200, 4), dtype=float32, min=-0.002, max=0.001, mean=-0.0),
# (pid=425286)             'dones': np.ndarray((200,), dtype=bool, min=0.0, max=1.0, mean=0.01),
# (pid=425286)             'eps_id': np.ndarray((200,), dtype=int64, min=604618307.0, max=1718079389.0, mean=1161348848.0),
# (pid=425286)             'infos': np.ndarray((200,), dtype=object, head={}),
# (pid=425286)             'new_obs': np.ndarray((200, 3), dtype=float32, min=-0.001, max=0.202, mean=0.078),
# (pid=425286)             'obs': np.ndarray((200, 3), dtype=float32, min=-0.001, max=0.202, mean=0.077),
# (pid=425286)             'prev_actions': np.ndarray((200, 2), dtype=float32, min=-3.379, max=2.901, mean=0.048),
# (pid=425286)             'prev_rewards': np.ndarray((200,), dtype=float32, min=-3.983, max=0.346, mean=-2.128),
# (pid=425286)             'rewards': np.ndarray((200,), dtype=float32, min=-3.983, max=0.346, mean=-2.161),
# (pid=425286)             't': np.ndarray((200,), dtype=int64, min=0.0, max=99.0, mean=49.5),
# (pid=425286)             'unroll_id': np.ndarray((200,), dtype=int64, min=0.0, max=0.0, mean=0.0),
# (pid=425286)             'value_targets': np.ndarray((200,), dtype=float32, min=-76.268, max=-3.19, mean=-46.872),
# (pid=425286)             'vf_preds': np.ndarray((200,), dtype=float32, min=-0.002, max=-0.001, mean=-0.001)},
# (pid=425286)   'type': 'SampleBatch'}
# (pid=425286)
# Result for PPO_WaveAttenuationPOEnv-v0_0:
#   custom_metrics: {}
#   date: 2020-03-20_13-12-48
#   done: true
#   episode_len_mean: 100.0
#   episode_reward_max: -210.55132397637385
#   episode_reward_mean: -216.14492953752364
#   episode_reward_min: -221.7385350986734
#   episodes_this_iter: 2
#   episodes_total: 2
#   experiment_id: ae7eaf374b9242988d875515203878a3
#   hostname: p0127.ten.osc.edu
#   info:
#     grad_time_ms: 328.805
#     learner:
#       default_policy:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 4.999999873689376e-05
#         entropy: 2.8356246948242188
#         entropy_coeff: 0.0
#         kl: 5.801618499390315e-06
#         policy_loss: -0.0005786530673503876
#         total_loss: 2528.408447265625
#         vf_explained_var: -7.981061935424805e-05
#         vf_loss: 2528.4091796875
#     load_time_ms: 44.2
#     num_steps_sampled: 200
#     num_steps_trained: 200
#     sample_time_ms: 7940.092
#     update_time_ms: 374.198
#   iterations_since_restore: 1
#   node_ip: 10.4.3.16
#   num_healthy_workers: 1
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 3.3000000000000003
#     ram_util_percent: 6.761538461538461
#   pid: 425025
#   policy_reward_mean: {}
#   sampler_perf:
#     mean_env_wait_ms: 8.87681358489231
#     mean_inference_ms: 0.7409824067680397
#     mean_processing_ms: 11.514438325492897
#   time_since_restore: 8.734707355499268
#   time_this_iter_s: 8.734707355499268
#   time_total_s: 8.734707355499268
#   timestamp: 1584724368
#   timesteps_since_restore: 200
#   timesteps_this_iter: 200
#   timesteps_total: 200
#   training_iteration: 1
#   trial_id: f3564f38
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/2 CPUs, 0/0 GPUs
# Memory usage on this node: 13.6/201.2 GB
# Result logdir: /users/PYS1027/chnrhughes/ray_results/training_example
# Number of trials: 1 ({'TERMINATED': 1})
# TERMINATED trials:
#  - PPO_WaveAttenuationPOEnv-v0_0:	TERMINATED, 1 failures: /users/PYS1027/chnrhughes/ray_results/training_example/PPO_WaveAttenuationPOEnv-v0_0_2020-03-20_13-12-17wfb54obv/error_2020-03-20_13-12-32.txt, [2 CPUs, 0 GPUs], [pid=425025], 8 s, 1 iter, 200 ts, -216 rew
#
# == Status ==
# Using FIFO scheduling algorithm.
# Resources requested: 0/2 CPUs, 0/0 GPUs
# Memory usage on this node: 13.6/201.2 GB
# Result logdir: /users/PYS1027/chnrhughes/ray_results/training_example
# Number of trials: 1 ({'TERMINATED': 1})
# TERMINATED trials:
#  - PPO_WaveAttenuationPOEnv-v0_0:	TERMINATED, 1 failures: /users/PYS1027/chnrhughes/ray_results/training_example/PPO_WaveAttenuationPOEnv-v0_0_2020-03-20_13-12-17wfb54obv/error_2020-03-20_13-12-32.txt, [2 CPUs, 0 GPUs], [pid=425025], 8 s, 1 iter, 200 ts, -216 rew

# %% [markdown]
# ### 4.5 Visualizing the results
#
# The simulation results are saved within the `ray_results/training_example` directory (we defined `training_example` at the start of this tutorial). The `ray_results` folder is by default located at your root `~/ray_results`.
#
# You can run `tensorboard --logdir=~/ray_results/training_example` (install it with `pip install tensorboard`) to visualize the different data outputted by your simulation.
#
# For more instructions about visualizing, please see `tutorial05_visualize.ipynb`.

# %% [markdown]
# ### 4.6 Restart from a checkpoint / Transfer learning
#
# If you wish to do transfer learning, or to resume a previous training, you will need to start the simulation from a previous checkpoint. To do that, you can add a `restore` parameter in the `run_experiments` argument, as follows:
#
# ```python
# trials = run_experiments({
#     flow_params["exp_tag"]: {
#         "run": alg_run,
#         "env": gym_name,
#         "config": {
#             **config
#         },
#         "restore": "/ray_results/experiment/dir/checkpoint_50/checkpoint-50"
#         "checkpoint_freq": 1,
#         "checkpoint_at_end": True,
#         "max_failures": 999,
#         "stop": {
#             "training_iteration": 1,
#         },
#     },
# })
# ```
#
# The `"restore"` path should be such that the `[restore]/.tune_metadata` file exists.
#
# There is also a `"resume"` parameter that you can set to `True` if you just wish to continue the training from a previously saved checkpoint, in case you are still training on the same experiment.
