# %%
import json
import ray
from ray.rllib.agents.registry import get_agent_class
from ray.tune import run_experiments
from ray.tune.registry import register_env
import numpy as np
from flow.networks.ring import RingNetwork, ADDITIONAL_NET_PARAMS
from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder
from flow.core.params import SumoParams, EnvParams, InitialConfig, NetParams
from flow.core.params import VehicleParams, SumoCarFollowingParams
from flow.controllers import RLController, IDMController, ContinuousRouter
from gym.spaces.box import Box
from gym.spaces import Tuple
from flow.core.params import InFlows
from flow.controllers import SimLaneChangeController
from flow.networks import Network
import os
from flow.core.params import SumoLaneChangeParams

from env_merge import myEnv

ADDITIONAL_ENV_PARAMS = {
    "max_accel": 1,
    "max_decel": 1,
}

# time horizon of a single rollout
HORIZON = 1000
# number of rollouts per training iteration
N_ROLLOUTS = 20
# number of parallel workers
N_CPUS = 2

vehicles = VehicleParams()
vehicles.add("rl",
             acceleration_controller=(IDMController, {}),
             lane_change_controller=(SimLaneChangeController, {}),
             #routing_controller=(ContinuousRouter, {}),
             car_following_params=SumoCarFollowingParams(
                 speed_mode="obey_safe_speed",  
                 # we use the speed mode "obey_safe_speed" for better dynamics at the merge
             ),
             num_vehicles=0)
vehicles.add("human",
             acceleration_controller=(IDMController, {}),
             lane_change_controller=(SimLaneChangeController, {}),
             #routing_controller=(ContinuousRouter, {}),
             car_following_params=SumoCarFollowingParams(
                 speed_mode="obey_safe_speed",  
                 # we use the speed mode "obey_safe_speed" for better dynamics at the merge
             ),
             lane_change_params = SumoLaneChangeParams(lane_change_mode="strategic",lcpushy=1.0),
             num_vehicles=0)

# specify the edges vehicles can originate on
initial_config = InitialConfig(
    edges_distribution=["gneE6","gneE7"]
)
    
# specify the routes for vehicles in the network
class Network(Network):

    def specify_routes(self, net_params):
        return {
                "gneE7": ["gneE7","gneE6.243"],
                "gneE6": ["gneE6","gneE6.243"]
               }


inflow = InFlows()

#highway vehicles
inflow.add(veh_type="human",
           edge="gneE6",
           vehs_per_hour=5000,
            depart_lane="random",
            depart_speed="random",
            color="white")

#merging vehicles
inflow.add(veh_type="rl",
           edge="gneE7",
           vehs_per_hour=1000,
            depart_lane="random",
            depart_speed="random",
            color="blue")
inflow.add(veh_type="rl",
           edge="gneE7",
           vehs_per_hour=500,
            depart_lane="random",
            depart_speed="random",
            color="red")


fileDir='/mnt/c/Users/llave/Documents/GitHub/flow_osuphysics/lucalavezzo/merge.net.xml'
net_params = NetParams(
    template=fileDir,
    inflows=inflow
)

flow_params = dict(
    # name of the experiment
    exp_tag="merge",

    # name of the flow environment the experiment is running on
    env_name=myEnv,  # <------ here we replace the environment with our new environment

    # name of the network class the experiment is running on
    network=Network,

    # simulator that is used by the experiment
    simulator='traci',

    # sumo-related parameters (see flow.core.params.SumoParams)
    sim=SumoParams(
        sim_step=0.1,
        render=False,
        restart_instance=True,
    ),

    # environment related parameters (see flow.core.params.EnvParams)
    env=EnvParams(
        horizon=HORIZON,
        warmup_steps=750,
        clip_actions=False,
        additional_params={
            "sort_vehicles": False,
            "max_accel": 1,
            "max_decel": 1,
        },
    ),

    # network-related parameters (see flow.core.params.NetParams and the
    # network's documentation or ADDITIONAL_NET_PARAMS component)
    net=net_params,

    # vehicles to be placed in the network at the start of a rollout (see
    # flow.core.params.VehicleParams)
    veh=vehicles,

    # parameters specifying the positioning of vehicles upon initialization/
    # reset (see flow.core.params.InitialConfig)
    initial=initial_config
)


def setup_exps():
    """Return the relevant components of an RLlib experiment.

    Returns
    -------
    str
        name of the training algorithm
    str
        name of the gym environment to be trained
    dict
        training configuration parameters
    """
    alg_run = "PPO"

    agent_cls = get_agent_class(alg_run)
    config = agent_cls._default_config.copy()
    config["num_workers"] = N_CPUS
    config["train_batch_size"] = HORIZON * N_ROLLOUTS
    config["gamma"] = 0.999  # discount rate
    config["model"].update({"fcnet_hiddens": [3, 3]})
    config["use_gae"] = True
    config["lambda"] = 0.97
    config["kl_target"] = 0.02
    config["num_sgd_iter"] = 10
    config['clip_actions'] = False  # FIXME(ev) temporary ray bug
    config["horizon"] = HORIZON

    # save the flow params for replay
    flow_json = json.dumps(
        flow_params, cls=FlowParamsEncoder, sort_keys=True, indent=4)
    config['env_config']['flow_params'] = flow_json
    config['env_config']['run'] = alg_run

    create_env, gym_name = make_create_env(params=flow_params, version=0)

    # Register as rllib env
    register_env(gym_name, create_env)
    return alg_run, gym_name, config
# Out:
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
alg_run, gym_name, config = setup_exps()
ray.init(num_cpus=N_CPUS + 1)
trials = run_experiments({
    flow_params["exp_tag"]: {
        "run": alg_run,
        "env": gym_name,
        "config": {
            **config
        },
        "checkpoint_freq": 20,
        "checkpoint_at_end": True,
        "max_failures": 999,
        "stop": {
            "training_iteration": 200,
        },
    }
})
# Out:
# 2020-03-17 11:54:34,006	WARNING services.py:592 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2020-03-17 11:54:34,009	INFO resource_spec.py:212 -- Starting Ray with 5.62 GiB memory available for workers and up to 2.83 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-03-17 11:54:34,677	WARNING services.py:1080 -- Failed to start the dashboard. The dashboard requires Python 3 as well as 'pip install aiohttp psutil setproctitle grpcio'.
# == Status ==<br>Memory usage on this node: 6.6/15.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3/3 CPUs, 0/0 GPUs, 0.0/5.62 GiB heap, 0.0/1.95 GiB objects<br>Result logdir: /home/llavezzo/ray_results/merge<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_99c8a8de</td><td>RUNNING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (pid=130) E0317 11:54:37.037067000     130 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1584460477.037039700","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=130) E0317 11:54:37.037477000     130 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=129) E0317 11:54:36.926637100     129 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1584460476.926615400","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=129) E0317 11:54:36.926917200     129 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=raylet) E0317 11:54:35.024423200     108 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1584460475.024386000","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=raylet) E0317 11:54:35.024992400     108 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=raylet) E0317 11:54:35.077171700     108 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=131) E0317 11:54:37.154996700     131 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1584460477.154977400","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=131) E0317 11:54:37.155261000     131 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=129) 2020-03-17 11:54:42,088	INFO trainer.py:370 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=129) 2020-03-17 11:54:43,085	INFO trainer.py:517 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=129)  Retrying in 1 seconds
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=129) 2020-03-17 11:54:54,285	INFO trainable.py:178 -- _setup took 12.196 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (pid=129) 2020-03-17 11:54:54,286	WARNING util.py:41 -- Install gputil for GPU system monitoring.
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=130)   out=out, **kwargs)
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=130)   ret = ret.dtype.type(ret / rcount)
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=131)   out=out, **kwargs)
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=131)   ret = ret.dtype.type(ret / rcount)
# (pid=131) Warning: Vehicle 'flow_20.0' performs emergency braking with decel=-10.69 wished=4.50 severity=1.37, time=1.80.
# (pid=130) Warning: Vehicle 'flow_00.1' performs emergency braking with decel=-53.36 wished=4.50 severity=10.86, time=20.90.
# (pid=130) Warning: Vehicle 'flow_00.4' performs emergency braking with decel=-127.91 wished=4.50 severity=27.43, time=23.70.
# (pid=131) Warning: Vehicle 'flow_00.6' performs emergency braking with decel=-147.35 wished=4.50 severity=31.74, time=24.90.
# (pid=130) Warning: Vehicle 'flow_10.2' performs emergency braking with decel=-41.53 wished=4.50 severity=8.23, time=27.30.
# (pid=131) Warning: Vehicle 'flow_10.2' performs emergency braking with decel=-103.55 wished=4.50 severity=22.01, time=28.60.
# (pid=131) Warning: Vehicle 'flow_20.1' performs emergency braking with decel=-9.47 wished=4.50 severity=1.10, time=28.70.
# (pid=130) Warning: Vehicle 'flow_00.9' performs emergency braking with decel=-41.77 wished=4.50 severity=8.28, time=29.60.
# (pid=131) Warning: Vehicle 'flow_00.10' performs emergency braking with decel=-11.13 wished=4.50 severity=1.47, time=30.50.
# (pid=130) Warning: Vehicle 'flow_00.9' performs emergency braking with decel=-10.51 wished=4.50 severity=1.33, time=32.30.
# (pid=130) Warning: Vehicle 'flow_00.9' performs emergency braking with decel=-12.83 wished=4.50 severity=1.85, time=36.50.
# (pid=131) Warning: Vehicle 'flow_10.4' performs emergency braking with decel=-50.27 wished=4.50 severity=10.17, time=37.70.
# (pid=130) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-15.19 wished=4.50 severity=2.38, time=43.50.
# (pid=130) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-38.87 wished=4.50 severity=7.64, time=46.10.
# (pid=130) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-12.26 wished=4.50 severity=1.73, time=51.50.
# (pid=130) Warning: Vehicle 'flow_10.8' performs emergency braking with decel=-15.16 wished=4.50 severity=2.37, time=55.70.
# (pid=131) Warning: Vehicle 'flow_00.27' performs emergency braking with decel=-9.11 wished=4.50 severity=1.02, time=57.50.
# (pid=130) Warning: Vehicle 'flow_00.29' performs emergency braking with decel=-9.22 wished=4.50 severity=1.05, time=58.80.
# (pid=131) Warning: Vehicle 'flow_20.4' performs emergency braking with decel=-56.28 wished=4.50 severity=11.51, time=59.20.
# (pid=130) Warning: Vehicle 'flow_00.29' performs emergency braking with decel=-10.63 wished=4.50 severity=1.36, time=58.90.
# (pid=130) Warning: Vehicle 'flow_00.29' performs emergency braking with decel=-12.48 wished=4.50 severity=1.77, time=63.30.
# (pid=131) Warning: Vehicle 'flow_00.32' performs emergency braking with decel=-10.45 wished=4.50 severity=1.32, time=65.60.
# (pid=130) Warning: Vehicle 'flow_10.10' performs emergency braking with decel=-31.57 wished=4.50 severity=6.02, time=65.50.
# (pid=131) Warning: Vehicle 'flow_20.5' performs emergency braking with decel=-99.41 wished=4.50 severity=21.09, time=69.30.
# (pid=130) Warning: Vehicle 'flow_00.35' performs emergency braking with decel=-12.91 wished=4.50 severity=1.87, time=68.70.
# (pid=130) Warning: Vehicle 'flow_10.12' performs emergency braking with decel=-12.55 wished=4.50 severity=1.79, time=75.20.
# (pid=131) Warning: Vehicle 'flow_10.12' performs emergency braking with decel=-72.94 wished=4.50 severity=15.21, time=77.60.
# (pid=130) Warning: Vehicle 'flow_00.45' performs emergency braking with decel=-13.48 wished=4.50 severity=1.99, time=78.60.
# (pid=131) Warning: Vehicle 'flow_00.48' performs emergency braking with decel=-9.25 wished=4.50 severity=1.06, time=81.10.
# (pid=130) Warning: Vehicle 'flow_00.45' performs emergency braking with decel=-10.57 wished=4.50 severity=1.35, time=82.80.
# (pid=130) Warning: Vehicle 'flow_00.49' performs emergency braking with decel=-9.72 wished=4.50 severity=1.16, time=87.70.
# (pid=130) Warning: Vehicle 'flow_00.49' performs emergency braking with decel=-12.32 wished=4.50 severity=1.74, time=87.80.
# (pid=131) Warning: Vehicle 'flow_20.7' performs emergency braking with decel=-44.02 wished=4.50 severity=8.78, time=89.00.
# (pid=131) Warning: Vehicle 'flow_20.7' performs emergency braking with decel=-24.86 wished=4.50 severity=4.53, time=89.40.
# (pid=130) Warning: Vehicle 'flow_00.49' performs emergency braking with decel=-10.02 wished=4.50 severity=1.23, time=90.50.
# (pid=130) Warning: Vehicle 'flow_00.49' performs emergency braking with decel=-12.04 wished=4.50 severity=1.68, time=92.30.
# (pid=130) Warning: Vehicle 'flow_10.16' performs emergency braking with decel=-55.17 wished=4.50 severity=11.26, time=94.40.
# (pid=131) Warning: Vehicle 'flow_00.51' performs emergency braking with decel=-9.59 wished=4.50 severity=1.13, time=95.40.
# (pid=130) Warning: Vehicle 'flow_00.56' performs emergency braking with decel=-12.00 wished=4.50 severity=1.67, time=97.80.
# (pid=131) Warning: Vehicle 'flow_20.8' performs emergency braking with decel=-36.68 wished=4.50 severity=7.15, time=99.00.
# (pid=131) Warning: Vehicle 'flow_00.60' performs emergency braking with decel=-11.37 wished=4.50 severity=1.53, time=102.40.
# (pid=130) Warning: Vehicle 'flow_00.56' performs emergency braking with decel=-13.79 wished=4.50 severity=2.06, time=102.50.
# (pid=130) Warning: Vehicle 'flow_10.18' performs emergency braking with decel=-19.05 wished=4.50 severity=3.23, time=104.00.
# (pid=130) Warning: Vehicle 'flow_10.18' performs emergency braking with decel=-27.31 wished=4.50 severity=5.07, time=104.20.
# (pid=131) Warning: Vehicle 'flow_00.60' performs emergency braking with decel=-10.38 wished=4.50 severity=1.31, time=106.80.
# (pid=130) Warning: Vehicle 'flow_00.66' performs emergency braking with decel=-15.30 wished=4.50 severity=2.40, time=107.40.
# (pid=131) Warning: Vehicle 'flow_20.9' performs emergency braking with decel=-112.83 wished=4.50 severity=24.07, time=108.80.
# (pid=130) Warning: Vehicle 'flow_10.19' performs emergency braking with decel=-100.69 wished=4.50 severity=21.38, time=112.40.
# (pid=131) Warning: Vehicle 'flow_10.20' performs emergency braking with decel=-84.97 wished=4.50 severity=17.88, time=117.10.
# (pid=131) Warning: Vehicle 'flow_00.76' performs emergency braking with decel=-9.98 wished=4.50 severity=1.22, time=121.50.
# (pid=130) Warning: Vehicle 'flow_00.88' performs emergency braking with decel=-12.54 wished=4.50 severity=1.79, time=125.50.
# (pid=130) Warning: Vehicle 'flow_00.88' performs emergency braking with decel=-9.07 wished=4.50 severity=1.02, time=128.30.
# (pid=131) Warning: Vehicle 'flow_20.11' performs emergency braking with decel=-14.57 wished=4.50 severity=2.24, time=129.30.
# (pid=131) Warning: Vehicle 'flow_00.84' performs emergency braking with decel=-12.69 wished=4.50 severity=1.82, time=132.40.
# (pid=130) Warning: Vehicle 'flow_00.88' performs emergency braking with decel=-9.66 wished=4.50 severity=1.15, time=132.20.
# (pid=130) Warning: Vehicle 'flow_10.24' performs emergency braking with decel=-73.11 wished=4.50 severity=15.25, time=134.00.
# (pid=131) Warning: Vehicle 'flow_00.84' performs emergency braking with decel=-10.20 wished=4.50 severity=1.27, time=135.00.
# (pid=131) Warning: Vehicle 'flow_00.84' performs emergency braking with decel=-9.42 wished=4.50 severity=1.09, time=138.80.
# (pid=131) Warning: Vehicle 'flow_10.25' performs emergency braking with decel=-31.81 wished=4.50 severity=6.07, time=140.50.
# (pid=130) Warning: Vehicle 'flow_00.112' performs emergency braking with decel=-23.83 wished=4.50 severity=4.30, time=142.00.
# (pid=130) Warning: Vehicle 'flow_00.112' performs emergency braking with decel=-20.76 wished=4.50 severity=3.61, time=142.50.
# (pid=131) Warning: Vehicle 'flow_00.97' performs emergency braking with decel=-10.07 wished=4.50 severity=1.24, time=144.00.
# (pid=130) Warning: Vehicle 'flow_20.13' performs emergency braking with decel=-27.99 wished=4.50 severity=5.22, time=146.60.
# (pid=131) Warning: Vehicle 'flow_00.97' performs emergency braking with decel=-12.64 wished=4.50 severity=1.81, time=148.60.
# (pid=130) Warning: Vehicle 'flow_00.124' performs emergency braking with decel=-14.62 wished=4.50 severity=2.25, time=149.80.
# (pid=131) Warning: Vehicle 'flow_10.27' performs emergency braking with decel=-10.91 wished=4.50 severity=1.43, time=150.50.
# (pid=131) Warning: Vehicle 'flow_00.101' performs emergency braking with decel=-15.56 wished=4.50 severity=2.46, time=153.70.
# (pid=130) Warning: Vehicle 'flow_00.124' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=154.70.
# (pid=131) Warning: Vehicle 'flow_00.101' performs emergency braking with decel=-12.78 wished=4.50 severity=1.84, time=156.40.
# (pid=131) Warning: Vehicle 'flow_00.101' performs emergency braking with decel=-14.94 wished=4.50 severity=2.32, time=158.50.
# (pid=130) Warning: Vehicle 'flow_00.130' performs emergency braking with decel=-16.49 wished=4.50 severity=2.66, time=159.50.
# (pid=131) Warning: Vehicle 'flow_00.112' performs emergency braking with decel=-17.50 wished=4.50 severity=2.89, time=163.50.
# (pid=130) Warning: Vehicle 'flow_10.30' performs emergency braking with decel=-105.23 wished=4.50 severity=22.38, time=164.30.
# (pid=131) Warning: Vehicle 'flow_00.112' performs emergency braking with decel=-9.09 wished=4.50 severity=1.02, time=166.00.
# (pid=131) Warning: Vehicle 'flow_10.31' performs emergency braking with decel=-34.35 wished=4.50 severity=6.63, time=170.00.
# (pid=130) Warning: Vehicle 'flow_10.31' performs emergency braking with decel=-83.28 wished=4.50 severity=17.51, time=172.30.
# (pid=130) Warning: Vehicle 'flow_10.32' performs emergency braking with decel=-9.57 wished=4.50 severity=1.13, time=172.40.
# (pid=131) Warning: Vehicle 'flow_00.123' performs emergency braking with decel=-13.42 wished=4.50 severity=1.98, time=173.30.
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=131)   out=out, **kwargs)
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=131)   ret = ret.dtype.type(ret / rcount)
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=130)   out=out, **kwargs)
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=130)   ret = ret.dtype.type(ret / rcount)
# (pid=131) Warning: Vehicle 'flow_00.0' performs emergency braking with decel=-122.81 wished=4.50 severity=26.29, time=18.70.
# (pid=130) Warning: Vehicle 'flow_00.3' performs emergency braking with decel=-9.53 wished=4.50 severity=1.12, time=18.40.
# (pid=131) Warning: Vehicle 'flow_00.0' performs emergency braking with decel=-9.71 wished=4.50 severity=1.16, time=22.10.
# (pid=130) Warning: Vehicle 'flow_10.1' performs emergency braking with decel=-145.32 wished=4.50 severity=31.29, time=24.80.
# (pid=131) Warning: Vehicle 'flow_10.2' performs emergency braking with decel=-9.31 wished=4.50 severity=1.07, time=26.70.
# (pid=131) Warning: Vehicle 'flow_00.8' performs emergency braking with decel=-112.19 wished=4.50 severity=23.93, time=28.10.
# (pid=131) Warning: Vehicle 'flow_00.11' performs emergency braking with decel=-11.79 wished=4.50 severity=1.62, time=28.20.
# (pid=131) Warning: Vehicle 'flow_00.8' performs emergency braking with decel=-21.32 wished=4.50 severity=3.74, time=31.50.
# (pid=130) Warning: Vehicle 'flow_00.11' performs emergency braking with decel=-94.88 wished=4.50 severity=20.09, time=33.40.
# (pid=131) Warning: Vehicle 'flow_10.3' performs emergency braking with decel=-48.80 wished=4.50 severity=9.84, time=34.20.
# (pid=130) Warning: Vehicle 'flow_00.11' performs emergency braking with decel=-9.46 wished=4.50 severity=1.10, time=36.10.
# (pid=131) Warning: Vehicle 'flow_00.11' performs emergency braking with decel=-15.31 wished=4.50 severity=2.40, time=37.20.
# (pid=130) Warning: Vehicle 'flow_10.4' performs emergency braking with decel=-12.16 wished=4.50 severity=1.70, time=38.30.
# (pid=131) Warning: Vehicle 'flow_20.2' performs emergency braking with decel=-24.51 wished=4.50 severity=4.45, time=41.50.
# (pid=130) Warning: Vehicle 'flow_00.17' performs emergency braking with decel=-12.18 wished=4.50 severity=1.71, time=41.60.
# (pid=130) Warning: Vehicle 'flow_00.17' performs emergency braking with decel=-14.66 wished=4.50 severity=2.26, time=43.80.
# (pid=131) Warning: Vehicle 'flow_00.24' performs emergency braking with decel=-9.82 wished=4.50 severity=1.18, time=45.00.
# (pid=130) Warning: Vehicle 'flow_10.5' performs emergency braking with decel=-51.07 wished=4.50 severity=10.35, time=45.80.
# (pid=131) Warning: Vehicle 'flow_00.24' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=49.00.
# (pid=130) Warning: Vehicle 'flow_00.20' performs emergency braking with decel=-19.73 wished=4.50 severity=3.39, time=52.10.
# (pid=131) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-18.88 wished=4.50 severity=3.20, time=53.80.
# (pid=130) Warning: Vehicle 'flow_10.7' performs emergency braking with decel=-64.62 wished=4.50 severity=13.36, time=56.00.
# (pid=130) Warning: Vehicle 'flow_10.7' performs emergency braking with decel=-12.66 wished=4.50 severity=1.81, time=56.60.
# (pid=131) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-9.43 wished=4.50 severity=1.10, time=56.50.
# (pid=131) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-13.50 wished=4.50 severity=2.00, time=58.40.
# (pid=130) Warning: Vehicle 'flow_00.24' performs emergency braking with decel=-11.87 wished=4.50 severity=1.64, time=59.60.
# (pid=131) Warning: Vehicle 'flow_20.4' performs emergency braking with decel=-35.75 wished=4.50 severity=6.94, time=60.20.
# (pid=130) Warning: Vehicle 'flow_00.24' performs emergency braking with decel=-10.41 wished=4.50 severity=1.31, time=63.90.
# (pid=131) Warning: Vehicle 'flow_00.36' performs emergency braking with decel=-12.47 wished=4.50 severity=1.77, time=63.60.
# (pid=130) Warning: Vehicle 'flow_00.29' performs emergency braking with decel=-17.30 wished=4.50 severity=2.85, time=66.30.
# (pid=131) Warning: Vehicle 'flow_10.10' performs emergency braking with decel=-43.60 wished=4.50 severity=8.69, time=68.60.
# (pid=130) Warning: Vehicle 'flow_20.5' performs emergency braking with decel=-137.48 wished=4.50 severity=29.55, time=71.70.
# (pid=130) Warning: Vehicle 'flow_00.36' performs emergency braking with decel=-38.01 wished=4.50 severity=7.45, time=75.20.
# (pid=130) Warning: Vehicle 'flow_10.11' performs emergency braking with decel=-80.85 wished=4.50 severity=16.97, time=77.90.
# (pid=131) Warning: Vehicle 'flow_10.12' performs emergency braking with decel=-91.42 wished=4.50 severity=19.32, time=78.10.
# (pid=131) Warning: Vehicle 'flow_00.43' performs emergency braking with decel=-9.24 wished=4.50 severity=1.05, time=82.50.
# (pid=130) Warning: Vehicle 'flow_10.13' performs emergency braking with decel=-77.16 wished=4.50 severity=16.15, time=87.90.
# (pid=130) Warning: Vehicle 'flow_10.14' performs emergency braking with decel=-9.91 wished=4.50 severity=1.20, time=88.00.
# (pid=131) Warning: Vehicle 'flow_10.14' performs emergency braking with decel=-84.12 wished=4.50 severity=17.69, time=88.20.
# (pid=131) Warning: Vehicle 'flow_20.7' performs emergency braking with decel=-10.52 wished=4.50 severity=1.34, time=88.30.
# (pid=130) Warning: Vehicle 'flow_00.48' performs emergency braking with decel=-11.29 wished=4.50 severity=1.51, time=94.40.
# (pid=131) Warning: Vehicle 'flow_00.62' performs emergency braking with decel=-9.08 wished=4.50 severity=1.02, time=102.70.
# (pid=130) Warning: Vehicle 'flow_00.63' performs emergency braking with decel=-26.97 wished=4.50 severity=4.99, time=104.60.
# (pid=130) Warning: Vehicle 'flow_10.18' performs emergency braking with decel=-72.55 wished=4.50 severity=15.12, time=111.00.
# (pid=130) Warning: Vehicle 'flow_20.9' performs emergency braking with decel=-9.34 wished=4.50 severity=1.08, time=111.10.
# (pid=131) Warning: Vehicle 'flow_20.9' performs emergency braking with decel=-33.42 wished=4.50 severity=6.43, time=110.90.
# (pid=131) Warning: Vehicle 'flow_20.9' performs emergency braking with decel=-39.33 wished=4.50 severity=7.74, time=111.20.
# (pid=131) Warning: Vehicle 'flow_10.19' performs emergency braking with decel=-9.94 wished=4.50 severity=1.21, time=111.30.
# (pid=131) Warning: Vehicle 'flow_00.66' performs emergency braking with decel=-11.04 wished=4.50 severity=1.45, time=115.30.
# (pid=130) Warning: Vehicle 'flow_20.10' performs emergency braking with decel=-80.57 wished=4.50 severity=16.91, time=123.20.
# (pid=131) Warning: Vehicle 'flow_20.10' performs emergency braking with decel=-77.16 wished=4.50 severity=16.15, time=121.10.
# (pid=130) Warning: Vehicle 'flow_10.21' performs emergency braking with decel=-10.42 wished=4.50 severity=1.32, time=123.30.
# (pid=130) Warning: Vehicle 'flow_00.81' performs emergency braking with decel=-9.68 wished=4.50 severity=1.15, time=126.90.
# (pid=130) Warning: Vehicle 'flow_10.23' performs emergency braking with decel=-89.14 wished=4.50 severity=18.81, time=135.20.
# (pid=130) Warning: Vehicle 'flow_10.24' performs emergency braking with decel=-10.09 wished=4.50 severity=1.24, time=135.30.
# (pid=131) Warning: Vehicle 'flow_10.23' performs emergency braking with decel=-83.33 wished=4.50 severity=17.52, time=133.30.
# (pid=131) Warning: Vehicle 'flow_00.82' performs emergency braking with decel=-9.59 wished=4.50 severity=1.13, time=139.80.
# (pid=130) Warning: Vehicle 'flow_00.102' performs emergency braking with decel=-57.76 wished=4.50 severity=11.84, time=143.90.
# (pid=130) Warning: Vehicle 'flow_00.102' performs emergency braking with decel=-9.33 wished=4.50 severity=1.07, time=146.20.
# (pid=131) Warning: Vehicle 'flow_10.26' performs emergency braking with decel=-9.84 wished=4.50 severity=1.19, time=145.10.
# (pid=130) Warning: Vehicle 'flow_10.26' performs emergency braking with decel=-97.08 wished=4.50 severity=20.57, time=148.10.
# (pid=131) Warning: Vehicle 'flow_00.95' performs emergency braking with decel=-15.58 wished=4.50 severity=2.46, time=148.40.
# (pid=131) Warning: Vehicle 'flow_00.95' performs emergency braking with decel=-10.61 wished=4.50 severity=1.36, time=155.10.
# (pid=130) Warning: Vehicle 'flow_10.28' performs emergency braking with decel=-58.22 wished=4.50 severity=11.94, time=158.30.
# (pid=131) Warning: Vehicle 'flow_20.14' performs emergency braking with decel=-16.03 wished=4.50 severity=2.56, time=156.70.
# (pid=130) Warning: Vehicle 'flow_00.112' performs emergency braking with decel=-9.80 wished=4.50 severity=1.18, time=162.20.
# (pid=131) Warning: Vehicle 'flow_00.104' performs emergency braking with decel=-10.10 wished=4.50 severity=1.25, time=160.00.
# (pid=131) Warning: Vehicle 'flow_00.104' performs emergency braking with decel=-10.16 wished=4.50 severity=1.26, time=162.80.
# (pid=131) Warning: Vehicle 'flow_00.104' performs emergency braking with decel=-14.86 wished=4.50 severity=2.30, time=164.90.
# (pid=130) Warning: Vehicle 'flow_10.30' performs emergency braking with decel=-85.72 wished=4.50 severity=18.05, time=168.50.
# (pid=130) Warning: Vehicle 'flow_20.15' performs emergency braking with decel=-11.21 wished=4.50 severity=1.49, time=168.60.
# (pid=131) Warning: Vehicle 'flow_20.15' performs emergency braking with decel=-53.13 wished=4.50 severity=10.81, time=166.70.
# (pid=131) Warning: Vehicle 'flow_10.32' performs emergency braking with decel=-100.74 wished=4.50 severity=21.39, time=175.00.
# (pid=131) Warning: Vehicle 'flow_20.16' performs emergency braking with decel=-9.83 wished=4.50 severity=1.18, time=175.10.
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=130)   out=out, **kwargs)
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=130)   ret = ret.dtype.type(ret / rcount)
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=131)   out=out, **kwargs)
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=131)   ret = ret.dtype.type(ret / rcount)
# (pid=130) Warning: Vehicle 'flow_00.13' performs emergency braking with decel=-28.66 wished=4.50 severity=5.37, time=30.50.
# (pid=131) Warning: Vehicle 'flow_00.3' performs emergency braking with decel=-137.48 wished=4.50 severity=29.55, time=20.80.
# (pid=130) Warning: Vehicle 'flow_00.17' performs emergency braking with decel=-55.49 wished=4.50 severity=11.33, time=34.00.
# (pid=131) Warning: Vehicle 'flow_10.1' performs emergency braking with decel=-24.17 wished=4.50 severity=4.37, time=23.10.
# (pid=130) Warning: Vehicle 'flow_00.17' performs emergency braking with decel=-25.80 wished=4.50 severity=4.73, time=34.30.
# (pid=130) Warning: Vehicle 'flow_00.17' performs emergency braking with decel=-20.39 wished=4.50 severity=3.53, time=37.10.
# (pid=131) Warning: Vehicle 'flow_10.2' performs emergency braking with decel=-103.72 wished=4.50 severity=22.05, time=28.20.
# (pid=131) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-17.89 wished=4.50 severity=2.98, time=31.80.
# (pid=131) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-74.76 wished=4.50 severity=15.61, time=32.00.
# (pid=131) Warning: Vehicle 'flow_00.20' performs emergency braking with decel=-9.66 wished=4.50 severity=1.15, time=32.10.
# (pid=130) Warning: Vehicle 'flow_00.21' performs emergency braking with decel=-11.96 wished=4.50 severity=1.66, time=42.70.
# (pid=131) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-12.09 wished=4.50 severity=1.69, time=34.80.
# (pid=131) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-9.53 wished=4.50 severity=1.12, time=37.30.
# (pid=130) Warning: Vehicle 'flow_10.5' performs emergency braking with decel=-44.18 wished=4.50 severity=8.82, time=45.40.
# (pid=131) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-14.78 wished=4.50 severity=2.28, time=40.00.
# (pid=131) Warning: Vehicle 'flow_20.2' performs emergency braking with decel=-62.26 wished=4.50 severity=12.84, time=42.40.
# (pid=131) Warning: Vehicle 'flow_00.24' performs emergency braking with decel=-9.37 wished=4.50 severity=1.08, time=45.80.
# (pid=131) Warning: Vehicle 'flow_10.6' performs emergency braking with decel=-78.00 wished=4.50 severity=16.33, time=49.70.
# (pid=130) Warning: Vehicle 'flow_00.31' performs emergency braking with decel=-17.48 wished=4.50 severity=2.88, time=57.70.
# (pid=131) Warning: Vehicle 'flow_00.32' performs emergency braking with decel=-9.21 wished=4.50 severity=1.05, time=57.20.
# (pid=130) Warning: Vehicle 'flow_00.31' performs emergency braking with decel=-9.65 wished=4.50 severity=1.14, time=64.10.
# (pid=130) Warning: Vehicle 'flow_10.10' performs emergency braking with decel=-20.62 wished=4.50 severity=3.58, time=66.00.
# (pid=131) Warning: Vehicle 'flow_20.4' performs emergency braking with decel=-107.27 wished=4.50 severity=22.84, time=61.70.
# (pid=130) Warning: Vehicle 'flow_00.33' performs emergency braking with decel=-13.34 wished=4.50 severity=1.97, time=69.30.
# (pid=130) Warning: Vehicle 'flow_00.33' performs emergency braking with decel=-12.27 wished=4.50 severity=1.73, time=72.10.
# (pid=130) Warning: Vehicle 'flow_10.11' performs emergency braking with decel=-100.23 wished=4.50 severity=21.27, time=74.40.
# (pid=130) Warning: Vehicle 'flow_10.12' performs emergency braking with decel=-12.70 wished=4.50 severity=1.82, time=74.50.
# (pid=131) Warning: Vehicle 'flow_00.45' performs emergency braking with decel=-17.16 wished=4.50 severity=2.81, time=74.80.
# (pid=131) Warning: Vehicle 'flow_00.45' performs emergency braking with decel=-9.84 wished=4.50 severity=1.19, time=77.30.
# (pid=130) Warning: Vehicle 'flow_10.13' performs emergency braking with decel=-87.29 wished=4.50 severity=18.40, time=84.10.
# (pid=130) Warning: Vehicle 'flow_10.14' performs emergency braking with decel=-9.45 wished=4.50 severity=1.10, time=84.20.
# (pid=131) Warning: Vehicle 'flow_00.45' performs emergency braking with decel=-10.87 wished=4.50 severity=1.42, time=81.30.
# (pid=131) Warning: Vehicle 'flow_00.48' performs emergency braking with decel=-15.70 wished=4.50 severity=2.49, time=86.50.
# (pid=130) Warning: Vehicle 'flow_10.15' performs emergency braking with decel=-41.25 wished=4.50 severity=8.17, time=94.40.
# (pid=131) Warning: Vehicle 'flow_00.48' performs emergency braking with decel=-11.59 wished=4.50 severity=1.58, time=89.00.
# (pid=131) Warning: Vehicle 'flow_00.48' performs emergency braking with decel=-14.05 wished=4.50 severity=2.12, time=91.00.
# (pid=131) Warning: Vehicle 'flow_10.15' performs emergency braking with decel=-89.55 wished=4.50 severity=18.90, time=92.90.
# (pid=131) Warning: Vehicle 'flow_00.53' performs emergency braking with decel=-9.56 wished=4.50 severity=1.13, time=96.40.
# (pid=130) Warning: Vehicle 'flow_10.18' performs emergency braking with decel=-52.13 wished=4.50 severity=10.59, time=106.70.
# (pid=131) Warning: Vehicle 'flow_00.53' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=101.20.
# (pid=131) Warning: Vehicle 'flow_00.56' performs emergency braking with decel=-9.78 wished=4.50 severity=1.17, time=105.90.
# (pid=131) Warning: Vehicle 'flow_00.56' performs emergency braking with decel=-10.83 wished=4.50 severity=1.41, time=106.00.
# (pid=131) Warning: Vehicle 'flow_10.18' performs emergency braking with decel=-93.69 wished=4.50 severity=19.82, time=109.10.
# (pid=130) Warning: Vehicle 'flow_00.61' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=117.10.
# (pid=130) Warning: Vehicle 'flow_00.77' performs emergency braking with decel=-12.04 wished=4.50 severity=1.68, time=124.20.
# (pid=130) Warning: Vehicle 'flow_10.22' performs emergency braking with decel=-91.90 wished=4.50 severity=19.42, time=126.30.
# (pid=130) Warning: Vehicle 'flow_00.94' performs emergency braking with decel=-11.60 wished=4.50 severity=1.58, time=129.80.
# (pid=131) Warning: Vehicle 'flow_10.22' performs emergency braking with decel=-81.13 wished=4.50 severity=17.03, time=128.20.
# (pid=130) Warning: Vehicle 'flow_10.24' performs emergency braking with decel=-106.01 wished=4.50 severity=22.56, time=136.20.
# (pid=131) Warning: Vehicle 'flow_00.78' performs emergency braking with decel=-9.23 wished=4.50 severity=1.05, time=132.30.
# (pid=131) Warning: Vehicle 'flow_00.87' performs emergency braking with decel=-14.28 wished=4.50 severity=2.17, time=143.40.
# (pid=130) Warning: Vehicle 'flow_00.101' performs emergency braking with decel=-9.09 wished=4.50 severity=1.02, time=152.20.
# (pid=131) Warning: Vehicle 'flow_00.99' performs emergency braking with decel=-27.75 wished=4.50 severity=5.17, time=148.30.
# (pid=130) Warning: Vehicle 'flow_00.101' performs emergency braking with decel=-9.37 wished=4.50 severity=1.08, time=156.10.
# (pid=131) Warning: Vehicle 'flow_00.99' performs emergency braking with decel=-13.49 wished=4.50 severity=2.00, time=150.80.
# (pid=130) Warning: Vehicle 'flow_20.14' performs emergency braking with decel=-36.97 wished=4.50 severity=7.22, time=157.80.
# (pid=131) Warning: Vehicle 'flow_00.99' performs emergency braking with decel=-18.10 wished=4.50 severity=3.02, time=153.30.
# (pid=130) Warning: Vehicle 'flow_00.105' performs emergency braking with decel=-10.07 wished=4.50 severity=1.24, time=161.30.
# (pid=131) Warning: Vehicle 'flow_00.117' performs emergency braking with decel=-9.97 wished=4.50 severity=1.21, time=158.70.
# (pid=131) Warning: Vehicle 'flow_00.117' performs emergency braking with decel=-11.64 wished=4.50 severity=1.59, time=158.80.
# (pid=130) Warning: Vehicle 'flow_00.109' performs emergency braking with decel=-38.66 wished=4.50 severity=7.59, time=168.30.
# (pid=131) Warning: Vehicle 'flow_10.29' performs emergency braking with decel=-112.07 wished=4.50 severity=23.91, time=163.10.
# (pid=130) Warning: Vehicle 'flow_00.125' performs emergency braking with decel=-14.92 wished=4.50 severity=2.31, time=173.70.
# (pid=131) Warning: Vehicle 'flow_20.15' performs emergency braking with decel=-83.81 wished=4.50 severity=17.63, time=171.30.
# (pid=131) Warning: Vehicle 'flow_10.31' performs emergency braking with decel=-9.84 wished=4.50 severity=1.19, time=171.40.
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=130)   out=out, **kwargs)
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=130)   ret = ret.dtype.type(ret / rcount)
# (pid=130) Warning: Vehicle 'flow_00.2' performs emergency braking with decel=-135.24 wished=4.50 severity=29.05, time=19.10.
# (pid=130) Warning: Vehicle 'flow_00.3' performs emergency braking with decel=-9.54 wished=4.50 severity=1.12, time=19.20.
# (pid=130) Warning: Vehicle 'flow_20.0' performs emergency braking with decel=-124.31 wished=4.50 severity=26.62, time=22.40.
# (pid=130) Warning: Vehicle 'flow_20.0' performs emergency braking with decel=-17.60 wished=4.50 severity=2.91, time=25.10.
# (pid=130) Warning: Vehicle 'flow_00.8' performs emergency braking with decel=-23.60 wished=4.50 severity=4.25, time=26.70.
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=131)   out=out, **kwargs)
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=131)   ret = ret.dtype.type(ret / rcount)
# (pid=130) Warning: Vehicle 'flow_20.1' performs emergency braking with decel=-77.82 wished=4.50 severity=16.29, time=33.90.
# (pid=130) Warning: Vehicle 'flow_00.10' performs emergency braking with decel=-9.34 wished=4.50 severity=1.08, time=37.60.
# (pid=131) Warning: Vehicle 'flow_00.2' performs emergency braking with decel=-124.63 wished=4.50 severity=26.70, time=20.40.
# (pid=130) Warning: Vehicle 'flow_00.10' performs emergency braking with decel=-9.97 wished=4.50 severity=1.22, time=40.30.
# (pid=131) Warning: Vehicle 'flow_00.6' performs emergency braking with decel=-104.71 wished=4.50 severity=22.27, time=25.40.
# (pid=131) Warning: Vehicle 'flow_00.10' performs emergency braking with decel=-12.46 wished=4.50 severity=1.77, time=25.50.
# (pid=131) Warning: Vehicle 'flow_20.1' performs emergency braking with decel=-21.11 wished=4.50 severity=3.69, time=27.80.
# (pid=130) Warning: Vehicle 'flow_00.10' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=44.30.
# (pid=131) Warning: Vehicle 'flow_00.10' performs emergency braking with decel=-15.14 wished=4.50 severity=2.36, time=30.10.
# (pid=131) Warning: Vehicle 'flow_00.10' performs emergency braking with decel=-11.27 wished=4.50 severity=1.51, time=33.00.
# (pid=130) Warning: Vehicle 'flow_00.14' performs emergency braking with decel=-15.69 wished=4.50 severity=2.49, time=49.10.
# (pid=131) Warning: Vehicle 'flow_00.14' performs emergency braking with decel=-14.91 wished=4.50 severity=2.31, time=39.90.
# (pid=130) Warning: Vehicle 'flow_10.7' performs emergency braking with decel=-108.40 wished=4.50 severity=23.09, time=55.70.
# (pid=130) Warning: Vehicle 'flow_10.8' performs emergency braking with decel=-9.78 wished=4.50 severity=1.17, time=55.80.
# (pid=131) Warning: Vehicle 'flow_00.20' performs emergency braking with decel=-28.32 wished=4.50 severity=5.29, time=44.60.
# ...
#         entropy: 0.0
#         entropy_coeff: 0.0
#         kl: 0.0
#         policy_loss: 0.00036239318433217704
#         total_loss: 60942.28125
#         vf_explained_var: -2.3230528256590333e-07
#         vf_loss: 60942.28125
#     load_time_ms: 1555.068
#     num_steps_sampled: 20000
#     num_steps_trained: 19968
#     sample_time_ms: 328654.78
#     update_time_ms: 1019.005
#   iterations_since_restore: 1
#   node_ip: 192.168.0.24
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 36.56721991701245
#     ram_util_percent: 50.23983402489627
#   pid: 129
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 21.22187644240261
#     mean_inference_ms: 1.0082252191765377
#     mean_processing_ms: 9.841986625579079
#   time_since_restore: 337.48589301109314
#   time_this_iter_s: 337.48589301109314
#   time_total_s: 337.48589301109314
#   timestamp: 1584460831
#   timesteps_since_restore: 20000
#   timesteps_this_iter: 20000
#   timesteps_total: 20000
#   training_iteration: 1
#   trial_id: 99c8a8de
#
# (pid=129) 2020-03-17 12:00:31,905	WARNING ppo.py:140 -- The magnitude of your environment rewards are more than 875.0x the scale of `vf_clip_param`. This means that it will take more than 875.0 iterations for your value function to converge. If this is not intended, consider increasing `vf_clip_param`.
# == Status ==<br>Memory usage on this node: 8.2/15.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3/3 CPUs, 0/0 GPUs, 0.0/5.62 GiB heap, 0.0/1.95 GiB objects<br>Result logdir: /home/llavezzo/ray_results/merge<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc             </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  timesteps</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_99c8a8de</td><td>RUNNING </td><td>192.168.0.24:129</td><td style="text-align: right;">     1</td><td style="text-align: right;">         337.486</td><td style="text-align: right;">      20000</td><td style="text-align: right;"> 8751.61</td></tr>
# </tbody>
# </table><br><br>
# (pid=131) Warning: Vehicle 'flow_00.41' performs emergency braking with decel=-9.85 wished=4.50 severity=1.19, time=76.80.
# (pid=130) Warning: Vehicle 'flow_00.47' performs emergency braking with decel=-43.23 wished=4.50 severity=8.61, time=78.80.
# (pid=131) Warning: Vehicle 'flow_10.12' performs emergency braking with decel=-29.18 wished=4.50 severity=5.49, time=81.00.
# (pid=130) Warning: Vehicle 'flow_10.14' performs emergency braking with decel=-18.31 wished=4.50 severity=3.07, time=82.40.
# (pid=131) Warning: Vehicle 'flow_00.46' performs emergency braking with decel=-12.65 wished=4.50 severity=1.81, time=84.30.
# (pid=131) Warning: Vehicle 'flow_00.46' performs emergency braking with decel=-11.07 wished=4.50 severity=1.46, time=88.60.
# (pid=131) Warning: Vehicle 'flow_10.14' performs emergency braking with decel=-97.76 wished=4.50 severity=20.72, time=90.80.
# (pid=131) Warning: Vehicle 'flow_20.7' performs emergency braking with decel=-10.71 wished=4.50 severity=1.38, time=90.90.
# (pid=130) Warning: Vehicle 'flow_00.53' performs emergency braking with decel=-13.16 wished=4.50 severity=1.92, time=90.80.
# (pid=130) Warning: Vehicle 'flow_10.16' performs emergency braking with decel=-60.86 wished=4.50 severity=12.52, time=92.90.
# (pid=131) Warning: Vehicle 'flow_00.51' performs emergency braking with decel=-11.80 wished=4.50 severity=1.62, time=94.50.
# (pid=130) Warning: Vehicle 'flow_00.60' performs emergency braking with decel=-9.41 wished=4.50 severity=1.09, time=96.40.
# (pid=131) Warning: Vehicle 'flow_00.51' performs emergency braking with decel=-9.54 wished=4.50 severity=1.12, time=98.50.
# (pid=131) Warning: Vehicle 'flow_10.16' performs emergency braking with decel=-84.48 wished=4.50 severity=17.77, time=100.30.
# (pid=131) Warning: Vehicle 'flow_00.55' performs emergency braking with decel=-10.93 wished=4.50 severity=1.43, time=103.90.
# (pid=130) Warning: Vehicle 'flow_10.18' performs emergency braking with decel=-99.73 wished=4.50 severity=21.16, time=102.80.
# (pid=131) Warning: Vehicle 'flow_00.55' performs emergency braking with decel=-9.95 wished=4.50 severity=1.21, time=106.40.
# (pid=131) Warning: Vehicle 'flow_10.18' performs emergency braking with decel=-100.08 wished=4.50 severity=21.24, time=110.40.
# (pid=131) Warning: Vehicle 'flow_20.9' performs emergency braking with decel=-10.35 wished=4.50 severity=1.30, time=110.50.
# (pid=131) Warning: Vehicle 'flow_00.84' performs emergency braking with decel=-11.13 wished=4.50 severity=1.47, time=118.60.
# (pid=130) Warning: Vehicle 'flow_00.66' performs emergency braking with decel=-9.40 wished=4.50 severity=1.09, time=116.20.
# (pid=131) Warning: Vehicle 'flow_00.84' performs emergency braking with decel=-16.63 wished=4.50 severity=2.70, time=121.40.
# (pid=131) Warning: Vehicle 'flow_00.84' performs emergency braking with decel=-12.09 wished=4.50 severity=1.69, time=123.80.
# (pid=131) Warning: Vehicle 'flow_10.21' performs emergency braking with decel=-127.47 wished=4.50 severity=27.33, time=125.90.
# (pid=130) Warning: Vehicle 'flow_00.66' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=122.90.
# (pid=131) Warning: Vehicle 'flow_00.87' performs emergency braking with decel=-37.19 wished=4.50 severity=7.26, time=129.30.
# (pid=130) Warning: Vehicle 'flow_00.71' performs emergency braking with decel=-12.30 wished=4.50 severity=1.73, time=127.70.
# (pid=130) Warning: Vehicle 'flow_10.24' performs emergency braking with decel=-12.01 wished=4.50 severity=1.67, time=132.40.
# (pid=131) Warning: Vehicle 'flow_00.96' performs emergency braking with decel=-9.66 wished=4.50 severity=1.15, time=137.10.
# (pid=131) Warning: Vehicle 'flow_00.96' performs emergency braking with decel=-15.61 wished=4.50 severity=2.47, time=137.20.
# (pid=131) Warning: Vehicle 'flow_00.96' performs emergency braking with decel=-9.56 wished=4.50 severity=1.12, time=139.70.
# (pid=130) Warning: Vehicle 'flow_10.25' performs emergency braking with decel=-91.38 wished=4.50 severity=19.31, time=139.50.
# (pid=131) Warning: Vehicle 'flow_00.96' performs emergency braking with decel=-11.79 wished=4.50 severity=1.62, time=143.90.
# (pid=131) Warning: Vehicle 'flow_10.25' performs emergency braking with decel=-19.20 wished=4.50 severity=3.27, time=145.50.
# (pid=130) Warning: Vehicle 'flow_10.25' performs emergency braking with decel=-19.33 wished=4.50 severity=3.30, time=142.00.
# (pid=130) Warning: Vehicle 'flow_00.98' performs emergency braking with decel=-56.98 wished=4.50 severity=11.66, time=143.70.
# (pid=131) Warning: Vehicle 'flow_00.102' performs emergency braking with decel=-12.37 wished=4.50 severity=1.75, time=148.90.
# (pid=130) Warning: Vehicle 'flow_00.98' performs emergency braking with decel=-10.79 wished=4.50 severity=1.40, time=147.30.
# (pid=131) Warning: Vehicle 'flow_00.119' performs emergency braking with decel=-45.10 wished=4.50 severity=9.02, time=154.10.
# (pid=130) Warning: Vehicle 'flow_20.13' performs emergency braking with decel=-49.91 wished=4.50 severity=10.09, time=149.50.
# (pid=131) Warning: Vehicle 'flow_10.27' performs emergency braking with decel=-112.98 wished=4.50 severity=24.11, time=156.40.
# (pid=131) Warning: Vehicle 'flow_00.115' performs emergency braking with decel=-16.41 wished=4.50 severity=2.65, time=159.50.
# (pid=131) Warning: Vehicle 'flow_20.14' performs emergency braking with decel=-77.77 wished=4.50 severity=16.28, time=164.60.
# (pid=130) Warning: Vehicle 'flow_20.14' performs emergency braking with decel=-61.77 wished=4.50 severity=12.73, time=160.40.
# (pid=130) Warning: Vehicle 'flow_00.114' performs emergency braking with decel=-9.38 wished=4.50 severity=1.09, time=165.00.
# (pid=130) Warning: Vehicle 'flow_00.114' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=167.30.
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=131)   out=out, **kwargs)
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=131)   ret = ret.dtype.type(ret / rcount)
# (pid=131) Warning: Vehicle 'flow_10.0' performs emergency braking with decel=-14.15 wished=4.50 severity=2.14, time=17.00.
# (pid=131) Warning: Vehicle 'flow_10.1' performs emergency braking with decel=-120.67 wished=4.50 severity=25.82, time=25.40.
# (pid=131) Warning: Vehicle 'flow_10.2' performs emergency braking with decel=-10.79 wished=4.50 severity=1.40, time=25.50.
# (pid=131) Warning: Vehicle 'flow_10.1' performs emergency braking with decel=-14.88 wished=4.50 severity=2.31, time=27.40.
# (pid=131) Warning: Vehicle 'flow_00.11' performs emergency braking with decel=-11.15 wished=4.50 severity=1.48, time=28.70.
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=130)   out=out, **kwargs)
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=130)   ret = ret.dtype.type(ret / rcount)
# (pid=131) Warning: Vehicle 'flow_00.11' performs emergency braking with decel=-51.53 wished=4.50 severity=10.45, time=31.70.
# (pid=131) Warning: Vehicle 'flow_00.11' performs emergency braking with decel=-13.65 wished=4.50 severity=2.03, time=32.50.
# (pid=130) Warning: Vehicle 'flow_10.0' performs emergency braking with decel=-11.47 wished=4.50 severity=1.55, time=18.00.
# (pid=130) Warning: Vehicle 'flow_00.4' performs emergency braking with decel=-14.31 wished=4.50 severity=2.18, time=18.90.
# (pid=131) Warning: Vehicle 'flow_00.11' performs emergency braking with decel=-10.93 wished=4.50 severity=1.43, time=36.40.
# (pid=131) Warning: Vehicle 'flow_10.4' performs emergency braking with decel=-39.16 wished=4.50 severity=7.70, time=37.90.
# (pid=130) Warning: Vehicle 'flow_10.1' performs emergency braking with decel=-102.24 wished=4.50 severity=21.72, time=28.00.
# (pid=130) Warning: Vehicle 'flow_10.2' performs emergency braking with decel=-14.05 wished=4.50 severity=2.12, time=28.10.
# (pid=130) Warning: Vehicle 'flow_10.1' performs emergency braking with decel=-19.80 wished=4.50 severity=3.40, time=30.20.
# (pid=130) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-10.29 wished=4.50 severity=1.29, time=31.70.
# (pid=131) Warning: Vehicle 'flow_00.14' performs emergency braking with decel=-9.30 wished=4.50 severity=1.07, time=46.00.
# (pid=130) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-80.29 wished=4.50 severity=16.84, time=35.30.
# (pid=130) Warning: Vehicle 'flow_00.20' performs emergency braking with decel=-9.45 wished=4.50 severity=1.10, time=35.40.
# (pid=131) Warning: Vehicle 'flow_10.6' performs emergency braking with decel=-104.03 wished=4.50 severity=22.12, time=48.20.
# (pid=131) Warning: Vehicle 'flow_00.69' performs emergency braking with decel=-10.89 wished=4.50 severity=1.42, time=50.70.
# (pid=131) Warning: Vehicle 'flow_00.22' performs emergency braking with decel=-48.35 wished=4.50 severity=9.75, time=51.50.
# (pid=130) Warning: Vehicle 'flow_10.4' performs emergency braking with decel=-50.13 wished=4.50 severity=10.14, time=41.50.
# (pid=131) Warning: Vehicle 'flow_10.8' performs emergency braking with decel=-12.76 wished=4.50 severity=1.84, time=58.40.
# (pid=131) Warning: Vehicle 'flow_00.31' performs emergency braking with decel=-11.56 wished=4.50 severity=1.57, time=61.80.
# (pid=130) Warning: Vehicle 'flow_20.3' performs emergency braking with decel=-73.26 wished=4.50 severity=15.28, time=53.80.
# (pid=131) Warning: Vehicle 'flow_00.31' performs emergency braking with decel=-9.11 wished=4.50 severity=1.03, time=68.20.
# (pid=130) Warning: Vehicle 'flow_00.25' performs emergency braking with decel=-9.32 wished=4.50 severity=1.07, time=60.30.
# (pid=131) Warning: Vehicle 'flow_20.5' performs emergency braking with decel=-26.81 wished=4.50 severity=4.96, time=70.10.
# (pid=131) Warning: Vehicle 'flow_00.38' performs emergency braking with decel=-9.26 wished=4.50 severity=1.06, time=73.50.
# (pid=130) Warning: Vehicle 'flow_10.9' performs emergency braking with decel=-35.54 wished=4.50 severity=6.90, time=65.70.
# (pid=131) Warning: Vehicle 'flow_00.38' performs emergency braking with decel=-9.14 wished=4.50 severity=1.03, time=76.20.
# (pid=131) Warning: Vehicle 'flow_00.38' performs emergency braking with decel=-12.70 wished=4.50 severity=1.82, time=78.10.
# (pid=130) Warning: Vehicle 'flow_00.33' performs emergency braking with decel=-9.41 wished=4.50 severity=1.09, time=71.50.
# (pid=131) Warning: Vehicle 'flow_20.6' performs emergency braking with decel=-110.11 wished=4.50 severity=23.47, time=80.10.
# (pid=130) Warning: Vehicle 'flow_20.5' performs emergency braking with decel=-88.37 wished=4.50 severity=18.64, time=73.70.
# (pid=130) Warning: Vehicle 'flow_10.11' performs emergency braking with decel=-10.55 wished=4.50 severity=1.35, time=73.80.
# (pid=131) Warning: Vehicle 'flow_00.44' performs emergency braking with decel=-43.11 wished=4.50 severity=8.58, time=85.70.
# (pid=131) Warning: Vehicle 'flow_10.14' performs emergency braking with decel=-94.26 wished=4.50 severity=19.95, time=87.80.
# (pid=130) Warning: Vehicle 'flow_10.12' performs emergency braking with decel=-16.22 wished=4.50 severity=2.60, time=82.20.
# (pid=130) Warning: Vehicle 'flow_00.52' performs emergency braking with decel=-11.43 wished=4.50 severity=1.54, time=85.60.
# (pid=131) Warning: Vehicle 'flow_10.16' performs emergency braking with decel=-27.81 wished=4.50 severity=5.18, time=97.60.
# (pid=130) Warning: Vehicle 'flow_20.7' performs emergency braking with decel=-78.16 wished=4.50 severity=16.37, time=94.00.
# (pid=131) Warning: Vehicle 'flow_00.63' performs emergency braking with decel=-22.26 wished=4.50 severity=3.95, time=105.80.
# (pid=130) Warning: Vehicle 'flow_00.66' performs emergency braking with decel=-42.66 wished=4.50 severity=8.48, time=101.60.
# (pid=131) Warning: Vehicle 'flow_00.63' performs emergency braking with decel=-10.64 wished=4.50 severity=1.36, time=108.90.
# (pid=130) Warning: Vehicle 'flow_20.8' performs emergency braking with decel=-85.19 wished=4.50 severity=17.93, time=103.70.
# (pid=131) Warning: Vehicle 'flow_10.19' performs emergency braking with decel=-119.61 wished=4.50 severity=25.58, time=113.20.
# (pid=131) Warning: Vehicle 'flow_00.69' performs emergency braking with decel=-29.55 wished=4.50 severity=5.57, time=116.50.
# (pid=130) Warning: Vehicle 'flow_20.9' performs emergency braking with decel=-77.06 wished=4.50 severity=16.12, time=113.80.
# (pid=131) Warning: Vehicle 'flow_20.10' performs emergency braking with decel=-81.21 wished=4.50 severity=17.05, time=121.40.
# (pid=130) Warning: Vehicle 'flow_00.78' performs emergency braking with decel=-9.10 wished=4.50 severity=1.02, time=117.60.
# (pid=130) Warning: Vehicle 'flow_00.78' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=124.20.
# (pid=131) Warning: Vehicle 'flow_10.23' performs emergency braking with decel=-37.02 wished=4.50 severity=7.23, time=133.30.
# (pid=130) Warning: Vehicle 'flow_00.93' performs emergency braking with decel=-53.32 wished=4.50 severity=10.85, time=133.40.
# (pid=130) Warning: Vehicle 'flow_00.93' performs emergency braking with decel=-11.80 wished=4.50 severity=1.62, time=137.40.
# (pid=130) Warning: Vehicle 'flow_20.12' performs emergency braking with decel=-68.82 wished=4.50 severity=14.29, time=141.00.
# (pid=131) Warning: Vehicle 'flow_10.26' performs emergency braking with decel=-35.72 wished=4.50 severity=6.94, time=145.20.
# (pid=130) Warning: Vehicle 'flow_00.105' performs emergency braking with decel=-10.72 wished=4.50 severity=1.38, time=144.40.
# (pid=130) Warning: Vehicle 'flow_00.105' performs emergency braking with decel=-12.44 wished=4.50 severity=1.76, time=149.00.
