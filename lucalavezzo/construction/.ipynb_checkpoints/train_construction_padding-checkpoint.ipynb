# %%
import os
import json
import ray
import numpy as np
from ray.rllib.agents.registry import get_agent_class
from ray.tune import run_experiments
from ray.tune.registry import register_env
from flow.networks import Network
from flow.networks.ring import RingNetwork, ADDITIONAL_NET_PARAMS
from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder
from flow.core.params import SumoParams, EnvParams, InitialConfig, NetParams, VehicleParams, SumoCarFollowingParams, InFlows, SumoLaneChangeParams
from flow.controllers import RLController, IDMController, SimLaneChangeController
from gym.spaces.box import Box
from gym.spaces import Tuple

from constructionRouter import ConstructionRouter
from env_constructionV4_padding import myEnv

# time horizon of a single rollout
HORIZON = 5000
# number of rollouts per training iteration
N_ROLLOUTS = 10
# number of parallel workers
N_CPUS = 2

vehicles = VehicleParams()
vehicles.add("rl",
             acceleration_controller=(RLController, {}),
             lane_change_controller=(SimLaneChangeController, {}),
             routing_controller=(ConstructionRouter, {}),
             car_following_params=SumoCarFollowingParams(
                 speed_mode="obey_safe_speed",  
             ),
             num_vehicles=10
             )
vehicles.add("human",
             acceleration_controller=(IDMController, {}),
             lane_change_controller=(SimLaneChangeController, {}),
             car_following_params=SumoCarFollowingParams(
                 speed_mode=25
             ),
             lane_change_params = SumoLaneChangeParams(lane_change_mode=1621),
             num_vehicles=0)

# specify the edges vehicles can originate on
initial_config = InitialConfig(
    edges_distribution=["gneE43"]
)

# specify the routes for vehicles in the network
class Network(Network):

    def specify_routes(self, net_params):
        return {
                "gneE43": ["gneE43","gneE4.264","gneE4.264.110","gneE8","gneE9","gneE9.252","gneE33"],
               "gneE8": ["gneE8","gneE9","gneE37","gneE38","gneE39","gneE4.264.110","gneE8"]
               }


inflow = InFlows()
inflow.add(veh_type="human",
           edge="gneE43",
           vehs_per_hour=10000,
            depart_lane="random",
            depart_speed="random",
            color="white")

file_dir = "/home/llavezzo/"
net_params = NetParams(
    template="/mnt/c/Users/llave/Documents/GitHub/flow_osuphysics/lucalavezzo/construction/constructionV4.net.xml",
    inflows=inflow
)

flow_params = dict(
    # name of the experiment
    exp_tag="construction_traffic",

    # name of the flow environment the experiment is running on
    env_name=myEnv,  # <------ here we replace the environment with our new environment

    # name of the network class the experiment is running on
    network=Network,

    # simulator that is used by the experiment
    simulator='traci',

    # sumo-related parameters (see flow.core.params.SumoParams)
    sim=SumoParams(
        sim_step=0.5,
        render=False,
        restart_instance=True
    ),

    # environment related parameters (see flow.core.params.EnvParams)
    env=EnvParams(
        horizon=HORIZON,
        warmup_steps=1000,
        clip_actions=False,
        additional_params={
            "target_velocity": 50,
            "sort_vehicles": False,
            "max_accel": 2,
            "max_decel": 2,
        },
    ),

    # network-related parameters (see flow.core.params.NetParams and the
    # network's documentation or ADDITIONAL_NET_PARAMS component)
    net=net_params,

    # vehicles to be placed in the network at the start of a rollout (see
    # flow.core.params.VehicleParams)
    veh=vehicles,

    # parameters specifying the positioning of vehicles upon initialization/
    # reset (see flow.core.params.InitialConfig)
    initial=initial_config
)


def setup_exps():
    """Return the relevant components of an RLlib experiment.

    Returns
    -------
    str
        name of the training algorithm
    str
        name of the gym environment to be trained
    dict
        training configuration parameters
    """
    alg_run = "PPO"

    agent_cls = get_agent_class(alg_run)
    config = agent_cls._default_config.copy()
    config["num_workers"] = N_CPUS
    config["train_batch_size"] = HORIZON * N_ROLLOUTS
    config["gamma"] = 0.999  # discount rate
    config["model"].update({"fcnet_hiddens": [16, 16, 16, 16]})
    config["use_gae"] = True
    config["lambda"] = 0.97
    config["kl_target"] = 0.02
    config["num_sgd_iter"] = 10
    config['clip_actions'] = False  # FIXME(ev) temporary ray bug
    config["horizon"] = HORIZON

    # save the flow params for replay
    flow_json = json.dumps(
        flow_params, cls=FlowParamsEncoder, sort_keys=True, indent=4)
    config['env_config']['flow_params'] = flow_json
    config['env_config']['run'] = alg_run

    create_env, gym_name = make_create_env(params=flow_params, version=0)

    # Register as rllib env
    register_env(gym_name, create_env)
    return alg_run, gym_name, config

# %%
alg_run, gym_name, config = setup_exps()
ray.init(num_cpus=N_CPUS + 1)
trials = run_experiments({
    flow_params["exp_tag"]: {
        "run": alg_run,
        "env": gym_name,
        "config": {
            **config
        },
        "checkpoint_freq": 5,
        "checkpoint_at_end": True,
        "max_failures": 999,
        "stop": {
            "training_iteration": 200,
        },
    }
})
# Out:
# 2020-03-25 09:35:43,786	WARNING services.py:592 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2020-03-25 09:35:43,790	INFO resource_spec.py:212 -- Starting Ray with 4.69 GiB memory available for workers and up to 2.36 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-03-25 09:35:44,213	WARNING services.py:1080 -- Failed to start the dashboard. The dashboard requires Python 3 as well as 'pip install aiohttp psutil setproctitle grpcio'.
# == Status ==<br>Memory usage on this node: 8.2/15.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3/3 CPUs, 0/0 GPUs, 0.0/4.69 GiB heap, 0.0/1.61 GiB objects<br>Result logdir: /home/llavezzo/ray_results/construction_traffic<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_8770493a</td><td>RUNNING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (pid=raylet) E0325 09:35:44.451950900     107 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1585143344.451935900","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=raylet) E0325 09:35:44.452209800     107 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=raylet) E0325 09:35:44.470990600     107 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=130) E0325 09:35:45.661735300     130 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1585143345.661725100","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=130) E0325 09:35:45.661854800     130 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=131) E0325 09:35:45.674507500     131 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1585143345.674494100","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=131) E0325 09:35:45.674669200     131 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=129) E0325 09:35:45.681970300     129 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1585143345.681961600","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=129) E0325 09:35:45.682083900     129 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=130) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=130)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=130) 2020-03-25 09:35:48,108	INFO trainer.py:370 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# 2020-03-25 09:35:48,740	ERROR trial_runner.py:480 -- Trial PPO_myEnv-v0_8770493a: Error processing event.
# Traceback (most recent call last):
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py", line 424, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/ray_trial_executor.py", line 377, in fetch_result
#     result = ray.get(trial_future[0], DEFAULT_GET_TIMEOUT)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/worker.py", line 1492, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(FileNotFoundError): ray::PPO.__init__() (pid=130, ip=192.168.0.24)
#   File "python/ray/_raylet.pyx", line 630, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 637, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 638, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 643, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 623, in function_executor
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer_template.py", line 83, in __init__
#     Trainer.__init__(self, config, env, logger_creator)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 397, in __init__
#     Trainable.__init__(self, config, logger_creator)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/trainable.py", line 172, in __init__
#     self._setup(copy.deepcopy(self.config))
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 528, in _setup
#     self._init(self.config, self.env_creator)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer_template.py", line 102, in _init
#     self.config["num_workers"])
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 573, in _make_workers
#     logdir=self.logdir)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/worker_set.py", line 60, in __init__
#     RolloutWorker, env_creator, policy, 0, self._local_config)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/worker_set.py", line 216, in _make_worker
#     _fake_sampler=config.get("_fake_sampler", False))
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/rollout_worker.py", line 269, in __init__
#     self.env = _validate_env(env_creator(env_context))
#   File "/mnt/c/Users/llave/Documents/GitHub/flow/flow/utils/registry.py", line 130, in create_env
#     return gym.envs.make(env_name)
#   File "/home/llavezzo/.local/lib/python3.6/site-packages/gym/envs/registration.py", line 156, in make
#     return registry.make(id, **kwargs)
#   File "/home/llavezzo/.local/lib/python3.6/site-packages/gym/envs/registration.py", line 101, in make
#     env = spec.make(**kwargs)
#   File "/home/llavezzo/.local/lib/python3.6/site-packages/gym/envs/registration.py", line 73, in make
#     env = cls(**_kwargs)
#   File "/mnt/c/Users/llave/Documents/GitHub/flow/flow/envs/base.py", line 163, in __init__
#     self.k.network.generate_network(self.network)
#   File "/mnt/c/Users/llave/Documents/GitHub/flow/flow/core/kernel/network/traci.py", line 124, in generate_network
#     self.network.net_params)
#   File "/mnt/c/Users/llave/Documents/GitHub/flow/flow/core/kernel/network/traci.py", line 613, in generate_net_from_template
#     edges_dict, conn_dict = self._import_edges_from_net(net_params)
#   File "/mnt/c/Users/llave/Documents/GitHub/flow/flow/core/kernel/network/traci.py", line 843, in _import_edges_from_net
#     tree = ElementTree.parse(net_path, parser=parser)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/xml/etree/ElementTree.py", line 1196, in parse
#     tree.parse(source, parser)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/xml/etree/ElementTree.py", line 586, in parse
#     source = open(source, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/c/Users/llave/Documents/GitHub/flow_osuphysics/lucalavezzo/constructionV4.net.xml'
# 2020-03-25 09:35:48,757	INFO trial_runner.py:547 -- Trial PPO_myEnv-v0_8770493a: Attempting to restore trial state from last checkpoint.
# (pid=130) 2020-03-25 09:35:48,625	INFO trainer.py:517 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=129) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=129)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=129) 2020-03-25 09:35:51,254	INFO trainer.py:370 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# 2020-03-25 09:35:51,775	ERROR trial_runner.py:480 -- Trial PPO_myEnv-v0_8770493a: Error processing event.
# Traceback (most recent call last):
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py", line 424, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/ray_trial_executor.py", line 377, in fetch_result
#     result = ray.get(trial_future[0], DEFAULT_GET_TIMEOUT)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/worker.py", line 1492, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(FileNotFoundError): ray::PPO.__init__() (pid=129, ip=192.168.0.24)
#   File "python/ray/_raylet.pyx", line 630, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 637, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 638, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 643, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 623, in function_executor
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer_template.py", line 83, in __init__
#     Trainer.__init__(self, config, env, logger_creator)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 397, in __init__
#     Trainable.__init__(self, config, logger_creator)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/trainable.py", line 172, in __init__
#     self._setup(copy.deepcopy(self.config))
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 528, in _setup
#     self._init(self.config, self.env_creator)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer_template.py", line 102, in _init
#     self.config["num_workers"])
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 573, in _make_workers
#     logdir=self.logdir)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/worker_set.py", line 60, in __init__
#     RolloutWorker, env_creator, policy, 0, self._local_config)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/worker_set.py", line 216, in _make_worker
#     _fake_sampler=config.get("_fake_sampler", False))
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/rollout_worker.py", line 269, in __init__
#     self.env = _validate_env(env_creator(env_context))
#   File "/mnt/c/Users/llave/Documents/GitHub/flow/flow/utils/registry.py", line 130, in create_env
#     return gym.envs.make(env_name)
#   File "/home/llavezzo/.local/lib/python3.6/site-packages/gym/envs/registration.py", line 156, in make
#     return registry.make(id, **kwargs)
#   File "/home/llavezzo/.local/lib/python3.6/site-packages/gym/envs/registration.py", line 101, in make
#     env = spec.make(**kwargs)
#   File "/home/llavezzo/.local/lib/python3.6/site-packages/gym/envs/registration.py", line 73, in make
#     env = cls(**_kwargs)
#   File "/mnt/c/Users/llave/Documents/GitHub/flow/flow/envs/base.py", line 163, in __init__
#     self.k.network.generate_network(self.network)
#   File "/mnt/c/Users/llave/Documents/GitHub/flow/flow/core/kernel/network/traci.py", line 124, in generate_network
#     self.network.net_params)
#   File "/mnt/c/Users/llave/Documents/GitHub/flow/flow/core/kernel/network/traci.py", line 613, in generate_net_from_template
#     edges_dict, conn_dict = self._import_edges_from_net(net_params)
#   File "/mnt/c/Users/llave/Documents/GitHub/flow/flow/core/kernel/network/traci.py", line 843, in _import_edges_from_net
#     tree = ElementTree.parse(net_path, parser=parser)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/xml/etree/ElementTree.py", line 1196, in parse
#     tree.parse(source, parser)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/xml/etree/ElementTree.py", line 586, in parse
#     source = open(source, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/c/Users/llave/Documents/GitHub/flow_osuphysics/lucalavezzo/constructionV4.net.xml'
# 2020-03-25 09:35:51,785	INFO trial_runner.py:547 -- Trial PPO_myEnv-v0_8770493a: Attempting to restore trial state from last checkpoint.
# (pid=129) 2020-03-25 09:35:51,749	INFO trainer.py:517 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# == Status ==<br>Memory usage on this node: 8.6/15.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3/3 CPUs, 0/0 GPUs, 0.0/4.69 GiB heap, 0.0/1.61 GiB objects<br>Result logdir: /home/llavezzo/ray_results/construction_traffic<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_8770493a</td><td>RUNNING </td><td>     </td></tr>
# </tbody>
# </table><br>Number of errored trials: 1<br><table>
# <thead>
# <tr><th>Trial name           </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                 </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_8770493a</td><td style="text-align: right;">           2</td><td>/home/llavezzo/ray_results/construction_traffic/PPO_myEnv-v0_8770493a_2020-03-25_09-35-444_duk9ya/error.txt</td></tr>
# </tbody>
# </table><br>
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=131) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=131)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=131) 2020-03-25 09:35:54,213	INFO trainer.py:370 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# 2020-03-25 09:35:54,733	ERROR trial_runner.py:480 -- Trial PPO_myEnv-v0_8770493a: Error processing event.
# Traceback (most recent call last):
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py", line 424, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/ray_trial_executor.py", line 377, in fetch_result
#     result = ray.get(trial_future[0], DEFAULT_GET_TIMEOUT)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/worker.py", line 1492, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(FileNotFoundError): ray::PPO.__init__() (pid=131, ip=192.168.0.24)
#   File "python/ray/_raylet.pyx", line 630, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 637, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 638, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 643, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 623, in function_executor
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer_template.py", line 83, in __init__
#     Trainer.__init__(self, config, env, logger_creator)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 397, in __init__
#     Trainable.__init__(self, config, logger_creator)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/trainable.py", line 172, in __init__
#     self._setup(copy.deepcopy(self.config))
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 528, in _setup
#     self._init(self.config, self.env_creator)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer_template.py", line 102, in _init
#     self.config["num_workers"])
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 573, in _make_workers
#     logdir=self.logdir)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/worker_set.py", line 60, in __init__
#     RolloutWorker, env_creator, policy, 0, self._local_config)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/worker_set.py", line 216, in _make_worker
#     _fake_sampler=config.get("_fake_sampler", False))
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/rollout_worker.py", line 269, in __init__
#     self.env = _validate_env(env_creator(env_context))
#   File "/mnt/c/Users/llave/Documents/GitHub/flow/flow/utils/registry.py", line 130, in create_env
#     return gym.envs.make(env_name)
#   File "/home/llavezzo/.local/lib/python3.6/site-packages/gym/envs/registration.py", line 156, in make
#     return registry.make(id, **kwargs)
#   File "/home/llavezzo/.local/lib/python3.6/site-packages/gym/envs/registration.py", line 101, in make
#     env = spec.make(**kwargs)
#   File "/home/llavezzo/.local/lib/python3.6/site-packages/gym/envs/registration.py", line 73, in make
#     env = cls(**_kwargs)
#   File "/mnt/c/Users/llave/Documents/GitHub/flow/flow/envs/base.py", line 163, in __init__
#     self.k.network.generate_network(self.network)
#   File "/mnt/c/Users/llave/Documents/GitHub/flow/flow/core/kernel/network/traci.py", line 124, in generate_network
#     self.network.net_params)
#   File "/mnt/c/Users/llave/Documents/GitHub/flow/flow/core/kernel/network/traci.py", line 613, in generate_net_from_template
#     edges_dict, conn_dict = self._import_edges_from_net(net_params)
#   File "/mnt/c/Users/llave/Documents/GitHub/flow/flow/core/kernel/network/traci.py", line 843, in _import_edges_from_net
#     tree = ElementTree.parse(net_path, parser=parser)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/xml/etree/ElementTree.py", line 1196, in parse
#     tree.parse(source, parser)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/xml/etree/ElementTree.py", line 586, in parse
#     source = open(source, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/c/Users/llave/Documents/GitHub/flow_osuphysics/lucalavezzo/constructionV4.net.xml'
# 2020-03-25 09:35:54,743	INFO trial_runner.py:547 -- Trial PPO_myEnv-v0_8770493a: Attempting to restore trial state from last checkpoint.
# (pid=131) 2020-03-25 09:35:54,707	INFO trainer.py:517 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=227) E0325 09:35:55.767767100     227 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1585143355.767744100","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=227) E0325 09:35:55.768071600     227 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=227) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=227)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=227) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=227)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=227) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=227)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=227) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=227)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=227) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=227)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=227) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=227)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=227) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=227)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=227) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=227)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=227) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=227)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=227) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=227)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=227) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=227)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=227) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=227)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=227) 2020-03-25 09:36:00,806	INFO trainer.py:370 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=227) 2020-03-25 09:36:01,679	INFO trainer.py:517 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-12dd705f520e> in <module>
#      12         "max_failures": 999,
#      13         "stop": {
# ---> 14             "training_iteration": 200,
#      15         },
#      16     }
#
# ~/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/tune.py in run_experiments(experiments, search_alg, scheduler, with_server, server_port, verbose, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial, concurrent)
#     402                 trial_executor=trial_executor,
#     403                 raise_on_failed_trial=raise_on_failed_trial,
# --> 404                 return_trials=True)
#     405         return trials
#
# ~/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/tune.py in run(run_or_experiment, name, stop, config, resources_per_trial, num_samples, local_dir, upload_dir, trial_name_creator, loggers, sync_to_cloud, sync_to_driver, checkpoint_freq, checkpoint_at_end, sync_on_checkpoint, keep_checkpoints_num, checkpoint_score_attr, global_checkpoint_period, export_formats, max_failures, restore, search_alg, scheduler, with_server, server_port, verbose, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial, return_trials, ray_auto_init, sync_function)
#     298     last_debug = 0
#     299     while not runner.is_finished():
# --> 300         runner.step()
#     301         if time.time() - last_debug > DEBUG_PRINT_INTERVAL:
#     302             if verbose:
#
# ~/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py in step(self)
#     328                 self.trial_executor.start_trial(next_trial)
#     329         elif self.trial_executor.get_running_trials():
# --> 330             self._process_events()  # blocking
#     331         else:
#     332             self.trial_executor.on_no_available_trials(self)
#
# ~/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py in _process_events(self)
#     411             # TODO(ujvl): Consider combining get_next_available_trial and
#     412             #  fetch_result functionality so that we don't timeout on fetch.
# --> 413             trial = self.trial_executor.get_next_available_trial()  # blocking
#     414             if trial.is_restoring:
#     415                 with warn_if_slow("process_trial_restore"):
#
# ~/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/ray_trial_executor.py in get_next_available_trial(self)
#     350         # See https://github.com/ray-project/ray/issues/4211 for details.
#     351         start = time.time()
# --> 352         [result_id], _ = ray.wait(shuffled_results)
#     353         wait_time = time.time() - start
#     354         if wait_time > NONTRIVIAL_WAIT_TIME_THRESHOLD_S:
#
# ~/anaconda2/envs/flow/lib/python3.6/site-packages/ray/worker.py in wait(object_ids, num_returns, timeout)
#    1634             num_returns,
#    1635             timeout_milliseconds,
# -> 1636             worker.current_task_id,
#    1637         )
#    1638         return ready_ids, remaining_ids
#
# KeyboardInterrupt:
