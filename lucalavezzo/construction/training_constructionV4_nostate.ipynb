# %%
import json
import ray
from ray.rllib.agents.registry import get_agent_class
from ray.tune import run_experiments
from ray.tune.registry import register_env
import numpy as np
from flow.networks.ring import RingNetwork, ADDITIONAL_NET_PARAMS
from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder
from flow.core.params import SumoParams, EnvParams, InitialConfig, NetParams
from flow.core.params import VehicleParams, SumoCarFollowingParams
from flow.controllers import RLController, IDMController, ContinuousRouter
from gym.spaces.box import Box
from gym.spaces import Tuple
from flow.core.params import InFlows
from flow.controllers import SimLaneChangeController
from flow.networks import Network
import os
from flow.controllers.routing_controllers import ConstructionRouter
from flow.core.params import SumoLaneChangeParams

from env_constructionV4_nostate import myEnv

ADDITIONAL_ENV_PARAMS = {
    "max_accel": 1,
    "max_decel": 1,
}

# time horizon of a single rollout
HORIZON = 1500
# number of rollouts per training iteration
N_ROLLOUTS = 20
# number of parallel workers
N_CPUS = 2

# We place one autonomous vehicle and 22 human-driven vehicles in the network
vehicles = VehicleParams()
vehicles.add("rl",
             acceleration_controller=(RLController, {}),
             lane_change_controller=(SimLaneChangeController, {}),
             routing_controller=(ConstructionRouter, {}),
             car_following_params=SumoCarFollowingParams(
                 speed_mode="obey_safe_speed",  
                 # we use the speed mode "obey_safe_speed" for better dynamics at the merge
             ),
             num_vehicles=2)
vehicles.add("human",
             acceleration_controller=(IDMController, {}),
             lane_change_controller=(SimLaneChangeController, {}),
             #routing_controller=(ContinuousRouter, {}),
             car_following_params=SumoCarFollowingParams(
                 speed_mode="obey_safe_speed",  
                 # we use the speed mode "obey_safe_speed" for better dynamics at the merge
             ),
             lane_change_params = SumoLaneChangeParams(lane_change_mode="strategic",lcpushy=1.0),
             num_vehicles=0)

# specify the edges vehicles can originate on
initial_config = InitialConfig(
    edges_distribution=["gneE4","gneE35","gneE38"]
)

# specify the routes for vehicles in the network
class Network(Network):

    def specify_routes(self, net_params):
        return {
                "gneE35": ["gneE35","gneE15","gneE13","gneE4.264","gneE4.264.110","gneE8","gneE9","gneE9.252","gneE33"],
                "gneE4": ["gneE4","gneE17","gneE11","gneE13","gneE4.264","gneE4.264.110","gneE8","gneE9","gneE9.252","gneE33"],
               "gneE8": ["gneE8","gneE9","gneE37","gneE38","gneE39","gneE4.264.110","gneE8"]
               }


inflow = InFlows()
inflow.add(veh_type="human",
           edge="gneE4",
           vehs_per_hour=1000,
            depart_lane="random",
            depart_speed="random",
            color="white")
inflow.add(veh_type="human",
           edge="gneE35",
           vehs_per_hour=5000,
            depart_lane="random",
            depart_speed="random",
            color="blue")


file_dir = "/home/llavezzo/"
net_params = NetParams(
    template="/mnt/c/Users/llave/Documents/GitHub/flow_osuphysics/lucalavezzo/constructionV4.net.xml",
    inflows=inflow
)

flow_params = dict(
    # name of the experiment
    exp_tag="construction_traffic",

    # name of the flow environment the experiment is running on
    env_name=myEnv,  # <------ here we replace the environment with our new environment

    # name of the network class the experiment is running on
    network=Network,

    # simulator that is used by the experiment
    simulator='traci',

    # sumo-related parameters (see flow.core.params.SumoParams)
    sim=SumoParams(
        sim_step=0.1,
        render=False,
        restart_instance=True
    ),

    # environment related parameters (see flow.core.params.EnvParams)
    env=EnvParams(
        horizon=HORIZON,
        warmup_steps=750,
        clip_actions=False,
        additional_params={
            "target_velocity": 20,
            "sort_vehicles": False,
            "max_accel": 1,
            "max_decel": 1,
        },
    ),

    # network-related parameters (see flow.core.params.NetParams and the
    # network's documentation or ADDITIONAL_NET_PARAMS component)
    net=net_params,

    # vehicles to be placed in the network at the start of a rollout (see
    # flow.core.params.VehicleParams)
    veh=vehicles,

    # parameters specifying the positioning of vehicles upon initialization/
    # reset (see flow.core.params.InitialConfig)
    initial=initial_config
)


def setup_exps():
    """Return the relevant components of an RLlib experiment.

    Returns
    -------
    str
        name of the training algorithm
    str
        name of the gym environment to be trained
    dict
        training configuration parameters
    """
    alg_run = "PPO"

    agent_cls = get_agent_class(alg_run)
    config = agent_cls._default_config.copy()
    config["num_workers"] = N_CPUS
    config["train_batch_size"] = HORIZON * N_ROLLOUTS
    config["gamma"] = 0.999  # discount rate
    config["model"].update({"fcnet_hiddens": [3, 3]})
    config["use_gae"] = True
    config["lambda"] = 0.97
    config["kl_target"] = 0.02
    config["num_sgd_iter"] = 10
    config['clip_actions'] = False  # FIXME(ev) temporary ray bug
    config["horizon"] = HORIZON

    # save the flow params for replay
    flow_json = json.dumps(
        flow_params, cls=FlowParamsEncoder, sort_keys=True, indent=4)
    config['env_config']['flow_params'] = flow_json
    config['env_config']['run'] = alg_run

    create_env, gym_name = make_create_env(params=flow_params, version=0)

    # Register as rllib env
    register_env(gym_name, create_env)
    return alg_run, gym_name, config

# %%
alg_run, gym_name, config = setup_exps()
ray.init(num_cpus=N_CPUS + 1)
trials = run_experiments({
    flow_params["exp_tag"]: {
        "run": alg_run,
        "env": gym_name,
        "config": {
            **config
        },
        "checkpoint_freq": 20,
        "checkpoint_at_end": True,
        "max_failures": 999,
        "stop": {
            "training_iteration": 200,
        },
    }
})
# Out:
# 2020-03-12 10:41:42,050	WARNING services.py:592 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2020-03-12 10:41:42,053	INFO resource_spec.py:212 -- Starting Ray with 4.54 GiB memory available for workers and up to 2.27 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-03-12 10:41:42,699	WARNING services.py:1080 -- Failed to start the dashboard. The dashboard requires Python 3 as well as 'pip install aiohttp psutil setproctitle grpcio'.
# == Status ==<br>Memory usage on this node: 8.4/15.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3/3 CPUs, 0/0 GPUs, 0.0/4.54 GiB heap, 0.0/1.56 GiB objects<br>Result logdir: /home/llavezzo/ray_results/construction_traffic<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_97b42628</td><td>RUNNING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (pid=raylet) E0312 10:41:43.036575200     123 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1584024103.036538000","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=raylet) E0312 10:41:43.036950700     123 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=raylet) E0312 10:41:43.096742600     123 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=146) E0312 10:41:44.931169400     146 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1584024104.931157900","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=146) E0312 10:41:44.931316900     146 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=145) E0312 10:41:44.920206400     145 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1584024104.920195900","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=145) E0312 10:41:44.920350200     145 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=145) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=145)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=145) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=145)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=145) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=145)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=145) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=145)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=145) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=145)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=145) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=145)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=145) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=145)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=145) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=145)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=145) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=145)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=145) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=145)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=145) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=145)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=145) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=145)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=145) 2020-03-12 10:41:50,143	INFO trainer.py:370 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=145) 2020-03-12 10:41:51,178	INFO trainer.py:517 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=145)  Retrying in 1 seconds
# (pid=146) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=146)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=146) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=146)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=146) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=146)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=146) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=146)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=146) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=146)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=146) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=146)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=262) E0312 10:41:57.422065300     262 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1584024117.422051600","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=262) E0312 10:41:57.422256800     262 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=262) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=262)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=262) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=262)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=262) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=262)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=262) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=262)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=262) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=262)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=262) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=262)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=146) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=146)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=146) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=146)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=146) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=146)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=146) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=146)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=146) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=146)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=146) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=146)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=145) 2020-03-12 10:42:00,636	INFO trainable.py:178 -- _setup took 10.492 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (pid=145) 2020-03-12 10:42:00,637	WARNING util.py:41 -- Install gputil for GPU system monitoring.
# (pid=262) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=262)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=262) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=262)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=262) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=262)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=262) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=262)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=262) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=262)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=262) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=262)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=146) Warning: Vehicle 'flow_00.2' performs emergency braking with decel=-119.33 wished=4.50 severity=25.52, time=46.90.
# (pid=146) Warning: Vehicle 'flow_00.3' performs emergency braking with decel=-9.96 wished=4.50 severity=1.21, time=51.20.
# (pid=146) Warning: Vehicle 'flow_10.89' performs emergency braking with decel=-10.62 wished=4.50 severity=1.36, time=65.10.
# (pid=146) Warning: Vehicle 'flow_00.7' performs emergency braking with decel=-47.65 wished=4.50 severity=9.59, time=70.60.
# (pid=262) Warning: Vehicle 'flow_00.6' performs emergency braking with decel=-83.27 wished=4.50 severity=17.50, time=63.90.
# (pid=146) Warning: Vehicle 'flow_00.12' performs emergency braking with decel=-78.62 wished=4.50 severity=16.47, time=86.40.
# (pid=146) Warning: Vehicle 'flow_00.13' performs emergency braking with decel=-26.00 wished=4.50 severity=4.78, time=86.40.
# (pid=146) Warning: Vehicle 'flow_00.13' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=87.40.
# (pid=262) Warning: Vehicle 'flow_00.13' performs emergency braking with decel=-19.75 wished=4.50 severity=3.39, time=82.70.
# (pid=262) Warning: Vehicle 'flow_10.3' performs emergency braking with decel=-90.52 wished=4.50 severity=19.12, time=84.30.
# (pid=146) Warning: Vehicle 'flow_00.14' performs emergency braking with decel=-91.16 wished=4.50 severity=19.26, time=93.90.
# (pid=262) Warning: Vehicle 'flow_10.2' performs emergency braking with decel=-122.69 wished=4.50 severity=26.26, time=92.20.
# (pid=146) Warning: Vehicle 'flow_10.9' performs emergency braking with decel=-82.46 wished=4.50 severity=17.32, time=100.40.
# (pid=262) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-81.33 wished=4.50 severity=17.07, time=96.70.
# (pid=262) Warning: Vehicle 'flow_10.24' performs emergency braking with decel=-130.18 wished=4.50 severity=27.93, time=99.60.
# (pid=262) Warning: Vehicle 'flow_10.14' performs emergency braking with decel=-55.06 wished=4.50 severity=11.24, time=99.60.
# (pid=146) Warning: Vehicle 'flow_00.18' performs emergency braking with decel=-25.09 wished=4.50 severity=4.58, time=109.20.
# (pid=146) Warning: Vehicle 'flow_00.18' performs emergency braking with decel=-20.13 wished=4.50 severity=3.47, time=111.20.
# (pid=262) Warning: Vehicle 'flow_10.10' performs emergency braking with decel=-35.47 wished=4.50 severity=6.88, time=106.30.
# (pid=262) Warning: Vehicle 'flow_00.17' performs emergency braking with decel=-62.89 wished=4.50 severity=12.98, time=106.30.
# (pid=146) Warning: Vehicle 'flow_00.18' performs emergency braking with decel=-19.81 wished=4.50 severity=3.40, time=113.30.
# (pid=262) Warning: Vehicle 'flow_00.19' performs emergency braking with decel=-18.17 wished=4.50 severity=3.04, time=111.10.
# (pid=262) Warning: Vehicle 'flow_10.25' performs emergency braking with decel=-30.47 wished=4.50 severity=5.77, time=114.60.
# (pid=262) Warning: Vehicle 'flow_00.21' performs emergency braking with decel=-17.50 wished=4.50 severity=2.89, time=117.50.
# (pid=262) Warning: Vehicle 'flow_10.17' performs emergency braking with decel=-17.05 wished=4.50 severity=2.79, time=119.80.
# (pid=262) Warning: Vehicle 'flow_10.30' performs emergency braking with decel=-44.82 wished=4.50 severity=8.96, time=120.80.
# (pid=262) Warning: Vehicle 'flow_10.17' performs emergency braking with decel=-11.46 wished=4.50 severity=1.55, time=121.40.
# (pid=262) Warning: Vehicle 'flow_10.37' performs emergency braking with decel=-18.60 wished=4.50 severity=3.13, time=123.10.
# (pid=262) Warning: Vehicle 'flow_10.17' performs emergency braking with decel=-11.09 wished=4.50 severity=1.46, time=123.10.
# (pid=262) Warning: Vehicle 'flow_00.24' performs emergency braking with decel=-13.71 wished=4.50 severity=2.05, time=128.20.
# (pid=262) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-25.12 wished=4.50 severity=4.58, time=130.30.
# (pid=262) Warning: Vehicle 'flow_10.0' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=132.10.
# (pid=262) Warning: Teleporting vehicle 'flow_10.0'; collision with vehicle 'flow_10.2', lane=':gneJ6_0_2', gap=-1.00, time=132.30 stage=move.
# (pid=262) Warning: Vehicle 'flow_10.0' ends teleporting on edge 'gneE8', time 132.30.
# (pid=262) Warning: Vehicle 'flow_00.25' performs emergency braking with decel=-11.75 wished=4.50 severity=1.61, time=133.40.
# (pid=146) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-17.29 wished=4.50 severity=2.84, time=142.60.
# (pid=262) Warning: Vehicle 'flow_10.194' performs emergency braking with decel=-11.76 wished=4.50 severity=1.61, time=140.70.
# (pid=262) Warning: Vehicle 'flow_10.32' performs emergency braking with decel=-23.01 wished=4.50 severity=4.11, time=145.70.
# (pid=262) Warning: Vehicle 'flow_00.28' performs emergency braking with decel=-24.25 wished=4.50 severity=4.39, time=145.70.
# (pid=262) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=149.50.
# (pid=262) Warning: Vehicle 'flow_10.26' performs emergency braking with decel=-23.46 wished=4.50 severity=4.21, time=161.30.
# (pid=262) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=165.20.
# (pid=146) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=178.40.
# (pid=146) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=181.70.
# (pid=146) Warning: Vehicle 'flow_00.19' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=183.00.
# (pid=146) Warning: Teleporting vehicle 'flow_00.19'; collision with vehicle 'flow_10.6', lane=':gneJ6_0_3', gap=-1.00, time=183.30 stage=move.
# (pid=146) Warning: Vehicle 'flow_00.19' ends teleporting on edge 'gneE8', time 183.30.
# (pid=262) Warning: Vehicle 'flow_00.34' performs emergency braking with decel=-19.21 wished=4.50 severity=3.27, time=181.10.
# (pid=146) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=185.00.
# (pid=146) Warning: Teleporting vehicle 'flow_10.64'; collision with vehicle 'flow_00.26', lane=':gneJ14_0_3', gap=-1.00, time=189.50 stage=move.
# (pid=146) Warning: Vehicle 'flow_10.64' ends teleporting on edge 'gneE13', time 189.50.
# (pid=146) Warning: Vehicle 'flow_10.17' performs emergency braking with decel=-15.01 wished=4.50 severity=2.34, time=196.60.
# (pid=146) Warning: Vehicle 'flow_10.36' performs emergency braking with decel=-105.86 wished=4.50 severity=22.53, time=201.10.
# (pid=146) Warning: Vehicle 'flow_10.38' performs emergency braking with decel=-10.76 wished=4.50 severity=1.39, time=201.20.
# (pid=146) Warning: Vehicle 'flow_10.20' performs emergency braking with decel=-21.14 wished=4.50 severity=3.70, time=207.60.
# (pid=262) Warning: Vehicle 'rl_0' performs emergency braking with decel=-37.78 wished=4.50 severity=7.40, time=204.30.
# (pid=146) Warning: Vehicle 'flow_10.47' performs emergency braking with decel=-68.93 wished=4.50 severity=14.32, time=209.00.
# (pid=146) Warning: Vehicle 'flow_10.30' performs emergency braking with decel=-81.47 wished=4.50 severity=17.11, time=211.00.
# (pid=146) Warning: Vehicle 'flow_10.34' performs emergency braking with decel=-9.69 wished=4.50 severity=1.15, time=211.10.
# (pid=262) Warning: Vehicle 'flow_10.85' performs emergency braking with decel=-132.41 wished=4.50 severity=28.42, time=208.50.
# (pid=262) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=209.70.
# (pid=146) Warning: Vehicle 'flow_10.30' performs emergency braking with decel=-17.09 wished=4.50 severity=2.80, time=213.70.
# (pid=146) Warning: Vehicle 'flow_10.54' performs emergency braking with decel=-101.36 wished=4.50 severity=21.53, time=215.20.
# (pid=146) Warning: Vehicle 'flow_10.62' performs emergency braking with decel=-16.55 wished=4.50 severity=2.68, time=215.30.
# (pid=262) Warning: Vehicle 'flow_00.41' performs emergency braking with decel=-23.66 wished=4.50 severity=4.26, time=213.80.
# (pid=146) Warning: Vehicle 'flow_10.54' performs emergency braking with decel=-10.79 wished=4.50 severity=1.40, time=219.10.
# (pid=262) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=217.90.
# (pid=146) Warning: Vehicle 'flow_00.1' performs emergency braking with decel=-108.10 wished=4.50 severity=23.02, time=44.70.
# (pid=146) Warning: Vehicle 'flow_00.3' performs emergency braking with decel=-10.25 wished=4.50 severity=1.28, time=48.30.
# (pid=146) Warning: Vehicle 'flow_00.2' performs emergency braking with decel=-60.78 wished=4.50 severity=12.51, time=50.70.
# (pid=146) Warning: Vehicle 'flow_00.6' performs emergency braking with decel=-110.89 wished=4.50 severity=23.64, time=58.70.
# (pid=146) Warning: Vehicle 'flow_00.9' performs emergency braking with decel=-20.39 wished=4.50 severity=3.53, time=68.00.
# (pid=262) Warning: Vehicle 'flow_00.6' performs emergency braking with decel=-125.81 wished=4.50 severity=26.96, time=62.30.
# (pid=262) Warning: Vehicle 'flow_00.6' performs emergency braking with decel=-26.61 wished=4.50 severity=4.91, time=65.60.
# (pid=262) Warning: Vehicle 'flow_00.6' performs emergency braking with decel=-13.62 wished=4.50 severity=2.03, time=66.10.
# (pid=146) Warning: Vehicle 'flow_00.10' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=80.40.
# (pid=146) Warning: Vehicle 'flow_00.14' performs emergency braking with decel=-9.51 wished=4.50 severity=1.11, time=86.40.
# (pid=146) Warning: Vehicle 'flow_00.12' performs emergency braking with decel=-18.41 wished=4.50 severity=3.09, time=86.40.
# (pid=146) Warning: Vehicle 'flow_00.14' performs emergency braking with decel=-9.11 wished=4.50 severity=1.02, time=86.70.
# (pid=146) Warning: Vehicle 'flow_00.12' performs emergency braking with decel=-66.10 wished=4.50 severity=13.69, time=86.70.
# (pid=146) Warning: Vehicle 'flow_00.13' performs emergency braking with decel=-9.52 wished=4.50 severity=1.12, time=86.80.
# (pid=146) Warning: Vehicle 'flow_10.2' performs emergency braking with decel=-134.02 wished=4.50 severity=28.78, time=88.10.
# (pid=146) Warning: Vehicle 'flow_00.13' performs emergency braking with decel=-32.59 wished=4.50 severity=6.24, time=90.60.
# (pid=262) Warning: Vehicle 'flow_00.12' performs emergency braking with decel=-109.39 wished=4.50 severity=23.31, time=84.30.
# (pid=262) Warning: Vehicle 'flow_00.13' performs emergency braking with decel=-10.47 wished=4.50 severity=1.33, time=84.40.
# (pid=262) Warning: Vehicle 'flow_10.116' performs emergency braking with decel=-11.39 wished=4.50 severity=1.53, time=84.70.
# (pid=146) Warning: Vehicle 'flow_10.12' performs emergency braking with decel=-89.77 wished=4.50 severity=18.95, time=93.20.
# (pid=146) Warning: Vehicle 'rl_1' performs emergency braking with decel=-55.19 wished=4.50 severity=11.27, time=93.20.
# (pid=262) Warning: Vehicle 'flow_00.12' performs emergency braking with decel=-16.67 wished=4.50 severity=2.70, time=87.10.
# (pid=146) Warning: Vehicle 'flow_00.15' performs emergency braking with decel=-17.36 wished=4.50 severity=2.86, time=96.60.
# (pid=262) Warning: Vehicle 'flow_10.4' performs emergency braking with decel=-11.09 wished=4.50 severity=1.47, time=89.00.
# (pid=146) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-56.49 wished=4.50 severity=11.55, time=100.60.
# (pid=262) Warning: Vehicle 'flow_00.14' performs emergency braking with decel=-38.80 wished=4.50 severity=7.62, time=94.20.
# (pid=146) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-28.93 wished=4.50 severity=5.43, time=102.40.
# (pid=262) Warning: Vehicle 'flow_10.9' performs emergency braking with decel=-10.45 wished=4.50 severity=1.32, time=95.50.
# (pid=262) Warning: Vehicle 'flow_00.15' performs emergency braking with decel=-13.51 wished=4.50 severity=2.00, time=97.80.
# (pid=146) Warning: Vehicle 'flow_10.25' performs emergency braking with decel=-63.99 wished=4.50 severity=13.22, time=106.00.
# (pid=146) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-13.17 wished=4.50 severity=1.93, time=107.30.
# (pid=146) Warning: Vehicle 'flow_00.18' performs emergency braking with decel=-15.66 wished=4.50 severity=2.48, time=107.30.
# (pid=262) Warning: Vehicle 'flow_10.2' performs emergency braking with decel=-23.73 wished=4.50 severity=4.27, time=99.80.
# (pid=262) Warning: Vehicle 'flow_00.17' performs emergency braking with decel=-37.88 wished=4.50 severity=7.42, time=99.80.
# (pid=262) Warning: Vehicle 'flow_00.17' performs emergency braking with decel=-12.27 wished=4.50 severity=1.73, time=102.20.
# (pid=146) Warning: Vehicle 'flow_00.20' performs emergency braking with decel=-10.38 wished=4.50 severity=1.31, time=111.90.
# (pid=262) Warning: Vehicle 'flow_10.17' performs emergency braking with decel=-120.09 wished=4.50 severity=25.69, time=104.70.
# (pid=262) Warning: Vehicle 'flow_10.6' performs emergency braking with decel=-32.31 wished=4.50 severity=6.18, time=107.70.
# (pid=262) Warning: Vehicle 'flow_00.19' performs emergency braking with decel=-49.55 wished=4.50 severity=10.01, time=110.20.
# (pid=262) Warning: Vehicle 'flow_00.20' performs emergency braking with decel=-43.49 wished=4.50 severity=8.66, time=110.20.
# (pid=262) Warning: Vehicle 'flow_10.26' performs emergency braking with decel=-85.51 wished=4.50 severity=18.00, time=113.30.
# (pid=146) Warning: Vehicle 'flow_00.21' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=123.20.
# (pid=262) Warning: Vehicle 'flow_10.26' performs emergency braking with decel=-27.87 wished=4.50 severity=5.19, time=116.60.
# (pid=146) Warning: Vehicle 'flow_00.21' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=126.40.
# (pid=146) Warning: Vehicle 'flow_00.21' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=133.30.
# (pid=146) Warning: Teleporting vehicle 'flow_10.54'; collision with vehicle 'flow_00.21', lane=':gneJ14_0_3', gap=-1.00, time=135.10 stage=move.
# (pid=146) Warning: Vehicle 'flow_10.54' ends teleporting on edge 'gneE13', time 135.10.
# (pid=146) Warning: Vehicle 'flow_10.58' performs emergency braking with decel=-49.97 wished=4.50 severity=10.11, time=135.30.
# (pid=146) Warning: Vehicle 'flow_10.55' performs emergency braking with decel=-58.13 wished=4.50 severity=11.92, time=136.30.
# (pid=262) Warning: Vehicle 'flow_00.25' performs emergency braking with decel=-59.19 wished=4.50 severity=12.15, time=130.90.
# (pid=262) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-23.32 wished=4.50 severity=4.18, time=141.10.
# (pid=262) Warning: Vehicle 'flow_00.27' performs emergency braking with decel=-31.42 wished=4.50 severity=5.98, time=141.20.
# (pid=146) Warning: Vehicle 'flow_00.22' performs emergency braking with decel=-36.28 wished=4.50 severity=7.06, time=149.30.
# (pid=262) Warning: Vehicle 'flow_00.27' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=145.10.
# (pid=262) Warning: Vehicle 'flow_00.29' performs emergency braking with decel=-23.68 wished=4.50 severity=4.26, time=148.80.
# (pid=146) Warning: Vehicle 'flow_10.30' performs emergency braking with decel=-134.87 wished=4.50 severity=28.97, time=160.10.
# (pid=146) Warning: Vehicle 'flow_10.30' performs emergency braking with decel=-19.61 wished=4.50 severity=3.36, time=162.40.
# (pid=146) Warning: Vehicle 'flow_10.30' performs emergency braking with decel=-21.95 wished=4.50 severity=3.88, time=164.90.
# (pid=262) Warning: Vehicle 'flow_10.30' performs emergency braking with decel=-11.28 wished=4.50 severity=1.51, time=158.10.
# (pid=146) Warning: Vehicle 'flow_10.43' performs emergency braking with decel=-125.31 wished=4.50 severity=26.85, time=166.40.
# (pid=146) Warning: Vehicle 'flow_10.40' performs emergency braking with decel=-13.34 wished=4.50 severity=1.96, time=166.50.
# (pid=146) Warning: Vehicle 'flow_10.43' performs emergency braking with decel=-9.07 wished=4.50 severity=1.01, time=169.70.
# (pid=146) Warning: Vehicle 'flow_10.43' performs emergency braking with decel=-15.11 wished=4.50 severity=2.36, time=169.80.
# (pid=146) Warning: Vehicle 'flow_10.43' performs emergency braking with decel=-9.03 wished=4.50 severity=1.01, time=172.40.
# (pid=146) Warning: Vehicle 'flow_10.43' performs emergency braking with decel=-11.75 wished=4.50 severity=1.61, time=174.10.
# (pid=146) Warning: Vehicle 'flow_10.48' performs emergency braking with decel=-98.58 wished=4.50 severity=20.91, time=176.10.
# (pid=146) Warning: Vehicle 'flow_10.40' performs emergency braking with decel=-26.14 wished=4.50 severity=4.81, time=179.00.
# (pid=262) Warning: Vehicle 'flow_00.34' performs emergency braking with decel=-9.93 wished=4.50 severity=1.21, time=173.70.
# (pid=146) Warning: Vehicle 'flow_00.21' performs emergency braking with decel=-24.43 wished=4.50 severity=4.43, time=183.20.
# (pid=146) Warning: Vehicle 'flow_00.21' performs emergency braking with decel=-59.99 wished=4.50 severity=12.33, time=183.30.
# (pid=262) Warning: Vehicle 'flow_00.36' performs emergency braking with decel=-11.14 wished=4.50 severity=1.48, time=177.50.
# (pid=146) Warning: Vehicle 'flow_10.45' performs emergency braking with decel=-21.14 wished=4.50 severity=3.70, time=186.00.
# (pid=262) Warning: Vehicle 'flow_10.32' performs emergency braking with decel=-9.82 wished=4.50 severity=1.18, time=180.10.
# (pid=146) Warning: Teleporting vehicle 'flow_10.58'; collision with vehicle 'flow_00.19', lane=':gneJ14_0_2', gap=-1.00, time=187.00 stage=laneChange.
# (pid=146) Warning: Vehicle 'flow_10.58' ends teleporting on edge 'gneE13', time 187.00.
# (pid=146) Warning: Vehicle 'flow_00.24' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=188.40.
# (pid=146) Warning: Vehicle 'flow_10.54' performs emergency braking with decel=-17.28 wished=4.50 severity=2.84, time=189.50.
# (pid=146) Warning: Vehicle 'flow_10.4' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=192.40.
# (pid=146) Warning: Vehicle 'flow_10.35' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=192.50.
# (pid=146) Warning: Vehicle 'flow_10.34' performs emergency braking with decel=-15.95 wished=4.50 severity=2.54, time=199.40.
# (pid=262) Warning: Vehicle 'flow_00.37' performs emergency braking with decel=-24.33 wished=4.50 severity=4.41, time=194.00.
# (pid=262) Warning: Vehicle 'flow_10.37' performs emergency braking with decel=-116.47 wished=4.50 severity=24.88, time=197.90.
# (pid=146) Warning: Vehicle 'flow_10.21' performs emergency braking with decel=-11.15 wished=4.50 severity=1.48, time=206.40.
# (pid=262) Warning: Vehicle 'flow_10.42' performs emergency braking with decel=-39.85 wished=4.50 severity=7.86, time=200.30.
# (pid=262) Warning: Vehicle 'flow_10.40' performs emergency braking with decel=-110.11 wished=4.50 severity=23.47, time=201.40.
# (pid=262) Warning: Vehicle 'flow_00.31' performs emergency braking with decel=-17.72 wished=4.50 severity=2.94, time=201.50.
# (pid=146) Warning: Vehicle 'flow_10.85' performs emergency braking with decel=-11.10 wished=4.50 severity=1.47, time=208.70.
# (pid=146) Warning: Vehicle 'flow_10.85' performs emergency braking with decel=-61.82 wished=4.50 severity=12.74, time=209.00.
# (pid=262) Warning: Vehicle 'flow_10.40' performs emergency braking with decel=-28.21 wished=4.50 severity=5.27, time=205.50.
# (pid=146) Warning: Vehicle 'flow_10.52' performs emergency braking with decel=-35.99 wished=4.50 severity=7.00, time=212.90.
# (pid=262) Warning: Vehicle 'flow_10.47' performs emergency braking with decel=-29.63 wished=4.50 severity=5.58, time=207.60.
# (pid=262) Warning: Vehicle 'flow_10.47' performs emergency braking with decel=-79.22 wished=4.50 severity=16.60, time=207.70.
# (pid=262) Warning: Vehicle 'flow_00.31' performs emergency braking with decel=-27.36 wished=4.50 severity=5.08, time=211.00.
# (pid=262) Warning: Vehicle 'flow_10.51' performs emergency braking with decel=-10.47 wished=4.50 severity=1.33, time=213.90.
# (pid=262) Warning: Vehicle 'flow_00.42' performs emergency braking with decel=-12.73 wished=4.50 severity=1.83, time=216.40.
# (pid=262) Warning: Vehicle 'flow_10.51' performs emergency braking with decel=-78.71 wished=4.50 severity=16.49, time=216.90.
# (pid=262) Warning: Vehicle 'flow_00.33' performs emergency braking with decel=-18.26 wished=4.50 severity=3.06, time=218.80.
# (pid=262) Warning: Vehicle 'flow_00.33' performs emergency braking with decel=-50.07 wished=4.50 severity=10.13, time=219.00.
# (pid=146) Warning: Vehicle 'flow_10.12' performs emergency braking with decel=-11.53 wished=4.50 severity=1.56, time=9.70.
# (pid=262) Warning: Vehicle 'flow_10.48' performs emergency braking with decel=-17.77 wished=4.50 severity=2.95, time=222.70.
# (pid=262) Warning: Vehicle 'flow_10.54' performs emergency braking with decel=-106.16 wished=4.50 severity=22.59, time=223.30.
# (pid=146) Warning: Vehicle 'flow_00.5' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=70.20.
# (pid=146) Warning: Vehicle 'flow_00.12' performs emergency braking with decel=-51.51 wished=4.50 severity=10.45, time=82.30.
# (pid=262) Warning: Vehicle 'flow_00.8' performs emergency braking with decel=-13.16 wished=4.50 severity=1.93, time=65.80.
# (pid=146) Warning: Vehicle 'flow_00.13' performs emergency braking with decel=-88.50 wished=4.50 severity=18.67, time=86.50.
# (pid=146) Warning: Vehicle 'flow_10.8' performs emergency braking with decel=-9.97 wished=4.50 severity=1.22, time=88.30.
# (pid=146) Warning: Vehicle 'flow_10.18' performs emergency braking with decel=-131.48 wished=4.50 severity=28.22, time=88.30.
# (pid=146) Warning: Vehicle 'flow_10.6' performs emergency braking with decel=-24.77 wished=4.50 severity=4.51, time=88.30.
# (pid=146) Warning: Vehicle 'flow_10.6' performs emergency braking with decel=-12.04 wished=4.50 severity=1.68, time=89.80.
# (pid=262) Warning: Vehicle 'flow_00.9' performs emergency braking with decel=-95.69 wished=4.50 severity=20.26, time=74.90.
# (pid=146) Warning: Vehicle 'flow_00.14' performs emergency braking with decel=-11.82 wished=4.50 severity=1.63, time=92.20.
# (pid=146) Warning: Vehicle 'flow_10.18' performs emergency braking with decel=-32.32 wished=4.50 severity=6.18, time=93.20.
# (pid=146) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-50.10 wished=4.50 severity=10.13, time=93.40.
# (pid=262) Warning: Vehicle 'flow_00.11' performs emergency braking with decel=-93.38 wished=4.50 severity=19.75, time=85.70.
# (pid=146) Warning: Vehicle 'flow_10.26' performs emergency braking with decel=-31.39 wished=4.50 severity=5.98, time=100.70.
# (pid=146) Warning: Vehicle 'flow_10.5' performs emergency braking with decel=-90.02 wished=4.50 severity=19.00, time=100.70.
# (pid=146) Warning: Vehicle 'rl_1' performs emergency braking with decel=-22.25 wished=4.50 severity=3.94, time=100.70.
# (pid=262) Warning: Vehicle 'flow_10.11' performs emergency braking with decel=-96.56 wished=4.50 severity=20.46, time=87.70.
# (pid=146) Warning: Vehicle 'flow_00.19' performs emergency braking with decel=-14.83 wished=4.50 severity=2.30, time=102.20.
# (pid=262) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-9.73 wished=4.50 severity=1.16, time=92.00.
# (pid=146) Warning: Vehicle 'flow_00.27' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=106.60.
# (pid=262) Warning: Vehicle 'flow_10.7' performs emergency braking with decel=-123.49 wished=4.50 severity=26.44, time=94.40.
# (pid=262) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-73.40 wished=4.50 severity=15.31, time=94.40.
# (pid=146) Warning: Vehicle 'flow_10.28' performs emergency braking with decel=-14.28 wished=4.50 severity=2.17, time=108.90.
# (pid=146) Warning: Vehicle 'flow_10.28' performs emergency braking with decel=-12.62 wished=4.50 severity=1.81, time=109.50.
# (pid=262) Warning: Vehicle 'flow_10.19' performs emergency braking with decel=-74.57 wished=4.50 severity=15.57, time=96.40.
# (pid=262) Warning: Vehicle 'flow_10.7' performs emergency braking with decel=-11.60 wished=4.50 severity=1.58, time=96.40.
# (pid=262) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=96.40.
# (pid=146) Warning: Vehicle 'flow_00.18' performs emergency braking with decel=-15.20 wished=4.50 severity=2.38, time=110.40.
# (pid=146) Warning: Vehicle 'flow_00.18' performs emergency braking with decel=-19.64 wished=4.50 severity=3.36, time=110.50.
# (pid=262) Warning: Vehicle 'flow_00.17' performs emergency braking with decel=-29.12 wished=4.50 severity=5.47, time=103.60.
# (pid=262) Warning: Vehicle 'flow_00.17' performs emergency braking with decel=-19.46 wished=4.50 severity=3.32, time=104.80.
# (pid=262) Warning: Vehicle 'flow_10.21' performs emergency braking with decel=-12.38 wished=4.50 severity=1.75, time=106.30.
# (pid=146) Warning: Vehicle 'flow_00.20' performs emergency braking with decel=-34.25 wished=4.50 severity=6.61, time=120.50.
# (pid=146) Warning: Vehicle 'flow_10.43' performs emergency braking with decel=-127.00 wished=4.50 severity=27.22, time=122.60.
# (pid=146) Warning: Vehicle 'flow_00.5' performs emergency braking with decel=-96.90 wished=4.50 severity=20.53, time=126.10.
# (pid=262) Warning: Vehicle 'flow_00.21' performs emergency braking with decel=-79.33 wished=4.50 severity=16.63, time=114.70.
# (pid=262) Warning: Vehicle 'flow_00.20' performs emergency braking with decel=-19.65 wished=4.50 severity=3.37, time=115.50.
# (pid=262) Warning: Vehicle 'flow_00.18' performs emergency braking with decel=-24.41 wished=4.50 severity=4.42, time=115.50.
# (pid=146) Warning: Vehicle 'flow_10.50' performs emergency braking with decel=-59.11 wished=4.50 severity=12.14, time=128.80.
# (pid=146) Warning: Vehicle 'flow_00.10' performs emergency braking with decel=-104.32 wished=4.50 severity=22.18, time=129.70.
# (pid=146) Warning: Vehicle 'flow_00.11' performs emergency braking with decel=-11.28 wished=4.50 severity=1.51, time=129.80.
# (pid=146) Warning: Vehicle 'flow_00.24' performs emergency braking with decel=-54.41 wished=4.50 severity=11.09, time=130.50.
# (pid=146) Warning: Vehicle 'flow_00.10' performs emergency braking with decel=-15.57 wished=4.50 severity=2.46, time=133.40.
# (pid=262) Warning: Vehicle 'flow_00.24' performs emergency braking with decel=-24.38 wished=4.50 severity=4.42, time=132.50.
# (pid=262) Warning: Vehicle 'flow_10.11' performs emergency braking with decel=-110.99 wished=4.50 severity=23.67, time=136.40.
# (pid=146) Warning: Vehicle 'flow_00.17' performs emergency braking with decel=-144.23 wished=4.50 severity=31.05, time=149.40.
# (pid=146) Warning: Vehicle 'flow_00.20' performs emergency braking with decel=-94.04 wished=4.50 severity=19.90, time=164.00.
# (pid=146) Warning: Vehicle 'flow_10.43' performs emergency braking with decel=-9.42 wished=4.50 severity=1.09, time=164.10.
# (pid=146) Warning: Vehicle 'flow_10.37' performs emergency braking with decel=-10.31 wished=4.50 severity=1.29, time=165.70.
# (pid=146) Warning: Vehicle 'flow_10.43' performs emergency braking with decel=-79.06 wished=4.50 severity=16.57, time=167.90.
# (pid=146) Warning: Vehicle 'flow_00.23' performs emergency braking with decel=-9.18 wished=4.50 severity=1.04, time=168.00.
# (pid=262) Warning: Vehicle 'flow_10.31' performs emergency braking with decel=-18.28 wished=4.50 severity=3.06, time=157.90.
# (pid=146) Warning: Vehicle 'flow_10.47' performs emergency braking with decel=-23.77 wished=4.50 severity=4.28, time=170.00.
# (pid=262) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=159.00.
# (pid=146) Warning: Vehicle 'flow_00.23' performs emergency braking with decel=-47.02 wished=4.50 severity=9.45, time=172.90.
# (pid=262) Warning: Vehicle 'flow_10.39' performs emergency braking with decel=-24.58 wished=4.50 severity=4.46, time=167.30.
# (pid=146) Warning: Vehicle 'flow_00.32' performs emergency braking with decel=-14.71 wished=4.50 severity=2.27, time=182.10.
# (pid=262) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=175.60.
# (pid=262) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=185.10.
# (pid=146) Warning: Vehicle 'flow_00.36' performs emergency braking with decel=-11.40 wished=4.50 severity=1.53, time=201.80.
# (pid=146) Warning: Vehicle 'flow_00.21' performs emergency braking with decel=-148.67 wished=4.50 severity=32.04, time=206.00.
# (pid=146) Warning: Vehicle 'flow_10.29' performs emergency braking with decel=-16.78 wished=4.50 severity=2.73, time=208.20.
# (pid=262) Warning: Vehicle 'flow_00.36' performs emergency braking with decel=-23.78 wished=4.50 severity=4.29, time=201.70.
# (pid=262) Warning: Vehicle 'flow_10.58' performs emergency braking with decel=-126.95 wished=4.50 severity=27.21, time=204.80.
# (pid=262) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=205.90.
# (pid=146) Warning: Vehicle 'flow_10.21' performs emergency braking with decel=-11.11 wished=4.50 severity=1.47, time=16.20.
# (pid=262) Warning: Vehicle 'flow_00.42' performs emergency braking with decel=-23.21 wished=4.50 severity=4.16, time=223.40.
# (pid=146) Warning: Vehicle 'flow_00.4' performs emergency braking with decel=-33.82 wished=4.50 severity=6.52, time=55.90.
# (pid=146) Warning: Vehicle 'flow_00.8' performs emergency braking with decel=-14.49 wished=4.50 severity=2.22, time=69.70.
# (pid=146) Warning: Vehicle 'flow_00.10' performs emergency braking with decel=-13.92 wished=4.50 severity=2.09, time=76.20.
# (pid=146) Warning: Vehicle 'flow_00.11' performs emergency braking with decel=-94.25 wished=4.50 severity=19.95, time=81.60.
# (pid=146) Warning: Vehicle 'flow_10.4' performs emergency braking with decel=-25.53 wished=4.50 severity=4.67, time=83.30.
# (pid=146) Warning: Vehicle 'flow_00.13' performs emergency braking with decel=-9.88 wished=4.50 severity=1.19, time=84.10.
# (pid=146) Warning: Vehicle 'flow_00.13' performs emergency braking with decel=-69.60 wished=4.50 severity=14.47, time=86.60.
# (pid=262) Warning: Vehicle 'flow_00.3' performs emergency braking with decel=-41.02 wished=4.50 severity=8.12, time=54.60.
# (pid=146) Warning: Vehicle 'flow_10.13' performs emergency braking with decel=-120.86 wished=4.50 severity=25.86, time=88.50.
# (pid=146) Warning: Vehicle 'flow_00.14' performs emergency braking with decel=-79.27 wished=4.50 severity=16.62, time=88.50.
# (pid=146) Warning: Vehicle 'flow_10.8' performs emergency braking with decel=-22.00 wished=4.50 severity=3.89, time=90.90.
# (pid=146) Warning: Vehicle 'flow_10.2' performs emergency braking with decel=-33.29 wished=4.50 severity=6.40, time=90.90.
# (pid=146) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-10.47 wished=4.50 severity=1.33, time=94.00.
# (pid=146) Warning: Vehicle 'flow_00.15' performs emergency braking with decel=-46.23 wished=4.50 severity=9.27, time=100.60.
# (pid=146) Warning: Vehicle 'flow_10.16' performs emergency braking with decel=-15.27 wished=4.50 severity=2.39, time=101.70.
# (pid=146) Warning: Vehicle 'flow_10.31' performs emergency braking with decel=-69.70 wished=4.50 severity=14.49, time=105.80.
# (pid=146) Warning: Vehicle 'flow_00.17' performs emergency braking with decel=-46.91 wished=4.50 severity=9.43, time=105.80.
# (pid=262) Warning: Vehicle 'flow_00.12' performs emergency braking with decel=-10.49 wished=4.50 severity=1.33, time=82.10.
# (pid=262) Warning: Vehicle 'rl_1' performs emergency braking with decel=-68.41 wished=4.50 severity=14.20, time=83.40.
# (pid=262) Warning: Vehicle 'flow_00.14' performs emergency braking with decel=-19.59 wished=4.50 severity=3.35, time=90.70.
# (pid=262) Warning: Vehicle 'flow_00.14' performs emergency braking with decel=-80.91 wished=4.50 severity=16.98, time=91.00.
# (pid=262) Warning: Vehicle 'flow_00.13' performs emergency braking with decel=-13.85 wished=4.50 severity=2.08, time=91.20.
# (pid=146) Warning: Vehicle 'flow_00.21' performs emergency braking with decel=-70.96 wished=4.50 severity=14.77, time=114.70.
# (pid=262) Warning: Vehicle 'flow_00.14' performs emergency braking with decel=-15.13 wished=4.50 severity=2.36, time=93.70.
# (pid=146) Warning: Vehicle 'flow_00.20' performs emergency braking with decel=-14.72 wished=4.50 severity=2.27, time=116.70.
# ...
# (pid=262) Warning: Vehicle 'flow_10.31' performs emergency braking with decel=-81.18 wished=4.50 severity=17.04, time=170.10.
# (pid=262) Warning: Vehicle 'flow_10.36' performs emergency braking with decel=-12.15 wished=4.50 severity=1.70, time=170.20.
# (pid=146) Warning: Vehicle 'flow_10.67' performs emergency braking with decel=-25.51 wished=4.50 severity=4.67, time=213.90.
# (pid=146) Warning: Vehicle 'flow_10.67' performs emergency braking with decel=-21.51 wished=4.50 severity=3.78, time=217.50.
# (pid=146) Warning: Vehicle 'flow_10.35' performs emergency braking with decel=-49.19 wished=4.50 severity=9.93, time=220.20.
# (pid=262) Warning: Vehicle 'flow_10.44' performs emergency braking with decel=-18.51 wished=4.50 severity=3.11, time=181.10.
# (pid=146) Warning: Vehicle 'flow_10.55' performs emergency braking with decel=-26.67 wished=4.50 severity=4.93, time=223.10.
# (pid=262) Warning: Vehicle 'flow_00.34' performs emergency braking with decel=-23.57 wished=4.50 severity=4.24, time=182.60.
# (pid=262) Warning: Vehicle 'flow_00.27' performs emergency braking with decel=-82.09 wished=4.50 severity=17.24, time=182.70.
# (pid=262) Warning: Vehicle 'flow_10.51' performs emergency braking with decel=-11.75 wished=4.50 severity=1.61, time=182.80.
# (pid=262) Warning: Vehicle 'flow_10.58' performs emergency braking with decel=-110.73 wished=4.50 severity=23.61, time=185.70.
# (pid=262) Warning: Vehicle 'flow_10.80' performs emergency braking with decel=-34.67 wished=4.50 severity=6.71, time=186.50.
# (pid=262) Warning: Vehicle 'flow_10.58' performs emergency braking with decel=-18.58 wished=4.50 severity=3.13, time=189.00.
# (pid=262) Warning: Vehicle 'flow_00.23' performs emergency braking with decel=-9.72 wished=4.50 severity=1.16, time=191.00.
# (pid=262) Warning: Vehicle 'flow_00.23' performs emergency braking with decel=-35.20 wished=4.50 severity=6.82, time=191.10.
# (pid=262) Warning: Vehicle 'flow_10.47' performs emergency braking with decel=-60.73 wished=4.50 severity=12.50, time=194.20.
# (pid=262) Warning: Vehicle 'flow_00.29' performs emergency braking with decel=-43.27 wished=4.50 severity=8.62, time=196.10.
# (pid=146) Warning: Vehicle 'flow_00.5' performs emergency braking with decel=-42.18 wished=4.50 severity=8.37, time=59.90.
# (pid=146) Warning: Vehicle 'flow_00.10' performs emergency braking with decel=-10.71 wished=4.50 severity=1.38, time=72.70.
# (pid=146) Warning: Vehicle 'flow_00.12' performs emergency braking with decel=-37.29 wished=4.50 severity=7.29, time=79.80.
# (pid=146) Warning: Vehicle 'flow_10.4' performs emergency braking with decel=-129.65 wished=4.50 severity=27.81, time=81.30.
# (pid=146) Warning: Vehicle 'flow_00.11' performs emergency braking with decel=-91.01 wished=4.50 severity=19.22, time=81.30.
# (pid=262) Warning: Vehicle 'flow_00.34' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=207.70.
# (pid=146) Warning: Vehicle 'flow_00.15' performs emergency braking with decel=-11.65 wished=4.50 severity=1.59, time=91.10.
# (pid=262) Warning: Vehicle 'flow_00.56' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=210.30.
# (pid=146) Warning: Vehicle 'flow_10.6' performs emergency braking with decel=-13.07 wished=4.50 severity=1.90, time=93.20.
# (pid=262) Warning: Vehicle 'rl_0' performs emergency braking with decel=-10.91 wished=4.50 severity=1.43, time=212.40.
# (pid=146) Warning: Vehicle 'flow_10.10' performs emergency braking with decel=-98.92 wished=4.50 severity=20.98, time=98.00.
# (pid=262) Warning: Vehicle 'flow_10.41' performs emergency braking with decel=-116.42 wished=4.50 severity=24.87, time=214.00.
# (pid=146) Warning: Vehicle 'flow_00.18' performs emergency braking with decel=-59.97 wished=4.50 severity=12.33, time=106.10.
# (pid=146) Warning: Vehicle 'flow_10.12' performs emergency braking with decel=-10.69 wished=4.50 severity=1.38, time=108.90.
# (pid=262) Warning: Vehicle 'flow_10.41' performs emergency braking with decel=-18.65 wished=4.50 severity=3.15, time=219.00.
# (pid=146) Warning: Vehicle 'flow_10.12' performs emergency braking with decel=-54.68 wished=4.50 severity=11.15, time=109.50.
# (pid=146) Warning: Vehicle 'flow_00.20' performs emergency braking with decel=-76.10 wished=4.50 severity=15.91, time=112.50.
# (pid=146) Warning: Vehicle 'flow_00.19' performs emergency braking with decel=-73.20 wished=4.50 severity=15.27, time=112.50.
# (pid=146) Warning: Vehicle 'flow_10.27' performs emergency braking with decel=-36.50 wished=4.50 severity=7.11, time=113.70.
# (pid=146) Warning: Vehicle 'flow_10.12' performs emergency braking with decel=-35.49 wished=4.50 severity=6.89, time=113.70.
# (pid=146) Warning: Vehicle 'flow_00.20' performs emergency braking with decel=-10.85 wished=4.50 severity=1.41, time=113.70.
# (pid=146) Warning: Vehicle 'flow_10.27' performs emergency braking with decel=-47.65 wished=4.50 severity=9.59, time=116.70.
# (pid=146) Warning: Vehicle 'flow_00.21' performs emergency braking with decel=-14.33 wished=4.50 severity=2.18, time=116.70.
# (pid=262) Warning: Vehicle 'flow_10.82' performs emergency braking with decel=-16.72 wished=4.50 severity=2.72, time=223.80.
# (pid=146) Warning: Vehicle 'flow_10.27' performs emergency braking with decel=-9.40 wished=4.50 severity=1.09, time=124.60.
# (pid=146) Warning: Vehicle 'flow_00.23' performs emergency braking with decel=-24.26 wished=4.50 severity=4.39, time=125.70.
# (pid=262) Warning: Vehicle 'flow_00.2' performs emergency braking with decel=-113.80 wished=4.50 severity=24.29, time=45.20.
# (pid=146) Warning: Vehicle 'flow_00.24' performs emergency braking with decel=-23.65 wished=4.50 severity=4.25, time=131.90.
# (pid=146) Warning: Vehicle 'flow_00.15' performs emergency braking with decel=-161.49 wished=4.50 severity=34.89, time=133.10.
# (pid=262) Warning: Vehicle 'flow_00.7' performs emergency braking with decel=-27.70 wished=4.50 severity=5.15, time=64.50.
# (pid=146) Warning: Vehicle 'flow_00.27' performs emergency braking with decel=-79.31 wished=4.50 severity=16.63, time=140.80.
# (pid=146) Warning: Vehicle 'flow_00.27' performs emergency braking with decel=-18.43 wished=4.50 severity=3.10, time=142.70.
# (pid=146) Warning: Vehicle 'flow_00.25' performs emergency braking with decel=-19.46 wished=4.50 severity=3.33, time=145.30.
# (pid=146) Warning: Vehicle 'flow_10.32' performs emergency braking with decel=-39.35 wished=4.50 severity=7.75, time=151.70.
# (pid=262) Warning: Vehicle 'flow_00.14' performs emergency braking with decel=-14.20 wished=4.50 severity=2.15, time=88.30.
# (pid=262) Warning: Vehicle 'flow_10.10' performs emergency braking with decel=-9.64 wished=4.50 severity=1.14, time=97.80.
# (pid=262) Warning: Vehicle 'flow_10.3' performs emergency braking with decel=-22.76 wished=4.50 severity=4.06, time=97.80.
# (pid=262) Warning: Vehicle 'flow_00.17' performs emergency braking with decel=-11.70 wished=4.50 severity=1.60, time=101.70.
# (pid=262) Warning: Vehicle 'flow_00.17' performs emergency braking with decel=-52.40 wished=4.50 severity=10.65, time=102.50.
# (pid=262) Warning: Vehicle 'flow_10.21' performs emergency braking with decel=-49.39 wished=4.50 severity=9.98, time=103.90.
# (pid=262) Warning: Vehicle 'flow_00.18' performs emergency braking with decel=-36.76 wished=4.50 severity=7.17, time=109.60.
# (pid=262) Warning: Vehicle 'flow_00.19' performs emergency braking with decel=-9.03 wished=4.50 severity=1.01, time=111.30.
# (pid=262) Warning: Vehicle 'flow_10.29' performs emergency braking with decel=-119.19 wished=4.50 severity=25.49, time=111.30.
# (pid=262) Warning: Vehicle 'flow_10.20' performs emergency braking with decel=-69.96 wished=4.50 severity=14.55, time=111.30.
# (pid=262) Warning: Vehicle 'flow_10.32' performs emergency braking with decel=-49.91 wished=4.50 severity=10.09, time=112.70.
# (pid=146) Warning: Vehicle 'flow_00.29' performs emergency braking with decel=-22.64 wished=4.50 severity=4.03, time=169.00.
# (pid=262) Warning: Vehicle 'flow_10.29' performs emergency braking with decel=-25.58 wished=4.50 severity=4.68, time=114.90.
# (pid=262) Warning: Vehicle 'flow_00.21' performs emergency braking with decel=-84.66 wished=4.50 severity=17.81, time=117.90.
# (pid=262) Warning: Vehicle 'flow_00.23' performs emergency braking with decel=-60.26 wished=4.50 severity=12.39, time=122.90.
# (pid=262) Warning: Vehicle 'flow_00.22' performs emergency braking with decel=-11.15 wished=4.50 severity=1.48, time=124.90.
# (pid=262) Warning: Vehicle 'flow_10.31' performs emergency braking with decel=-41.35 wished=4.50 severity=8.19, time=128.80.
# (pid=262) Warning: Vehicle 'flow_00.25' performs emergency braking with decel=-27.12 wished=4.50 severity=5.03, time=130.20.
# (pid=262) Warning: Vehicle 'flow_10.11' performs emergency braking with decel=-146.25 wished=4.50 severity=31.50, time=131.10.
# (pid=262) Warning: Vehicle 'flow_10.31' performs emergency braking with decel=-16.55 wished=4.50 severity=2.68, time=132.30.
# (pid=262) Warning: Vehicle 'flow_00.24' performs emergency braking with decel=-10.26 wished=4.50 severity=1.28, time=133.70.
# (pid=262) Warning: Vehicle 'flow_10.22' performs emergency braking with decel=-48.16 wished=4.50 severity=9.70, time=142.00.
# (pid=146) Warning: Vehicle 'flow_00.34' performs emergency braking with decel=-20.97 wished=4.50 severity=3.66, time=189.70.
# (pid=146) Warning: Vehicle 'flow_10.35' performs emergency braking with decel=-144.18 wished=4.50 severity=31.04, time=189.90.
# (pid=262) Warning: Vehicle 'flow_10.24' performs emergency braking with decel=-24.52 wished=4.50 severity=4.45, time=144.40.
# (pid=262) Warning: Vehicle 'flow_00.28' performs emergency braking with decel=-10.58 wished=4.50 severity=1.35, time=144.40.
# (pid=146) Warning: Vehicle 'flow_10.47' performs emergency braking with decel=-15.23 wished=4.50 severity=2.39, time=193.70.
# (pid=146) Warning: Vehicle 'flow_10.52' performs emergency braking with decel=-80.78 wished=4.50 severity=16.95, time=196.00.
# (pid=262) Warning: Vehicle 'rl_0' performs emergency braking with decel=-54.35 wished=4.50 severity=11.08, time=154.70.
# (pid=262) Warning: Vehicle 'flow_00.29' performs emergency braking with decel=-9.94 wished=4.50 severity=1.21, time=156.90.
# (pid=262) Warning: Vehicle 'flow_00.32' performs emergency braking with decel=-23.04 wished=4.50 severity=4.12, time=163.40.
# (pid=146) Warning: Vehicle 'flow_10.55' performs emergency braking with decel=-13.62 wished=4.50 severity=2.03, time=209.30.
# (pid=146) Warning: Vehicle 'flow_00.39' performs emergency braking with decel=-22.20 wished=4.50 severity=3.93, time=213.60.
# (pid=262) Warning: Vehicle 'flow_00.34' performs emergency braking with decel=-21.09 wished=4.50 severity=3.69, time=181.00.
# (pid=262) Warning: Vehicle 'flow_10.57' performs emergency braking with decel=-130.03 wished=4.50 severity=27.90, time=194.10.
# (pid=146) Warning: Vehicle 'flow_00.10' performs emergency braking with decel=-10.44 wished=4.50 severity=1.32, time=72.80.
# (pid=146) Warning: Vehicle 'flow_00.9' performs emergency braking with decel=-12.05 wished=4.50 severity=1.68, time=75.20.
# (pid=146) Warning: Vehicle 'flow_00.14' performs emergency braking with decel=-35.82 wished=4.50 severity=6.96, time=86.30.
# (pid=146) Warning: Vehicle 'flow_00.13' performs emergency braking with decel=-15.39 wished=4.50 severity=2.42, time=88.20.
# Result for PPO_myEnv-v0_97b42628:
#   custom_metrics: {}
#   date: 2020-03-12_10-59-36
#   done: false
#   episode_len_mean: 1500.0
#   episode_reward_max: 14107.255359663995
#   episode_reward_mean: -784890.0883690993
#   episode_reward_min: -8896807.735804098
#   episodes_this_iter: 19
#   episodes_total: 19
#   experiment_id: 18f276c7b7454dbd99ecc006cd7e3707
#   experiment_tag: '0'
#   hostname: DESKTOP-3S8E765
#   info:
#     grad_time_ms: 5074.423
#     learner:
#       default_policy:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 4.999999873689376e-05
#         entropy: 2.830448627471924
#         entropy_coeff: 0.0
#         kl: 0.00015303466352634132
#         policy_loss: -0.000778078509029001
#         total_loss: 62730670080.0
#         vf_explained_var: -9.16994569166718e-09
#         vf_loss: 62730670080.0
#     load_time_ms: 118.288
#     num_steps_sampled: 30000
#     num_steps_trained: 29952
#     sample_time_ms: 1050028.282
#     update_time_ms: 756.964
#   iterations_since_restore: 1
#   node_ip: 160.39.217.237
#   num_healthy_workers: 2
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 41.338247011952184
#     ram_util_percent: 60.65212483399735
#   pid: 145
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_env_wait_ms: 60.1802300894553
#     mean_inference_ms: 0.9874816959164704
#     mean_processing_ms: 8.307167800604482
#   time_since_restore: 1056.0601215362549
#   time_this_iter_s: 1056.0601215362549
#   time_total_s: 1056.0601215362549
#   timestamp: 1584025176
#   timesteps_since_restore: 30000
#   timesteps_this_iter: 30000
#   timesteps_total: 30000
#   training_iteration: 1
#   trial_id: 97b42628
#
# (pid=145) 2020-03-12 10:59:36,858	WARNING ppo.py:140 -- The magnitude of your environment rewards are more than 78489.0x the scale of `vf_clip_param`. This means that it will take more than 78489.0 iterations for your value function to converge. If this is not intended, consider increasing `vf_clip_param`.
# == Status ==<br>Memory usage on this node: 10.5/15.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3/3 CPUs, 0/0 GPUs, 0.0/4.54 GiB heap, 0.0/1.56 GiB objects<br>Result logdir: /home/llavezzo/ray_results/construction_traffic<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc               </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  timesteps</th><th style="text-align: right;">  reward</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_97b42628</td><td>RUNNING </td><td>160.39.217.237:145</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1056.06</td><td style="text-align: right;">      30000</td><td style="text-align: right;"> -784890</td></tr>
# </tbody>
# </table><br><br>
# (pid=146) Warning: Vehicle 'flow_10.5' performs emergency braking with decel=-23.62 wished=4.50 severity=4.25, time=98.00.
# (pid=146) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-26.72 wished=4.50 severity=4.94, time=99.80.
# (pid=146) Warning: Vehicle 'flow_10.16' performs emergency braking with decel=-133.74 wished=4.50 severity=28.72, time=101.80.
# (pid=146) Warning: Vehicle 'flow_10.3' performs emergency braking with decel=-38.51 wished=4.50 severity=7.56, time=101.80.
# (pid=146) Warning: Vehicle 'flow_10.2' performs emergency braking with decel=-14.63 wished=4.50 severity=2.25, time=102.70.
# (pid=146) Warning: Vehicle 'flow_00.18' performs emergency braking with decel=-61.60 wished=4.50 severity=12.69, time=104.00.
# (pid=146) Warning: Vehicle 'flow_10.15' performs emergency braking with decel=-35.25 wished=4.50 severity=6.83, time=106.50.
# (pid=146) Warning: Vehicle 'flow_00.17' performs emergency braking with decel=-36.38 wished=4.50 severity=7.08, time=108.20.
# (pid=146) Warning: Vehicle 'flow_00.17' performs emergency braking with decel=-10.99 wished=4.50 severity=1.44, time=111.00.
# (pid=146) Warning: Vehicle 'flow_00.19' performs emergency braking with decel=-29.60 wished=4.50 severity=5.58, time=111.60.
# (pid=146) Warning: Vehicle 'flow_00.19' performs emergency braking with decel=-29.36 wished=4.50 severity=5.52, time=113.50.
# (pid=146) Warning: Vehicle 'flow_00.20' performs emergency braking with decel=-18.85 wished=4.50 severity=3.19, time=113.50.
# (pid=146) Warning: Vehicle 'flow_10.24' performs emergency braking with decel=-19.43 wished=4.50 severity=3.32, time=116.70.
# (pid=146) Warning: Vehicle 'flow_00.22' performs emergency braking with decel=-9.60 wished=4.50 severity=1.13, time=118.50.
# (pid=262) Warning: Vehicle 'flow_10.80' performs emergency braking with decel=-128.27 wished=4.50 severity=27.51, time=223.60.
