# %%
import json
import ray
from ray.rllib.agents.registry import get_agent_class
from ray.tune import run_experiments
from ray.tune.registry import register_env
import numpy as np
from flow.networks.ring import RingNetwork, ADDITIONAL_NET_PARAMS
from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder
from flow.core.params import SumoParams, EnvParams, InitialConfig, NetParams
from flow.core.params import VehicleParams, SumoCarFollowingParams
from flow.controllers import RLController, IDMController, ContinuousRouter
from gym.spaces.box import Box
from gym.spaces import Tuple
from flow.core.params import InFlows
from flow.controllers import SimLaneChangeController
from flow.networks import Network
import os
from flow.controllers.routing_controllers import ConstructionRouter
from flow.core.params import SumoLaneChangeParams

from env_testV1 import myEnv

ADDITIONAL_ENV_PARAMS = {
    "max_accel": 1,
    "max_decel": 1,
}

# time horizon of a single rollout
HORIZON = 1500
# number of rollouts per training iteration
N_ROLLOUTS = 20
# number of parallel workers
N_CPUS = 2

# We place one autonomous vehicle and 22 human-driven vehicles in the network
vehicles = VehicleParams()
vehicles.add("rl",
             acceleration_controller=(RLController, {}),
             lane_change_controller=(SimLaneChangeController, {}),
             routing_controller=(ConstructionRouter, {}),
             car_following_params=SumoCarFollowingParams(
                 speed_mode="obey_safe_speed",  
             ),
             num_vehicles=1)
vehicles.add("human",
             acceleration_controller=(IDMController, {}),
             lane_change_controller=(SimLaneChangeController, {}),
             routing_controller=(ContinuousRouter, {}),
             car_following_params=SumoCarFollowingParams(
                 speed_mode="obey_safe_speed",  
             ),
             lane_change_params = SumoLaneChangeParams(
                 lane_change_mode="aggressive",
                 lc_speed_gain=5.0),
             num_vehicles=200)

# specify the edges vehicles can originate on
initial_config = InitialConfig(
    edges_distribution=["gneE15","gneE13","gneE35"]
)
    
# specify the routes for vehicles in the network
class Network(Network):

    def specify_routes(self, net_params):
        return {"gneE15": ["gneE15","gneE13","gneE4.264","gneE8","gneE9","gneE33","gneE35","gneE15"],
                "gneE13": ["gneE13","gneE4.264","gneE8","gneE9","gneE33","gneE35","gneE15","gneE13"],
                "gneE35": ["gneE35","gneE15","gneE13","gneE4.264","gneE8","gneE9","gneE33","gneE35"],
               "gneE8": ["gneE8","gneE7","gneE6","gneE5","gneE8"]
               }


inflow = InFlows()
inflow.add(veh_type="human",
           edge="gneE4",
           vehs_per_hour=5000,
            depart_lane="random",
            depart_speed="random",
            color="white")
# inflow.add(veh_type="human",
#            edge="gneE15",
#            vehs_per_hour=300,
#             depart_lane="2",
#             depart_speed="random",
#             color="white")
# inflow.add(veh_type="rl",
#            edge="gneE15",
#            vehs_per_hour=200,
#             depart_lane="2",
#             depart_speed="random",
#             color="red")

file_dir = "/home/llavezzo/"
net_params = NetParams(
    template="/mnt/c/Users/llave/Documents/GitHub/flow_osuphysics/lucalavezzo/constructionV3.net.xml"
    #inflows=inflow
)

flow_params = dict(
    # name of the experiment
    exp_tag="construction_traffic",

    # name of the flow environment the experiment is running on
    env_name=myEnv,  # <------ here we replace the environment with our new environment

    # name of the network class the experiment is running on
    network=Network,

    # simulator that is used by the experiment
    simulator='traci',

    # sumo-related parameters (see flow.core.params.SumoParams)
    sim=SumoParams(
        sim_step=0.1,
        render=False,
        restart_instance=True
    ),

    # environment related parameters (see flow.core.params.EnvParams)
    env=EnvParams(
        horizon=HORIZON,
        warmup_steps=750,
        clip_actions=False,
        additional_params={
            "target_velocity": 20,
            "sort_vehicles": False,
            "max_accel": 1,
            "max_decel": 1,
        },
    ),

    # network-related parameters (see flow.core.params.NetParams and the
    # network's documentation or ADDITIONAL_NET_PARAMS component)
    net=net_params,

    # vehicles to be placed in the network at the start of a rollout (see
    # flow.core.params.VehicleParams)
    veh=vehicles,

    # parameters specifying the positioning of vehicles upon initialization/
    # reset (see flow.core.params.InitialConfig)
    initial=initial_config
)


def setup_exps():
    """Return the relevant components of an RLlib experiment.

    Returns
    -------
    str
        name of the training algorithm
    str
        name of the gym environment to be trained
    dict
        training configuration parameters
    """
    alg_run = "PPO"

    agent_cls = get_agent_class(alg_run)
    config = agent_cls._default_config.copy()
    config["num_workers"] = N_CPUS
    config["train_batch_size"] = HORIZON * N_ROLLOUTS
    config["gamma"] = 0.999  # discount rate
    config["model"].update({"fcnet_hiddens": [3, 3]})
    config["use_gae"] = True
    config["lambda"] = 0.97
    config["kl_target"] = 0.02
    config["num_sgd_iter"] = 10
    config['clip_actions'] = False  # FIXME(ev) temporary ray bug
    config["horizon"] = HORIZON

    # save the flow params for replay
    flow_json = json.dumps(
        flow_params, cls=FlowParamsEncoder, sort_keys=True, indent=4)
    config['env_config']['flow_params'] = flow_json
    config['env_config']['run'] = alg_run

    create_env, gym_name = make_create_env(params=flow_params, version=0)

    # Register as rllib env
    register_env(gym_name, create_env)
    return alg_run, gym_name, config
# Out:
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
alg_run, gym_name, config = setup_exps()
ray.init(num_cpus=N_CPUS + 1)
trials = run_experiments({
    flow_params["exp_tag"]: {
        "run": alg_run,
        "env": gym_name,
        "config": {
            **config
        },
        "checkpoint_freq": 20,
        "checkpoint_at_end": True,
        "max_failures": 999,
        "stop": {
            "training_iteration": 200,
        },
    }
})
# Out:
# 2020-03-02 14:44:59,970	WARNING services.py:592 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2020-03-02 14:44:59,973	INFO resource_spec.py:212 -- Starting Ray with 4.88 GiB memory available for workers and up to 2.46 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-03-02 14:45:00,550	WARNING services.py:1080 -- Failed to start the dashboard. The dashboard requires Python 3 as well as 'pip install aiohttp psutil setproctitle grpcio'.
# == Status ==<br>Memory usage on this node: 7.8/15.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3/3 CPUs, 0/0 GPUs, 0.0/4.88 GiB heap, 0.0/1.66 GiB objects<br>Result logdir: /home/llavezzo/ray_results/construction_traffic<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_4e5535ac</td><td>RUNNING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (pid=raylet) E0302 14:45:00.850722100    1457 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583178300.850669700","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=raylet) E0302 14:45:00.851347500    1457 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=raylet) E0302 14:45:00.925553900    1457 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=1478) E0302 14:45:02.627599400    1478 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583178302.627570200","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=1478) E0302 14:45:02.628014100    1478 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=1479) E0302 14:45:02.654120200    1479 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583178302.654104800","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=1479) E0302 14:45:02.654328300    1479 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=1480) E0302 14:45:02.703392200    1480 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583178302.703358500","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=1480) E0302 14:45:02.703803700    1480 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=1478) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1478)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=1478) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1478)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=1478) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1478)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=1478) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1478)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=1478) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1478)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=1478) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1478)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=1478) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1478)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=1478) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1478)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=1478) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1478)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=1478) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1478)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=1478) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1478)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=1478) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1478)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=1478) 2020-03-02 14:45:07,806	INFO trainer.py:370 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=1478) 2020-03-02 14:45:08,837	INFO trainer.py:517 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=1480) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1480)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=1480) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1480)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=1480) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1480)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=1480) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1480)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=1480) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1480)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=1480) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1480)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=1479) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1479)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=1479) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1479)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=1479) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1479)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=1479) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1479)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=1479) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1479)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=1479) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1479)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=1480) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1480)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=1480) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1480)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=1480) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1480)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=1480) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1480)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=1480) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1480)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=1480) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1480)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=1479) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1479)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=1479) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1479)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=1479) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1479)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=1479) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1479)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=1479) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1479)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=1479) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1479)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=1478) 2020-03-02 14:45:17,351	WARNING util.py:41 -- Install gputil for GPU system monitoring.
# (pid=1479) Warning: Vehicle 'human_27' performs emergency braking with decel=-157.87 wished=4.50 severity=34.08, time=21.90.
# (pid=1480) Warning: Vehicle 'human_28' performs emergency braking with decel=-144.45 wished=4.50 severity=31.10, time=22.20.
# (pid=1479) Warning: Vehicle 'human_22' performs emergency braking with decel=-15.69 wished=4.50 severity=2.49, time=28.30.
# (pid=1479) Warning: Vehicle 'human_24' performs emergency braking with decel=-101.86 wished=4.50 severity=21.64, time=28.30.
# (pid=1480) Warning: Vehicle 'human_21' performs emergency braking with decel=-133.69 wished=4.50 severity=28.71, time=28.50.
# (pid=1480) Warning: Vehicle 'human_19' performs emergency braking with decel=-57.84 wished=4.50 severity=11.85, time=30.00.
# (pid=1480) Warning: Vehicle 'human_22' performs emergency braking with decel=-121.15 wished=4.50 severity=25.92, time=31.30.
# (pid=1480) Warning: Vehicle 'human_20' performs emergency braking with decel=-43.59 wished=4.50 severity=8.69, time=31.30.
# (pid=1480) Warning: Vehicle 'human_18' performs emergency braking with decel=-13.36 wished=4.50 severity=1.97, time=31.40.
# (pid=1479) Warning: Vehicle 'human_20' performs emergency braking with decel=-92.05 wished=4.50 severity=19.45, time=33.90.
# (pid=1479) Warning: Vehicle 'human_16' performs emergency braking with decel=-14.23 wished=4.50 severity=2.16, time=34.00.
# (pid=1480) Warning: Vehicle 'human_22' performs emergency braking with decel=-17.97 wished=4.50 severity=2.99, time=34.60.
# (pid=1479) Warning: Vehicle 'human_18' performs emergency braking with decel=-115.73 wished=4.50 severity=24.72, time=35.00.
# (pid=1479) Warning: Vehicle 'human_14' performs emergency braking with decel=-16.25 wished=4.50 severity=2.61, time=35.10.
# (pid=1480) Warning: Vehicle 'human_15' performs emergency braking with decel=-85.90 wished=4.50 severity=18.09, time=35.60.
# (pid=1480) Warning: Vehicle 'human_22' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=36.50.
# (pid=1479) Warning: Vehicle 'human_18' performs emergency braking with decel=-13.10 wished=4.50 severity=1.91, time=37.00.
# (pid=1480) Warning: Vehicle 'human_12' performs emergency braking with decel=-25.98 wished=4.50 severity=4.77, time=37.20.
# (pid=1480) Warning: Vehicle 'human_12' performs emergency braking with decel=-47.77 wished=4.50 severity=9.62, time=37.70.
# (pid=1480) Warning: Vehicle 'human_9' performs emergency braking with decel=-40.33 wished=4.50 severity=7.96, time=38.30.
# (pid=1479) Warning: Vehicle 'human_13' performs emergency braking with decel=-105.59 wished=4.50 severity=22.46, time=38.50.
# (pid=1479) Warning: Vehicle 'human_11' performs emergency braking with decel=-18.18 wished=4.50 severity=3.04, time=38.50.
# (pid=1479) Warning: Vehicle 'human_9' performs emergency braking with decel=-15.16 wished=4.50 severity=2.37, time=38.60.
# (pid=1479) Warning: Vehicle 'human_11' performs emergency braking with decel=-51.97 wished=4.50 severity=10.55, time=38.60.
# (pid=1480) Warning: Vehicle 'human_12' performs emergency braking with decel=-16.47 wished=4.50 severity=2.66, time=40.90.
# (pid=1479) Warning: Vehicle 'human_14' performs emergency braking with decel=-11.44 wished=4.50 severity=1.54, time=41.70.
# (pid=1479) Warning: Vehicle 'human_16' performs emergency braking with decel=-19.58 wished=4.50 severity=3.35, time=41.80.
# (pid=1480) Warning: Vehicle 'human_12' performs emergency braking with decel=-9.56 wished=4.50 severity=1.12, time=43.10.
# (pid=1480) Warning: Vehicle 'human_5' performs emergency braking with decel=-89.17 wished=4.50 severity=18.82, time=44.30.
# (pid=1480) Warning: Vehicle 'human_1' performs emergency braking with decel=-10.98 wished=4.50 severity=1.44, time=44.40.
# (pid=1479) Warning: Vehicle 'human_14' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=44.80.
# (pid=1480) Warning: Vehicle 'human_3' performs emergency braking with decel=-101.62 wished=4.50 severity=21.58, time=45.20.
# (pid=1480) Warning: Vehicle 'rl_0' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=45.30.
# (pid=1479) Warning: Vehicle 'human_16' performs emergency braking with decel=-9.90 wished=4.50 severity=1.20, time=45.70.
# (pid=1479) Warning: Vehicle 'human_5' performs emergency braking with decel=-9.88 wished=4.50 severity=1.20, time=47.30.
# (pid=1479) Warning: Vehicle 'rl_0' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=47.30.
# (pid=1479) Warning: Vehicle 'human_5' performs emergency braking with decel=-9.42 wished=4.50 severity=1.09, time=47.70.
# (pid=1480) Warning: Vehicle 'human_8' performs emergency braking with decel=-12.82 wished=4.50 severity=1.85, time=48.40.
# (pid=1480) Warning: Vehicle 'human_14' performs emergency braking with decel=-14.32 wished=4.50 severity=2.18, time=50.30.
# (pid=1479) Warning: Vehicle 'human_10' performs emergency braking with decel=-31.61 wished=4.50 severity=6.02, time=50.40.
# (pid=1479) Warning: Vehicle 'human_12' performs emergency braking with decel=-22.77 wished=4.50 severity=4.06, time=50.90.
# (pid=1480) Warning: Vehicle 'human_41' performs emergency braking with decel=-49.77 wished=4.50 severity=10.06, time=52.60.
# (pid=1480) Warning: Vehicle 'human_8' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=53.40.
# (pid=1479) Warning: Vehicle 'human_1' performs emergency braking with decel=-38.74 wished=4.50 severity=7.61, time=53.70.
# (pid=1480) Warning: Vehicle 'human_35' performs emergency braking with decel=-20.47 wished=4.50 severity=3.55, time=55.70.
# (pid=1479) Warning: Vehicle 'human_12' performs emergency braking with decel=-10.00 wished=4.50 severity=1.22, time=55.70.
# (pid=1480) Warning: Vehicle 'human_10' performs emergency braking with decel=-19.62 wished=4.50 severity=3.36, time=56.10.
# (pid=1479) Warning: Vehicle 'human_31' performs emergency braking with decel=-64.49 wished=4.50 severity=13.33, time=57.50.
# (pid=1480) Warning: Vehicle 'human_4' performs emergency braking with decel=-21.35 wished=4.50 severity=3.74, time=58.60.
# (pid=1479) Warning: Vehicle 'human_31' performs emergency braking with decel=-9.73 wished=4.50 severity=1.16, time=58.80.
# (pid=1480) Warning: Vehicle 'human_10' performs emergency braking with decel=-19.67 wished=4.50 severity=3.37, time=59.20.
# (pid=1479) Warning: Vehicle 'human_6' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=60.20.
# (pid=1479) Warning: Vehicle 'human_8' performs emergency braking with decel=-9.82 wished=4.50 severity=1.18, time=61.20.
# (pid=1480) Warning: Vehicle 'human_33' performs emergency braking with decel=-15.91 wished=4.50 severity=2.54, time=61.50.
# (pid=1479) Warning: Vehicle 'human_37' performs emergency braking with decel=-24.23 wished=4.50 severity=4.39, time=62.90.
# (pid=1480) Warning: Vehicle 'human_4' performs emergency braking with decel=-9.87 wished=4.50 severity=1.19, time=63.10.
# (pid=1479) Warning: Vehicle 'human_199' performs emergency braking with decel=-19.91 wished=4.50 severity=3.42, time=64.40.
# (pid=1480) Warning: Vehicle 'human_6' performs emergency braking with decel=-12.68 wished=4.50 severity=1.82, time=65.00.
# (pid=1480) Warning: Vehicle 'human_195' performs emergency braking with decel=-68.61 wished=4.50 severity=14.25, time=65.00.
# (pid=1479) Warning: Vehicle 'human_2' performs emergency braking with decel=-34.97 wished=4.50 severity=6.77, time=66.10.
# (pid=1480) Warning: Vehicle 'human_6' performs emergency braking with decel=-18.89 wished=4.50 severity=3.20, time=68.10.
# (pid=1480) Warning: Vehicle 'human_0' performs emergency braking with decel=-16.48 wished=4.50 severity=2.66, time=68.60.
# (pid=1480) Warning: Vehicle 'human_193' performs emergency braking with decel=-15.82 wished=4.50 severity=2.51, time=70.30.
# (pid=1479) Warning: Vehicle 'human_195' performs emergency braking with decel=-38.15 wished=4.50 severity=7.48, time=70.90.
# (pid=1480) Warning: Vehicle 'human_0' performs emergency braking with decel=-20.46 wished=4.50 severity=3.55, time=71.80.
# (pid=1480) Warning: Vehicle 'human_2' performs emergency braking with decel=-14.03 wished=4.50 severity=2.12, time=73.80.
# (pid=1479) Warning: Vehicle 'human_0' performs emergency braking with decel=-9.42 wished=4.50 severity=1.09, time=74.10.
# (pid=1480) Warning: Vehicle 'human_187' performs emergency braking with decel=-10.08 wished=4.50 severity=1.24, time=75.10.
# (pid=1479) Warning: Vehicle 'human_42' performs emergency braking with decel=-19.19 wished=4.50 severity=3.27, time=75.40.
# (pid=1480) Warning: Vehicle 'human_2' performs emergency braking with decel=-18.90 wished=4.50 severity=3.20, time=76.90.
# (pid=1479) Warning: Vehicle 'human_191' performs emergency braking with decel=-36.72 wished=4.50 severity=7.16, time=77.30.
# (pid=1480) Warning: Vehicle 'human_185' performs emergency braking with decel=-18.56 wished=4.50 severity=3.12, time=79.20.
# (pid=1480) Warning: Vehicle 'human_40' performs emergency braking with decel=-16.45 wished=4.50 severity=2.65, time=80.50.
# (pid=1479) Warning: Vehicle 'human_38' performs emergency braking with decel=-15.84 wished=4.50 severity=2.52, time=80.90.
# (pid=1480) Warning: Vehicle 'human_42' performs emergency braking with decel=-13.22 wished=4.50 severity=1.94, time=82.70.
# (pid=1479) Warning: Vehicle 'human_187' performs emergency braking with decel=-36.72 wished=4.50 severity=7.16, time=83.60.
# (pid=1479) Warning: Vehicle 'human_38' performs emergency braking with decel=-17.37 wished=4.50 severity=2.86, time=83.70.
# (pid=1480) Warning: Vehicle 'rl_0' performs emergency braking with decel=-37.39 wished=4.50 severity=7.31, time=85.40.
# (pid=1480) Warning: Vehicle 'human_42' performs emergency braking with decel=-18.82 wished=4.50 severity=3.18, time=85.80.
# (pid=1479) Warning: Vehicle 'rl_0' performs emergency braking with decel=-29.37 wished=4.50 severity=5.53, time=86.00.
# (pid=1480) Warning: Vehicle 'human_36' performs emergency braking with decel=-22.78 wished=4.50 severity=4.06, time=86.10.
# (pid=1479) Warning: Vehicle 'human_185' performs emergency braking with decel=-51.50 wished=4.50 severity=10.44, time=86.20.
# (pid=1480) Warning: Vehicle 'human_177' performs emergency braking with decel=-18.08 wished=4.50 severity=3.02, time=88.10.
# (pid=1480) Warning: Vehicle 'human_36' performs emergency braking with decel=-17.95 wished=4.50 severity=2.99, time=88.90.
# (pid=1479) Warning: Vehicle 'human_34' performs emergency braking with decel=-12.63 wished=4.50 severity=1.81, time=89.60.
# (pid=1479) Warning: Vehicle 'human_183' performs emergency braking with decel=-37.05 wished=4.50 severity=7.23, time=90.10.
# (pid=1480) Warning: Vehicle 'human_171' performs emergency braking with decel=-51.10 wished=4.50 severity=10.36, time=91.40.
# (pid=1480) Warning: Vehicle 'human_38' performs emergency braking with decel=-13.75 wished=4.50 severity=2.06, time=91.60.
# (pid=1479) Warning: Vehicle 'human_34' performs emergency braking with decel=-20.48 wished=4.50 severity=3.55, time=92.90.
# (pid=1480) Warning: Vehicle 'human_38' performs emergency braking with decel=-18.88 wished=4.50 severity=3.20, time=94.70.
# (pid=1480) Warning: Vehicle 'human_32' performs emergency braking with decel=-13.54 wished=4.50 severity=2.01, time=94.80.
# (pid=1479) Warning: Vehicle 'human_177' performs emergency braking with decel=-10.46 wished=4.50 severity=1.32, time=95.50.
# (pid=1479) Warning: Vehicle 'human_177' performs emergency braking with decel=-9.82 wished=4.50 severity=1.18, time=96.20.
# (pid=1479) Warning: Vehicle 'human_179' performs emergency braking with decel=-36.19 wished=4.50 severity=7.04, time=96.50.
# (pid=1480) Warning: Vehicle 'human_169' performs emergency braking with decel=-18.05 wished=4.50 severity=3.01, time=97.00.
# (pid=1480) Warning: Vehicle 'human_32' performs emergency braking with decel=-17.92 wished=4.50 severity=2.98, time=97.80.
# (pid=1480) Warning: Vehicle 'human_167' performs emergency braking with decel=-36.13 wished=4.50 severity=7.03, time=97.80.
# (pid=1479) Warning: Vehicle 'human_196' performs emergency braking with decel=-11.40 wished=4.50 severity=1.53, time=99.60.
# (pid=1480) Warning: Vehicle 'human_34' performs emergency braking with decel=-13.63 wished=4.50 severity=2.03, time=100.50.
# (pid=1479) Warning: Vehicle 'human_173' performs emergency braking with decel=-40.35 wished=4.50 severity=7.97, time=101.60.
# (pid=1480) Warning: Vehicle 'human_34' performs emergency braking with decel=-18.89 wished=4.50 severity=3.20, time=103.60.
# (pid=1480) Warning: Vehicle 'human_161' performs emergency braking with decel=-18.37 wished=4.50 severity=3.08, time=105.90.
# (pid=1479) Warning: Vehicle 'human_169' performs emergency braking with decel=-35.51 wished=4.50 severity=6.89, time=108.00.
# (pid=1480) Warning: Vehicle 'human_198' performs emergency braking with decel=-13.06 wished=4.50 severity=1.90, time=109.40.
# (pid=1480) Warning: Vehicle 'human_198' performs emergency braking with decel=-18.85 wished=4.50 severity=3.19, time=112.50.
# (pid=1479) Warning: Vehicle 'human_165' performs emergency braking with decel=-37.35 wished=4.50 severity=7.30, time=114.40.
# (pid=1480) Warning: Vehicle 'human_153' performs emergency braking with decel=-18.24 wished=4.50 severity=3.05, time=114.80.
# (pid=1480) Warning: Vehicle 'human_194' performs emergency braking with decel=-13.97 wished=4.50 severity=2.10, time=118.30.
# (pid=1479) Warning: Vehicle 'human_175' performs emergency braking with decel=-17.60 wished=4.50 severity=2.91, time=120.40.
# (pid=1479) Warning: Vehicle 'human_161' performs emergency braking with decel=-37.27 wished=4.50 severity=7.28, time=120.90.
# (pid=1480) Warning: Vehicle 'human_194' performs emergency braking with decel=-18.87 wished=4.50 severity=3.19, time=121.40.
# (pid=1480) Warning: Vehicle 'human_145' performs emergency braking with decel=-17.65 wished=4.50 severity=2.92, time=123.70.
# (pid=1480) Warning: Vehicle 'human_32' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=126.80.
# (pid=1480) Warning: Vehicle 'human_190' performs emergency braking with decel=-14.28 wished=4.50 severity=2.17, time=127.20.
# (pid=1479) Warning: Vehicle 'human_157' performs emergency braking with decel=-36.10 wished=4.50 severity=7.02, time=127.20.
# (pid=1480) Warning: Teleporting vehicle 'human_167'; collision with vehicle 'human_32', lane=':gneJ6_2_0', gap=-1.00, time=128.30 stage=move.
# (pid=1480) Warning: Vehicle 'human_163' performs emergency braking with decel=-11.17 wished=4.50 severity=1.48, time=129.00.
# (pid=1480) Warning: Vehicle 'human_190' performs emergency braking with decel=-18.90 wished=4.50 severity=3.20, time=130.30.
# (pid=1480) Warning: Vehicle 'human_163' performs emergency braking with decel=-10.04 wished=4.50 severity=1.23, time=130.40.
# (pid=1480) Warning: Vehicle 'human_167' ends teleporting on edge 'gneE8', time 130.80.
# (pid=1479) Warning: Teleporting vehicle 'human_171'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=130.90 stage=move.
# (pid=1479) Warning: Vehicle 'human_171' ends teleporting on edge 'gneE8', time 130.90.
# (pid=1480) Warning: Vehicle 'human_137' performs emergency braking with decel=-27.95 wished=4.50 severity=5.21, time=132.70.
# (pid=1479) Warning: Vehicle 'human_153' performs emergency braking with decel=-37.17 wished=4.50 severity=7.26, time=133.70.
# (pid=1479) Warning: Vehicle 'human_188' performs emergency braking with decel=-11.87 wished=4.50 severity=1.64, time=134.90.
# (pid=1480) Warning: Vehicle 'human_159' performs emergency braking with decel=-18.90 wished=4.50 severity=3.20, time=135.80.
# (pid=1480) Warning: Vehicle 'human_186' performs emergency braking with decel=-9.03 wished=4.50 severity=1.01, time=136.40.
# (pid=1479) Warning: Teleporting vehicle 'human_167'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=136.80 stage=move.
# (pid=1479) Warning: Vehicle 'human_167' ends teleporting on edge 'gneE8', time 136.80.
# (pid=1479) Warning: Vehicle 'human_163' performs emergency braking with decel=-11.45 wished=4.50 severity=1.54, time=139.00.
# (pid=1480) Warning: Vehicle 'human_186' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=139.50.
# (pid=1480) Warning: Vehicle 'human_188' performs emergency braking with decel=-15.79 wished=4.50 severity=2.51, time=140.20.
# (pid=1479) Warning: Vehicle 'human_174' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=140.10.
# (pid=1480) Warning: Vehicle 'human_129' performs emergency braking with decel=-23.63 wished=4.50 severity=4.25, time=142.10.
# (pid=1479) Warning: Vehicle 'human_145' performs emergency braking with decel=-26.45 wished=4.50 severity=4.88, time=142.70.
# (pid=1479) Warning: Teleporting vehicle 'human_163'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=144.10 stage=move.
# (pid=1479) Warning: Vehicle 'human_163' ends teleporting on edge 'gneE8', time 144.10.
# (pid=1480) Warning: Vehicle 'human_155' performs emergency braking with decel=-15.43 wished=4.50 severity=2.43, time=145.00.
# (pid=1479) Warning: Vehicle 'human_159' performs emergency braking with decel=-10.24 wished=4.50 severity=1.28, time=145.70.
# (pid=1480) Warning: Vehicle 'human_182' performs emergency braking with decel=-16.28 wished=4.50 severity=2.62, time=147.80.
# (pid=1479) Warning: Vehicle 'human_170' performs emergency braking with decel=-14.93 wished=4.50 severity=2.32, time=148.40.
# (pid=1480) Warning: Vehicle 'human_121' performs emergency braking with decel=-14.41 wished=4.50 severity=2.20, time=149.80.
# (pid=1480) Warning: Vehicle 'human_184' performs emergency braking with decel=-11.14 wished=4.50 severity=1.48, time=149.80.
# (pid=1479) Warning: Teleporting vehicle 'human_159'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=150.80 stage=move.
# (pid=1479) Warning: Vehicle 'human_159' ends teleporting on edge 'gneE8', time 150.80.
# (pid=1479) Warning: Vehicle 'human_155' performs emergency braking with decel=-21.44 wished=4.50 severity=3.76, time=152.50.
# (pid=1480) Warning: Vehicle 'human_178' performs emergency braking with decel=-16.17 wished=4.50 severity=2.59, time=153.40.
# (pid=1479) Warning: Vehicle 'human_166' performs emergency braking with decel=-19.78 wished=4.50 severity=3.40, time=154.00.
# (pid=1480) Warning: Vehicle 'human_151' performs emergency braking with decel=-10.56 wished=4.50 severity=1.35, time=154.30.
# (pid=1480) Warning: Vehicle 'human_178' performs emergency braking with decel=-19.28 wished=4.50 severity=3.29, time=156.50.
# (pid=1479) Warning: Vehicle 'human_166' performs emergency braking with decel=-18.10 wished=4.50 severity=3.02, time=156.90.
# (pid=1479) Warning: Teleporting vehicle 'human_155'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=157.40 stage=move.
# (pid=1479) Warning: Vehicle 'human_155' ends teleporting on edge 'gneE8', time 157.40.
# (pid=1480) Warning: Vehicle 'human_113' performs emergency braking with decel=-13.33 wished=4.50 severity=1.96, time=158.70.
# (pid=1479) Warning: Vehicle 'human_151' performs emergency braking with decel=-19.76 wished=4.50 severity=3.39, time=159.20.
# (pid=1479) Warning: Vehicle 'human_129' performs emergency braking with decel=-49.06 wished=4.50 severity=9.90, time=159.40.
# (pid=1480) Warning: Vehicle 'human_174' performs emergency braking with decel=-14.27 wished=4.50 severity=2.17, time=162.30.
# (pid=1480) Warning: Vehicle 'human_147' performs emergency braking with decel=-9.21 wished=4.50 severity=1.05, time=162.90.
# (pid=1479) Warning: Vehicle 'human_162' performs emergency braking with decel=-13.45 wished=4.50 severity=1.99, time=162.80.
# (pid=1479) Warning: Teleporting vehicle 'human_151'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=164.10 stage=move.
# (pid=1479) Warning: Vehicle 'human_151' ends teleporting on edge 'gneE8', time 164.10.
# (pid=1480) Warning: Vehicle 'human_174' performs emergency braking with decel=-18.67 wished=4.50 severity=3.15, time=165.30.
# (pid=1479) Warning: Vehicle 'human_147' performs emergency braking with decel=-19.74 wished=4.50 severity=3.39, time=165.80.
# (pid=1479) Warning: Vehicle 'human_162' performs emergency braking with decel=-19.04 wished=4.50 severity=3.23, time=165.90.
# (pid=1480) Warning: Vehicle 'human_105' performs emergency braking with decel=-14.17 wished=4.50 severity=2.15, time=167.50.
# (pid=1479) Warning: Vehicle 'human_121' performs emergency braking with decel=-12.30 wished=4.50 severity=1.73, time=168.10.
# (pid=1479) Warning: Teleporting vehicle 'human_147'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=170.70 stage=move.
# (pid=1479) Warning: Vehicle 'human_147' ends teleporting on edge 'gneE8', time 170.90.
# (pid=1480) Warning: Vehicle 'human_170' performs emergency braking with decel=-14.94 wished=4.50 severity=2.32, time=171.10.
# (pid=1479) Warning: Vehicle 'human_158' performs emergency braking with decel=-16.06 wished=4.50 severity=2.57, time=171.60.
# (pid=1480) Warning: Vehicle 'human_143' performs emergency braking with decel=-15.65 wished=4.50 severity=2.48, time=171.80.
# (pid=1479) Warning: Vehicle 'human_143' performs emergency braking with decel=-23.28 wished=4.50 severity=4.17, time=172.50.
# (pid=1480) Warning: Vehicle 'human_170' performs emergency braking with decel=-18.70 wished=4.50 severity=3.16, time=174.10.
# (pid=1479) Warning: Vehicle 'human_158' performs emergency braking with decel=-19.16 wished=4.50 severity=3.26, time=174.70.
# (pid=1480) Warning: Vehicle 'human_97' performs emergency braking with decel=-12.84 wished=4.50 severity=1.85, time=176.30.
# (pid=1479) Warning: Vehicle 'human_113' performs emergency braking with decel=-26.95 wished=4.50 severity=4.99, time=177.00.
# (pid=1479) Warning: Teleporting vehicle 'human_143'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=177.40 stage=move.
# (pid=1479) Warning: Vehicle 'human_143' ends teleporting on edge 'gneE8', time 177.40.
# (pid=1479) Warning: Vehicle 'human_139' performs emergency braking with decel=-25.53 wished=4.50 severity=4.67, time=179.10.
# (pid=1480) Warning: Vehicle 'human_166' performs emergency braking with decel=-15.75 wished=4.50 severity=2.50, time=179.90.
# (pid=1480) Warning: Vehicle 'human_139' performs emergency braking with decel=-18.23 wished=4.50 severity=3.05, time=180.50.
# (pid=1479) Warning: Vehicle 'human_154' performs emergency braking with decel=-11.78 wished=4.50 severity=1.62, time=180.50.
# (pid=1480) Warning: Vehicle 'human_166' performs emergency braking with decel=-18.76 wished=4.50 severity=3.17, time=182.90.
# (pid=1479) Warning: Vehicle 'human_154' performs emergency braking with decel=-19.70 wished=4.50 severity=3.38, time=183.70.
# (pid=1479) Warning: Teleporting vehicle 'human_139'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=183.90 stage=move.
# (pid=1479) Warning: Vehicle 'human_139' ends teleporting on edge 'gneE8', time 183.90.
# (pid=1480) Warning: Vehicle 'human_89' performs emergency braking with decel=-14.23 wished=4.50 severity=2.16, time=185.10.
# (pid=1480) Warning: Vehicle 'human_168' performs emergency braking with decel=-19.97 wished=4.50 severity=3.44, time=185.60.
# (pid=1479) Warning: Vehicle 'human_135' performs emergency braking with decel=-24.96 wished=4.50 severity=4.55, time=185.70.
# (pid=1479) Warning: Vehicle 'human_105' performs emergency braking with decel=-9.76 wished=4.50 severity=1.17, time=187.20.
# (pid=1480) Warning: Vehicle 'human_162' performs emergency braking with decel=-14.12 wished=4.50 severity=2.14, time=188.70.
# (pid=1479) Warning: Teleporting vehicle 'human_135'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=190.50 stage=move.
# (pid=1479) Warning: Vehicle 'human_135' ends teleporting on edge 'gneE8', time 190.50.
# (pid=1480) Warning: Vehicle 'human_162' performs emergency braking with decel=-18.67 wished=4.50 severity=3.15, time=191.70.
# (pid=1480) Warning: Vehicle 'human_135' performs emergency braking with decel=-12.71 wished=4.50 severity=1.83, time=191.70.
# (pid=1479) Warning: Vehicle 'human_131' performs emergency braking with decel=-26.45 wished=4.50 severity=4.88, time=192.30.
# (pid=1479) Warning: Vehicle 'human_150' performs emergency braking with decel=-18.04 wished=4.50 severity=3.01, time=192.50.
# (pid=1480) Warning: Vehicle 'human_81' performs emergency braking with decel=-13.19 wished=4.50 severity=1.93, time=193.90.
# (pid=1479) Warning: Teleporting vehicle 'human_131'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=197.10 stage=move.
# (pid=1479) Warning: Vehicle 'human_131' ends teleporting on edge 'gneE8', time 197.20.
# (pid=1480) Warning: Vehicle 'human_158' performs emergency braking with decel=-15.47 wished=4.50 severity=2.44, time=197.50.
# (pid=1480) Warning: Vehicle 'human_164' performs emergency braking with decel=-18.18 wished=4.50 severity=3.04, time=197.60.
# (pid=1479) Warning: Vehicle 'human_146' performs emergency braking with decel=-14.33 wished=4.50 severity=2.18, time=198.20.
# (pid=1479) Warning: Vehicle 'human_127' performs emergency braking with decel=-28.93 wished=4.50 severity=5.43, time=198.80.
# (pid=1480) Warning: Vehicle 'human_158' performs emergency braking with decel=-18.75 wished=4.50 severity=3.17, time=200.50.
# (pid=1479) Warning: Teleporting vehicle 'human_152'; collision with vehicle 'rl_0', lane=':gneJ6_2_1', gap=-1.00, time=200.90 stage=move.
# (pid=1479) Warning: Vehicle 'human_152' ends teleporting on edge 'gneE8', time 200.90.
# (pid=1479) Warning: Vehicle 'human_146' performs emergency braking with decel=-17.70 wished=4.50 severity=2.93, time=201.10.
# (pid=1479) Warning: Vehicle 'human_148' performs emergency braking with decel=-26.46 wished=4.50 severity=4.88, time=201.30.
# (pid=1480) Warning: Vehicle 'human_73' performs emergency braking with decel=-13.96 wished=4.50 severity=2.10, time=202.70.
# (pid=1479) Warning: Vehicle 'human_89' performs emergency braking with decel=-34.63 wished=4.50 severity=6.70, time=203.50.
# (pid=1479) Warning: Teleporting vehicle 'human_127'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=203.50 stage=move.
# (pid=1479) Warning: Vehicle 'human_127' ends teleporting on edge 'gneE8', time 203.50.
# (pid=1479) Warning: Vehicle 'human_148' performs emergency braking with decel=-20.11 wished=4.50 severity=3.47, time=205.70.
# (pid=1480) Warning: Vehicle 'human_154' performs emergency braking with decel=-15.59 wished=4.50 severity=2.46, time=206.20.
# (pid=1479) Warning: Vehicle 'human_142' performs emergency braking with decel=-15.56 wished=4.50 severity=2.46, time=207.00.
# (pid=1479) Warning: Teleporting vehicle 'human_123'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=207.40 stage=move.
# (pid=1479) Warning: Vehicle 'human_123' ends teleporting on edge 'gneE8', time 207.40.
# (pid=1479) Warning: Vehicle 'human_119' performs emergency braking with decel=-9.18 wished=4.50 severity=1.04, time=208.00.
# (pid=1479) Warning: Vehicle 'human_119' performs emergency braking with decel=-11.72 wished=4.50 severity=1.61, time=208.10.
# (pid=1480) Warning: Vehicle 'human_154' performs emergency braking with decel=-19.03 wished=4.50 severity=3.23, time=209.30.
# (pid=1479) Warning: Vehicle 'human_142' performs emergency braking with decel=-19.45 wished=4.50 severity=3.32, time=210.10.
# (pid=1479) Warning: Teleporting vehicle 'human_148'; collision with vehicle 'rl_0', lane=':gneJ6_2_1', gap=-1.00, time=210.30 stage=move.
# (pid=1479) Warning: Vehicle 'human_148' ends teleporting on edge 'gneE8', time 210.30.
# (pid=1479) Warning: Vehicle 'human_144' performs emergency braking with decel=-23.24 wished=4.50 severity=4.16, time=210.80.
# (pid=1480) Warning: Vehicle 'human_65' performs emergency braking with decel=-21.29 wished=4.50 severity=3.73, time=211.60.
# (pid=1479) Warning: Teleporting vehicle 'human_119'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=212.90 stage=move.
# (pid=1479) Warning: Vehicle 'human_119' ends teleporting on edge 'gneE8', time 212.90.
# (pid=1480) Warning: Vehicle 'human_156' performs emergency braking with decel=-11.48 wished=4.50 severity=1.55, time=214.80.
# (pid=1479) Warning: Vehicle 'human_144' performs emergency braking with decel=-9.87 wished=4.50 severity=1.19, time=214.70.
# (pid=1480) Warning: Vehicle 'human_150' performs emergency braking with decel=-12.94 wished=4.50 severity=1.88, time=215.10.
# (pid=1479) Warning: Vehicle 'human_138' performs emergency braking with decel=-19.09 wished=4.50 severity=3.24, time=215.80.
# (pid=1479) Warning: Teleporting vehicle 'human_115'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=216.40 stage=move.
# (pid=1479) Warning: Vehicle 'human_115' ends teleporting on edge 'gneE8', time 216.40.
# (pid=1480) Warning: Vehicle 'human_150' performs emergency braking with decel=-18.82 wished=4.50 severity=3.18, time=218.20.
# (pid=1479) Warning: Vehicle 'human_138' performs emergency braking with decel=-18.27 wished=4.50 severity=3.06, time=218.70.
# (pid=1480) Warning: Vehicle 'human_123' performs emergency braking with decel=-12.28 wished=4.50 severity=1.73, time=219.30.
# (pid=1479) Warning: Teleporting vehicle 'human_111'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=219.60 stage=move.
# (pid=1479) Warning: Vehicle 'human_111' ends teleporting on edge 'gneE8', time 219.60.
# (pid=1479) Warning: Vehicle 'human_107' performs emergency braking with decel=-36.43 wished=4.50 severity=7.10, time=219.90.
# (pid=1480) Warning: Vehicle 'human_57' performs emergency braking with decel=-16.32 wished=4.50 severity=2.63, time=220.50.
# (pid=1479) Warning: Vehicle 'human_73' performs emergency braking with decel=-50.02 wished=4.50 severity=10.12, time=221.20.
# (pid=1479) Warning: Teleporting vehicle 'human_144'; collision with vehicle 'rl_0', lane=':gneJ6_2_1', gap=-1.00, time=222.30 stage=move.
# (pid=1480) Warning: Vehicle 'human_146' performs emergency braking with decel=-14.55 wished=4.50 severity=2.23, time=224.00.
# (pid=1479) Warning: Vehicle 'human_140' performs emergency braking with decel=-23.78 wished=4.50 severity=4.28, time=224.10.
# (pid=1479) Warning: Vehicle 'human_134' performs emergency braking with decel=-12.71 wished=4.50 severity=1.82, time=224.60.
# (pid=1479) Warning: Vehicle 'human_27' performs emergency braking with decel=-156.95 wished=4.50 severity=33.88, time=22.10.
# (pid=1479) Warning: Vehicle 'human_30' performs emergency braking with decel=-132.02 wished=4.50 severity=28.34, time=23.30.
# (pid=1480) Warning: Vehicle 'human_25' performs emergency braking with decel=-89.59 wished=4.50 severity=18.91, time=25.70.
# (pid=1479) Warning: Vehicle 'human_25' performs emergency braking with decel=-137.96 wished=4.50 severity=29.66, time=26.70.
# (pid=1480) Warning: Vehicle 'human_22' performs emergency braking with decel=-18.74 wished=4.50 severity=3.16, time=27.10.
# (pid=1479) Warning: Vehicle 'human_23' performs emergency braking with decel=-49.47 wished=4.50 severity=9.99, time=28.60.
# (pid=1480) Warning: Vehicle 'human_21' performs emergency braking with decel=-15.03 wished=4.50 severity=2.34, time=29.10.
# (pid=1479) Warning: Vehicle 'human_20' performs emergency braking with decel=-31.93 wished=4.50 severity=6.09, time=29.80.
# (pid=1480) Warning: Vehicle 'human_19' performs emergency braking with decel=-128.33 wished=4.50 severity=27.52, time=31.60.
# (pid=1479) Warning: Vehicle 'human_21' performs emergency braking with decel=-32.58 wished=4.50 severity=6.24, time=32.10.
# (pid=1480) Warning: Vehicle 'human_19' performs emergency braking with decel=-19.29 wished=4.50 severity=3.29, time=34.00.
# (pid=1479) Warning: Vehicle 'human_22' performs emergency braking with decel=-73.34 wished=4.50 severity=15.30, time=33.80.
# (pid=1479) Warning: Vehicle 'human_18' performs emergency braking with decel=-9.93 wished=4.50 severity=1.21, time=33.90.
# (pid=1480) Warning: Vehicle 'human_12' performs emergency braking with decel=-127.21 wished=4.50 severity=27.27, time=35.40.
# (pid=1480) Warning: Vehicle 'human_14' performs emergency braking with decel=-116.44 wished=4.50 severity=24.88, time=35.50.
# (pid=1480) Warning: Vehicle 'human_10' performs emergency braking with decel=-9.55 wished=4.50 severity=1.12, time=35.60.
# (pid=1479) Warning: Vehicle 'human_15' performs emergency braking with decel=-20.67 wished=4.50 severity=3.59, time=36.00.
# (pid=1479) Warning: Vehicle 'human_22' performs emergency braking with decel=-9.32 wished=4.50 severity=1.07, time=36.90.
# (pid=1480) Warning: Vehicle 'human_14' performs emergency braking with decel=-13.57 wished=4.50 severity=2.02, time=37.80.
# ...
# (pid=1480) Warning: Vehicle 'human_123' ends teleporting on edge 'gneE8', time 195.70.
# (pid=1480) Warning: Vehicle 'human_119' performs emergency braking with decel=-13.73 wished=4.50 severity=2.05, time=195.80.
# (pid=1480) Warning: Vehicle 'human_97' performs emergency braking with decel=-38.59 wished=4.50 severity=7.58, time=196.20.
# (pid=1479) Warning: Vehicle 'human_81' performs emergency braking with decel=-17.08 wished=4.50 severity=2.80, time=197.20.
# (pid=1480) Warning: Teleporting vehicle 'human_164'; collision with vehicle 'rl_0', lane=':gneJ6_2_1', gap=-1.00, time=198.10 stage=move.
# (pid=1480) Warning: Vehicle 'human_164' ends teleporting on edge 'gneE8', time 198.10.
# (pid=1479) Warning: Teleporting vehicle 'human_123'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=198.10 stage=move.
# (pid=1479) Warning: Vehicle 'human_123' ends teleporting on edge 'gneE8', time 198.10.
# (pid=1480) Warning: Vehicle 'human_160' performs emergency braking with decel=-23.74 wished=4.50 severity=4.28, time=198.60.
# (pid=1480) Warning: Vehicle 'human_138' performs emergency braking with decel=-14.54 wished=4.50 severity=2.23, time=199.70.
# (pid=1479) Warning: Vehicle 'human_119' performs emergency braking with decel=-13.83 wished=4.50 severity=2.07, time=199.60.
# (pid=1480) Warning: Teleporting vehicle 'human_119'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=200.80 stage=move.
# (pid=1479) Warning: Vehicle 'human_158' performs emergency braking with decel=-13.53 wished=4.50 severity=2.01, time=200.80.
# (pid=1480) Warning: Vehicle 'human_138' performs emergency braking with decel=-18.74 wished=4.50 severity=3.17, time=202.70.
# (pid=1480) Warning: Vehicle 'human_160' performs emergency braking with decel=-20.67 wished=4.50 severity=3.59, time=202.70.
# (pid=1479) Warning: Vehicle 'human_158' performs emergency braking with decel=-18.53 wished=4.50 severity=3.12, time=203.80.
# (pid=1480) Warning: Teleporting vehicle 'human_115'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=204.40 stage=move.
# (pid=1480) Warning: Vehicle 'human_89' performs emergency braking with decel=-11.69 wished=4.50 severity=1.60, time=204.90.
# (pid=1479) Warning: Teleporting vehicle 'human_119'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=204.80 stage=move.
# (pid=1479) Warning: Vehicle 'human_119' ends teleporting on edge 'gneE8', time 204.80.
# (pid=1480) Warning: Vehicle 'human_111' performs emergency braking with decel=-35.55 wished=4.50 severity=6.90, time=205.60.
# (pid=1480) Warning: Vehicle 'human_119' ends teleporting on edge 'gneE8', time 205.70.
# (pid=1480) Warning: Vehicle 'human_115' ends teleporting on edge 'gneE8', time 206.00.
# (pid=1479) Warning: Vehicle 'human_73' performs emergency braking with decel=-16.85 wished=4.50 severity=2.75, time=206.10.
# (pid=1479) Warning: Vehicle 'human_115' performs emergency braking with decel=-17.96 wished=4.50 severity=2.99, time=206.40.
# (pid=1480) Warning: Teleporting vehicle 'human_160'; collision with vehicle 'rl_0', lane=':gneJ6_2_1', gap=-1.00, time=207.90 stage=move.
# (pid=1480) Warning: Vehicle 'human_160' ends teleporting on edge 'gneE8', time 207.90.
# (pid=1480) Warning: Vehicle 'human_156' performs emergency braking with decel=-24.96 wished=4.50 severity=4.55, time=208.30.
# (pid=1480) Warning: Vehicle 'human_134' performs emergency braking with decel=-9.87 wished=4.50 severity=1.19, time=208.80.
# (pid=1479) Warning: Vehicle 'human_154' performs emergency braking with decel=-15.01 wished=4.50 severity=2.34, time=209.60.
# (pid=1480) Warning: Teleporting vehicle 'human_111'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=210.60 stage=move.
# (pid=1480) Warning: Vehicle 'human_134' performs emergency braking with decel=-17.18 wished=4.50 severity=2.82, time=211.60.
# (pid=1479) Warning: Teleporting vehicle 'human_115'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=211.40 stage=move.
# (pid=1479) Warning: Vehicle 'human_115' ends teleporting on edge 'gneE8', time 211.70.
# (pid=1480) Warning: Vehicle 'human_156' performs emergency braking with decel=-21.18 wished=4.50 severity=3.71, time=212.70.
# (pid=1479) Warning: Vehicle 'human_154' performs emergency braking with decel=-18.95 wished=4.50 severity=3.21, time=212.70.
# (pid=1479) Warning: Vehicle 'human_111' performs emergency braking with decel=-16.55 wished=4.50 severity=2.68, time=213.10.
# (pid=1480) Warning: Teleporting vehicle 'human_107'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=214.40 stage=move.
# (pid=1480) Warning: Vehicle 'human_81' performs emergency braking with decel=-9.86 wished=4.50 severity=1.19, time=215.00.
# (pid=1480) Warning: Vehicle 'human_103' performs emergency braking with decel=-10.75 wished=4.50 severity=1.39, time=215.00.
# (pid=1480) Warning: Vehicle 'human_103' performs emergency braking with decel=-12.16 wished=4.50 severity=1.70, time=215.10.
# (pid=1480) Warning: Vehicle 'human_111' ends teleporting on edge 'gneE8', time 215.40.
# (pid=1480) Warning: Vehicle 'human_107' ends teleporting on edge 'gneE8', time 215.40.
# (pid=1479) Warning: Vehicle 'human_65' performs emergency braking with decel=-19.08 wished=4.50 severity=3.24, time=215.00.
# (pid=1480) Warning: Vehicle 'human_103' performs emergency braking with decel=-9.67 wished=4.50 severity=1.15, time=216.20.
# (pid=1480) Warning: Teleporting vehicle 'human_156'; collision with vehicle 'rl_0', lane=':gneJ6_2_1', gap=-1.00, time=217.40 stage=move.
# (pid=1480) Warning: Vehicle 'human_156' ends teleporting on edge 'gneE8', time 217.40.
# (pid=1480) Warning: Vehicle 'human_152' performs emergency braking with decel=-18.00 wished=4.50 severity=3.00, time=218.00.
# (pid=1479) Warning: Teleporting vehicle 'human_111'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=218.00 stage=move.
# (pid=1479) Warning: Vehicle 'human_111' ends teleporting on edge 'gneE8', time 218.00.
# (pid=1479) Warning: Vehicle 'human_150' performs emergency braking with decel=-13.41 wished=4.50 severity=1.98, time=218.50.
# (pid=1480) Warning: Teleporting vehicle 'human_103'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=220.00 stage=move.
# (pid=1480) Warning: Vehicle 'human_103' ends teleporting on edge 'gneE8', time 220.00.
# (pid=1480) Warning: Vehicle 'human_130' performs emergency braking with decel=-16.72 wished=4.50 severity=2.72, time=220.30.
# (pid=1479) Warning: Vehicle 'human_107' performs emergency braking with decel=-23.82 wished=4.50 severity=4.29, time=219.80.
# (pid=1480) Warning: Vehicle 'human_152' performs emergency braking with decel=-19.57 wished=4.50 severity=3.35, time=221.80.
# (pid=1479) Warning: Vehicle 'human_150' performs emergency braking with decel=-18.86 wished=4.50 severity=3.19, time=221.60.
# (pid=1480) Warning: Vehicle 'human_73' performs emergency braking with decel=-13.93 wished=4.50 severity=2.10, time=222.50.
# (pid=1480) Warning: Teleporting vehicle 'human_99'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=223.50 stage=move.
# (pid=1479) Warning: Vehicle 'human_57' performs emergency braking with decel=-17.51 wished=4.50 severity=2.89, time=223.90.
# (pid=1480) Warning: Vehicle 'human_95' performs emergency braking with decel=-38.41 wished=4.50 severity=7.53, time=224.60.
# (pid=1479) Warning: Teleporting vehicle 'human_107'; collision with vehicle 'rl_0', lane=':gneJ6_2_0', gap=-1.00, time=224.60 stage=move.
# (pid=1479) Warning: Vehicle 'human_107' ends teleporting on edge 'gneE8', time 224.60.
# (pid=1480) Warning: Vehicle 'human_28' performs emergency braking with decel=-35.15 wished=4.50 severity=6.81, time=22.50.
# (pid=1480) Warning: Vehicle 'human_26' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=28.00.
# (pid=1480) Warning: Vehicle 'human_24' performs emergency braking with decel=-64.58 wished=4.50 severity=13.35, time=28.20.
# (pid=1480) Warning: Teleporting vehicle 'human_25'; collision with vehicle 'human_26', lane=':gneJ6_2_2', gap=-1.00, time=28.50 stage=move.
# (pid=1480) Warning: Vehicle 'human_25' ends teleporting on edge 'gneE8', time 28.50.
# (pid=1479) Warning: Vehicle 'human_24' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=27.90.
# (pid=1479) Warning: Teleporting vehicle 'human_23'; collision with vehicle 'human_24', lane=':gneJ6_2_0', gap=-1.00, time=28.30 stage=move.
# (pid=1479) Warning: Vehicle 'human_23' ends teleporting on edge 'gneE8', time 28.30.
# (pid=1479) Warning: Vehicle 'human_22' performs emergency braking with decel=-21.88 wished=4.50 severity=3.86, time=29.40.
# (pid=1479) Warning: Vehicle 'human_21' performs emergency braking with decel=-52.05 wished=4.50 severity=10.57, time=30.80.
# (pid=1480) Warning: Vehicle 'human_17' performs emergency braking with decel=-27.70 wished=4.50 severity=5.16, time=32.00.
# (pid=1479) Warning: Vehicle 'human_16' performs emergency braking with decel=-125.66 wished=4.50 severity=26.93, time=32.00.
# (pid=1479) Warning: Vehicle 'human_12' performs emergency braking with decel=-14.03 wished=4.50 severity=2.12, time=32.10.
# (pid=1479) Warning: Vehicle 'human_18' performs emergency braking with decel=-24.86 wished=4.50 severity=4.53, time=32.40.
# (pid=1480) Warning: Vehicle 'human_18' performs emergency braking with decel=-31.49 wished=4.50 severity=6.00, time=33.40.
# (pid=1479) Warning: Vehicle 'human_17' performs emergency braking with decel=-67.99 wished=4.50 severity=14.11, time=34.40.
# (pid=1479) Warning: Vehicle 'human_16' performs emergency braking with decel=-23.90 wished=4.50 severity=4.31, time=34.60.
# (pid=1480) Warning: Vehicle 'human_12' performs emergency braking with decel=-80.52 wished=4.50 severity=16.89, time=35.70.
# (pid=1479) Warning: Vehicle 'human_14' performs emergency braking with decel=-71.07 wished=4.50 severity=14.79, time=36.50.
# (pid=1479) Warning: Vehicle 'human_10' performs emergency braking with decel=-9.29 wished=4.50 severity=1.06, time=36.60.
# (pid=1480) Warning: Vehicle 'human_15' performs emergency braking with decel=-97.71 wished=4.50 severity=20.71, time=37.40.
# (pid=1480) Warning: Vehicle 'human_13' performs emergency braking with decel=-15.49 wished=4.50 severity=2.44, time=37.60.
# (pid=1479) Warning: Vehicle 'human_11' performs emergency braking with decel=-51.28 wished=4.50 severity=10.40, time=37.40.
# (pid=1479) Warning: Vehicle 'human_11' performs emergency braking with decel=-75.66 wished=4.50 severity=15.81, time=37.50.
# (pid=1480) Warning: Vehicle 'human_10' performs emergency braking with decel=-44.30 wished=4.50 severity=8.85, time=39.10.
# (pid=1480) Warning: Vehicle 'human_8' performs emergency braking with decel=-23.66 wished=4.50 severity=4.26, time=39.30.
# (pid=1480) Warning: Vehicle 'human_8' performs emergency braking with decel=-46.81 wished=4.50 severity=9.40, time=39.70.
# (pid=1480) Warning: Vehicle 'human_9' performs emergency braking with decel=-77.13 wished=4.50 severity=16.14, time=40.80.
# (pid=1479) Warning: Vehicle 'human_11' performs emergency braking with decel=-14.48 wished=4.50 severity=2.22, time=41.00.
# (pid=1479) Warning: Vehicle 'human_14' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=41.60.
# (pid=1480) Warning: Vehicle 'human_9' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=43.40.
# (pid=1479) Warning: Vehicle 'human_11' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=42.90.
# (pid=1479) Warning: Vehicle 'human_5' performs emergency braking with decel=-34.59 wished=4.50 severity=6.69, time=43.80.
# (pid=1480) Warning: Vehicle 'human_8' performs emergency braking with decel=-9.03 wished=4.50 severity=1.01, time=44.80.
# (pid=1480) Warning: Vehicle 'human_2' performs emergency braking with decel=-22.10 wished=4.50 severity=3.91, time=45.80.
# (pid=1479) Warning: Vehicle 'human_4' performs emergency braking with decel=-32.58 wished=4.50 severity=6.24, time=45.10.
# (pid=1480) Warning: Vehicle 'human_8' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=46.90.
# (pid=1479) Warning: Vehicle 'human_10' performs emergency braking with decel=-36.51 wished=4.50 severity=7.11, time=47.30.
# (pid=1480) Warning: Vehicle 'human_2' performs emergency braking with decel=-10.63 wished=4.50 severity=1.36, time=48.50.
# (pid=1480) Warning: Vehicle 'human_1' performs emergency braking with decel=-49.58 wished=4.50 severity=10.02, time=51.00.
# (pid=1479) Warning: Vehicle 'human_4' performs emergency braking with decel=-10.95 wished=4.50 severity=1.43, time=50.40.
# (pid=1480) Warning: Vehicle 'human_4' performs emergency braking with decel=-19.52 wished=4.50 severity=3.34, time=51.70.
# (pid=1479) Warning: Vehicle 'rl_0' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=52.20.
# (pid=1480) Warning: Vehicle 'human_42' performs emergency braking with decel=-11.68 wished=4.50 severity=1.60, time=54.50.
# (pid=1480) Warning: Vehicle 'human_4' performs emergency braking with decel=-9.85 wished=4.50 severity=1.19, time=55.80.
# (pid=1479) Warning: Vehicle 'human_0' performs emergency braking with decel=-22.42 wished=4.50 severity=3.98, time=55.80.
# (pid=1479) Warning: Vehicle 'human_6' performs emergency braking with decel=-17.18 wished=4.50 severity=2.82, time=56.10.
# (pid=1480) Warning: Vehicle 'human_31' performs emergency braking with decel=-75.95 wished=4.50 severity=15.88, time=57.50.
# (pid=1480) Warning: Vehicle 'human_199' performs emergency braking with decel=-10.01 wished=4.50 severity=1.22, time=57.60.
# (pid=1480) Warning: Vehicle 'human_42' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=57.80.
# (pid=1480) Warning: Vehicle 'human_31' performs emergency braking with decel=-10.09 wished=4.50 severity=1.24, time=58.90.
# (pid=1479) Warning: Vehicle 'human_0' performs emergency braking with decel=-20.43 wished=4.50 severity=3.54, time=58.90.
# (pid=1480) Warning: Vehicle 'human_37' performs emergency braking with decel=-24.79 wished=4.50 severity=4.51, time=60.40.
# (pid=1480) Warning: Vehicle 'human_0' performs emergency braking with decel=-11.33 wished=4.50 severity=1.52, time=61.20.
# (pid=1479) Warning: Vehicle 'human_2' performs emergency braking with decel=-16.80 wished=4.50 severity=2.73, time=61.70.
# (pid=1479) Warning: Vehicle 'human_35' performs emergency braking with decel=-9.36 wished=4.50 severity=1.08, time=62.30.
# (pid=1480) Warning: Vehicle 'human_38' performs emergency braking with decel=-35.93 wished=4.50 severity=6.98, time=63.70.
# (pid=1480) Warning: Vehicle 'human_199' performs emergency braking with decel=-36.03 wished=4.50 severity=7.01, time=64.30.
# (pid=1479) Warning: Vehicle 'human_2' performs emergency braking with decel=-18.83 wished=4.50 severity=3.18, time=64.70.
# (pid=1479) Warning: Vehicle 'human_40' performs emergency braking with decel=-20.25 wished=4.50 severity=3.50, time=64.80.
# (pid=1479) Warning: Vehicle 'human_197' performs emergency braking with decel=-49.37 wished=4.50 severity=9.97, time=67.10.
# (pid=1479) Warning: Vehicle 'human_31' performs emergency braking with decel=-14.96 wished=4.50 severity=2.32, time=67.80.
# (pid=1480) Warning: Vehicle 'human_40' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=70.90.
# (pid=1479) Warning: Vehicle 'human_42' performs emergency braking with decel=-16.01 wished=4.50 severity=2.56, time=70.50.
# (pid=1480) Warning: Vehicle 'human_34' performs emergency braking with decel=-17.22 wished=4.50 severity=2.83, time=72.50.
# (pid=1480) Warning: Vehicle 'human_191' performs emergency braking with decel=-25.02 wished=4.50 severity=4.56, time=73.50.
# (pid=1479) Warning: Vehicle 'human_42' performs emergency braking with decel=-19.35 wished=4.50 severity=3.30, time=73.60.
# (pid=1480) Warning: Vehicle 'human_193' performs emergency braking with decel=-14.79 wished=4.50 severity=2.29, time=74.70.
# (pid=1479) Warning: Vehicle 'human_36' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=74.40.
