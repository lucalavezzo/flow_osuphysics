# %%
import json
import ray
from ray.rllib.agents.registry import get_agent_class
from ray.tune import run_experiments
from ray.tune.registry import register_env
import numpy as np
from flow.networks.ring import RingNetwork, ADDITIONAL_NET_PARAMS
from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder
from flow.core.params import SumoParams, EnvParams, InitialConfig, NetParams
from flow.core.params import VehicleParams, SumoCarFollowingParams
from flow.controllers import RLController, IDMController, ContinuousRouter
from gym.spaces.box import Box
from gym.spaces import Tuple
from flow.core.params import InFlows
from flow.controllers import SimLaneChangeController
from flow.networks import Network
import os
from flow.controllers.routing_controllers import ConstructionRouter
from flow.core.params import SumoLaneChangeParams

from env_testV1 import myEnv

ADDITIONAL_ENV_PARAMS = {
    "max_accel": 1,
    "max_decel": 1,
}

# time horizon of a single rollout
HORIZON = 1500
# number of rollouts per training iteration
N_ROLLOUTS = 20
# number of parallel workers
N_CPUS = 2

# We place one autonomous vehicle and 22 human-driven vehicles in the network
vehicles = VehicleParams()
vehicles.add("rl",
             acceleration_controller=(IDMController, {}),
             lane_change_controller=(SimLaneChangeController, {}),
             routing_controller=(ConstructionRouter, {}),
             car_following_params=SumoCarFollowingParams(
                 speed_mode="obey_safe_speed",  
                 # we use the speed mode "obey_safe_speed" for better dynamics at the merge
             ),
             num_vehicles=2)
vehicles.add("human",
             acceleration_controller=(IDMController, {}),
             lane_change_controller=(SimLaneChangeController, {}),
             #routing_controller=(ContinuousRouter, {}),
             car_following_params=SumoCarFollowingParams(
                 speed_mode="obey_safe_speed",  
                 # we use the speed mode "obey_safe_speed" for better dynamics at the merge
             ),
             lane_change_params = SumoLaneChangeParams(lane_change_mode="strategic",lcpushy=1.0),
             num_vehicles=0)

# specify the edges vehicles can originate on
initial_config = InitialConfig(
    edges_distribution=["gneE4","gneE35","gneE38"]
)

# specify the routes for vehicles in the network
class Network(Network):

    def specify_routes(self, net_params):
        return {
                "gneE35": ["gneE35","gneE15","gneE13","gneE4.264","gneE4.264.110","gneE8","gneE9","gneE9.252","gneE33"],
                "gneE4": ["gneE4","gneE17","gneE11","gneE13","gneE4.264","gneE4.264.110","gneE8","gneE9","gneE9.252","gneE33"],
               "gneE8": ["gneE8","gneE9","gneE37","gneE38","gneE39","gneE4.264.110","gneE8"]
               }


inflow = InFlows()
inflow.add(veh_type="human",
           edge="gneE4",
           vehs_per_hour=1000,
            depart_lane="random",
            depart_speed="random",
            color="white")
inflow.add(veh_type="human",
           edge="gneE35",
           vehs_per_hour=5000,
            depart_lane="random",
            depart_speed="random",
            color="blue")


file_dir = "/home/llavezzo/"
net_params = NetParams(
    template="/mnt/c/Users/llave/Documents/GitHub/flow_osuphysics/lucalavezzo/constructionV4.net.xml",
    inflows=inflow
)

flow_params = dict(
    # name of the experiment
    exp_tag="construction_traffic",

    # name of the flow environment the experiment is running on
    env_name=myEnv,  # <------ here we replace the environment with our new environment

    # name of the network class the experiment is running on
    network=Network,

    # simulator that is used by the experiment
    simulator='traci',

    # sumo-related parameters (see flow.core.params.SumoParams)
    sim=SumoParams(
        sim_step=0.1,
        render=False,
        restart_instance=True
    ),

    # environment related parameters (see flow.core.params.EnvParams)
    env=EnvParams(
        horizon=HORIZON,
        warmup_steps=750,
        clip_actions=False,
        additional_params={
            "target_velocity": 20,
            "sort_vehicles": False,
            "max_accel": 1,
            "max_decel": 1,
        },
    ),

    # network-related parameters (see flow.core.params.NetParams and the
    # network's documentation or ADDITIONAL_NET_PARAMS component)
    net=net_params,

    # vehicles to be placed in the network at the start of a rollout (see
    # flow.core.params.VehicleParams)
    veh=vehicles,

    # parameters specifying the positioning of vehicles upon initialization/
    # reset (see flow.core.params.InitialConfig)
    initial=initial_config
)


def setup_exps():
    """Return the relevant components of an RLlib experiment.

    Returns
    -------
    str
        name of the training algorithm
    str
        name of the gym environment to be trained
    dict
        training configuration parameters
    """
    alg_run = "PPO"

    agent_cls = get_agent_class(alg_run)
    config = agent_cls._default_config.copy()
    config["num_workers"] = N_CPUS
    config["train_batch_size"] = HORIZON * N_ROLLOUTS
    config["gamma"] = 0.999  # discount rate
    config["model"].update({"fcnet_hiddens": [3, 3]})
    config["use_gae"] = True
    config["lambda"] = 0.97
    config["kl_target"] = 0.02
    config["num_sgd_iter"] = 10
    config['clip_actions'] = False  # FIXME(ev) temporary ray bug
    config["horizon"] = HORIZON

    # save the flow params for replay
    flow_json = json.dumps(
        flow_params, cls=FlowParamsEncoder, sort_keys=True, indent=4)
    config['env_config']['flow_params'] = flow_json
    config['env_config']['run'] = alg_run

    create_env, gym_name = make_create_env(params=flow_params, version=0)

    # Register as rllib env
    register_env(gym_name, create_env)
    return alg_run, gym_name, config
# Out:
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
alg_run, gym_name, config = setup_exps()
ray.init(num_cpus=N_CPUS + 1)
trials = run_experiments({
    flow_params["exp_tag"]: {
        "run": alg_run,
        "env": gym_name,
        "config": {
            **config
        },
        "checkpoint_freq": 20,
        "checkpoint_at_end": True,
        "max_failures": 999,
        "stop": {
            "training_iteration": 200,
        },
    }
})
# Out:
# 2020-03-04 14:49:32,476	WARNING services.py:592 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2020-03-04 14:49:32,479	INFO resource_spec.py:212 -- Starting Ray with 4.0 GiB memory available for workers and up to 2.01 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-03-04 14:49:32,678	WARNING services.py:856 -- Redis failed to start, retrying now.
# 2020-03-04 14:49:33,269	WARNING services.py:1080 -- Failed to start the dashboard. The dashboard requires Python 3 as well as 'pip install aiohttp psutil setproctitle grpcio'.
# == Status ==<br>Memory usage on this node: 9.3/15.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3/3 CPUs, 0/0 GPUs, 0.0/4.0 GiB heap, 0.0/1.37 GiB objects<br>Result logdir: /home/llavezzo/ray_results/construction_traffic<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_45d8cff8</td><td>RUNNING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (pid=2176) E0304 14:49:35.696097300    2176 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583351375.696051900","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=2176) E0304 14:49:35.696512700    2176 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=2177) E0304 14:49:35.677687300    2177 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583351375.677663400","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=2177) E0304 14:49:35.678006000    2177 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=2168) E0304 14:49:35.612058000    2168 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583351375.612034700","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=2168) E0304 14:49:35.612339700    2168 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=raylet) E0304 14:49:33.549064000    2154 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583351373.549039900","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=raylet) E0304 14:49:33.549475500    2154 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=raylet) E0304 14:49:33.592908700    2154 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=2168) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2168)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2168) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2168)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2168) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2168)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2168) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2168)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2168) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2168)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2168) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2168)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2168) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2168)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2168) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2168)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2168) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2168)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2168) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2168)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2168) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2168)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2168) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2168)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2168) 2020-03-04 14:49:40,797	INFO trainer.py:370 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=2168) 2020-03-04 14:49:41,771	INFO trainer.py:517 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=2176) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2176)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2176) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2176)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2176) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2176)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2176) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2176)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2176) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2176)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2176) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2176)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2177) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2177)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2177) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2177)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2177) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2177)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2177) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2177)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2177) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2177)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2177) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2177)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2176) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2176)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2176) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2176)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2176) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2176)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2176) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2176)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2176) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2176)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2176) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2176)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2177) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2177)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2177) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2177)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2177) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2177)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2177) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2177)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2177) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2177)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2177) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2177)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2168) 2020-03-04 14:49:50,771	WARNING util.py:41 -- Install gputil for GPU system monitoring.
# 2020-03-04 14:49:56,961	ERROR trial_runner.py:480 -- Trial PPO_myEnv-v0_45d8cff8: Error processing event.
# Traceback (most recent call last):
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py", line 424, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/ray_trial_executor.py", line 377, in fetch_result
#     result = ray.get(trial_future[0], DEFAULT_GET_TIMEOUT)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/worker.py", line 1492, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(UnboundLocalError): ray::PPO.train() (pid=2168, ip=172.31.50.197)
#   File "python/ray/_raylet.pyx", line 643, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 623, in function_executor
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 443, in train
#     raise e
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 432, in train
#     result = Trainable.train(self)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/trainable.py", line 254, in train
#     result = self._train()
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer_template.py", line 122, in _train
#     fetches = self.optimizer.step()
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/optimizers/multi_gpu_optimizer.py", line 136, in step
#     self.num_envs_per_worker, self.train_batch_size)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/optimizers/rollout.py", line 25, in collect_samples
#     next_sample = ray_get_and_free(fut_sample)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/memory.py", line 29, in ray_get_and_free
#     result = ray.get(object_ids)
# ray.exceptions.RayTaskError(UnboundLocalError): ray::RolloutWorker.sample() (pid=2177, ip=172.31.50.197)
#   File "python/ray/_raylet.pyx", line 643, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 623, in function_executor
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/rollout_worker.py", line 475, in sample
#     batches = [self.input_reader.next()]
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 52, in next
#     batches = [self.get_data()]
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 95, in get_data
#     item = next(self.rollout_provider)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 301, in _env_runner
#     base_env.poll()
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/env/base_env.py", line 308, in poll
#     self.new_obs = self.vector_env.vector_reset()
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/env/vector_env.py", line 96, in vector_reset
#     return [e.reset() for e in self.envs]
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/env/vector_env.py", line 96, in <listcomp>
#     return [e.reset() for e in self.envs]
#   File "/mnt/c/Users/llave/Documents/GitHub/flow/flow/envs/base.py", line 530, in reset
#     states = self.get_state()
#   File "/mnt/c/Users/llave/Documents/GitHub/flow_osuphysics/lucalavezzo/env_testV1.py", line 54, in get_state
#     print(len(ids))
# UnboundLocalError: local variable 'ids' referenced before assignment
# 2020-03-04 14:49:56,973	INFO trial_runner.py:547 -- Trial PPO_myEnv-v0_45d8cff8: Attempting to restore trial state from last checkpoint.
# == Status ==<br>Memory usage on this node: 10.3/15.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3/3 CPUs, 0/0 GPUs, 0.0/4.0 GiB heap, 0.0/1.37 GiB objects<br>Result logdir: /home/llavezzo/ray_results/construction_traffic<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_45d8cff8</td><td>RUNNING </td><td>     </td></tr>
# </tbody>
# </table><br>Number of errored trials: 1<br><table>
# <thead>
# <tr><th>Trial name           </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                 </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_45d8cff8</td><td style="text-align: right;">           1</td><td>/home/llavezzo/ray_results/construction_traffic/PPO_myEnv-v0_45d8cff8_2020-03-04_14-49-3452xr2pku/error.txt</td></tr>
# </tbody>
# </table><br>
# (pid=2340) E0304 14:49:58.822048000    2340 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583351398.822036800","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=2340) E0304 14:49:58.822179300    2340 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=2340) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2340)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2340) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2340)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2340) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2340)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2340) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2340)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2340) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2340)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2340) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2340)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2340) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2340)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2340) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2340)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2340) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2340)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2340) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2340)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2340) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2340)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2340) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2340)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2340) 2020-03-04 14:50:03,242	INFO trainer.py:370 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=2340) 2020-03-04 14:50:03,856	INFO trainer.py:517 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=2404) E0304 14:50:08.073453100    2404 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583351408.073442000","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=2404) E0304 14:50:08.073615700    2404 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=2403) E0304 14:50:08.146143800    2403 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583351408.146123300","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=2403) E0304 14:50:08.146505400    2403 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=2404) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2404)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2404) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2404)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2404) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2404)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2404) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2404)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2404) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2404)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2404) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2404)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2403) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2403)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2403) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2403)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2403) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2403)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2403) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2403)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2403) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2403)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2403) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2403)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2433) E0304 14:50:09.853498700    2433 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583351409.853481100","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=2433) E0304 14:50:09.853741900    2433 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=2340) 2020-03-04 14:50:11,328	WARNING util.py:41 -- Install gputil for GPU system monitoring.
# (pid=2404) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2404)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2404) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2404)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2404) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2404)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2404) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2404)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2404) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2404)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2404) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2404)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2403) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2403)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2403) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2403)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2403) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2403)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2403) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2403)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2403) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2403)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2403) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2403)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2020-03-04 14:50:17,944	ERROR trial_runner.py:480 -- Trial PPO_myEnv-v0_45d8cff8: Error processing event.
# Traceback (most recent call last):
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py", line 424, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/ray_trial_executor.py", line 377, in fetch_result
#     result = ray.get(trial_future[0], DEFAULT_GET_TIMEOUT)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/worker.py", line 1492, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(UnboundLocalError): ray::PPO.train() (pid=2340, ip=172.31.50.197)
#   File "python/ray/_raylet.pyx", line 643, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 623, in function_executor
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 443, in train
#     raise e
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 432, in train
#     result = Trainable.train(self)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/trainable.py", line 254, in train
#     result = self._train()
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer_template.py", line 122, in _train
#     fetches = self.optimizer.step()
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/optimizers/multi_gpu_optimizer.py", line 136, in step
#     self.num_envs_per_worker, self.train_batch_size)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/optimizers/rollout.py", line 25, in collect_samples
#     next_sample = ray_get_and_free(fut_sample)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/memory.py", line 29, in ray_get_and_free
#     result = ray.get(object_ids)
# ray.exceptions.RayTaskError(UnboundLocalError): ray::RolloutWorker.sample() (pid=2404, ip=172.31.50.197)
#   File "python/ray/_raylet.pyx", line 643, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 623, in function_executor
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/rollout_worker.py", line 475, in sample
#     batches = [self.input_reader.next()]
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 52, in next
#     batches = [self.get_data()]
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 95, in get_data
#     item = next(self.rollout_provider)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 301, in _env_runner
#     base_env.poll()
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/env/base_env.py", line 308, in poll
#     self.new_obs = self.vector_env.vector_reset()
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/env/vector_env.py", line 96, in vector_reset
#     return [e.reset() for e in self.envs]
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/env/vector_env.py", line 96, in <listcomp>
#     return [e.reset() for e in self.envs]
#   File "/mnt/c/Users/llave/Documents/GitHub/flow/flow/envs/base.py", line 530, in reset
#     states = self.get_state()
#   File "/mnt/c/Users/llave/Documents/GitHub/flow_osuphysics/lucalavezzo/env_testV1.py", line 54, in get_state
#     print(len(ids))
# UnboundLocalError: local variable 'ids' referenced before assignment
# 2020-03-04 14:50:17,953	INFO trial_runner.py:547 -- Trial PPO_myEnv-v0_45d8cff8: Attempting to restore trial state from last checkpoint.
# == Status ==<br>Memory usage on this node: 10.4/15.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3/3 CPUs, 0/0 GPUs, 0.0/4.0 GiB heap, 0.0/1.37 GiB objects<br>Result logdir: /home/llavezzo/ray_results/construction_traffic<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_45d8cff8</td><td>RUNNING </td><td>     </td></tr>
# </tbody>
# </table><br>Number of errored trials: 1<br><table>
# <thead>
# <tr><th>Trial name           </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                 </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_45d8cff8</td><td style="text-align: right;">           2</td><td>/home/llavezzo/ray_results/construction_traffic/PPO_myEnv-v0_45d8cff8_2020-03-04_14-49-3452xr2pku/error.txt</td></tr>
# </tbody>
# </table><br>
# (pid=2433) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2433)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2433) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2433)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2433) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2433)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2433) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2433)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2433) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2433)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2433) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2433)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2433) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2433)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2433) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2433)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2433) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2433)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2433) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2433)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2433) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2433)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2433) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2433)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2433) 2020-03-04 14:50:22,615	INFO trainer.py:370 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=2433) 2020-03-04 14:50:23,488	INFO trainer.py:517 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=2534) E0304 14:50:27.949312900    2534 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583351427.949294700","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=2534) E0304 14:50:27.949566200    2534 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=2535) E0304 14:50:27.965537900    2535 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583351427.965527400","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=2535) E0304 14:50:27.965672900    2535 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=2534) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2534)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2534) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2534)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2534) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2534)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2534) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2534)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2534) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2534)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2534) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2534)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2535) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2535)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2535) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2535)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2535) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2535)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
#     item = next(self.rollout_provider)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 301, in _env_runner
#     base_env.poll()
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/env/base_env.py", line 308, in poll
#     self.new_obs = self.vector_env.vector_reset()
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/env/vector_env.py", line 96, in vector_reset
#     return [e.reset() for e in self.envs]
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/env/vector_env.py", line 96, in <listcomp>
#     return [e.reset() for e in self.envs]
#   File "/mnt/c/Users/llave/Documents/GitHub/flow/flow/envs/base.py", line 530, in reset
#     states = self.get_state()
#   File "/mnt/c/Users/llave/Documents/GitHub/flow_osuphysics/lucalavezzo/env_testV1.py", line 54, in get_state
#     print(len(ids))
# UnboundLocalError: local variable 'ids' referenced before assignment
# 2020-03-04 14:50:38,331	INFO trial_runner.py:547 -- Trial PPO_myEnv-v0_45d8cff8: Attempting to restore trial state from last checkpoint.
# == Status ==<br>Memory usage on this node: 10.4/15.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3/3 CPUs, 0/0 GPUs, 0.0/4.0 GiB heap, 0.0/1.37 GiB objects<br>Result logdir: /home/llavezzo/ray_results/construction_traffic<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_45d8cff8</td><td>RUNNING </td><td>     </td></tr>
# </tbody>
# </table><br>Number of errored trials: 1<br><table>
# <thead>
# <tr><th>Trial name           </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                 </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_45d8cff8</td><td style="text-align: right;">           3</td><td>/home/llavezzo/ray_results/construction_traffic/PPO_myEnv-v0_45d8cff8_2020-03-04_14-49-3452xr2pku/error.txt</td></tr>
# </tbody>
# </table><br>
# (pid=2565) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2565)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2565) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2565)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2565) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2565)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2565) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2565)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2565) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2565)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2565) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2565)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2565) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2565)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2565) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2565)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2565) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2565)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2565) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2565)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2565) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2565)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2565) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2565)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2565) 2020-03-04 14:50:43,365	INFO trainer.py:370 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=2565) 2020-03-04 14:50:44,223	INFO trainer.py:517 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=2665) E0304 14:50:49.527616900    2665 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583351449.527591300","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=2665) E0304 14:50:49.527968400    2665 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=2666) E0304 14:50:49.601709400    2666 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583351449.601676500","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=2666) E0304 14:50:49.602140000    2666 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=2665) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2665)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2665) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2665)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2665) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2665)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2665) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2665)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2665) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2665)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2665) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2665)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2666) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2666)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2666) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2666)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2666) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2666)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2666) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2666)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2666) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2666)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2666) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2666)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2696) E0304 14:50:51.643523700    2696 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583351451.643504400","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=2696) E0304 14:50:51.643799500    2696 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=2565) 2020-03-04 14:50:53,190	WARNING util.py:41 -- Install gputil for GPU system monitoring.
# (pid=2665) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2665)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2665) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2665)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2665) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2665)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2665) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2665)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2665) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2665)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2665) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2665)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2666) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2666)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2666) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2666)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2666) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2666)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2666) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2666)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2666) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2666)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2666) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2666)   np_resource = np.dtype([("resource", np.ubyte, 1)])
