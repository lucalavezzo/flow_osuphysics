# %%
import json
import ray
from ray.rllib.agents.registry import get_agent_class
from ray.tune import run_experiments
from ray.tune.registry import register_env
import numpy as np
from flow.networks.ring import RingNetwork, ADDITIONAL_NET_PARAMS
from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder
from flow.core.params import SumoParams, EnvParams, InitialConfig, NetParams
from flow.core.params import VehicleParams, SumoCarFollowingParams
from flow.controllers import RLController, IDMController, ContinuousRouter
from gym.spaces.box import Box
from gym.spaces import Tuple
from flow.core.params import InFlows
from flow.controllers import SimLaneChangeController
from flow.networks import Network
import os
from flow.core.params import SumoLaneChangeParams

from env_merge import myEnv

ADDITIONAL_ENV_PARAMS = {
    "max_accel": 1,
    "max_decel": 1,
}

# time horizon of a single rollout
HORIZON = 1000
# number of rollouts per training iteration
N_ROLLOUTS = 20
# number of parallel workers
N_CPUS = 2

vehicles = VehicleParams()
vehicles.add("rl",
             acceleration_controller=(IDMController, {}),
             lane_change_controller=(SimLaneChangeController, {}),
             #routing_controller=(ContinuousRouter, {}),
             car_following_params=SumoCarFollowingParams(
                 speed_mode="obey_safe_speed",  
                 # we use the speed mode "obey_safe_speed" for better dynamics at the merge
             ),
             num_vehicles=0)
vehicles.add("human",
             acceleration_controller=(IDMController, {}),
             lane_change_controller=(SimLaneChangeController, {}),
             #routing_controller=(ContinuousRouter, {}),
             car_following_params=SumoCarFollowingParams(
                 speed_mode="obey_safe_speed",  
                 # we use the speed mode "obey_safe_speed" for better dynamics at the merge
             ),
             lane_change_params = SumoLaneChangeParams(lane_change_mode="strategic",lcpushy=1.0),
             num_vehicles=0)

# specify the edges vehicles can originate on
initial_config = InitialConfig(
    edges_distribution=["gneE6","gneE7"]
)
    
# specify the routes for vehicles in the network
class Network(Network):

    def specify_routes(self, net_params):
        return {
                "gneE7": ["gneE7","gneE6.243"],
                "gneE6": ["gneE6","gneE6.243"]
               }


inflow = InFlows()

#highway vehicles
inflow.add(veh_type="human",
           edge="gneE6",
           vehs_per_hour=5000,
            depart_lane="random",
            depart_speed="random",
            color="white")

#merging vehicles
inflow.add(veh_type="rl",
           edge="gneE7",
           vehs_per_hour=1000,
            depart_lane="random",
            depart_speed="random",
            color="blue")
inflow.add(veh_type="rl",
           edge="gneE7",
           vehs_per_hour=500,
            depart_lane="random",
            depart_speed="random",
            color="red")


fileDir='/mnt/c/Users/llave/Documents/GitHub/flow_osuphysics/lucalavezzo/merge.net.xml'
net_params = NetParams(
    template=fileDir,
    inflows=inflow
)

flow_params = dict(
    # name of the experiment
    exp_tag="merge",

    # name of the flow environment the experiment is running on
    env_name=myEnv,  # <------ here we replace the environment with our new environment

    # name of the network class the experiment is running on
    network=Network,

    # simulator that is used by the experiment
    simulator='traci',

    # sumo-related parameters (see flow.core.params.SumoParams)
    sim=SumoParams(
        sim_step=0.1,
        render=False,
        restart_instance=True,
    ),

    # environment related parameters (see flow.core.params.EnvParams)
    env=EnvParams(
        horizon=HORIZON,
        warmup_steps=750,
        clip_actions=False,
        additional_params={
            "target_velocity": 20,
            "sort_vehicles": False,
            "max_accel": 1,
            "max_decel": 1,
        },
    ),

    # network-related parameters (see flow.core.params.NetParams and the
    # network's documentation or ADDITIONAL_NET_PARAMS component)
    net=net_params,

    # vehicles to be placed in the network at the start of a rollout (see
    # flow.core.params.VehicleParams)
    veh=vehicles,

    # parameters specifying the positioning of vehicles upon initialization/
    # reset (see flow.core.params.InitialConfig)
    initial=initial_config
)


def setup_exps():
    """Return the relevant components of an RLlib experiment.

    Returns
    -------
    str
        name of the training algorithm
    str
        name of the gym environment to be trained
    dict
        training configuration parameters
    """
    alg_run = "PPO"

    agent_cls = get_agent_class(alg_run)
    config = agent_cls._default_config.copy()
    config["num_workers"] = N_CPUS
    config["train_batch_size"] = HORIZON * N_ROLLOUTS
    config["gamma"] = 0.999  # discount rate
    config["model"].update({"fcnet_hiddens": [3, 3]})
    config["use_gae"] = True
    config["lambda"] = 0.97
    config["kl_target"] = 0.02
    config["num_sgd_iter"] = 10
    config['clip_actions'] = False  # FIXME(ev) temporary ray bug
    config["horizon"] = HORIZON

    # save the flow params for replay
    flow_json = json.dumps(
        flow_params, cls=FlowParamsEncoder, sort_keys=True, indent=4)
    config['env_config']['flow_params'] = flow_json
    config['env_config']['run'] = alg_run

    create_env, gym_name = make_create_env(params=flow_params, version=0)

    # Register as rllib env
    register_env(gym_name, create_env)
    return alg_run, gym_name, config
# Out:
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
alg_run, gym_name, config = setup_exps()
ray.init(num_cpus=N_CPUS + 1)
trials = run_experiments({
    flow_params["exp_tag"]: {
        "run": alg_run,
        "env": gym_name,
        "config": {
            **config
        },
        "checkpoint_freq": 20,
        "checkpoint_at_end": True,
        "max_failures": 999,
        "stop": {
            "training_iteration": 200,
        },
    }
})
# Out:
# 2020-03-17 11:37:40,101	WARNING services.py:592 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2020-03-17 11:37:40,105	INFO resource_spec.py:212 -- Starting Ray with 5.03 GiB memory available for workers and up to 2.54 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-03-17 11:37:40,766	WARNING services.py:1080 -- Failed to start the dashboard. The dashboard requires Python 3 as well as 'pip install aiohttp psutil setproctitle grpcio'.
# == Status ==<br>Memory usage on this node: 7.6/15.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3/3 CPUs, 0/0 GPUs, 0.0/5.03 GiB heap, 0.0/1.71 GiB objects<br>Result logdir: /home/llavezzo/ray_results/merge<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_3d68d76e</td><td>RUNNING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (pid=568) E0317 11:37:43.216030400     568 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1584459463.216008800","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=568) E0317 11:37:43.216359800     568 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=569) E0317 11:37:43.257234500     569 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1584459463.257203800","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=569) E0317 11:37:43.257604500     569 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=567) E0317 11:37:43.180202100     567 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1584459463.180179800","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=567) E0317 11:37:43.180473600     567 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=raylet) E0317 11:37:41.113206100     546 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1584459461.113192400","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=raylet) E0317 11:37:41.113448800     546 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=raylet) E0317 11:37:41.147901900     546 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=567) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=567)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=567) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=567)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=567) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=567)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=567) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=567)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=567) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=567)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=567) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=567)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=567) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=567)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=567) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=567)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=567) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=567)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=567) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=567)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=567) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=567)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=567) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=567)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=567) 2020-03-17 11:37:48,606	INFO trainer.py:370 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=567) 2020-03-17 11:37:49,668	INFO trainer.py:517 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=569)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=569)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=569)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=569)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=569)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=569)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=568)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=568)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=568)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=568)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=568)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=568)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=568)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=568)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=568)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=568)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=568)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=568)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=569)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=569)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=569)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=569)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=569)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=569)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=567) 2020-03-17 11:38:00,023	INFO trainable.py:178 -- _setup took 11.417 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (pid=567) 2020-03-17 11:38:00,023	WARNING util.py:41 -- Install gputil for GPU system monitoring.
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=568)   out=out, **kwargs)
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=568)   ret = ret.dtype.type(ret / rcount)
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=569)   out=out, **kwargs)
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=569)   ret = ret.dtype.type(ret / rcount)
# (pid=569) Warning: Vehicle 'flow_10.0' performs emergency braking with decel=-11.58 wished=4.50 severity=1.57, time=16.50.
# (pid=568) Warning: Vehicle 'flow_00.4' performs emergency braking with decel=-12.17 wished=4.50 severity=1.70, time=19.50.
# (pid=568) Warning: Vehicle 'flow_10.1' performs emergency braking with decel=-106.73 wished=4.50 severity=22.72, time=21.40.
# (pid=568) Warning: Vehicle 'flow_10.2' performs emergency braking with decel=-16.11 wished=4.50 severity=2.58, time=21.50.
# (pid=568) Warning: Vehicle 'flow_00.5' performs emergency braking with decel=-82.71 wished=4.50 severity=17.38, time=26.50.
# (pid=569) Warning: Vehicle 'flow_00.1' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=26.60.
# (pid=569) Warning: Teleporting vehicle 'flow_20.1'; collision with vehicle 'flow_00.1', lane=':gneJ11_0_0', gap=-1.00, time=27.10 stage=move.
# (pid=569) Warning: Vehicle 'flow_20.1' ends teleporting on edge 'gneE6.243', time 27.10.
# (pid=568) Warning: Vehicle 'flow_00.5' performs emergency braking with decel=-13.26 wished=4.50 severity=1.95, time=28.80.
# (pid=568) Warning: Vehicle 'flow_00.5' performs emergency braking with decel=-10.38 wished=4.50 severity=1.31, time=31.00.
# (pid=569) Warning: Vehicle 'flow_00.8' performs emergency braking with decel=-10.56 wished=4.50 severity=1.35, time=32.80.
# (pid=568) Warning: Vehicle 'flow_00.5' performs emergency braking with decel=-11.77 wished=4.50 severity=1.62, time=33.40.
# (pid=569) Warning: Vehicle 'flow_20.2' performs emergency braking with decel=-92.73 wished=4.50 severity=19.61, time=36.90.
# (pid=568) Warning: Vehicle 'flow_10.5' performs emergency braking with decel=-116.50 wished=4.50 severity=24.89, time=37.90.
# (pid=568) Warning: Vehicle 'flow_10.6' performs emergency braking with decel=-9.81 wished=4.50 severity=1.18, time=38.00.
# (pid=569) Warning: Vehicle 'flow_00.20' performs emergency braking with decel=-27.18 wished=4.50 severity=5.04, time=38.30.
# (pid=569) Warning: Vehicle 'flow_00.20' performs emergency braking with decel=-10.38 wished=4.50 severity=1.31, time=42.00.
# (pid=569) Warning: Vehicle 'flow_10.6' performs emergency braking with decel=-41.50 wished=4.50 severity=8.22, time=43.90.
# (pid=569) Warning: Vehicle 'flow_00.24' performs emergency braking with decel=-10.56 wished=4.50 severity=1.35, time=47.80.
# (pid=568) Warning: Vehicle 'flow_00.18' performs emergency braking with decel=-10.05 wished=4.50 severity=1.23, time=51.50.
# (pid=569) Warning: Vehicle 'flow_00.24' performs emergency braking with decel=-10.37 wished=4.50 severity=1.30, time=51.90.
# (pid=569) Warning: Vehicle 'flow_10.8' performs emergency braking with decel=-54.53 wished=4.50 severity=11.12, time=53.50.
# (pid=569) Warning: Vehicle 'flow_00.31' performs emergency braking with decel=-9.57 wished=4.50 severity=1.13, time=60.00.
# (pid=568) Warning: Vehicle 'flow_10.10' performs emergency braking with decel=-87.95 wished=4.50 severity=18.54, time=59.70.
# (pid=568) Warning: Vehicle 'flow_20.5' performs emergency braking with decel=-9.63 wished=4.50 severity=1.14, time=59.80.
# (pid=569) Warning: Vehicle 'flow_00.31' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=63.70.
# (pid=569) Warning: Vehicle 'flow_00.38' performs emergency braking with decel=-13.03 wished=4.50 severity=1.90, time=68.50.
# (pid=568) Warning: Vehicle 'flow_10.12' performs emergency braking with decel=-79.23 wished=4.50 severity=16.61, time=70.20.
# (pid=568) Warning: Vehicle 'flow_20.6' performs emergency braking with decel=-9.18 wished=4.50 severity=1.04, time=70.30.
# (pid=569) Warning: Vehicle 'flow_00.38' performs emergency braking with decel=-9.28 wished=4.50 severity=1.06, time=71.10.
# (pid=569) Warning: Vehicle 'flow_20.6' performs emergency braking with decel=-23.87 wished=4.50 severity=4.30, time=75.00.
# (pid=568) Warning: Vehicle 'flow_00.34' performs emergency braking with decel=-9.54 wished=4.50 severity=1.12, time=76.70.
# (pid=569) Warning: Vehicle 'flow_00.52' performs emergency braking with decel=-13.82 wished=4.50 severity=2.07, time=78.20.
# (pid=569) Warning: Vehicle 'flow_00.52' performs emergency braking with decel=-9.04 wished=4.50 severity=1.01, time=81.10.
# (pid=568) Warning: Vehicle 'flow_20.7' performs emergency braking with decel=-89.25 wished=4.50 severity=18.83, time=82.20.
# (pid=569) Warning: Vehicle 'flow_10.14' performs emergency braking with decel=-111.78 wished=4.50 severity=23.84, time=83.10.
# (pid=569) Warning: Vehicle 'flow_00.56' performs emergency braking with decel=-25.30 wished=4.50 severity=4.62, time=86.40.
# (pid=568) Warning: Vehicle 'flow_20.7' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=85.70.
# (pid=569) Warning: Vehicle 'flow_10.15' performs emergency braking with decel=-82.31 wished=4.50 severity=17.29, time=91.30.
# (pid=568) Warning: Vehicle 'flow_00.53' performs emergency braking with decel=-11.57 wished=4.50 severity=1.57, time=90.90.
# (pid=568) Warning: Vehicle 'flow_10.16' performs emergency braking with decel=-50.18 wished=4.50 severity=10.15, time=93.40.
# (pid=569) Warning: Vehicle 'flow_00.61' performs emergency braking with decel=-9.46 wished=4.50 severity=1.10, time=97.70.
# (pid=568) Warning: Vehicle 'flow_00.62' performs emergency braking with decel=-9.78 wished=4.50 severity=1.17, time=97.90.
# (pid=568) Warning: Vehicle 'flow_00.62' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=100.20.
# (pid=569) Warning: Vehicle 'flow_10.17' performs emergency braking with decel=-67.92 wished=4.50 severity=14.09, time=101.90.
# (pid=569) Warning: Vehicle 'flow_00.71' performs emergency braking with decel=-48.48 wished=4.50 severity=9.77, time=108.10.
# (pid=568) Warning: Vehicle 'flow_00.69' performs emergency braking with decel=-9.70 wished=4.50 severity=1.16, time=110.80.
# (pid=568) Warning: Vehicle 'flow_10.19' performs emergency braking with decel=-60.01 wished=4.50 severity=12.34, time=112.90.
# (pid=569) Warning: Vehicle 'flow_10.20' performs emergency braking with decel=-73.01 wished=4.50 severity=15.22, time=114.90.
# (pid=569) Warning: Vehicle 'flow_20.10' performs emergency braking with decel=-9.41 wished=4.50 severity=1.09, time=115.00.
# (pid=569) Warning: Vehicle 'flow_00.83' performs emergency braking with decel=-13.84 wished=4.50 severity=2.08, time=121.60.
# (pid=569) Warning: Vehicle 'flow_10.21' performs emergency braking with decel=-27.16 wished=4.50 severity=5.04, time=123.90.
# (pid=568) Warning: Vehicle 'flow_00.84' performs emergency braking with decel=-10.40 wished=4.50 severity=1.31, time=123.20.
# (pid=568) Warning: Vehicle 'flow_00.84' performs emergency braking with decel=-10.90 wished=4.50 severity=1.42, time=123.30.
# (pid=568) Warning: Vehicle 'flow_00.84' performs emergency braking with decel=-11.63 wished=4.50 severity=1.58, time=127.80.
# (pid=568) Warning: Vehicle 'flow_20.11' performs emergency braking with decel=-75.35 wished=4.50 severity=15.74, time=129.80.
# (pid=569) Warning: Vehicle 'flow_20.11' performs emergency braking with decel=-51.61 wished=4.50 severity=10.47, time=133.00.
# (pid=569) Warning: Vehicle 'flow_00.90' performs emergency braking with decel=-9.71 wished=4.50 severity=1.16, time=137.10.
# (pid=568) Warning: Vehicle 'flow_00.92' performs emergency braking with decel=-11.46 wished=4.50 severity=1.55, time=136.50.
# (pid=569) Warning: Vehicle 'flow_00.90' performs emergency braking with decel=-13.97 wished=4.50 severity=2.10, time=139.30.
# (pid=568) Warning: Vehicle 'flow_10.24' performs emergency braking with decel=-12.81 wished=4.50 severity=1.85, time=138.60.
# (pid=569) Warning: Vehicle 'flow_10.24' performs emergency braking with decel=-29.87 wished=4.50 severity=5.64, time=141.80.
# (pid=569) Warning: Vehicle 'flow_10.25' performs emergency braking with decel=-51.73 wished=4.50 severity=10.50, time=150.70.
# (pid=568) Warning: Vehicle 'flow_00.100' performs emergency braking with decel=-10.25 wished=4.50 severity=1.28, time=147.60.
# (pid=568) Warning: Vehicle 'flow_10.26' performs emergency braking with decel=-28.32 wished=4.50 severity=5.29, time=149.60.
# (pid=569) Warning: Vehicle 'flow_00.102' performs emergency braking with decel=-14.78 wished=4.50 severity=2.28, time=157.10.
# (pid=569) Warning: Vehicle 'flow_20.13' performs emergency braking with decel=-20.52 wished=4.50 severity=3.56, time=159.50.
# (pid=568) Warning: Vehicle 'flow_00.108' performs emergency braking with decel=-9.88 wished=4.50 severity=1.20, time=158.50.
# (pid=568) Warning: Vehicle 'flow_10.28' performs emergency braking with decel=-24.87 wished=4.50 severity=4.53, time=160.50.
# (pid=569) Warning: Vehicle 'flow_00.116' performs emergency braking with decel=-10.79 wished=4.50 severity=1.40, time=165.60.
# (pid=569) Warning: Vehicle 'flow_10.28' performs emergency braking with decel=-48.43 wished=4.50 severity=9.76, time=168.00.
# (pid=568) Warning: Vehicle 'flow_00.121' performs emergency braking with decel=-10.75 wished=4.50 severity=1.39, time=169.50.
# (pid=568) Warning: Vehicle 'flow_10.30' performs emergency braking with decel=-15.06 wished=4.50 severity=2.35, time=171.30.
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=569)   out=out, **kwargs)
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=569)   ret = ret.dtype.type(ret / rcount)
# (pid=569) Warning: Vehicle 'flow_10.0' performs emergency braking with decel=-12.43 wished=4.50 severity=1.76, time=19.40.
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=568)   out=out, **kwargs)
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=568)   ret = ret.dtype.type(ret / rcount)
# (pid=569) Warning: Vehicle 'flow_20.0' performs emergency braking with decel=-120.56 wished=4.50 severity=25.79, time=22.70.
# (pid=569) Warning: Vehicle 'flow_20.0' performs emergency braking with decel=-25.95 wished=4.50 severity=4.77, time=25.50.
# (pid=569) Warning: Vehicle 'flow_00.7' performs emergency braking with decel=-19.02 wished=4.50 severity=3.23, time=26.90.
# (pid=569) Warning: Vehicle 'flow_00.7' performs emergency braking with decel=-65.97 wished=4.50 severity=13.66, time=30.00.
# (pid=568) Warning: Vehicle 'flow_00.2' performs emergency braking with decel=-118.67 wished=4.50 severity=25.37, time=19.80.
# (pid=568) Warning: Vehicle 'flow_00.2' performs emergency braking with decel=-11.22 wished=4.50 severity=1.49, time=23.30.
# (pid=568) Warning: Vehicle 'flow_00.2' performs emergency braking with decel=-14.77 wished=4.50 severity=2.28, time=25.20.
# (pid=568) Warning: Vehicle 'flow_20.1' performs emergency braking with decel=-23.30 wished=4.50 severity=4.18, time=27.20.
# (pid=568) Warning: Vehicle 'flow_20.1' performs emergency braking with decel=-17.24 wished=4.50 severity=2.83, time=27.50.
# (pid=569) Warning: Vehicle 'flow_10.3' performs emergency braking with decel=-97.64 wished=4.50 severity=20.70, time=36.60.
# (pid=568) Warning: Vehicle 'flow_10.3' performs emergency braking with decel=-74.71 wished=4.50 severity=15.60, time=32.10.
# (pid=568) Warning: Vehicle 'flow_00.13' performs emergency braking with decel=-27.47 wished=4.50 severity=5.10, time=33.80.
# (pid=568) Warning: Vehicle 'flow_00.13' performs emergency braking with decel=-12.29 wished=4.50 severity=1.73, time=34.90.
# (pid=568) Warning: Vehicle 'flow_00.13' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=38.90.
# (pid=569) Warning: Vehicle 'flow_10.5' performs emergency braking with decel=-94.94 wished=4.50 severity=20.10, time=46.60.
# (pid=568) Warning: Vehicle 'flow_00.19' performs emergency braking with decel=-12.61 wished=4.50 severity=1.80, time=43.00.
# (pid=568) Warning: Vehicle 'flow_00.19' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=46.10.
# (pid=569) Warning: Vehicle 'flow_00.25' performs emergency braking with decel=-60.14 wished=4.50 severity=12.36, time=55.00.
# (pid=568) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-14.74 wished=4.50 severity=2.28, time=51.00.
# (pid=568) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-9.34 wished=4.50 severity=1.08, time=53.80.
# (pid=569) Warning: Vehicle 'flow_10.8' performs emergency braking with decel=-99.96 wished=4.50 severity=21.21, time=59.70.
# (pid=568) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-13.10 wished=4.50 severity=1.91, time=55.70.
# (pid=568) Warning: Vehicle 'flow_20.4' performs emergency braking with decel=-48.89 wished=4.50 severity=9.86, time=57.60.
# (pid=568) Warning: Vehicle 'flow_00.32' performs emergency braking with decel=-9.21 wished=4.50 severity=1.05, time=61.20.
# (pid=569) Warning: Vehicle 'flow_10.9' performs emergency braking with decel=-76.69 wished=4.50 severity=16.04, time=67.90.
# (pid=569) Warning: Vehicle 'flow_10.10' performs emergency braking with decel=-11.10 wished=4.50 severity=1.47, time=68.00.
# (pid=568) Warning: Vehicle 'flow_00.32' performs emergency braking with decel=-11.01 wished=4.50 severity=1.45, time=65.50.
# (pid=568) Warning: Vehicle 'flow_20.5' performs emergency braking with decel=-26.03 wished=4.50 severity=4.78, time=67.60.
# (pid=568) Warning: Vehicle 'flow_00.36' performs emergency braking with decel=-12.55 wished=4.50 severity=1.79, time=70.90.
# (pid=568) Warning: Vehicle 'flow_00.36' performs emergency braking with decel=-10.20 wished=4.50 severity=1.27, time=73.50.
# (pid=569) Warning: Vehicle 'flow_10.11' performs emergency braking with decel=-67.06 wished=4.50 severity=13.90, time=78.60.
# (pid=568) Warning: Vehicle 'flow_20.6' performs emergency braking with decel=-106.81 wished=4.50 severity=22.74, time=77.50.
# (pid=569) Warning: Vehicle 'flow_00.42' performs emergency braking with decel=-9.33 wished=4.50 severity=1.07, time=87.50.
# (pid=569) Warning: Vehicle 'flow_10.13' performs emergency braking with decel=-61.36 wished=4.50 severity=12.63, time=89.50.
# (pid=568) Warning: Vehicle 'flow_00.52' performs emergency braking with decel=-15.55 wished=4.50 severity=2.46, time=92.80.
# (pid=568) Warning: Vehicle 'flow_00.52' performs emergency braking with decel=-10.66 wished=4.50 severity=1.37, time=93.60.
# (pid=569) Warning: Vehicle 'flow_00.54' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=98.70.
# (pid=568) Warning: Vehicle 'flow_00.52' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=97.50.
# (pid=569) Warning: Vehicle 'flow_00.63' performs emergency braking with decel=-9.80 wished=4.50 severity=1.18, time=104.40.
# (pid=568) Warning: Vehicle 'flow_00.59' performs emergency braking with decel=-14.70 wished=4.50 severity=2.27, time=102.20.
# (pid=568) Warning: Vehicle 'flow_00.59' performs emergency braking with decel=-12.13 wished=4.50 severity=1.70, time=104.90.
# (pid=569) Warning: Vehicle 'flow_00.63' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=109.40.
# (pid=568) Warning: Vehicle 'flow_00.59' performs emergency braking with decel=-12.10 wished=4.50 severity=1.69, time=106.70.
# (pid=568) Warning: Vehicle 'flow_10.19' performs emergency braking with decel=-29.95 wished=4.50 severity=5.66, time=108.70.
# (pid=569) Warning: Vehicle 'flow_00.72' performs emergency braking with decel=-9.88 wished=4.50 severity=1.20, time=119.90.
# (pid=568) Warning: Vehicle 'flow_00.67' performs emergency braking with decel=-11.83 wished=4.50 severity=1.63, time=116.50.
# (pid=569) Warning: Vehicle 'flow_10.19' performs emergency braking with decel=-34.11 wished=4.50 severity=6.58, time=121.90.
# (pid=568) Warning: Vehicle 'flow_10.21' performs emergency braking with decel=-52.45 wished=4.50 severity=10.66, time=118.50.
# (pid=568) Warning: Vehicle 'flow_00.80' performs emergency braking with decel=-11.20 wished=4.50 severity=1.49, time=121.90.
# (pid=568) Warning: Vehicle 'flow_00.80' performs emergency braking with decel=-9.05 wished=4.50 severity=1.01, time=124.60.
# (pid=568) Warning: Vehicle 'flow_00.80' performs emergency braking with decel=-13.22 wished=4.50 severity=1.94, time=126.50.
# (pid=569) Warning: Vehicle 'flow_00.84' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=131.00.
# (pid=568) Warning: Vehicle 'flow_10.23' performs emergency braking with decel=-11.67 wished=4.50 severity=1.59, time=128.20.
# (pid=568) Warning: Vehicle 'flow_00.90' performs emergency braking with decel=-13.65 wished=4.50 severity=2.03, time=131.50.
# (pid=568) Warning: Vehicle 'flow_00.90' performs emergency braking with decel=-9.01 wished=4.50 severity=1.00, time=134.10.
# (pid=568) Warning: Vehicle 'flow_00.90' performs emergency braking with decel=-13.20 wished=4.50 severity=1.93, time=136.00.
# (pid=569) Warning: Vehicle 'flow_00.101' performs emergency braking with decel=-10.15 wished=4.50 severity=1.26, time=141.40.
# (pid=568) Warning: Vehicle 'flow_10.25' performs emergency braking with decel=-109.63 wished=4.50 severity=23.36, time=138.10.
# (pid=569) Warning: Vehicle 'flow_10.23' performs emergency braking with decel=-54.82 wished=4.50 severity=11.18, time=143.40.
# (pid=568) Warning: Vehicle 'flow_20.13' performs emergency braking with decel=-98.71 wished=4.50 severity=20.94, time=146.20.
# (pid=568) Warning: Vehicle 'flow_10.27' performs emergency braking with decel=-10.44 wished=4.50 severity=1.32, time=146.30.
# (pid=569) Warning: Vehicle 'flow_00.105' performs emergency braking with decel=-10.54 wished=4.50 severity=1.34, time=152.20.
# (pid=568) Warning: Vehicle 'flow_00.102' performs emergency braking with decel=-44.47 wished=4.50 severity=8.88, time=149.40.
# (pid=569) Warning: Vehicle 'flow_10.25' performs emergency braking with decel=-20.75 wished=4.50 severity=3.61, time=154.10.
# (pid=568) Warning: Vehicle 'flow_10.27' performs emergency braking with decel=-46.29 wished=4.50 severity=9.29, time=152.10.
# (pid=569) Warning: Vehicle 'flow_00.111' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=158.10.
# (pid=569) Warning: Vehicle 'flow_00.111' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=163.10.
# (pid=568) Warning: Vehicle 'flow_00.108' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=161.30.
# (pid=569) Warning: Vehicle 'flow_00.123' performs emergency braking with decel=-9.78 wished=4.50 severity=1.17, time=173.50.
# (pid=568) Warning: Vehicle 'flow_00.120' performs emergency braking with decel=-10.49 wished=4.50 severity=1.33, time=172.00.
# (pid=568) Warning: Vehicle 'flow_10.31' performs emergency braking with decel=-20.98 wished=4.50 severity=3.66, time=173.80.
# (pid=568) Warning: Vehicle 'flow_10.31' performs emergency braking with decel=-25.93 wished=4.50 severity=4.76, time=174.10.
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=569)   out=out, **kwargs)
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=569)   ret = ret.dtype.type(ret / rcount)
# (pid=569) Warning: Vehicle 'flow_00.5' performs emergency braking with decel=-102.17 wished=4.50 severity=21.71, time=24.90.
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=568)   out=out, **kwargs)
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=568)   ret = ret.dtype.type(ret / rcount)
# (pid=569) Warning: Vehicle 'flow_00.5' performs emergency braking with decel=-16.69 wished=4.50 severity=2.71, time=26.90.
# (pid=569) Warning: Vehicle 'flow_10.3' performs emergency braking with decel=-99.01 wished=4.50 severity=21.00, time=30.90.
# (pid=568) Warning: Vehicle 'flow_00.9' performs emergency braking with decel=-27.85 wished=4.50 severity=5.19, time=24.10.
# (pid=568) Warning: Vehicle 'flow_10.1' performs emergency braking with decel=-12.74 wished=4.50 severity=1.83, time=25.70.
# (pid=569) Warning: Vehicle 'flow_20.2' performs emergency braking with decel=-90.32 wished=4.50 severity=19.07, time=38.30.
# (pid=568) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-120.20 wished=4.50 severity=25.71, time=31.10.
# (pid=568) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-12.31 wished=4.50 severity=1.74, time=35.00.
# (pid=568) Warning: Vehicle 'flow_10.3' performs emergency braking with decel=-118.48 wished=4.50 severity=25.33, time=37.10.
# (pid=568) Warning: Vehicle 'flow_00.18' performs emergency braking with decel=-43.88 wished=4.50 severity=8.75, time=40.10.
# (pid=569) Warning: Vehicle 'flow_20.3' performs emergency braking with decel=-78.54 wished=4.50 severity=16.45, time=48.60.
# (pid=569) Warning: Vehicle 'flow_10.7' performs emergency braking with decel=-10.47 wished=4.50 severity=1.33, time=48.70.
# (pid=568) Warning: Vehicle 'flow_10.4' performs emergency braking with decel=-57.97 wished=4.50 severity=11.88, time=42.90.
# (pid=569) Warning: Vehicle 'flow_10.9' performs emergency braking with decel=-87.76 wished=4.50 severity=18.50, time=60.70.
# (pid=569) Warning: Vehicle 'flow_10.10' performs emergency braking with decel=-12.00 wished=4.50 severity=1.67, time=60.80.
# (pid=568) Warning: Vehicle 'flow_20.3' performs emergency braking with decel=-76.26 wished=4.50 severity=15.95, time=55.20.
# (pid=569) Warning: Vehicle 'flow_00.20' performs emergency braking with decel=-10.22 wished=4.50 severity=1.27, time=67.10.
# (pid=569) Warning: Vehicle 'flow_10.12' performs emergency braking with decel=-27.71 wished=4.50 severity=5.16, time=72.20.
# (pid=568) Warning: Vehicle 'flow_10.9' performs emergency braking with decel=-84.62 wished=4.50 severity=17.80, time=67.30.
# (pid=568) Warning: Vehicle 'flow_10.10' performs emergency braking with decel=-9.08 wished=4.50 severity=1.02, time=67.40.
# (pid=569) Warning: Vehicle 'flow_00.24' performs emergency braking with decel=-9.41 wished=4.50 severity=1.09, time=76.00.
# (pid=569) Warning: Vehicle 'flow_00.24' performs emergency braking with decel=-10.46 wished=4.50 severity=1.32, time=78.60.
# (pid=569) Warning: Vehicle 'flow_10.14' performs emergency braking with decel=-100.67 wished=4.50 severity=21.37, time=82.50.
# (pid=568) Warning: Vehicle 'flow_10.12' performs emergency braking with decel=-16.60 wished=4.50 severity=2.69, time=79.20.
# (pid=568) Warning: Vehicle 'flow_00.37' performs emergency braking with decel=-10.45 wished=4.50 severity=1.32, time=82.50.
# (pid=568) Warning: Vehicle 'flow_00.37' performs emergency braking with decel=-9.43 wished=4.50 severity=1.10, time=85.20.
# (pid=569) Warning: Vehicle 'flow_10.15' performs emergency braking with decel=-79.67 wished=4.50 severity=16.70, time=90.80.
# (pid=569) Warning: Vehicle 'flow_10.16' performs emergency braking with decel=-10.07 wished=4.50 severity=1.24, time=90.90.
# (pid=568) Warning: Vehicle 'flow_10.14' performs emergency braking with decel=-105.70 wished=4.50 severity=22.49, time=89.10.
# (pid=568) Warning: Vehicle 'flow_10.15' performs emergency braking with decel=-79.96 wished=4.50 severity=16.77, time=97.40.
# (pid=569) Warning: Vehicle 'flow_10.20' performs emergency braking with decel=-84.12 wished=4.50 severity=17.69, time=112.90.
# (pid=569) Warning: Vehicle 'flow_20.10' performs emergency braking with decel=-10.23 wished=4.50 severity=1.27, time=113.00.
# (pid=568) Warning: Vehicle 'flow_10.18' performs emergency braking with decel=-57.87 wished=4.50 severity=11.86, time=109.40.
# (pid=569) Warning: Vehicle 'flow_00.64' performs emergency braking with decel=-9.93 wished=4.50 severity=1.21, time=116.60.
# (pid=568) Warning: Vehicle 'flow_00.54' performs emergency braking with decel=-9.23 wished=4.50 severity=1.05, time=115.90.
# (pid=569) Warning: Vehicle 'flow_20.11' performs emergency braking with decel=-97.65 wished=4.50 severity=20.70, time=124.80.
# (pid=568) Warning: Vehicle 'flow_10.20' performs emergency braking with decel=-94.03 wished=4.50 severity=19.90, time=119.80.
# (pid=568) Warning: Vehicle 'flow_20.10' performs emergency braking with decel=-13.68 wished=4.50 severity=2.04, time=119.90.
# (pid=568) Warning: Vehicle 'flow_00.66' performs emergency braking with decel=-37.57 wished=4.50 severity=7.35, time=123.20.
# (pid=569) Warning: Vehicle 'flow_00.79' performs emergency braking with decel=-10.78 wished=4.50 severity=1.39, time=131.50.
# (pid=569) Warning: Vehicle 'flow_10.24' performs emergency braking with decel=-70.61 wished=4.50 severity=14.69, time=133.30.
# (pid=569) Warning: Vehicle 'flow_10.24' performs emergency braking with decel=-14.44 wished=4.50 severity=2.21, time=133.50.
# (pid=568) Warning: Vehicle 'flow_00.92' performs emergency braking with decel=-46.95 wished=4.50 severity=9.43, time=134.00.
# (pid=568) Warning: Vehicle 'flow_20.11' performs emergency braking with decel=-51.57 wished=4.50 severity=10.46, time=136.20.
# (pid=569) Warning: Vehicle 'flow_10.25' performs emergency braking with decel=-59.15 wished=4.50 severity=12.15, time=142.20.
# (pid=568) Warning: Vehicle 'flow_00.101' performs emergency braking with decel=-12.35 wished=4.50 severity=1.74, time=142.50.
# (pid=569) Warning: Vehicle 'flow_00.104' performs emergency braking with decel=-15.84 wished=4.50 severity=2.52, time=148.80.
# (pid=568) Warning: Vehicle 'flow_10.24' performs emergency braking with decel=-39.17 wished=4.50 severity=7.71, time=144.90.
# (pid=569) Warning: Vehicle 'flow_20.13' performs emergency braking with decel=-50.14 wished=4.50 severity=10.14, time=151.60.
# (pid=569) Warning: Vehicle 'flow_00.106' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=158.20.
# (pid=568) Warning: Vehicle 'flow_00.108' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=154.00.
# (pid=569) Warning: Vehicle 'flow_00.119' performs emergency braking with decel=-9.53 wished=4.50 severity=1.12, time=168.80.
# (pid=568) Warning: Vehicle 'flow_00.125' performs emergency braking with decel=-9.60 wished=4.50 severity=1.13, time=164.40.
# (pid=569) Warning: Vehicle 'flow_10.30' performs emergency braking with decel=-46.09 wished=4.50 severity=9.24, time=170.80.
# (pid=568) Warning: Vehicle 'flow_10.28' performs emergency braking with decel=-60.61 wished=4.50 severity=12.47, time=166.50.
# (pid=568) Warning: Vehicle 'flow_00.137' performs emergency braking with decel=-12.64 wished=4.50 severity=1.81, time=173.30.
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=569)   out=out, **kwargs)
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=569)   ret = ret.dtype.type(ret / rcount)
# (pid=569) Warning: Vehicle 'flow_00.3' performs emergency braking with decel=-30.15 wished=4.50 severity=5.70, time=20.20.
# (pid=569) Warning: Vehicle 'flow_00.4' performs emergency braking with decel=-95.27 wished=4.50 severity=20.17, time=23.30.
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=568)   out=out, **kwargs)
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=568)   ret = ret.dtype.type(ret / rcount)
# (pid=569) Warning: Vehicle 'flow_00.4' performs emergency braking with decel=-36.98 wished=4.50 severity=7.22, time=27.50.
# (pid=568) Warning: Vehicle 'flow_00.21' performs emergency braking with decel=-14.16 wished=4.50 severity=2.15, time=16.30.
# (pid=569) Warning: Vehicle 'flow_00.8' performs emergency braking with decel=-11.67 wished=4.50 severity=1.59, time=32.70.
# (pid=568) Warning: Vehicle 'flow_00.31' performs emergency braking with decel=-11.09 wished=4.50 severity=1.47, time=23.50.
# (pid=569) Warning: Vehicle 'flow_00.8' performs emergency braking with decel=-16.73 wished=4.50 severity=2.72, time=35.00.
# (pid=568) Warning: Vehicle 'flow_00.3' performs emergency braking with decel=-50.62 wished=4.50 severity=10.25, time=24.00.
# (pid=569) Warning: Vehicle 'flow_10.4' performs emergency braking with decel=-15.76 wished=4.50 severity=2.50, time=36.40.
# (pid=568) Warning: Vehicle 'flow_10.1' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=28.60.
# (pid=569) Warning: Vehicle 'flow_00.10' performs emergency braking with decel=-16.16 wished=4.50 severity=2.59, time=39.80.
# (pid=568) Warning: Vehicle 'flow_00.11' performs emergency braking with decel=-88.94 wished=4.50 severity=18.76, time=32.50.
# (pid=568) Warning: Vehicle 'flow_00.20' performs emergency braking with decel=-13.92 wished=4.50 severity=2.09, time=32.60.
# (pid=568) Warning: Vehicle 'flow_20.1' performs emergency braking with decel=-106.25 wished=4.50 severity=22.61, time=34.60.
# (pid=568) Warning: Vehicle 'flow_10.3' performs emergency braking with decel=-10.68 wished=4.50 severity=1.37, time=34.70.
# (pid=569) Warning: Vehicle 'flow_10.5' performs emergency braking with decel=-110.72 wished=4.50 severity=23.61, time=44.80.
# (pid=568) Warning: Vehicle 'flow_00.20' performs emergency braking with decel=-39.58 wished=4.50 severity=7.80, time=37.60.
# (pid=569) Warning: Vehicle 'flow_00.25' performs emergency braking with decel=-12.28 wished=4.50 severity=1.73, time=48.00.
# (pid=568) Warning: Vehicle 'flow_00.21' performs emergency braking with decel=-12.02 wished=4.50 severity=1.67, time=43.10.
# (pid=568) Warning: Vehicle 'flow_00.21' performs emergency braking with decel=-14.51 wished=4.50 severity=2.22, time=45.60.
# (pid=568) Warning: Vehicle 'flow_00.21' performs emergency braking with decel=-13.80 wished=4.50 severity=2.07, time=48.40.
# (pid=569) Warning: Vehicle 'flow_00.27' performs emergency braking with decel=-9.39 wished=4.50 severity=1.09, time=58.20.
# (pid=568) Warning: Vehicle 'flow_00.21' performs emergency braking with decel=-16.29 wished=4.50 severity=2.62, time=50.50.
# (pid=568) Warning: Vehicle 'flow_20.3' performs emergency braking with decel=-16.90 wished=4.50 severity=2.76, time=52.00.
# (pid=568) Warning: Vehicle 'flow_00.32' performs emergency braking with decel=-13.62 wished=4.50 severity=2.03, time=55.40.
# (pid=569) Warning: Vehicle 'flow_00.27' performs emergency braking with decel=-10.27 wished=4.50 severity=1.28, time=64.70.
# (pid=569) Warning: Vehicle 'flow_10.10' performs emergency braking with decel=-14.52 wished=4.50 severity=2.23, time=66.20.
# (pid=568) Warning: Vehicle 'flow_10.8' performs emergency braking with decel=-27.08 wished=4.50 severity=5.02, time=60.10.
# (pid=569) Warning: Vehicle 'flow_00.32' performs emergency braking with decel=-10.99 wished=4.50 severity=1.44, time=69.60.
# (pid=568) Warning: Vehicle 'flow_00.37' performs emergency braking with decel=-10.65 wished=4.50 severity=1.37, time=63.30.
# (pid=569) Warning: Vehicle 'flow_00.32' performs emergency braking with decel=-11.45 wished=4.50 severity=1.54, time=72.50.
# (pid=569) Warning: Vehicle 'flow_10.11' performs emergency braking with decel=-105.02 wished=4.50 severity=22.34, time=74.70.
# (pid=568) Warning: Vehicle 'flow_00.37' performs emergency braking with decel=-10.97 wished=4.50 severity=1.44, time=67.60.
# (pid=568) Warning: Vehicle 'flow_10.10' performs emergency braking with decel=-39.02 wished=4.50 severity=7.67, time=69.60.
# (pid=568) Warning: Vehicle 'flow_00.40' performs emergency braking with decel=-10.39 wished=4.50 severity=1.31, time=73.10.
# ...
# (pid=569) Warning: Vehicle 'flow_00.13' performs emergency braking with decel=-16.92 wished=4.50 severity=2.76, time=53.50.
# (pid=569) Warning: Vehicle 'flow_20.4' performs emergency braking with decel=-34.41 wished=4.50 severity=6.65, time=55.10.
# (pid=568) Warning: Vehicle 'flow_00.19' performs emergency braking with decel=-9.43 wished=4.50 severity=1.10, time=62.10.
# (pid=569) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-12.30 wished=4.50 severity=1.73, time=58.70.
# (pid=569) Warning: Vehicle 'flow_00.16' performs emergency braking with decel=-10.57 wished=4.50 severity=1.35, time=63.00.
# (pid=569) Warning: Vehicle 'flow_20.5' performs emergency braking with decel=-97.22 wished=4.50 severity=20.60, time=65.10.
# (pid=569) Warning: Vehicle 'flow_00.23' performs emergency braking with decel=-11.70 wished=4.50 severity=1.60, time=68.50.
# (pid=569) Warning: Vehicle 'flow_00.23' performs emergency braking with decel=-10.60 wished=4.50 severity=1.36, time=73.00.
# (pid=569) Warning: Vehicle 'flow_20.6' performs emergency braking with decel=-23.29 wished=4.50 severity=4.18, time=74.90.
# (pid=568) Warning: Vehicle 'flow_20.6' performs emergency braking with decel=-64.92 wished=4.50 severity=13.43, time=82.60.
# (pid=569) Warning: Vehicle 'flow_00.25' performs emergency braking with decel=-13.63 wished=4.50 severity=2.03, time=78.20.
# (pid=569) Warning: Vehicle 'flow_00.25' performs emergency braking with decel=-11.62 wished=4.50 severity=1.58, time=80.90.
# (pid=569) Warning: Vehicle 'flow_00.25' performs emergency braking with decel=-10.81 wished=4.50 severity=1.40, time=82.70.
# (pid=568) Warning: Vehicle 'flow_20.7' performs emergency braking with decel=-16.63 wished=4.50 severity=2.69, time=92.70.
# (pid=569) Warning: Vehicle 'flow_00.29' performs emergency braking with decel=-11.40 wished=4.50 severity=1.53, time=88.70.
# (pid=568) Warning: Vehicle 'flow_00.49' performs emergency braking with decel=-9.19 wished=4.50 severity=1.04, time=96.00.
# (pid=569) Warning: Vehicle 'flow_10.16' performs emergency braking with decel=-105.80 wished=4.50 severity=22.51, time=92.70.
# (pid=568) Warning: Vehicle 'flow_00.49' performs emergency braking with decel=-9.74 wished=4.50 severity=1.17, time=98.50.
# (pid=568) Warning: Vehicle 'flow_00.49' performs emergency braking with decel=-11.13 wished=4.50 severity=1.47, time=100.40.
# (pid=569) Warning: Vehicle 'flow_00.32' performs emergency braking with decel=-17.84 wished=4.50 severity=2.97, time=96.20.
# (pid=568) Warning: Vehicle 'flow_20.8' performs emergency braking with decel=-104.28 wished=4.50 severity=22.17, time=102.70.
# (pid=569) Warning: Vehicle 'flow_00.37' performs emergency braking with decel=-21.29 wished=4.50 severity=3.73, time=99.60.
# (pid=569) Warning: Vehicle 'flow_00.37' performs emergency braking with decel=-12.05 wished=4.50 severity=1.68, time=103.60.
# (pid=568) Warning: Vehicle 'flow_10.18' performs emergency braking with decel=-87.39 wished=4.50 severity=18.42, time=111.10.
# (pid=568) Warning: Vehicle 'flow_20.9' performs emergency braking with decel=-9.70 wished=4.50 severity=1.16, time=111.20.
# (pid=569) Warning: Vehicle 'flow_00.43' performs emergency braking with decel=-15.04 wished=4.50 severity=2.34, time=108.70.
# (pid=568) Warning: Vehicle 'flow_10.18' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=114.50.
# (pid=569) Warning: Vehicle 'flow_00.43' performs emergency braking with decel=-10.49 wished=4.50 severity=1.33, time=111.20.
# (pid=569) Warning: Vehicle 'flow_00.43' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=113.40.
# (pid=568) Warning: Vehicle 'flow_00.73' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=120.00.
# (pid=569) Warning: Vehicle 'flow_00.54' performs emergency braking with decel=-14.23 wished=4.50 severity=2.16, time=118.10.
# (pid=568) Warning: Vehicle 'flow_00.84' performs emergency braking with decel=-10.03 wished=4.50 severity=1.23, time=126.00.
# (pid=569) Warning: Vehicle 'flow_10.22' performs emergency braking with decel=-105.09 wished=4.50 severity=22.35, time=122.80.
# (pid=568) Warning: Vehicle 'flow_00.84' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=131.10.
# (pid=569) Warning: Vehicle 'flow_00.60' performs emergency braking with decel=-9.93 wished=4.50 severity=1.21, time=126.10.
# (pid=569) Warning: Vehicle 'flow_10.23' performs emergency braking with decel=-78.03 wished=4.50 severity=16.34, time=131.10.
# (pid=569) Warning: Vehicle 'flow_10.24' performs emergency braking with decel=-9.57 wished=4.50 severity=1.13, time=131.20.
# (pid=568) Warning: Vehicle 'flow_00.100' performs emergency braking with decel=-15.36 wished=4.50 severity=2.41, time=142.30.
# (pid=568) Warning: Vehicle 'flow_00.100' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=146.40.
# (pid=568) Warning: Vehicle 'flow_00.112' performs emergency braking with decel=-10.74 wished=4.50 severity=1.39, time=151.70.
# (pid=568) Warning: Vehicle 'flow_00.112' performs emergency braking with decel=-9.53 wished=4.50 severity=1.12, time=156.40.
# (pid=568) Warning: Vehicle 'flow_20.13' performs emergency braking with decel=-61.83 wished=4.50 severity=12.74, time=158.60.
# (pid=569) Warning: Vehicle 'flow_00.93' performs emergency braking with decel=-19.12 wished=4.50 severity=3.25, time=151.30.
# (pid=569) Warning: Vehicle 'flow_00.93' performs emergency braking with decel=-12.12 wished=4.50 severity=1.69, time=153.60.
# (pid=569) Warning: Vehicle 'flow_00.93' performs emergency braking with decel=-14.35 wished=4.50 severity=2.19, time=156.10.
# (pid=568) Warning: Vehicle 'flow_00.123' performs emergency braking with decel=-14.47 wished=4.50 severity=2.22, time=165.40.
# (pid=569) Warning: Vehicle 'flow_00.93' performs emergency braking with decel=-16.77 wished=4.50 severity=2.73, time=158.30.
# (pid=569) Warning: Vehicle 'flow_10.30' performs emergency braking with decel=-19.75 wished=4.50 severity=3.39, time=160.30.
# (pid=568) Warning: Vehicle 'flow_00.135' performs emergency braking with decel=-9.51 wished=4.50 severity=1.11, time=171.30.
# (pid=569) Warning: Vehicle 'flow_00.105' performs emergency braking with decel=-14.05 wished=4.50 severity=2.12, time=163.50.
# (pid=569) Warning: Vehicle 'flow_10.31' performs emergency braking with decel=-103.28 wished=4.50 severity=21.95, time=168.40.
# (pid=569) Warning: Vehicle 'flow_10.32' performs emergency braking with decel=-12.84 wished=4.50 severity=1.85, time=168.50.
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=568)   out=out, **kwargs)
# (pid=568) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=568)   ret = ret.dtype.type(ret / rcount)
# (pid=568) Warning: Vehicle 'flow_20.0' performs emergency braking with decel=-11.35 wished=4.50 severity=1.52, time=1.70.
# (pid=569) Warning: Vehicle 'flow_00.114' performs emergency braking with decel=-13.63 wished=4.50 severity=2.03, time=171.70.
# (pid=568) Warning: Vehicle 'flow_20.1' performs emergency braking with decel=-120.66 wished=4.50 severity=25.81, time=23.90.
# (pid=568) Warning: Vehicle 'flow_00.33' performs emergency braking with decel=-9.37 wished=4.50 severity=1.08, time=24.90.
# (pid=568) Warning: Vehicle 'flow_00.5' performs emergency braking with decel=-118.63 wished=4.50 severity=25.36, time=26.80.
# (pid=568) Warning: Vehicle 'flow_10.3' performs emergency braking with decel=-28.20 wished=4.50 severity=5.27, time=29.50.
# (pid=568) Warning: Vehicle 'flow_00.10' performs emergency braking with decel=-9.81 wished=4.50 severity=1.18, time=32.00.
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
# (pid=569)   out=out, **kwargs)
# (pid=569) /home/llavezzo/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
# (pid=569)   ret = ret.dtype.type(ret / rcount)
# (pid=568) Warning: Vehicle 'flow_10.4' performs emergency braking with decel=-18.91 wished=4.50 severity=3.20, time=35.50.
# (pid=568) Warning: Vehicle 'flow_00.18' performs emergency braking with decel=-10.05 wished=4.50 severity=1.23, time=37.80.
# (pid=568) Warning: Vehicle 'flow_00.18' performs emergency braking with decel=-12.02 wished=4.50 severity=1.67, time=38.90.
# (pid=569) Warning: Vehicle 'flow_00.0' performs emergency braking with decel=-19.13 wished=4.50 severity=3.25, time=19.60.
# (pid=569) Warning: Vehicle 'flow_00.7' performs emergency braking with decel=-116.29 wished=4.50 severity=24.84, time=23.80.
# (pid=568) Warning: Vehicle 'flow_10.6' performs emergency braking with decel=-14.53 wished=4.50 severity=2.23, time=44.40.
# (pid=569) Warning: Vehicle 'flow_00.7' performs emergency braking with decel=-21.13 wished=4.50 severity=3.70, time=26.90.
# (pid=569) Warning: Vehicle 'flow_20.1' performs emergency braking with decel=-17.06 wished=4.50 severity=2.79, time=28.30.
# (pid=568) Warning: Vehicle 'flow_00.24' performs emergency braking with decel=-11.56 wished=4.50 severity=1.57, time=47.80.
# (pid=569) Warning: Vehicle 'flow_00.9' performs emergency braking with decel=-16.21 wished=4.50 severity=2.60, time=31.10.
# (pid=569) Warning: Vehicle 'flow_00.9' performs emergency braking with decel=-20.42 wished=4.50 severity=3.54, time=31.80.
# (pid=569) Warning: Vehicle 'flow_00.9' performs emergency braking with decel=-12.27 wished=4.50 severity=1.73, time=34.10.
# (pid=569) Warning: Vehicle 'flow_10.4' performs emergency braking with decel=-108.07 wished=4.50 severity=23.02, time=36.30.
# (pid=569) Warning: Vehicle 'flow_20.2' performs emergency braking with decel=-9.40 wished=4.50 severity=1.09, time=36.40.
# (pid=568) Warning: Vehicle 'flow_00.24' performs emergency braking with decel=-9.66 wished=4.50 severity=1.15, time=52.50.
# (pid=568) Warning: Vehicle 'flow_10.8' performs emergency braking with decel=-12.48 wished=4.50 severity=1.77, time=54.70.
# (pid=569) Warning: Vehicle 'flow_00.13' performs emergency braking with decel=-37.48 wished=4.50 severity=7.33, time=39.80.
# (pid=568) Warning: Vehicle 'flow_00.28' performs emergency braking with decel=-17.33 wished=4.50 severity=2.85, time=57.90.
# (pid=569) Warning: Vehicle 'flow_10.5' performs emergency braking with decel=-71.64 wished=4.50 severity=14.92, time=44.40.
# (pid=568) Warning: Vehicle 'flow_00.28' performs emergency braking with decel=-11.65 wished=4.50 severity=1.59, time=62.20.
# (pid=568) Warning: Vehicle 'flow_10.10' performs emergency braking with decel=-25.72 wished=4.50 severity=4.72, time=64.20.
# (pid=568) Warning: Vehicle 'flow_00.37' performs emergency braking with decel=-12.16 wished=4.50 severity=1.70, time=67.40.
# (pid=569) Warning: Vehicle 'flow_10.8' performs emergency braking with decel=-59.52 wished=4.50 severity=12.23, time=56.50.
# (pid=568) Warning: Vehicle 'flow_00.37' performs emergency braking with decel=-10.35 wished=4.50 severity=1.30, time=70.20.
# (pid=568) Warning: Vehicle 'flow_00.37' performs emergency braking with decel=-13.33 wished=4.50 severity=1.96, time=72.10.
# (pid=568) Warning: Vehicle 'flow_10.12' performs emergency braking with decel=-47.06 wished=4.50 severity=9.46, time=73.90.
# (pid=568) Warning: Vehicle 'flow_00.45' performs emergency braking with decel=-11.23 wished=4.50 severity=1.50, time=77.40.
# (pid=568) Warning: Vehicle 'flow_00.45' performs emergency braking with decel=-9.37 wished=4.50 severity=1.08, time=80.20.
# (pid=569) Warning: Vehicle 'flow_20.5' performs emergency braking with decel=-36.21 wished=4.50 severity=7.05, time=68.50.
# (pid=568) Warning: Vehicle 'flow_00.45' performs emergency braking with decel=-11.09 wished=4.50 severity=1.46, time=81.90.
# (pid=568) Warning: Vehicle 'flow_10.14' performs emergency braking with decel=-22.15 wished=4.50 severity=3.92, time=83.80.
# (pid=569) Warning: Vehicle 'flow_00.30' performs emergency braking with decel=-10.32 wished=4.50 severity=1.29, time=72.10.
# (pid=568) Warning: Vehicle 'flow_00.48' performs emergency braking with decel=-14.00 wished=4.50 severity=2.11, time=87.10.
# (pid=568) Warning: Vehicle 'flow_00.48' performs emergency braking with decel=-11.10 wished=4.50 severity=1.47, time=89.80.
# (pid=569) Warning: Vehicle 'flow_20.6' performs emergency braking with decel=-104.25 wished=4.50 severity=22.17, time=78.70.
# (pid=568) Warning: Vehicle 'flow_00.48' performs emergency braking with decel=-15.71 wished=4.50 severity=2.49, time=92.00.
# (pid=568) Warning: Vehicle 'flow_10.16' performs emergency braking with decel=-27.31 wished=4.50 severity=5.07, time=93.60.
# (pid=568) Warning: Vehicle 'flow_10.16' performs emergency braking with decel=-19.05 wished=4.50 severity=3.23, time=94.00.
# (pid=569) Warning: Vehicle 'flow_00.39' performs emergency braking with decel=-9.94 wished=4.50 severity=1.21, time=82.80.
# (pid=568) Warning: Vehicle 'flow_00.59' performs emergency braking with decel=-11.47 wished=4.50 severity=1.55, time=97.20.
# (pid=569) Warning: Vehicle 'flow_20.7' performs emergency braking with decel=-59.66 wished=4.50 severity=12.26, time=88.50.
# (pid=568) Warning: Vehicle 'flow_00.59' performs emergency braking with decel=-11.17 wished=4.50 severity=1.48, time=101.60.
# (pid=568) Warning: Vehicle 'flow_10.18' performs emergency braking with decel=-16.81 wished=4.50 severity=2.73, time=103.30.
# (pid=569) Warning: Vehicle 'flow_00.57' performs emergency braking with decel=-9.83 wished=4.50 severity=1.18, time=92.20.
# (pid=568) Warning: Vehicle 'flow_00.67' performs emergency braking with decel=-15.82 wished=4.50 severity=2.52, time=106.60.
# (pid=569) Warning: Vehicle 'flow_00.61' performs emergency braking with decel=-24.64 wished=4.50 severity=4.48, time=96.50.
# (pid=569) Warning: Vehicle 'flow_00.61' performs emergency braking with decel=-29.62 wished=4.50 severity=5.58, time=100.30.
# (pid=568) Warning: Vehicle 'flow_10.19' performs emergency braking with decel=-113.39 wished=4.50 severity=24.20, time=111.70.
# (pid=569) Warning: Vehicle 'flow_10.18' performs emergency braking with decel=-44.61 wished=4.50 severity=8.91, time=104.40.
# (pid=569) Warning: Vehicle 'flow_00.69' performs emergency braking with decel=-12.30 wished=4.50 severity=1.73, time=107.80.
# (pid=568) Warning: Vehicle 'flow_20.10' performs emergency braking with decel=-37.04 wished=4.50 severity=7.23, time=119.80.
# (pid=569) Warning: Vehicle 'flow_00.69' performs emergency braking with decel=-11.68 wished=4.50 severity=1.60, time=112.30.
# (pid=569) Warning: Vehicle 'flow_10.20' performs emergency braking with decel=-107.71 wished=4.50 severity=22.94, time=114.30.
# (pid=568) Warning: Vehicle 'flow_00.88' performs emergency braking with decel=-10.27 wished=4.50 severity=1.28, time=126.00.
# (pid=568) Warning: Vehicle 'flow_00.88' performs emergency braking with decel=-9.22 wished=4.50 severity=1.05, time=129.80.
# (pid=568) Warning: Vehicle 'flow_10.23' performs emergency braking with decel=-15.08 wished=4.50 severity=2.35, time=131.40.
# (pid=568) Warning: Vehicle 'flow_00.96' performs emergency braking with decel=-9.31 wished=4.50 severity=1.07, time=134.80.
# (pid=569) Warning: Vehicle 'flow_00.86' performs emergency braking with decel=-12.10 wished=4.50 severity=1.69, time=127.70.
# (pid=568) Warning: Vehicle 'flow_00.96' performs emergency braking with decel=-10.66 wished=4.50 severity=1.37, time=141.40.
# (pid=568) Warning: Vehicle 'flow_10.26' performs emergency braking with decel=-28.55 wished=4.50 severity=5.34, time=143.10.
# (pid=569) Warning: Vehicle 'flow_10.24' performs emergency braking with decel=-100.08 wished=4.50 severity=21.24, time=134.50.
# (pid=569) Warning: Vehicle 'flow_20.12' performs emergency braking with decel=-10.23 wished=4.50 severity=1.27, time=134.60.
# (pid=568) Warning: Vehicle 'flow_00.102' performs emergency braking with decel=-10.01 wished=4.50 severity=1.22, time=146.60.
