# %%
import json
import ray
from ray.rllib.agents.registry import get_agent_class
from ray.tune import run_experiments
from ray.tune.registry import register_env
import numpy as np
from flow.networks.ring import RingNetwork, ADDITIONAL_NET_PARAMS
from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder
from flow.core.params import SumoParams, EnvParams, InitialConfig, NetParams
from flow.core.params import VehicleParams, SumoCarFollowingParams
from flow.controllers import RLController, IDMController, ContinuousRouter
from gym.spaces.box import Box
from gym.spaces import Tuple
from flow.core.params import InFlows
from flow.controllers import SimLaneChangeController
from flow.networks import Network
import os

from modified_env import myEnv

ADDITIONAL_ENV_PARAMS = {
    "max_accel": 1,
    "max_decel": 1,
}

# time horizon of a single rollout
HORIZON = 1500
# number of rollouts per training iteration
N_ROLLOUTS = 20
# number of parallel workers
N_CPUS = 2

# We place one autonomous vehicle and 22 human-driven vehicles in the network
vehicles = VehicleParams()
vehicles.add("human",
             acceleration_controller=(IDMController, {}),
             lane_change_controller=(SimLaneChangeController, {}),
             routing_controller=(ContinuousRouter, {}),
             car_following_params=SumoCarFollowingParams(
                 speed_mode="obey_safe_speed",  
                 # we use the speed mode "obey_safe_speed" for better dynamics at the merge
             ),
             num_vehicles=20)
vehicles.add(
    veh_id="rl",
    acceleration_controller=(RLController, {}),
    routing_controller=(ContinuousRouter, {}),
    num_vehicles=1,
    )


# specify the edges vehicles can originate on
initial_config = InitialConfig(
    edges_distribution=["gneE4","gneE15"]
)
    
# specify the routes for vehicles in the network
class Network(Network):

    def specify_routes(self, net_params):
        return {"gneE4": ["gneE4","gneE17","gneE11","gneE13","gneE4.264","gneE8","gneE9","gneE18","gneE20"],
                "gneE15": ["gneE15","gneE13","gneE4.264","gneE8","gneE9","gneE18","gneE20"]
               }


inflow = InFlows()
inflow.add(veh_type="human",
           edge="gneE4",
           vehs_per_hour=1000,
            depart_lane="random",
            depart_speed="random",
            color="white")
inflow.add(veh_type="human",
           edge="gneE15",
           vehs_per_hour=300,
            depart_lane="2",
            depart_speed="random",
            color="white")
inflow.add(veh_type="rl",
           edge="gneE15",
           vehs_per_hour=200,
            depart_lane="2",
            depart_speed="random",
            color="red")

file_dir = "/home/llavezzo/"
net_params = NetParams(
    template="/mnt/c/Users/llave/Documents/GitHub/flow_osuphysics/lucalavezzo/constructionV2.net.xml",
    #inflows=inflow
)

flow_params = dict(
    # name of the experiment
    exp_tag="construction_traffic",

    # name of the flow environment the experiment is running on
    env_name=myEnv,  # <------ here we replace the environment with our new environment

    # name of the network class the experiment is running on
    network=Network,

    # simulator that is used by the experiment
    simulator='traci',

    # sumo-related parameters (see flow.core.params.SumoParams)
    sim=SumoParams(
        sim_step=0.1,
        render=False,
        restart_instance=True
    ),

    # environment related parameters (see flow.core.params.EnvParams)
    env=EnvParams(
        horizon=HORIZON,
        warmup_steps=750,
        clip_actions=False,
        additional_params={
            "target_velocity": 20,
            "sort_vehicles": False,
            "max_accel": 1,
            "max_decel": 1,
        },
    ),

    # network-related parameters (see flow.core.params.NetParams and the
    # network's documentation or ADDITIONAL_NET_PARAMS component)
    net=net_params,

    # vehicles to be placed in the network at the start of a rollout (see
    # flow.core.params.VehicleParams)
    veh=vehicles,

    # parameters specifying the positioning of vehicles upon initialization/
    # reset (see flow.core.params.InitialConfig)
    initial=initial_config
)


def setup_exps():
    """Return the relevant components of an RLlib experiment.

    Returns
    -------
    str
        name of the training algorithm
    str
        name of the gym environment to be trained
    dict
        training configuration parameters
    """
    alg_run = "PPO"

    agent_cls = get_agent_class(alg_run)
    config = agent_cls._default_config.copy()
    config["num_workers"] = N_CPUS
    config["train_batch_size"] = HORIZON * N_ROLLOUTS
    config["gamma"] = 0.999  # discount rate
    config["model"].update({"fcnet_hiddens": [3, 3]})
    config["use_gae"] = True
    config["lambda"] = 0.97
    config["kl_target"] = 0.02
    config["num_sgd_iter"] = 10
    config['clip_actions'] = False  # FIXME(ev) temporary ray bug
    config["horizon"] = HORIZON

    # save the flow params for replay
    flow_json = json.dumps(
        flow_params, cls=FlowParamsEncoder, sort_keys=True, indent=4)
    config['env_config']['flow_params'] = flow_json
    config['env_config']['run'] = alg_run

    create_env, gym_name = make_create_env(params=flow_params, version=0)

    # Register as rllib env
    register_env(gym_name, create_env)
    return alg_run, gym_name, config
# Out:
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
alg_run, gym_name, config = setup_exps()
ray.init(num_cpus=N_CPUS + 1)
trials = run_experiments({
    flow_params["exp_tag"]: {
        "run": alg_run,
        "env": gym_name,
        "config": {
            **config
        },
        "checkpoint_freq": 20,
        "checkpoint_at_end": True,
        "max_failures": 999,
        "stop": {
            "training_iteration": 200,
        },
    }
})
# Out:
# 2020-03-01 12:19:36,417	WARNING services.py:592 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2020-03-01 12:19:36,420	INFO resource_spec.py:212 -- Starting Ray with 5.03 GiB memory available for workers and up to 2.52 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-03-01 12:19:36,824	WARNING services.py:1080 -- Failed to start the dashboard. The dashboard requires Python 3 as well as 'pip install aiohttp psutil setproctitle grpcio'.
# == Status ==<br>Memory usage on this node: 7.6/15.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3/3 CPUs, 0/0 GPUs, 0.0/5.03 GiB heap, 0.0/1.71 GiB objects<br>Result logdir: /home/llavezzo/ray_results/construction_traffic<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_d4244bd4</td><td>RUNNING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (pid=raylet) E0301 12:19:37.065352300    2059 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583083177.065328300","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=raylet) E0301 12:19:37.065624700    2059 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=raylet) E0301 12:19:37.092530400    2059 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=2081) E0301 12:19:38.765747900    2081 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583083178.765734900","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=2081) E0301 12:19:38.765922900    2081 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=2082) E0301 12:19:38.775877800    2082 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583083178.775865500","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=2082) E0301 12:19:38.776029500    2082 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=2083) E0301 12:19:38.774476200    2083 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583083178.774463000","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=2083) E0301 12:19:38.774641200    2083 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=2081) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2081)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2081) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2081)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2081) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2081)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2081) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2081)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2081) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2081)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2081) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2081)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2081) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2081)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2081) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2081)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2081) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2081)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2081) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2081)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2081) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2081)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2081) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2081)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2081) 2020-03-01 12:19:41,298	INFO trainer.py:370 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=2081) 2020-03-01 12:19:41,764	INFO trainer.py:517 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=2082) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2082)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2082) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2082)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2082) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2082)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2082) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2082)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2082) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2082)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2082) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2082)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2083) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2083)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2083) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2083)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2083) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2083)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2083) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2083)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2083) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2083)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2083) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2083)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2082) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2082)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2082) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2082)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2082) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2082)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2082) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2082)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2082) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2082)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2082) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2082)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2083) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2083)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2083) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2083)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2083) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2083)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2083) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2083)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2083) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2083)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2083) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2083)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2081) 2020-03-01 12:19:47,043	WARNING util.py:41 -- Install gputil for GPU system monitoring.
# (pid=2082) Warning: Vehicle 'human_3' performs emergency braking with decel=-121.11 wished=4.50 severity=25.91, time=45.60.
# (pid=2083) Warning: Vehicle 'human_3' performs emergency braking with decel=-118.31 wished=4.50 severity=25.29, time=46.80.
# 2020-03-01 12:19:54,416	ERROR trial_runner.py:480 -- Trial PPO_myEnv-v0_d4244bd4: Error processing event.
# Traceback (most recent call last):
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py", line 424, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/ray_trial_executor.py", line 377, in fetch_result
#     result = ray.get(trial_future[0], DEFAULT_GET_TIMEOUT)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/worker.py", line 1492, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ValueError): ray::PPO.train() (pid=2081, ip=100.64.13.11)
#   File "python/ray/_raylet.pyx", line 643, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 623, in function_executor
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 443, in train
#     raise e
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer.py", line 432, in train
#     result = Trainable.train(self)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/trainable.py", line 254, in train
#     result = self._train()
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/agents/trainer_template.py", line 122, in _train
#     fetches = self.optimizer.step()
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/optimizers/multi_gpu_optimizer.py", line 136, in step
#     self.num_envs_per_worker, self.train_batch_size)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/optimizers/rollout.py", line 25, in collect_samples
#     next_sample = ray_get_and_free(fut_sample)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/utils/memory.py", line 29, in ray_get_and_free
#     result = ray.get(object_ids)
# ray.exceptions.RayTaskError(ValueError): ray::RolloutWorker.sample() (pid=2082, ip=100.64.13.11)
#   File "python/ray/_raylet.pyx", line 643, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 623, in function_executor
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/rollout_worker.py", line 475, in sample
#     batches = [self.input_reader.next()]
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 52, in next
#     batches = [self.get_data()]
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 95, in get_data
#     item = next(self.rollout_provider)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 315, in _env_runner
#     soft_horizon, no_done_at_end)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/evaluation/sampler.py", line 403, in _process_observations
#     policy_id).transform(raw_obs)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/models/preprocessors.py", line 162, in transform
#     self.check_shape(observation)
#   File "/home/llavezzo/anaconda2/envs/flow/lib/python3.6/site-packages/ray/rllib/models/preprocessors.py", line 61, in check_shape
#     self._obs_space, observation)
# ValueError: ('Observation outside expected value range', Box(42, 1), array([ 1258.26310606,  1354.86544038,  1473.3171246 ,  1321.32876718,
#         1483.87275928,  1380.73038954,  1516.65082679,   718.10187758,
#          697.38564295,   729.79264387,   794.56376757,   754.9435734 ,
#          815.07570185,   822.27298262,   826.56645824, -1001.        ,
#         1035.76697486,  1056.03046498,  1179.19634962,    11.55019831,
#           11.97383254,    14.77056293,    12.83694088,    14.1043093 ,
#           11.99213424,    14.09206891,    12.77217829,    12.15990593,
#           12.93694691,    13.32835199,    12.61134905,    13.24753572,
#           13.09945877,    11.23497176,    12.68076653,    12.95056024,
#           13.15847055,    15.98995186]))
# 2020-03-01 12:19:54,422	INFO trial_runner.py:547 -- Trial PPO_myEnv-v0_d4244bd4: Attempting to restore trial state from last checkpoint.
# == Status ==<br>Memory usage on this node: 8.5/15.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 3/3 CPUs, 0/0 GPUs, 0.0/5.03 GiB heap, 0.0/1.71 GiB objects<br>Result logdir: /home/llavezzo/ray_results/construction_traffic<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_d4244bd4</td><td>RUNNING </td><td>     </td></tr>
# </tbody>
# </table><br>Number of errored trials: 1<br><table>
# <thead>
# <tr><th>Trial name           </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                 </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_d4244bd4</td><td style="text-align: right;">           1</td><td>/home/llavezzo/ray_results/construction_traffic/PPO_myEnv-v0_d4244bd4_2020-03-01_12-19-37qu11ccnd/error.txt</td></tr>
# </tbody>
# </table><br>
# (pid=2245) E0301 12:19:56.035674000    2245 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583083196.035657500","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=2245) E0301 12:19:56.035843600    2245 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=2247) E0301 12:19:56.099254500    2247 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583083196.099241400","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=2247) E0301 12:19:56.099421900    2247 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=2248) E0301 12:19:56.182660500    2248 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1583083196.182647000","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=2248) E0301 12:19:56.182846700    2248 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=2245) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2245)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2245) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2245)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2245) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2245)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2245) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2245)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2245) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2245)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2245) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2245)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2245) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2245)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2245) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2245)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2245) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2245)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2245) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2245)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2245) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2245)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2245) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2245)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2245) 2020-03-01 12:19:58,633	INFO trainer.py:370 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=2245) 2020-03-01 12:19:59,141	INFO trainer.py:517 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=2247) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2247)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2247) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2247)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2247) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2247)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2247) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2247)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2247) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2247)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2247) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2247)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2248) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2248)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2248) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2248)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2248) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2248)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2248) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2248)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2248) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2248)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2248) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2248)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2247) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2247)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2247) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2247)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2247) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2247)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2247) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2247)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2247) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2247)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2247) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2247)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2248) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2248)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=2248) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2248)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=2248) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2248)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=2248) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2248)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=2248) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2248)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=2248) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=2248)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=2245) 2020-03-01 12:20:04,605	WARNING util.py:41 -- Install gputil for GPU system monitoring.
# (pid=2247) Warning: Vehicle 'human_7' performs emergency braking with decel=-9.68 wished=4.50 severity=1.15, time=36.90.
# (pid=2248) Warning: Vehicle 'human_0' performs emergency braking with decel=-11.26 wished=4.50 severity=1.50, time=46.90.
# (pid=2248) Warning: Vehicle 'human_1' performs emergency braking with decel=-9.02 wished=4.50 severity=1.00, time=48.30.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d9fda4726b58> in <module>
#      12         "max_failures": 999,
#      13         "stop": {
# ---> 14             "training_iteration": 200,
#      15         },
#      16     }
#
# ~/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/tune.py in run_experiments(experiments, search_alg, scheduler, with_server, server_port, verbose, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial, concurrent)
#     402                 trial_executor=trial_executor,
#     403                 raise_on_failed_trial=raise_on_failed_trial,
# --> 404                 return_trials=True)
#     405         return trials
#
# ~/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/tune.py in run(run_or_experiment, name, stop, config, resources_per_trial, num_samples, local_dir, upload_dir, trial_name_creator, loggers, sync_to_cloud, sync_to_driver, checkpoint_freq, checkpoint_at_end, sync_on_checkpoint, keep_checkpoints_num, checkpoint_score_attr, global_checkpoint_period, export_formats, max_failures, restore, search_alg, scheduler, with_server, server_port, verbose, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial, return_trials, ray_auto_init, sync_function)
#     298     last_debug = 0
#     299     while not runner.is_finished():
# --> 300         runner.step()
#     301         if time.time() - last_debug > DEBUG_PRINT_INTERVAL:
#     302             if verbose:
#
# ~/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py in step(self)
#     328                 self.trial_executor.start_trial(next_trial)
#     329         elif self.trial_executor.get_running_trials():
# --> 330             self._process_events()  # blocking
#     331         else:
#     332             self.trial_executor.on_no_available_trials(self)
#
# ~/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/trial_runner.py in _process_events(self)
#     411             # TODO(ujvl): Consider combining get_next_available_trial and
#     412             #  fetch_result functionality so that we don't timeout on fetch.
# --> 413             trial = self.trial_executor.get_next_available_trial()  # blocking
#     414             if trial.is_restoring:
#     415                 with warn_if_slow("process_trial_restore"):
#
# ~/anaconda2/envs/flow/lib/python3.6/site-packages/ray/tune/ray_trial_executor.py in get_next_available_trial(self)
#     350         # See https://github.com/ray-project/ray/issues/4211 for details.
#     351         start = time.time()
# --> 352         [result_id], _ = ray.wait(shuffled_results)
#     353         wait_time = time.time() - start
#     354         if wait_time > NONTRIVIAL_WAIT_TIME_THRESHOLD_S:
#
# ~/anaconda2/envs/flow/lib/python3.6/site-packages/ray/worker.py in wait(object_ids, num_returns, timeout)
#    1634             num_returns,
#    1635             timeout_milliseconds,
# -> 1636             worker.current_task_id,
#    1637         )
#    1638         return ready_ids, remaining_ids
#
# KeyboardInterrupt:
