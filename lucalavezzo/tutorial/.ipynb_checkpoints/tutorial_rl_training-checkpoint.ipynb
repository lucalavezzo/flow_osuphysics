# %% [markdown]
# ## 4. Training
# Finally, we are ready to work on the __environment__ which determines the training of the RL agents.<br>
# This is the code contained in construction_env.py, which will be imported to run the training.
#
# ### 4.1 Action and Observation Spaces
# __Action Space__<br>
# Controls the number of the actions and their max. and min. bounds.<br>
# e.g. If we have 10 RL vehicles, and we want to control their accelerations, we would have an action space of 10, and we could bound their max. and min. accelrations by, say, 1 and -1.
# e.g. If we want to add lane changes, we'd have a total of 20 actions per iteration.
#
# __Observation Space__<br>
# The vector of information that is read in at each time step and on which is run the training. This function simply specifies what size and bounds this vector is to be, we will write the function that fills it in later.

# %%
import json
import ray
from ray.rllib.agents.registry import get_agent_class
from ray.tune import run_experiments
from ray.tune.registry import register_env
import numpy as np
from flow.networks.ring import RingNetwork, ADDITIONAL_NET_PARAMS
from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder
from flow.core.params import SumoParams, EnvParams, InitialConfig, NetParams
from flow.core.params import VehicleParams, SumoCarFollowingParams
from flow.controllers import RLController, IDMController, ContinuousRouter
from gym.spaces.box import Box
from gym.spaces import Tuple
from flow.envs import Env
from flow.core import rewards


ADDITIONAL_ENV_PARAMS = {
    "max_accel": 2,
    "max_decel": 2,
    "lane_change_duration": 5,
}

MAX_EDGE = 12
MAX_LANE = 2
observation_edges = [2,3,4,5]

class myEnv(Env):

    @property
    def action_space(self):
        num_actions = self.initial_vehicles.num_rl_vehicles
        
        max_decel = self.env_params.additional_params["max_decel"]
        max_accel = self.env_params.additional_params["max_accel"]

        lb = [-abs(max_decel), -1] * num_actions
        ub = [max_accel, 1] * num_actions

        return Box(np.array(lb), np.array(ub), dtype=np.float32)

    @property
    def observation_space(self):
        return Box(
            low=-1,
            high=1,
            shape=(10*8+4,),
            dtype=np.float32
        )
# Out:
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ### 4.2 Apply Actions
# At each time step, we want to apply certain actions.<br>
# Here, we apply an __acceleration__ and a __lane change__ to each of the RL vehicles.<br>
# In the implementation, we see that vehicles that changed lanes recently aren't allowed to do so again for a certain time 'lane_change_duration', and vehicles in the junction right before the bottleneck of the construction zone aren't allowed to change lanes.

# %%
def _apply_rl_actions(self, rl_actions):
    num_rl = self.k.vehicle.num_rl_vehicles
    rl_ids = self.k.vehicle.get_rl_ids()
    sorted_rl_ids = sorted(self.k.vehicle.get_rl_ids(),
                           key=self.k.vehicle.get_x_by_id)

    acceleration = rl_actions[::2][:num_rl]
    direction = np.round(rl_actions[1::2])[:num_rl]

    # represents vehicles that are allowed to change lanes
    non_lane_changing_veh = [
        self.time_counter <= self.env_params.additional_params[
            'lane_change_duration'] + self.k.vehicle.get_last_lc(veh_id)
        for veh_id in sorted_rl_ids]

    #Check that vehicles in junction before the constructione zone
    # don't change lanes
    for i, veh_id in enumerate(sorted_rl_ids):
        edge_num = self.k.vehicle.get_edge(veh_id)
        if(edge_num == '' or edge_num[0] == ':'):
            direction[i] = 0
        if(edge_num == ':gneJ6'):
            direction[i] = 0

    # vehicle that are not allowed to change have their directions set to 0
    direction[non_lane_changing_veh] = \
        np.array([0] * sum(non_lane_changing_veh))

    self.k.vehicle.apply_acceleration(sorted_rl_ids, acc=acceleration)
    self.k.vehicle.apply_lane_change(sorted_rl_ids, direction=direction)

# %% [markdown]
# ### 4.3 Get State
# At each time step, we are interested in obtaining information about the network and the vehicles in it, which is then used to train the RL agents.<br>
# To do so, we use get_state, which returns a vector of information whose size and bounds are specified by observation_space.
#
# We collect the following:
# - Position, Velocity, Edge, and Lane of all RL vehicles in the network.
# - The relative position, speed, and type (i.e. human or RL) of the vehicle in front of and behind of every RL vehicle.
# - The density of vehicles and the average speed in each lane in the highway prior to the construction zone.
#
# One could feed all the positions and speeds of all the cars in the network, though that would be a really large observation space, which will make the training much longer and may not be as relevant as some of the information provided through this environment. Furthermore, the number of cars in the network is changing, as some are spawned at the inflow, and some disappear at the end of the highway. Therefore, one would have to initialize a very large initial observation space, fill it with all this info, and then pad it with 0's to fill it up completely.

# %%
def get_state(self, **kwargs):
        
        ids = self.k.vehicle.get_ids()
        rl_ids = self.k.vehicle.get_rl_ids()
        
        #normalizing constants
        max_speed = self.k.network.max_speed()
        for veh_id in ids:
            if(abs(self.k.vehicle.get_speed(veh_id)) > 10000): continue
            if(self.k.vehicle.get_speed(veh_id) > max_speed): max_speed = self.k.vehicle.get_speed(veh_id)
        max_length = self.k.network.length()
        
        #rl vehicle info (size 4*num_rl)
        pos=[]  
        vel=[]  
        edges=[] 
        lanes=[] 

        #follower/leader info (size 6*num_rl)
        types=[]
        follower_dv = []
        follower_dx = []
        leader_dv = []
        leader_dx = []

        #network info (2*2)
        lane_traffic=[0,0] 
        lane_traffic_speed=[0,0]


        #Density and average speed of vehicles in lane before construction zone
        for veh_id in ids:

            edge_num = self.k.vehicle.get_edge(veh_id)
            lane_num = int(self.k.vehicle.get_lane(veh_id))
            v = self.k.vehicle.get_speed(veh_id)
            if(-1 <= v/max_speed <= 1):
                if(edge_num == "edge3"):
                    lane_traffic[lane_num] += 1
                    lane_traffic_speed[lane_num] += v/max_speed
                

        #Info for each RL vehicle
        for rl_id in rl_ids:
            
            edge_num = self.k.vehicle.get_edge(rl_id)
            if edge_num is None or edge_num == '' or edge_num[0] == ':':
                edge_num = -1
            else:
                edge_num = edge_num[4:]
            lane_num = self.k.vehicle.get_lane(rl_id)
            r = self.k.vehicle.get_x_by_id(rl_id)
            v = self.k.vehicle.get_speed(rl_id)
            
            follower_id = self.k.vehicle.get_follower(rl_id)
            leader_id = self.k.vehicle.get_leader(rl_id)

            if leader_id in ["", None]:
                leader_dv.append(1)
                leader_dx.append(1)
                types.append(0)
            else:
                leader_pos = (self.k.vehicle.get_x_by_id(leader_id) - self.k.vehicle.get_x_by_id(rl_id))/max_length
                leader_speed = self.k.vehicle.get_speed(leader_id)/max_speed

                if -1 <= leader_speed <= 1:
                    leader_dv.append(leader_speed)
                else: 
                    leader_dv.append(0)

                if -1 <= leader_pos <= 1:
                    leader_dx.append(leader_pos)
                else: 
                    leader_dx.append(0)

                if(rl_id in rl_ids): types.append(1)
                else: types.append(-1)

            if follower_id in ["",None]:
                follower_dv.append(1)
                follower_dx.append(1)
                types.append(0)
            else:
                follower_pos = (self.k.vehicle.get_x_by_id(rl_id) - self.k.vehicle.get_x_by_id(follower_id))/max_length
                follower_speed = self.k.vehicle.get_speed(follower_id)/max_speed

                if -1 <= follower_speed <= 1:
                    follower_dv.append(follower_speed)
                else: 
                    follower_dv.append(0)
                 
                if -1 <= follower_pos <= 1:
                    follower_dx.append(follower_pos)
                else: 
                    follower_dx.append(0)

                if(rl_id in rl_ids): types.append(1)
                else: types.append(-1)


            edge_num = int(edge_num)/MAX_EDGE
            lane_num = int(lane_num)/MAX_LANE
            if -1 <= edge_num <= 1:
                edges.append(edge_num)
            else: 
                edge.append(0)
            if -1 <= lane_num <= 1:
                lanes.append(lane_num)
            else: 
                lanes.append(0)

            r = r/max_length
            v = v/max_speed
            
            if -1 <= r <= 1:
                pos.append(r)
            else:
                pos.append(0)

            if -1 <= v <= 1:
                vel.append(v)
            else:
                vel.append(0)

        #Normalize
        for i in range(2):
            if(lane_traffic[i] != 0): lane_traffic_speed[i] = (lane_traffic_speed[i]/lane_traffic[i])
            else: lane_traffic_speed[i] = 0
            lane_traffic[i] = lane_traffic[i] / len(ids)

        state = np.concatenate((pos,vel,edges,lanes,
                                types,follower_dx,follower_dv,leader_dv,leader_dx,
                                lane_traffic,lane_traffic_speed))
                    
        return state

# %% [markdown]
# ### 4.4 The Reward Function
# We are now collecting the state of the network and its vehicles at each time step and we defined the possible actions that the Rl agents can take, we need to define a __reward function__ that the training will be based on.<br>
# This is another place where one can affect the training by prioritizing certain behvaiovrs and punishing others.<br>
# Three specific features are taken into account in this reward function:
# 1. Mean speed of the human vehicles in the edges preceding the construction zone.
# 2. The acceleration of the RL agents.
# 3. The number of vehicles not moving.
#
# The inclusion of the first parameter is to encourage the increase of the mean velocity of the human cars on the highway where the construction zone causes the slowdown. Since the RL agents will be rewarded based on the magnitude of this number, they will try to increase it.<br>
# The acceleration of the RL agents is also rewarded because we want them to be driving as fast as possible when they can. This encourages them to keep going if they have the space to.<br>
# The penalization of the standstill similiarly punsishes the training by returning a negative number calculated by the number of vehicles that aren't moving in the edges before the consturction zone.<br>
#
# Each of the parameters are multiplied by a specific gain, and everything is normalized to be in (0,1). By changing the gains we can control how each parameter affects the training.
#
# Some other sample reward functions are included in /flow/core/rewards.py

# %%
def compute_reward(self, rl_actions, **kwargs):
    ids = self.k.vehicle.get_ids()
    speeds = self.k.vehicle.get_speed(ids)
    rl_ids = self.k.vehicle.get_rl_ids()

    #Only count speeds of human cars in edge prior to the 'construction site'
    #RL vehicles encouraged to make forward progress
    meanHumanSpeed = 0
    meanRLSpeed = 0
    RL_SPEED_GAIN = 0.1
    humanSpeeds = []
    rlSpeeds = []
    for veh_id in ids: 
        if veh_id in rl_ids:
            speed = self.k.vehicle.get_speed(veh_id)
            if abs(speed) > 10000: continue
            rlSpeeds.append(abs(speed))
        else:
            edge = self.k.vehicle.get_edge(veh_id)
            if edge == "edge3" or edge == "edge4":
                speed = self.k.vehicle.get_speed(veh_id)
                if abs(speed) > 10000: continue
                humanSpeeds.append(abs(speed))

    if(len(humanSpeeds)==0): meanHumanSpeed = 0
    else: meanHumanSpeed = np.mean(humanSpeeds)

    if(len(rlSpeeds)==0): meanRLSpeed = 0
    else: meanRLSpeed = np.mean(rlSpeeds)*RL_SPEED_GAIN

    return (meanHumanSpeed + meanRLSpeed - abs(rewards.penalize_standstill(self,gain=0.3)))

# %% [markdown]
# ### 4.5 Putting it all togheter
# Define the environment, and run the training.
#
# To run the training, we import the environment as was outlined above, which is included in the file constructionEnv.py.<br>
# The rest of the code has the same setup as the simulation in the previous part of the tutorial (that's why we went through it).<br>
# The RL vehicle class is given the RLController, which is guided by the environment we wrote. This will supercede any action by SUMO on the RL agent that would conflict with the apply_rl_actions function of the environment.<br>
#
# It's better to submit this as a Python script, and you can make use of multiple CPUs.

# %%
import os
import json
import ray
import numpy as np
from ray.rllib.agents.registry import get_agent_class
from ray.tune import run_experiments
from ray.tune.registry import register_env
from flow.networks import Network
from flow.networks.ring import RingNetwork, ADDITIONAL_NET_PARAMS
from flow.utils.registry import make_create_env
from flow.utils.rllib import FlowParamsEncoder
from flow.core.params import SumoParams, EnvParams, InitialConfig, NetParams, VehicleParams, SumoCarFollowingParams, InFlows, SumoLaneChangeParams
from flow.controllers import RLController, IDMController, SimLaneChangeController, ContinuousRouter
from gym.spaces.box import Box
from gym.spaces import Tuple

from constructionEnv import myEnv

# time horizon of a single rollout
HORIZON = 5000 #5000
# number of rollouts per training iteration
N_ROLLOUTS = 10
# number of parallel workers
N_CPUS = 1

vehicles = VehicleParams()
vehicles.add("rl",
             acceleration_controller=(RLController, {}),
             routing_controller=(ContinuousRouter, {}),
             car_following_params=SumoCarFollowingParams(
                 speed_mode="obey_safe_speed",  
             ),
             num_vehicles=8
             )
vehicles.add("human",
             acceleration_controller=(IDMController, {}),
             lane_change_controller=(SimLaneChangeController, {}),
             car_following_params=SumoCarFollowingParams(
                 speed_mode=25
             ),
             lane_change_params = SumoLaneChangeParams(lane_change_mode=1621),
             num_vehicles=0)

# specify the edges vehicles can originate on
initial_config = InitialConfig(
    edges_distribution=["edge4"]
)

# specify the routes for vehicles in the network
class Network(Network):

    def specify_routes(self, net_params):
        return {
                "edge1": ["edge1","edge2","edge3","edge4","edge5","edge6"],
                "edge4": ["edge4","edge5","edge10","edge11","edge12","edge3","edge4"],
                }


inflow = InFlows()
inflow.add(veh_type="human",
           edge="edge1",
           vehs_per_hour=1700,
            depart_lane="random",
            depart_speed="random",
            color="white")

currentDir = '/mnt/c/users/llave/Documents/GitHub/flow_osuphysics/lucalavezzo/'
net_params = NetParams(
    template=currentDir+"tutorial/construction.net.xml",
    inflows=inflow
)

flow_params = dict(
    # name of the experiment
    exp_tag="construction_traffic_simplified",

    # name of the flow environment the experiment is running on
    env_name=myEnv,  # <------ here we replace the environment with our new environment

    # name of the network class the experiment is running on
    network=Network,

    # simulator that is used by the experiment
    simulator='traci',

    # sumo-related parameters (see flow.core.params.SumoParams)
    sim=SumoParams(
        sim_step=0.5,
        render=False,
        restart_instance=True,
    ),

    # environment related parameters (see flow.core.params.EnvParams)
    env=EnvParams(
        horizon=HORIZON,
        warmup_steps=1000,
        clip_actions=False,
        additional_params={
            "target_velocity": 50,
            "sort_vehicles": False,
            "max_accel": 3,
            "max_decel": 3,
            "lane_change_duration": 3,
        },
    ),

    # network-related parameters (see flow.core.params.NetParams and the
    # network's documentation or ADDITIONAL_NET_PARAMS component)
    net=net_params,

    # vehicles to be placed in the network at the start of a rollout (see
    # flow.core.params.VehicleParams)
    veh=vehicles,

    # parameters specifying the positioning of vehicles upon initialization/
    # reset (see flow.core.params.InitialConfig)
    initial=initial_config
)


def setup_exps():
    """Return the relevant components of an RLlib experiment.

    Returns
    -------
    str
        name of the training algorithm
    str
        name of the gym environment to be trained
    dict
        training configuration parameters
    """
    alg_run = "PPO"

    agent_cls = get_agent_class(alg_run)
    config = agent_cls._default_config.copy()
    config["num_workers"] = N_CPUS
    config["train_batch_size"] = HORIZON * N_ROLLOUTS
    config["gamma"] = 0.999  # discount rate
    config["model"].update({"fcnet_hiddens": [128]*10})
    config["use_gae"] = True
    config["lambda"] = 0.97
    config["kl_target"] = 0.02
    config["num_sgd_iter"] = 10
    config['clip_actions'] = False  # FIXME(ev) temporary ray bug
    config["horizon"] = HORIZON

    # save the flow params for replay
    flow_json = json.dumps(
        flow_params, cls=FlowParamsEncoder, sort_keys=True, indent=4)
    config['env_config']['flow_params'] = flow_json
    config['env_config']['run'] = alg_run

    create_env, gym_name = make_create_env(params=flow_params, version=0)

    # Register as rllib env
    register_env(gym_name, create_env)
    return alg_run, gym_name, config

alg_run, gym_name, config = setup_exps()
ray.init(num_cpus=N_CPUS + 1)
trials = run_experiments({
    flow_params["exp_tag"]: {
        "run": alg_run,
        "env": gym_name,
        "config": {
            **config
        },
        "checkpoint_freq": 10,
        "checkpoint_at_end": True,
        "max_failures": 999,
        "stop": {
            "training_iteration": 2000,
        },
    }
})
# Out:
# 2020-04-26 18:59:12,114	WARNING services.py:592 -- setpgrp failed, processes may not be cleaned up properly: [Errno 1] Operation not permitted.
# 2020-04-26 18:59:12,118	INFO resource_spec.py:212 -- Starting Ray with 4.49 GiB memory available for workers and up to 2.26 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-04-26 18:59:12,742	WARNING services.py:1080 -- Failed to start the dashboard. The dashboard requires Python 3 as well as 'pip install aiohttp psutil setproctitle grpcio'.
# == Status ==<br>Memory usage on this node: 8.5/15.8 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 2/2 CPUs, 0/0 GPUs, 0.0/4.49 GiB heap, 0.0/1.51 GiB objects<br>Result logdir: /home/llavezzo/ray_results/construction_traffic_simplified<br>Number of trials: 1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc  </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_myEnv-v0_8c5c4a74</td><td>RUNNING </td><td>     </td></tr>
# </tbody>
# </table><br><br>
# (pid=raylet) E0426 18:59:13.056280200    1224 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1587941953.056231600","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=raylet) E0426 18:59:13.056838100    1224 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=raylet) E0426 18:59:13.075256100    1224 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=1239) E0426 18:59:15.151883700    1239 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1587941955.151859300","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=1239) E0426 18:59:15.152228700    1239 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=1240) E0426 18:59:15.254126500    1240 socket_utils_common_posix.cc:208] check for SO_REUSEPORT: {"created":"@1587941955.254103200","description":"Protocol not available","errno":92,"file":"external/com_github_grpc_grpc/src/core/lib/iomgr/socket_utils_common_posix.cc","file_line":185,"os_error":"Protocol not available","syscall":"getsockopt(SO_REUSEPORT)"}
# (pid=1240) E0426 18:59:15.254443800    1240 socket_utils_common_posix.cc:313] setsockopt(TCP_USER_TIMEOUT) Protocol not available
# (pid=1239) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1239)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=1239) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1239)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=1239) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1239)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=1239) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1239)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=1239) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1239)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=1239) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1239)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=1239) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1239)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=1239) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1239)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=1239) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1239)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=1239) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1239)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=1239) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1239)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=1239) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1239)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=1239) 2020-04-26 18:59:20,318	INFO trainer.py:370 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# (pid=1239) 2020-04-26 18:59:21,394	INFO trainer.py:517 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=1240) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1240)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=1240) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1240)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=1240) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1240)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=1240) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1240)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=1240) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1240)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=1240) /home/llavezzo/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1240)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=1240) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1240)   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# (pid=1240) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1240)   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# (pid=1240) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1240)   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# (pid=1240) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1240)   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# (pid=1240) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1240)   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# (pid=1240) /home/llavezzo/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# (pid=1240)   np_resource = np.dtype([("resource", np.ubyte, 1)])
# (pid=1239) 2020-04-26 18:59:30,274	WARNING util.py:41 -- Install gputil for GPU system monitoring.
# (pid=1240) Warning: Vehicle 'flow_00.28' performs emergency braking with decel=-25.31 wished=4.50 severity=4.62, time=94.00.
# (pid=1240) Warning: Vehicle 'rl_5' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=101.00.
# (pid=1240) Warning: Vehicle 'flow_00.31' performs emergency braking with decel=-20.37 wished=4.50 severity=3.53, time=101.50.
# (pid=1240) Warning: Vehicle 'flow_00.34' performs emergency braking with decel=-22.95 wished=4.50 severity=4.10, time=102.00.
# (pid=1240) Warning: Vehicle 'flow_00.34' performs emergency braking with decel=-14.56 wished=4.50 severity=2.24, time=110.00.
# (pid=1240) Warning: Vehicle 'flow_00.35' performs emergency braking with decel=-12.24 wished=4.50 severity=1.72, time=110.50.
# (pid=1240) Warning: Vehicle 'rl_3' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=124.00.
# (pid=1240) Warning: Vehicle 'flow_00.42' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=127.50.
# (pid=1240) Warning: Vehicle 'flow_00.44' performs emergency braking with decel=-17.46 wished=4.50 severity=2.88, time=127.50.
# (pid=1240) Warning: Vehicle 'flow_00.43' performs emergency braking with decel=-9.22 wished=4.50 severity=1.05, time=132.00.
# (pid=1240) Warning: Vehicle 'flow_00.76' performs emergency braking with decel=-9.16 wished=4.50 severity=1.04, time=231.50.
# (pid=1240) Warning: Vehicle 'flow_00.103' performs emergency braking with decel=-24.05 wished=4.50 severity=4.34, time=253.00.
# (pid=1240) Warning: Vehicle 'rl_6' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=253.00.
# (pid=1240) Warning: Teleporting vehicle 'flow_00.101'; collision with vehicle 'rl_6', lane=':gneJ30_2_0', gap=-1.00, time=253.00 stage=move.
# (pid=1240) Warning: Vehicle 'flow_00.101' ends teleporting on edge 'edge3', time 253.00.
# (pid=1240) Warning: Vehicle 'flow_00.102' performs emergency braking with decel=-15.12 wished=4.50 severity=2.36, time=253.50.
# (pid=1240) Warning: Vehicle 'flow_00.105' performs emergency braking with decel=-9.82 wished=4.50 severity=1.18, time=254.00.
# (pid=1240) Warning: Vehicle 'rl_5' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=265.00.
# (pid=1240) Warning: Vehicle 'rl_4' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=280.50.
# (pid=1240) Warning: Vehicle 'flow_00.131' performs emergency braking with decel=-16.74 wished=4.50 severity=2.72, time=314.50.
# (pid=1240) Warning: Vehicle 'rl_0' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=332.50.
# (pid=1240) Warning: Vehicle 'flow_00.144' performs emergency braking with decel=-30.16 wished=4.50 severity=5.70, time=334.00.
# (pid=1240) Warning: Vehicle 'flow_00.137' performs emergency braking with decel=-15.60 wished=4.50 severity=2.47, time=334.00.
# (pid=1240) Warning: Vehicle 'flow_00.141' performs emergency braking with decel=-14.52 wished=4.50 severity=2.23, time=334.50.
# (pid=1240) Warning: Vehicle 'flow_00.142' performs emergency braking with decel=-14.37 wished=4.50 severity=2.19, time=335.00.
# (pid=1240) Warning: Vehicle 'flow_00.143' performs emergency braking with decel=-15.33 wished=4.50 severity=2.41, time=335.50.
# (pid=1240) Warning: Vehicle 'rl_7' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=449.50.
# (pid=1240) Warning: Vehicle 'flow_00.192' performs emergency braking with decel=-13.97 wished=4.50 severity=2.10, time=451.00.
# (pid=1240) Warning: Vehicle 'flow_00.193' performs emergency braking with decel=-14.68 wished=4.50 severity=2.26, time=451.50.
# (pid=1240) Warning: Vehicle 'flow_00.191' performs emergency braking with decel=-14.56 wished=4.50 severity=2.24, time=452.00.
# (pid=1240) Warning: Vehicle 'flow_00.195' performs emergency braking with decel=-14.19 wished=4.50 severity=2.15, time=452.50.
# (pid=1240) Warning: Vehicle 'flow_00.194' performs emergency braking with decel=-13.52 wished=4.50 severity=2.01, time=453.00.
# (pid=1240) Warning: Vehicle 'flow_00.196' performs emergency braking with decel=-12.89 wished=4.50 severity=1.86, time=453.50.
# (pid=1240) Warning: Vehicle 'flow_00.197' performs emergency braking with decel=-12.27 wished=4.50 severity=1.73, time=454.00.
# (pid=1240) Warning: Vehicle 'flow_00.198' performs emergency braking with decel=-12.22 wished=4.50 severity=1.72, time=454.50.
# (pid=1240) Warning: Vehicle 'flow_00.199' performs emergency braking with decel=-12.59 wished=4.50 severity=1.80, time=455.00.
# (pid=1240) Warning: Vehicle 'flow_00.201' performs emergency braking with decel=-15.37 wished=4.50 severity=2.42, time=455.50.
# (pid=1240) Warning: Vehicle 'flow_00.202' performs emergency braking with decel=-18.72 wished=4.50 severity=3.16, time=456.00.
# (pid=1240) Warning: Vehicle 'flow_00.205' performs emergency braking with decel=-15.21 wished=4.50 severity=2.38, time=456.50.
# (pid=1240) Warning: Vehicle 'rl_5' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=478.00.
# (pid=1240) Warning: Vehicle 'flow_00.210' performs emergency braking with decel=-25.62 wished=4.50 severity=4.69, time=478.50.
# (pid=1240) /mnt/c/Users/llave/Documents/GitHub/flow/flow/core/kernel/vehicle/traci.py:957: UserWarning: API change now handles duration as floating point seconds
# (pid=1240)   veh_id, int(target_lane), 100000)
# (pid=1240) Warning: Vehicle 'flow_00.137' performs emergency braking with decel=-22.64 wished=4.50 severity=4.03, time=514.00.
# (pid=1240) Warning: Vehicle 'flow_00.144' performs emergency braking with decel=-20.52 wished=4.50 severity=3.56, time=514.50.
# (pid=1240) Warning: Teleporting vehicle 'flow_00.215'; collision with vehicle 'rl_4', lane=':gneJ30_2_1', gap=-1.00, time=524.50 stage=move.
# (pid=1240) Warning: Vehicle 'flow_00.215' ends teleporting on edge 'edge3', time 524.50.
# (pid=1240) Warning: Vehicle 'rl_6' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=98.00.
# (pid=1240) Warning: Vehicle 'flow_00.30' performs emergency braking with decel=-14.58 wished=4.50 severity=2.24, time=99.00.
# (pid=1240) Warning: Vehicle 'flow_00.31' performs emergency braking with decel=-19.55 wished=4.50 severity=3.34, time=99.00.
# (pid=1240) Warning: Vehicle 'rl_5' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=103.00.
# (pid=1240) Warning: Vehicle 'flow_00.33' performs emergency braking with decel=-17.03 wished=4.50 severity=2.79, time=105.00.
# (pid=1240) Warning: Vehicle 'flow_00.32' performs emergency braking with decel=-17.68 wished=4.50 severity=2.93, time=106.50.
# (pid=1240) Warning: Vehicle 'flow_00.35' performs emergency braking with decel=-10.51 wished=4.50 severity=1.34, time=107.00.
# (pid=1240) Warning: Vehicle 'flow_00.40' performs emergency braking with decel=-13.38 wished=4.50 severity=1.97, time=121.00.
# (pid=1240) Warning: Vehicle 'flow_00.42' performs emergency braking with decel=-17.32 wished=4.50 severity=2.85, time=121.50.
# (pid=1240) Warning: Vehicle 'flow_00.41' performs emergency braking with decel=-17.41 wished=4.50 severity=2.87, time=122.00.
# (pid=1240) Warning: Vehicle 'flow_00.66' performs emergency braking with decel=-9.36 wished=4.50 severity=1.08, time=219.00.
# (pid=1240) Warning: Vehicle 'flow_00.94' performs emergency braking with decel=-12.37 wished=4.50 severity=1.75, time=237.00.
# (pid=1240) Warning: Vehicle 'flow_00.104' performs emergency braking with decel=-24.88 wished=4.50 severity=4.53, time=254.00.
# (pid=1240) Warning: Vehicle 'rl_5' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=263.50.
# (pid=1240) Warning: Vehicle 'flow_00.108' performs emergency braking with decel=-16.60 wished=4.50 severity=2.69, time=264.50.
# (pid=1240) Warning: Vehicle 'flow_00.110' performs emergency braking with decel=-22.73 wished=4.50 severity=4.05, time=271.00.
# (pid=1240) Warning: Vehicle 'flow_00.111' performs emergency braking with decel=-15.35 wished=4.50 severity=2.41, time=271.00.
# (pid=1240) Warning: Vehicle 'flow_00.112' performs emergency braking with decel=-16.08 wished=4.50 severity=2.57, time=271.50.
# (pid=1240) Warning: Vehicle 'flow_00.113' performs emergency braking with decel=-14.60 wished=4.50 severity=2.24, time=272.00.
# (pid=1240) Warning: Vehicle 'flow_00.127' performs emergency braking with decel=-17.61 wished=4.50 severity=2.91, time=306.00.
# (pid=1240) Warning: Vehicle 'flow_00.127' performs emergency braking with decel=-11.96 wished=4.50 severity=1.66, time=308.50.
# (pid=1240) Warning: Vehicle 'rl_1' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=320.50.
# (pid=1240) Warning: Vehicle 'flow_00.135' performs emergency braking with decel=-26.41 wished=4.50 severity=4.87, time=322.00.
# (pid=1240) Warning: Vehicle 'flow_00.137' performs emergency braking with decel=-9.70 wished=4.50 severity=1.16, time=322.00.
# (pid=1240) Warning: Vehicle 'flow_00.136' performs emergency braking with decel=-18.57 wished=4.50 severity=3.13, time=322.50.
# (pid=1240) Warning: Vehicle 'flow_00.138' performs emergency braking with decel=-21.10 wished=4.50 severity=3.69, time=327.00.
# (pid=1240) Warning: Vehicle 'flow_00.139' performs emergency braking with decel=-20.65 wished=4.50 severity=3.59, time=327.50.
# (pid=1240) Warning: Vehicle 'rl_7' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=432.00.
# (pid=1240) Warning: Vehicle 'flow_00.192' performs emergency braking with decel=-17.50 wished=4.50 severity=2.89, time=435.00.
# (pid=1240) Warning: Vehicle 'rl_6' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=472.00.
# (pid=1240) Warning: Vehicle 'flow_00.217' performs emergency braking with decel=-29.73 wished=4.50 severity=5.61, time=490.00.
# (pid=1240) Warning: Vehicle 'flow_00.200' performs emergency braking with decel=-12.46 wished=4.50 severity=1.77, time=490.00.
# (pid=1240) /mnt/c/Users/llave/Documents/GitHub/flow/flow/core/kernel/vehicle/traci.py:957: UserWarning: API change now handles duration as floating point seconds
# (pid=1240)   veh_id, int(target_lane), 100000)
# (pid=1240) Warning: Vehicle 'flow_00.221' performs emergency braking with decel=-24.31 wished=4.50 severity=4.40, time=504.00.
# (pid=1240) Warning: Vehicle 'flow_00.224' performs emergency braking with decel=-23.85 wished=4.50 severity=4.30, time=504.50.
# (pid=1240) Warning: Teleporting vehicle 'flow_00.205'; collision with vehicle 'rl_4', lane=':gneJ30_2_1', gap=-1.00, time=519.00 stage=move.
# (pid=1240) Warning: Vehicle 'flow_00.205' ends teleporting on edge 'edge3', time 519.00.
# (pid=1240) Warning: Vehicle 'flow_00.23' performs emergency braking with decel=-23.40 wished=4.50 severity=4.20, time=86.50.
# (pid=1240) Warning: Vehicle 'rl_6' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=96.50.
# (pid=1240) Warning: Vehicle 'flow_00.30' performs emergency braking with decel=-18.97 wished=4.50 severity=3.22, time=100.00.
# (pid=1240) Warning: Vehicle 'flow_00.29' performs emergency braking with decel=-16.82 wished=4.50 severity=2.74, time=100.00.
# (pid=1240) Warning: Vehicle 'flow_00.35' performs emergency braking with decel=-24.86 wished=4.50 severity=4.53, time=111.50.
# (pid=1240) Warning: Vehicle 'flow_00.36' performs emergency braking with decel=-23.84 wished=4.50 severity=4.30, time=111.50.
# (pid=1240) Warning: Vehicle 'flow_00.35' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=117.00.
# (pid=1240) Warning: Vehicle 'flow_00.37' performs emergency braking with decel=-16.65 wished=4.50 severity=2.70, time=121.50.
# (pid=1240) Warning: Vehicle 'flow_00.44' performs emergency braking with decel=-9.72 wished=4.50 severity=1.16, time=181.50.
# (pid=1240) Warning: Vehicle 'flow_00.48' performs emergency braking with decel=-9.63 wished=4.50 severity=1.14, time=182.00.
# (pid=1240) Warning: Vehicle 'flow_00.95' performs emergency braking with decel=-27.40 wished=4.50 severity=5.09, time=232.00.
# (pid=1240) Warning: Vehicle 'rl_7' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=232.00.
# (pid=1240) Warning: Vehicle 'flow_00.96' performs emergency braking with decel=-16.70 wished=4.50 severity=2.71, time=232.50.
# (pid=1240) Warning: Vehicle 'rl_6' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=248.00.
# (pid=1240) Warning: Vehicle 'flow_00.103' performs emergency braking with decel=-21.70 wished=4.50 severity=3.82, time=252.00.
# (pid=1240) Warning: Vehicle 'flow_00.102' performs emergency braking with decel=-22.85 wished=4.50 severity=4.08, time=252.00.
# (pid=1240) Warning: Vehicle 'flow_00.101' performs emergency braking with decel=-22.51 wished=4.50 severity=4.00, time=252.50.
# (pid=1240) Warning: Vehicle 'flow_00.104' performs emergency braking with decel=-13.70 wished=4.50 severity=2.05, time=252.50.
# (pid=1240) Warning: Vehicle 'flow_00.105' performs emergency braking with decel=-14.10 wished=4.50 severity=2.13, time=253.00.
# (pid=1240) Warning: Vehicle 'rl_4' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=284.00.
# (pid=1240) Warning: Vehicle 'flow_00.119' performs emergency braking with decel=-10.67 wished=4.50 severity=1.37, time=285.50.
# (pid=1240) Warning: Vehicle 'flow_00.120' performs emergency braking with decel=-10.60 wished=4.50 severity=1.36, time=286.00.
# (pid=1240) Warning: Vehicle 'flow_00.118' performs emergency braking with decel=-18.18 wished=4.50 severity=3.04, time=288.50.
# (pid=1240) Warning: Vehicle 'rl_1' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=294.00.
# (pid=1240) Warning: Vehicle 'rl_0' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=315.00.
# (pid=1240) Warning: Vehicle 'flow_00.131' performs emergency braking with decel=-13.23 wished=4.50 severity=1.94, time=316.50.
# (pid=1240) Warning: Vehicle 'flow_00.133' performs emergency braking with decel=-13.35 wished=4.50 severity=1.97, time=316.50.
# (pid=1240) Warning: Vehicle 'flow_00.110' performs emergency braking with decel=-10.54 wished=4.50 severity=1.34, time=317.50.
# (pid=1240) Warning: Vehicle 'flow_00.156' performs emergency braking with decel=-9.96 wished=4.50 severity=1.21, time=408.50.
# (pid=1240) Warning: Vehicle 'flow_00.119' performs emergency braking with decel=-9.27 wished=4.50 severity=1.06, time=413.00.
# (pid=1240) Warning: Vehicle 'flow_00.124' performs emergency braking with decel=-10.74 wished=4.50 severity=1.39, time=428.00.
# (pid=1240) Warning: Vehicle 'rl_7' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=431.50.
# (pid=1240) /mnt/c/Users/llave/Documents/GitHub/flow/flow/core/kernel/vehicle/traci.py:957: UserWarning: API change now handles duration as floating point seconds
# (pid=1240)   veh_id, int(target_lane), 100000)
# (pid=1240) Warning: Teleporting vehicle 'flow_00.225'; collision with vehicle 'rl_3', lane=':gneJ30_2_1', gap=-1.00, time=592.00 stage=move.
# (pid=1240) Warning: Vehicle 'flow_00.225' ends teleporting on edge 'edge3', time 592.00.
# (pid=1240) Warning: Vehicle 'flow_00.29' performs emergency braking with decel=-10.27 wished=4.50 severity=1.28, time=92.00.
# (pid=1240) Warning: Vehicle 'flow_00.12' performs emergency braking with decel=-13.89 wished=4.50 severity=2.09, time=101.00.
# (pid=1240) Warning: Vehicle 'flow_00.35' performs emergency braking with decel=-26.20 wished=4.50 severity=4.82, time=107.00.
# (pid=1240) Warning: Vehicle 'rl_6' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=107.00.
# (pid=1240) Warning: Vehicle 'flow_00.36' performs emergency braking with decel=-9.25 wished=4.50 severity=1.06, time=108.00.
# (pid=1240) Warning: Vehicle 'rl_5' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=111.50.
# (pid=1240) Warning: Vehicle 'flow_00.37' performs emergency braking with decel=-10.53 wished=4.50 severity=1.34, time=113.50.
# (pid=1240) Warning: Vehicle 'flow_00.38' performs emergency braking with decel=-12.42 wished=4.50 severity=1.76, time=114.00.
# (pid=1240) Warning: Vehicle 'flow_00.39' performs emergency braking with decel=-14.12 wished=4.50 severity=2.14, time=119.00.
# (pid=1240) Warning: Vehicle 'rl_7' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=248.50.
# (pid=1240) Warning: Vehicle 'flow_00.102' performs emergency braking with decel=-26.89 wished=4.50 severity=4.97, time=249.00.
# (pid=1240) Warning: Vehicle 'rl_6' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=276.00.
# (pid=1240) Warning: Vehicle 'flow_00.114' performs emergency braking with decel=-10.98 wished=4.50 severity=1.44, time=276.50.
# (pid=1240) Warning: Vehicle 'rl_5' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=281.50.
# (pid=1240) Warning: Vehicle 'flow_00.119' performs emergency braking with decel=-28.61 wished=4.50 severity=5.36, time=283.00.
# (pid=1240) Warning: Vehicle 'flow_00.115' performs emergency braking with decel=-14.07 wished=4.50 severity=2.13, time=283.00.
# (pid=1240) Warning: Vehicle 'flow_00.115' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=285.50.
# (pid=1240) Warning: Vehicle 'rl_3' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=291.00.
# (pid=1240) Warning: Vehicle 'flow_00.122' performs emergency braking with decel=-24.36 wished=4.50 severity=4.41, time=292.50.
# (pid=1240) Warning: Vehicle 'flow_00.120' performs emergency braking with decel=-11.94 wished=4.50 severity=1.65, time=292.50.
# (pid=1240) Warning: Vehicle 'flow_00.121' performs emergency braking with decel=-10.82 wished=4.50 severity=1.40, time=293.00.
# (pid=1240) Warning: Vehicle 'flow_00.123' performs emergency braking with decel=-11.08 wished=4.50 severity=1.46, time=293.50.
# (pid=1240) Warning: Vehicle 'rl_0' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=302.50.
# (pid=1240) Warning: Vehicle 'flow_00.125' performs emergency braking with decel=-9.95 wished=4.50 severity=1.21, time=430.00.
# (pid=1240) Warning: Vehicle 'flow_00.186' performs emergency braking with decel=-20.51 wished=4.50 severity=3.56, time=435.00.
# (pid=1240) Warning: Vehicle 'flow_00.188' performs emergency braking with decel=-9.54 wished=4.50 severity=1.12, time=435.50.
# (pid=1240) Warning: Vehicle 'flow_00.218' performs emergency braking with decel=-9.69 wished=4.50 severity=1.15, time=498.50.
# (pid=1240) Warning: Vehicle 'flow_00.220' performs emergency braking with decel=-12.35 wished=4.50 severity=1.75, time=499.00.
# (pid=1240) /mnt/c/Users/llave/Documents/GitHub/flow/flow/core/kernel/vehicle/traci.py:957: UserWarning: API change now handles duration as floating point seconds
# (pid=1240)   veh_id, int(target_lane), 100000)
# (pid=1240) Warning: Vehicle 'flow_00.227' performs emergency braking with decel=-17.65 wished=4.50 severity=2.92, time=528.50.
# (pid=1240) Warning: Vehicle 'flow_00.230' performs emergency braking with decel=-15.90 wished=4.50 severity=2.53, time=529.00.
# (pid=1240) Warning: Vehicle 'flow_00.232' performs emergency braking with decel=-15.98 wished=4.50 severity=2.55, time=529.50.
# (pid=1240) Warning: Vehicle 'flow_00.234' performs emergency braking with decel=-16.46 wished=4.50 severity=2.66, time=530.00.
# (pid=1240) Warning: Vehicle 'flow_00.232' performs emergency braking with decel=-9.27 wished=4.50 severity=1.06, time=541.00.
# (pid=1240) Warning: Vehicle 'flow_00.207' performs emergency braking with decel=-25.53 wished=4.50 severity=4.67, time=588.00.
# (pid=1240) Warning: Vehicle 'flow_00.210' performs emergency braking with decel=-18.96 wished=4.50 severity=3.21, time=588.50.
# (pid=1240) Warning: Vehicle 'flow_00.209' performs emergency braking with decel=-18.97 wished=4.50 severity=3.22, time=589.00.
# (pid=1240) Warning: Vehicle 'flow_00.211' performs emergency braking with decel=-14.99 wished=4.50 severity=2.33, time=589.50.
# (pid=1240) Warning: Teleporting vehicle 'flow_00.236'; collision with vehicle 'rl_1', lane=':gneJ30_2_1', gap=-1.00, time=591.00 stage=move.
# (pid=1240) Warning: Vehicle 'flow_00.236' ends teleporting on edge 'edge3', time 591.00.
# (pid=1240) Warning: Vehicle 'rl_7' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=101.00.
# (pid=1240) Warning: Vehicle 'rl_6' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=106.00.
# (pid=1240) Warning: Vehicle 'flow_00.31' performs emergency braking with decel=-10.59 wished=4.50 severity=1.35, time=107.50.
# (pid=1240) Warning: Vehicle 'flow_00.33' performs emergency braking with decel=-14.33 wished=4.50 severity=2.18, time=108.00.
# (pid=1240) Warning: Vehicle 'flow_00.38' performs emergency braking with decel=-14.37 wished=4.50 severity=2.19, time=118.00.
# (pid=1240) Warning: Vehicle 'flow_00.39' performs emergency braking with decel=-14.52 wished=4.50 severity=2.23, time=118.50.
# (pid=1240) Warning: Vehicle 'flow_00.40' performs emergency braking with decel=-13.11 wished=4.50 severity=1.91, time=119.00.
# (pid=1240) Warning: Vehicle 'flow_00.20' performs emergency braking with decel=-16.63 wished=4.50 severity=2.70, time=119.50.
# (pid=1240) Warning: Vehicle 'flow_00.41' performs emergency braking with decel=-12.11 wished=4.50 severity=1.69, time=119.50.
# (pid=1240) Warning: Vehicle 'flow_00.27' performs emergency braking with decel=-9.78 wished=4.50 severity=1.17, time=140.00.
# (pid=1240) Warning: Vehicle 'rl_7' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=261.00.
# (pid=1240) Warning: Vehicle 'flow_00.110' performs emergency braking with decel=-22.28 wished=4.50 severity=3.95, time=267.00.
# (pid=1240) Warning: Vehicle 'flow_00.109' performs emergency braking with decel=-24.59 wished=4.50 severity=4.46, time=267.00.
# (pid=1240) Warning: Vehicle 'flow_00.112' performs emergency braking with decel=-24.51 wished=4.50 severity=4.45, time=267.50.
# (pid=1240) Warning: Vehicle 'flow_00.113' performs emergency braking with decel=-9.08 wished=4.50 severity=1.02, time=268.00.
# (pid=1240) Warning: Vehicle 'rl_5' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=269.00.
# (pid=1240) Warning: Vehicle 'rl_2' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=293.50.
# (pid=1240) Warning: Vehicle 'flow_00.124' performs emergency braking with decel=-11.41 wished=4.50 severity=1.54, time=296.50.
# (pid=1240) Warning: Vehicle 'rl_0' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=311.50.
# (pid=1240) Warning: Vehicle 'flow_00.130' performs emergency braking with decel=-14.28 wished=4.50 severity=2.17, time=313.50.
# (pid=1240) Warning: Vehicle 'flow_00.112' performs emergency braking with decel=-13.59 wished=4.50 severity=2.02, time=330.50.
# (pid=1240) Warning: Vehicle 'flow_00.117' performs emergency braking with decel=-9.53 wished=4.50 severity=1.12, time=342.00.
# (pid=1240) Warning: Vehicle 'flow_00.132' performs emergency braking with decel=-9.61 wished=4.50 severity=1.14, time=368.50.
# (pid=1240) Warning: Vehicle 'flow_00.111' performs emergency braking with decel=-9.94 wished=4.50 severity=1.21, time=402.00.
# (pid=1240) Warning: Vehicle 'flow_00.208' performs emergency braking with decel=-13.16 wished=4.50 severity=1.92, time=475.00.
# (pid=1240) Warning: Vehicle 'rl_4' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=496.50.
# (pid=1240) Warning: Vehicle 'flow_00.205' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=497.00.
# (pid=1240) /mnt/c/Users/llave/Documents/GitHub/flow/flow/core/kernel/vehicle/traci.py:957: UserWarning: API change now handles duration as floating point seconds
# (pid=1240)   veh_id, int(target_lane), 100000)
# (pid=1240) Warning: Vehicle 'flow_00.223' performs emergency braking with decel=-16.56 wished=4.50 severity=2.68, time=505.00.
# (pid=1240) Warning: Teleporting vehicle 'flow_00.206'; collision with vehicle 'rl_4', lane=':gneJ30_2_1', gap=-1.00, time=522.50 stage=move.
# (pid=1240) Warning: Vehicle 'flow_00.206' ends teleporting on edge 'edge3', time 522.50.
# (pid=1240) Warning: Vehicle 'flow_00.32' performs emergency braking with decel=-27.70 wished=4.50 severity=5.16, time=100.50.
# (pid=1240) Warning: Vehicle 'rl_6' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=106.00.
# (pid=1240) Warning: Vehicle 'flow_00.33' performs emergency braking with decel=-20.56 wished=4.50 severity=3.57, time=108.50.
# (pid=1240) Warning: Vehicle 'flow_00.34' performs emergency braking with decel=-12.40 wished=4.50 severity=1.76, time=109.00.
# (pid=1240) Warning: Vehicle 'flow_00.105' performs emergency braking with decel=-25.49 wished=4.50 severity=4.66, time=259.00.
# (pid=1240) Warning: Vehicle 'flow_00.106' performs emergency braking with decel=-24.91 wished=4.50 severity=4.54, time=259.50.
# (pid=1240) Warning: Vehicle 'flow_00.112' performs emergency braking with decel=-23.27 wished=4.50 severity=4.17, time=271.50.
# (pid=1240) Warning: Vehicle 'rl_6' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=271.50.
# (pid=1240) Warning: Vehicle 'flow_00.113' performs emergency braking with decel=-23.03 wished=4.50 severity=4.12, time=272.00.
# (pid=1240) Warning: Vehicle 'flow_00.111' performs emergency braking with decel=-12.75 wished=4.50 severity=1.83, time=273.00.
# (pid=1240) Warning: Vehicle 'rl_4' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=278.50.
# (pid=1240) Warning: Vehicle 'flow_00.109' performs emergency braking with decel=-16.00 wished=4.50 severity=2.56, time=323.00.
# (pid=1240) Warning: Vehicle 'flow_00.99' performs emergency braking with decel=-11.94 wished=4.50 severity=1.65, time=332.50.
# (pid=1240) Warning: Vehicle 'flow_00.114' performs emergency braking with decel=-9.80 wished=4.50 severity=1.18, time=342.00.
# (pid=1240) Warning: Vehicle 'flow_00.131' performs emergency braking with decel=-13.81 wished=4.50 severity=2.07, time=364.50.
# (pid=1240) Warning: Vehicle 'rl_7' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=462.50.
# (pid=1240) Warning: Vehicle 'flow_00.204' performs emergency braking with decel=-25.47 wished=4.50 severity=4.66, time=465.50.
# (pid=1240) Warning: Vehicle 'rl_6' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=498.00.
# (pid=1240) Warning: Vehicle 'flow_00.212' performs emergency braking with decel=-14.83 wished=4.50 severity=2.30, time=499.50.
# (pid=1240) Warning: Vehicle 'flow_00.214' performs emergency braking with decel=-14.00 wished=4.50 severity=2.11, time=500.00.
# (pid=1240) Warning: Vehicle 'flow_00.215' performs emergency braking with decel=-13.30 wished=4.50 severity=1.96, time=500.50.
# (pid=1240) /mnt/c/Users/llave/Documents/GitHub/flow/flow/core/kernel/vehicle/traci.py:957: UserWarning: API change now handles duration as floating point seconds
# (pid=1240)   veh_id, int(target_lane), 100000)
# (pid=1240) Warning: Vehicle 'flow_00.217' performs emergency braking with decel=-12.75 wished=4.50 severity=1.83, time=501.00.
# (pid=1240) Warning: Vehicle 'flow_00.218' performs emergency braking with decel=-12.35 wished=4.50 severity=1.74, time=501.50.
# (pid=1240) Warning: Vehicle 'flow_00.220' performs emergency braking with decel=-12.54 wished=4.50 severity=1.79, time=502.00.
# (pid=1240) Warning: Vehicle 'flow_00.222' performs emergency braking with decel=-12.69 wished=4.50 severity=1.82, time=502.50.
# (pid=1240) Warning: Vehicle 'flow_00.219' performs emergency braking with decel=-21.46 wished=4.50 severity=3.77, time=503.00.
# (pid=1240) Warning: Vehicle 'flow_00.224' performs emergency braking with decel=-12.72 wished=4.50 severity=1.83, time=503.00.
# (pid=1240) Warning: Vehicle 'flow_00.221' performs emergency braking with decel=-12.77 wished=4.50 severity=1.84, time=503.50.
# (pid=1240) Warning: Vehicle 'flow_00.222' performs emergency braking with decel=-9.86 wished=4.50 severity=1.19, time=523.00.
# (pid=1240) Warning: Vehicle 'flow_00.224' performs emergency braking with decel=-10.24 wished=4.50 severity=1.28, time=523.50.
# (pid=1240) Warning: Teleporting vehicle 'flow_00.243'; collision with vehicle 'rl_4', lane=':gneJ30_2_1', gap=-1.00, time=588.50 stage=move.
# (pid=1240) Warning: Vehicle 'flow_00.243' ends teleporting on edge 'edge3', time 588.50.
# (pid=1240) Warning: Vehicle 'rl_7' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=88.00.
# (pid=1240) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-17.39 wished=4.50 severity=2.86, time=92.50.
# (pid=1240) Warning: Vehicle 'flow_00.28' performs emergency braking with decel=-22.89 wished=4.50 severity=4.09, time=95.00.
# (pid=1240) Warning: Vehicle 'rl_4' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=105.00.
# (pid=1240) Warning: Vehicle 'flow_00.34' performs emergency braking with decel=-17.65 wished=4.50 severity=2.92, time=109.50.
# (pid=1240) Warning: Vehicle 'rl_2' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=112.00.
# (pid=1240) Warning: Vehicle 'flow_00.38' performs emergency braking with decel=-12.51 wished=4.50 severity=1.78, time=114.00.
# (pid=1240) Warning: Vehicle 'flow_00.42' performs emergency braking with decel=-9.20 wished=4.50 severity=1.04, time=121.00.
# (pid=1240) Warning: Vehicle 'flow_00.41' performs emergency braking with decel=-14.86 wished=4.50 severity=2.30, time=127.50.
# (pid=1240) Warning: Vehicle 'flow_00.43' performs emergency braking with decel=-10.04 wished=4.50 severity=1.23, time=128.00.
# (pid=1240) Warning: Vehicle 'flow_00.36' performs emergency braking with decel=-11.53 wished=4.50 severity=1.56, time=182.00.
# (pid=1240) Warning: Vehicle 'rl_6' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=245.50.
# (pid=1240) Warning: Vehicle 'flow_00.100' performs emergency braking with decel=-14.25 wished=4.50 severity=2.17, time=246.50.
# (pid=1240) Warning: Vehicle 'rl_5' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=249.00.
# (pid=1240) Warning: Vehicle 'flow_00.119' performs emergency braking with decel=-15.26 wished=4.50 severity=2.39, time=285.50.
# (pid=1240) Warning: Vehicle 'flow_00.117' performs emergency braking with decel=-12.64 wished=4.50 severity=1.81, time=287.50.
# (pid=1240) Warning: Vehicle 'flow_00.119' performs emergency braking with decel=-15.28 wished=4.50 severity=2.40, time=287.50.
# (pid=1240) Warning: Vehicle 'flow_00.120' performs emergency braking with decel=-12.04 wished=4.50 severity=1.67, time=288.00.
# (pid=1240) Warning: Vehicle 'flow_00.126' performs emergency braking with decel=-24.92 wished=4.50 severity=4.54, time=301.50.
# (pid=1240) Warning: Vehicle 'flow_00.125' performs emergency braking with decel=-23.59 wished=4.50 severity=4.24, time=301.50.
# (pid=1240) Warning: Vehicle 'flow_00.128' performs emergency braking with decel=-19.89 wished=4.50 severity=3.42, time=302.00.
# (pid=1240) Warning: Vehicle 'flow_00.127' performs emergency braking with decel=-19.91 wished=4.50 severity=3.42, time=302.00.
# (pid=1240) Warning: Vehicle 'flow_00.132' performs emergency braking with decel=-17.76 wished=4.50 severity=2.95, time=320.00.
# (pid=1240) Warning: Vehicle 'flow_00.134' performs emergency braking with decel=-11.00 wished=4.50 severity=1.45, time=320.50.
# (pid=1240) Warning: Vehicle 'flow_00.137' performs emergency braking with decel=-11.82 wished=4.50 severity=1.63, time=331.00.
# (pid=1240) Warning: Vehicle 'flow_00.139' performs emergency braking with decel=-13.17 wished=4.50 severity=1.93, time=331.50.
# (pid=1240) Warning: Vehicle 'flow_00.142' performs emergency braking with decel=-16.07 wished=4.50 severity=2.57, time=332.00.
# (pid=1240) Warning: Vehicle 'flow_00.116' performs emergency braking with decel=-13.87 wished=4.50 severity=2.08, time=332.50.
# (pid=1240) Warning: Vehicle 'flow_00.141' performs emergency braking with decel=-17.68 wished=4.50 severity=2.93, time=332.50.
# (pid=1240) Warning: Vehicle 'flow_00.143' performs emergency braking with decel=-20.07 wished=4.50 severity=3.46, time=333.00.
# (pid=1240) Warning: Vehicle 'flow_00.115' performs emergency braking with decel=-9.74 wished=4.50 severity=1.16, time=342.50.
# (pid=1240) Warning: Vehicle 'flow_00.99' performs emergency braking with decel=-9.85 wished=4.50 severity=1.19, time=361.00.
# (pid=1240) Warning: Vehicle 'flow_00.184' performs emergency braking with decel=-15.87 wished=4.50 severity=2.53, time=422.50.
# (pid=1240) Warning: Vehicle 'flow_00.190' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=453.50.
# (pid=1240) Warning: Vehicle 'flow_00.192' performs emergency braking with decel=-10.43 wished=4.50 severity=1.32, time=454.00.
# (pid=1240) Warning: Vehicle 'flow_00.194' performs emergency braking with decel=-12.99 wished=4.50 severity=1.89, time=454.50.
# (pid=1240) Warning: Vehicle 'flow_00.193' performs emergency braking with decel=-14.49 wished=4.50 severity=2.22, time=455.00.
# (pid=1240) Warning: Vehicle 'flow_00.195' performs emergency braking with decel=-15.50 wished=4.50 severity=2.45, time=455.50.
# (pid=1240) Warning: Vehicle 'flow_00.197' performs emergency braking with decel=-15.68 wished=4.50 severity=2.48, time=456.00.
# (pid=1240) Warning: Vehicle 'flow_00.198' performs emergency braking with decel=-15.49 wished=4.50 severity=2.44, time=456.50.
# (pid=1240) Warning: Vehicle 'flow_00.199' performs emergency braking with decel=-15.09 wished=4.50 severity=2.35, time=457.00.
# (pid=1240) Warning: Vehicle 'flow_00.200' performs emergency braking with decel=-15.43 wished=4.50 severity=2.43, time=457.50.
# (pid=1240) Warning: Vehicle 'flow_00.201' performs emergency braking with decel=-16.49 wished=4.50 severity=2.66, time=458.00.
# (pid=1240) Warning: Vehicle 'rl_5' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=467.00.
# (pid=1240) Warning: Vehicle 'flow_00.197' performs emergency braking with decel=-11.05 wished=4.50 severity=1.46, time=469.00.
# (pid=1240) Warning: Vehicle 'flow_00.198' performs emergency braking with decel=-12.43 wished=4.50 severity=1.76, time=469.50.
# (pid=1240) Warning: Vehicle 'flow_00.199' performs emergency braking with decel=-13.53 wished=4.50 severity=2.01, time=470.00.
# (pid=1240) Warning: Vehicle 'flow_00.200' performs emergency braking with decel=-14.11 wished=4.50 severity=2.14, time=470.50.
# (pid=1240) Warning: Vehicle 'flow_00.201' performs emergency braking with decel=-14.54 wished=4.50 severity=2.23, time=471.00.
# (pid=1240) Warning: Vehicle 'flow_00.203' performs emergency braking with decel=-14.31 wished=4.50 severity=2.18, time=471.50.
# (pid=1240) Warning: Vehicle 'flow_00.205' performs emergency braking with decel=-13.98 wished=4.50 severity=2.11, time=472.00.
# (pid=1240) Warning: Vehicle 'flow_00.206' performs emergency braking with decel=-13.48 wished=4.50 severity=2.00, time=472.50.
# (pid=1240) Warning: Vehicle 'flow_00.208' performs emergency braking with decel=-12.94 wished=4.50 severity=1.88, time=473.00.
# (pid=1240) Warning: Vehicle 'flow_00.207' performs emergency braking with decel=-12.61 wished=4.50 severity=1.80, time=473.50.
# (pid=1240) Warning: Vehicle 'flow_00.210' performs emergency braking with decel=-13.89 wished=4.50 severity=2.09, time=474.00.
# (pid=1240) Warning: Vehicle 'flow_00.211' performs emergency braking with decel=-15.03 wished=4.50 severity=2.34, time=474.50.
# (pid=1240) /mnt/c/Users/llave/Documents/GitHub/flow/flow/core/kernel/vehicle/traci.py:957: UserWarning: API change now handles duration as floating point seconds
# (pid=1240)   veh_id, int(target_lane), 100000)
# (pid=1240) Warning: Teleporting vehicle 'flow_00.139'; collision with vehicle 'rl_0', lane=':gneJ31_1_0', gap=-1.00, time=534.00 stage=move.
# (pid=1240) Warning: Vehicle 'flow_00.139' ends teleporting on edge 'edge6', time 534.00.
# (pid=1240) Warning: Vehicle 'rl_7' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=83.50.
# (pid=1240) Warning: Vehicle 'flow_00.31' performs emergency braking with decel=-23.43 wished=4.50 severity=4.21, time=101.50.
# (pid=1240) Warning: Vehicle 'flow_00.30' performs emergency braking with decel=-9.88 wished=4.50 severity=1.20, time=102.00.
# (pid=1240) Warning: Vehicle 'rl_5' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=106.50.
# (pid=1240) Warning: Vehicle 'rl_5' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=107.50.
# (pid=1240) Warning: Vehicle 'flow_00.36' performs emergency braking with decel=-16.06 wished=4.50 severity=2.57, time=108.00.
# (pid=1240) Warning: Vehicle 'flow_00.37' performs emergency braking with decel=-18.75 wished=4.50 severity=3.17, time=108.50.
# (pid=1240) Warning: Vehicle 'flow_00.36' performs emergency braking with decel=-10.48 wished=4.50 severity=1.33, time=112.00.
# (pid=1240) Warning: Vehicle 'flow_00.51' performs emergency braking with decel=-9.20 wished=4.50 severity=1.04, time=204.00.
# (pid=1240) Warning: Vehicle 'rl_7' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=231.50.
# (pid=1240) Warning: Vehicle 'flow_00.91' performs emergency braking with decel=-20.40 wished=4.50 severity=3.53, time=232.50.
# ...
# (pid=1240) Warning: Vehicle 'flow_00.256' performs emergency braking with decel=-9.49 wished=4.50 severity=1.11, time=579.50.
# (pid=1240) Warning: Vehicle 'flow_00.258' performs emergency braking with decel=-12.12 wished=4.50 severity=1.69, time=580.00.
# (pid=1240) Warning: Vehicle 'flow_00.259' performs emergency braking with decel=-9.15 wished=4.50 severity=1.03, time=580.50.
# (pid=1240) Warning: Teleporting vehicle 'flow_00.254'; collision with vehicle 'rl_5', lane=':gneJ30_2_1', gap=-1.00, time=596.50 stage=move.
# (pid=1240) Warning: Vehicle 'flow_00.254' ends teleporting on edge 'edge3', time 596.50.
# (pid=1240) Warning: Vehicle 'flow_00.33' performs emergency braking with decel=-26.92 wished=4.50 severity=4.98, time=102.00.
# (pid=1240) Warning: Vehicle 'flow_00.31' performs emergency braking with decel=-14.68 wished=4.50 severity=2.26, time=102.50.
# (pid=1240) Warning: Vehicle 'flow_00.32' performs emergency braking with decel=-10.36 wished=4.50 severity=1.30, time=103.00.
# (pid=1240) Warning: Vehicle 'flow_00.36' performs emergency braking with decel=-16.76 wished=4.50 severity=2.73, time=112.50.
# (pid=1240) Warning: Vehicle 'rl_5' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=112.50.
# (pid=1240) Warning: Vehicle 'flow_00.37' performs emergency braking with decel=-17.10 wished=4.50 severity=2.80, time=113.00.
# (pid=1240) Warning: Vehicle 'flow_00.38' performs emergency braking with decel=-15.96 wished=4.50 severity=2.55, time=114.00.
# (pid=1240) Warning: Vehicle 'rl_1' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=123.50.
# (pid=1240) Warning: Vehicle 'flow_00.39' performs emergency braking with decel=-9.15 wished=4.50 severity=1.03, time=173.00.
# (pid=1240) Warning: Vehicle 'flow_00.37' performs emergency braking with decel=-9.84 wished=4.50 severity=1.19, time=186.50.
# (pid=1240) Warning: Vehicle 'flow_00.108' performs emergency braking with decel=-17.07 wished=4.50 severity=2.79, time=262.50.
# (pid=1240) Warning: Vehicle 'rl_6' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=265.00.
# (pid=1240) Warning: Vehicle 'flow_00.117' performs emergency braking with decel=-23.45 wished=4.50 severity=4.21, time=280.00.
# (pid=1240) Warning: Vehicle 'flow_00.118' performs emergency braking with decel=-10.06 wished=4.50 severity=1.24, time=280.50.
# (pid=1240) Warning: Vehicle 'rl_3' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=284.50.
# (pid=1240) Warning: Vehicle 'flow_00.118' performs emergency braking with decel=-16.96 wished=4.50 severity=2.77, time=286.50.
# (pid=1240) Warning: Vehicle 'rl_2' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=288.50.
# (pid=1240) Warning: Vehicle 'flow_00.120' performs emergency braking with decel=-15.30 wished=4.50 severity=2.40, time=292.00.
# (pid=1240) Warning: Vehicle 'flow_00.208' performs emergency braking with decel=-17.63 wished=4.50 severity=2.92, time=475.50.
# (pid=1240) /mnt/c/Users/llave/Documents/GitHub/flow/flow/core/kernel/vehicle/traci.py:957: UserWarning: API change now handles duration as floating point seconds
# (pid=1240)   veh_id, int(target_lane), 100000)
# (pid=1240) Warning: Vehicle 'flow_00.219' performs emergency braking with decel=-11.29 wished=4.50 severity=1.51, time=511.50.
# (pid=1240) Warning: Vehicle 'flow_00.221' performs emergency braking with decel=-11.79 wished=4.50 severity=1.62, time=512.00.
# (pid=1240) Warning: Vehicle 'flow_00.223' performs emergency braking with decel=-12.46 wished=4.50 severity=1.77, time=512.50.
# (pid=1240) Warning: Vehicle 'flow_00.225' performs emergency braking with decel=-24.34 wished=4.50 severity=4.41, time=513.00.
# (pid=1240) Warning: Vehicle 'flow_00.224' performs emergency braking with decel=-13.50 wished=4.50 severity=2.00, time=513.00.
# (pid=1240) Warning: Vehicle 'flow_00.226' performs emergency braking with decel=-15.34 wished=4.50 severity=2.41, time=513.50.
# (pid=1240) Warning: Vehicle 'flow_00.228' performs emergency braking with decel=-18.63 wished=4.50 severity=3.14, time=514.00.
# (pid=1240) Warning: Vehicle 'flow_00.227' performs emergency braking with decel=-19.89 wished=4.50 severity=3.42, time=514.50.
# (pid=1240) Warning: Vehicle 'flow_00.229' performs emergency braking with decel=-21.13 wished=4.50 severity=3.70, time=515.00.
# (pid=1240) Warning: Teleporting vehicle 'rl_5'; collision with vehicle 'flow_00.219', lane=':gneJ30_1_0', gap=-1.00, time=521.50 stage=move.
# (pid=1240) Warning: Vehicle 'rl_5' ends teleporting on edge 'edge3', time 521.50.
# (pid=1240) Warning: Vehicle 'flow_00.27' performs emergency braking with decel=-23.65 wished=4.50 severity=4.26, time=93.50.
# (pid=1240) Warning: Vehicle 'flow_00.12' performs emergency braking with decel=-10.37 wished=4.50 severity=1.31, time=94.00.
# (pid=1240) Warning: Vehicle 'flow_00.29' performs emergency braking with decel=-19.72 wished=4.50 severity=3.38, time=94.00.
# (pid=1240) Warning: Vehicle 'rl_6' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=100.00.
# (pid=1240) Warning: Vehicle 'rl_6' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=101.50.
# (pid=1240) Warning: Vehicle 'flow_00.32' performs emergency braking with decel=-11.27 wished=4.50 severity=1.50, time=102.00.
# (pid=1240) Warning: Vehicle 'flow_00.34' performs emergency braking with decel=-18.46 wished=4.50 severity=3.10, time=103.00.
# (pid=1240) Warning: Vehicle 'flow_00.32' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=106.50.
# (pid=1240) Warning: Vehicle 'rl_2' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=118.00.
# (pid=1240) Warning: Vehicle 'flow_00.41' performs emergency braking with decel=-10.78 wished=4.50 severity=1.40, time=123.00.
# (pid=1240) Warning: Vehicle 'rl_7' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=250.00.
# (pid=1240) Warning: Vehicle 'rl_6' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=263.50.
# (pid=1240) Warning: Vehicle 'flow_00.109' performs emergency braking with decel=-26.44 wished=4.50 severity=4.88, time=264.50.
# (pid=1240) Warning: Vehicle 'flow_00.113' performs emergency braking with decel=-18.60 wished=4.50 severity=3.13, time=274.00.
# (pid=1240) Warning: Vehicle 'rl_4' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=276.50.
# (pid=1240) Warning: Vehicle 'flow_00.115' performs emergency braking with decel=-24.40 wished=4.50 severity=4.42, time=277.00.
# (pid=1240) Warning: Teleporting vehicle 'flow_00.112'; collision with vehicle 'flow_00.115', lane='edge2_0', gap=-0.24, time=277.00 stage=move.
# (pid=1240) Warning: Vehicle 'flow_00.112' ends teleporting on edge 'edge3', time 277.00.
# (pid=1240) Warning: Vehicle 'flow_00.114' performs emergency braking with decel=-9.64 wished=4.50 severity=1.14, time=282.00.
# (pid=1240) Warning: Vehicle 'flow_00.117' performs emergency braking with decel=-18.35 wished=4.50 severity=3.08, time=293.00.
# (pid=1240) Warning: Vehicle 'rl_2' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=293.00.
# (pid=1240) Warning: Vehicle 'flow_00.121' performs emergency braking with decel=-19.04 wished=4.50 severity=3.23, time=293.50.
# (pid=1240) Warning: Vehicle 'flow_00.123' performs emergency braking with decel=-18.04 wished=4.50 severity=3.01, time=294.00.
# (pid=1240) Warning: Vehicle 'flow_00.122' performs emergency braking with decel=-16.08 wished=4.50 severity=2.57, time=294.50.
# (pid=1240) Warning: Vehicle 'rl_1' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=297.50.
# (pid=1240) Warning: Vehicle 'flow_00.121' performs emergency braking with decel=-10.86 wished=4.50 severity=1.41, time=300.00.
# (pid=1240) Warning: Vehicle 'flow_00.125' performs emergency braking with decel=-10.81 wished=4.50 severity=1.40, time=312.00.
# (pid=1240) Warning: Vehicle 'flow_00.193' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=466.50.
# (pid=1240) Warning: Vehicle 'flow_00.207' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=492.00.
# (pid=1240) /mnt/c/Users/llave/Documents/GitHub/flow/flow/core/kernel/vehicle/traci.py:957: UserWarning: API change now handles duration as floating point seconds
# (pid=1240)   veh_id, int(target_lane), 100000)
# (pid=1240) Warning: Vehicle 'rl_4' performs emergency braking with decel=-15.89 wished=4.50 severity=2.53, time=503.50.
# (pid=1240) Warning: Teleporting vehicle 'flow_00.233'; collision with vehicle 'rl_3', lane=':gneJ30_2_0', gap=-1.00, time=564.50 stage=move.
# (pid=1240) Warning: Vehicle 'flow_00.233' ends teleporting on edge 'edge3', time 564.50.
# (pid=1240) Warning: Vehicle 'rl_7' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=88.00.
# (pid=1240) Warning: Vehicle 'flow_00.26' performs emergency braking with decel=-17.39 wished=4.50 severity=2.86, time=92.50.
# (pid=1240) Warning: Vehicle 'flow_00.28' performs emergency braking with decel=-22.89 wished=4.50 severity=4.09, time=95.00.
# (pid=1240) Warning: Vehicle 'rl_4' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=105.00.
# (pid=1240) Warning: Vehicle 'flow_00.34' performs emergency braking with decel=-17.65 wished=4.50 severity=2.92, time=109.50.
# (pid=1240) Warning: Vehicle 'rl_2' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=112.00.
# (pid=1240) Warning: Vehicle 'flow_00.38' performs emergency braking with decel=-12.51 wished=4.50 severity=1.78, time=114.00.
# (pid=1240) Warning: Vehicle 'flow_00.42' performs emergency braking with decel=-9.20 wished=4.50 severity=1.04, time=121.00.
# (pid=1240) Warning: Vehicle 'flow_00.41' performs emergency braking with decel=-14.86 wished=4.50 severity=2.30, time=127.50.
# (pid=1240) Warning: Vehicle 'flow_00.43' performs emergency braking with decel=-10.04 wished=4.50 severity=1.23, time=128.00.
# (pid=1240) Warning: Vehicle 'flow_00.36' performs emergency braking with decel=-11.53 wished=4.50 severity=1.56, time=182.00.
# (pid=1240) Warning: Vehicle 'rl_6' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=245.50.
# (pid=1240) Warning: Vehicle 'flow_00.100' performs emergency braking with decel=-14.25 wished=4.50 severity=2.17, time=246.50.
# (pid=1240) Warning: Vehicle 'rl_5' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=249.00.
# (pid=1240) Warning: Vehicle 'flow_00.119' performs emergency braking with decel=-15.26 wished=4.50 severity=2.39, time=285.50.
# (pid=1240) Warning: Vehicle 'flow_00.117' performs emergency braking with decel=-12.64 wished=4.50 severity=1.81, time=287.50.
# (pid=1240) Warning: Vehicle 'flow_00.119' performs emergency braking with decel=-15.28 wished=4.50 severity=2.40, time=287.50.
# (pid=1240) Warning: Vehicle 'flow_00.120' performs emergency braking with decel=-12.04 wished=4.50 severity=1.67, time=288.00.
# (pid=1240) Warning: Vehicle 'flow_00.126' performs emergency braking with decel=-24.92 wished=4.50 severity=4.54, time=301.50.
# (pid=1240) Warning: Vehicle 'flow_00.125' performs emergency braking with decel=-23.59 wished=4.50 severity=4.24, time=301.50.
# (pid=1240) Warning: Vehicle 'flow_00.128' performs emergency braking with decel=-19.89 wished=4.50 severity=3.42, time=302.00.
# (pid=1240) Warning: Vehicle 'flow_00.127' performs emergency braking with decel=-19.91 wished=4.50 severity=3.42, time=302.00.
# (pid=1240) Warning: Vehicle 'flow_00.132' performs emergency braking with decel=-17.76 wished=4.50 severity=2.95, time=320.00.
# (pid=1240) Warning: Vehicle 'flow_00.134' performs emergency braking with decel=-11.00 wished=4.50 severity=1.45, time=320.50.
# (pid=1240) Warning: Vehicle 'flow_00.137' performs emergency braking with decel=-11.82 wished=4.50 severity=1.63, time=331.00.
# (pid=1240) Warning: Vehicle 'flow_00.139' performs emergency braking with decel=-13.17 wished=4.50 severity=1.93, time=331.50.
# (pid=1240) Warning: Vehicle 'flow_00.142' performs emergency braking with decel=-16.07 wished=4.50 severity=2.57, time=332.00.
# (pid=1240) Warning: Vehicle 'flow_00.116' performs emergency braking with decel=-13.87 wished=4.50 severity=2.08, time=332.50.
# (pid=1240) Warning: Vehicle 'flow_00.141' performs emergency braking with decel=-17.68 wished=4.50 severity=2.93, time=332.50.
# (pid=1240) Warning: Vehicle 'flow_00.143' performs emergency braking with decel=-20.07 wished=4.50 severity=3.46, time=333.00.
# (pid=1240) Warning: Vehicle 'flow_00.115' performs emergency braking with decel=-9.74 wished=4.50 severity=1.16, time=342.50.
# (pid=1240) Warning: Vehicle 'flow_00.99' performs emergency braking with decel=-9.85 wished=4.50 severity=1.19, time=361.00.
# (pid=1240) Warning: Vehicle 'flow_00.184' performs emergency braking with decel=-15.87 wished=4.50 severity=2.53, time=422.50.
# (pid=1240) Warning: Vehicle 'flow_00.190' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=453.50.
# (pid=1240) Warning: Vehicle 'flow_00.192' performs emergency braking with decel=-10.43 wished=4.50 severity=1.32, time=454.00.
# (pid=1240) Warning: Vehicle 'flow_00.194' performs emergency braking with decel=-12.99 wished=4.50 severity=1.89, time=454.50.
# (pid=1240) Warning: Vehicle 'flow_00.193' performs emergency braking with decel=-14.49 wished=4.50 severity=2.22, time=455.00.
# (pid=1240) Warning: Vehicle 'flow_00.195' performs emergency braking with decel=-15.50 wished=4.50 severity=2.45, time=455.50.
# (pid=1240) Warning: Vehicle 'flow_00.197' performs emergency braking with decel=-15.68 wished=4.50 severity=2.48, time=456.00.
# (pid=1240) Warning: Vehicle 'flow_00.198' performs emergency braking with decel=-15.49 wished=4.50 severity=2.44, time=456.50.
# (pid=1240) Warning: Vehicle 'flow_00.199' performs emergency braking with decel=-15.09 wished=4.50 severity=2.35, time=457.00.
# (pid=1240) Warning: Vehicle 'flow_00.200' performs emergency braking with decel=-15.43 wished=4.50 severity=2.43, time=457.50.
# (pid=1240) Warning: Vehicle 'flow_00.201' performs emergency braking with decel=-16.49 wished=4.50 severity=2.66, time=458.00.
# (pid=1240) Warning: Vehicle 'rl_5' performs emergency braking with decel=-9.00 wished=4.50 severity=1.00, time=467.00.
# (pid=1240) Warning: Vehicle 'flow_00.197' performs emergency braking with decel=-11.05 wished=4.50 severity=1.46, time=469.00.
# (pid=1240) Warning: Vehicle 'flow_00.198' performs emergency braking with decel=-12.43 wished=4.50 severity=1.76, time=469.50.
# (pid=1240) Warning: Vehicle 'flow_00.199' performs emergency braking with decel=-13.53 wished=4.50 severity=2.01, time=470.00.
# (pid=1240) Warning: Vehicle 'flow_00.200' performs emergency braking with decel=-14.11 wished=4.50 severity=2.14, time=470.50.
# (pid=1240) Warning: Vehicle 'flow_00.201' performs emergency braking with decel=-14.54 wished=4.50 severity=2.23, time=471.00.
# (pid=1240) Warning: Vehicle 'flow_00.203' performs emergency braking with decel=-14.31 wished=4.50 severity=2.18, time=471.50.
# (pid=1240) Warning: Vehicle 'flow_00.205' performs emergency braking with decel=-13.98 wished=4.50 severity=2.11, time=472.00.
# (pid=1240) Warning: Vehicle 'flow_00.206' performs emergency braking with decel=-13.48 wished=4.50 severity=2.00, time=472.50.
# (pid=1240) Warning: Vehicle 'flow_00.208' performs emergency braking with decel=-12.94 wished=4.50 severity=1.88, time=473.00.
# (pid=1240) Warning: Vehicle 'flow_00.207' performs emergency braking with decel=-12.61 wished=4.50 severity=1.80, time=473.50.
# (pid=1240) Warning: Vehicle 'flow_00.210' performs emergency braking with decel=-13.89 wished=4.50 severity=2.09, time=474.00.
# (pid=1240) Warning: Vehicle 'flow_00.211' performs emergency braking with decel=-15.03 wished=4.50 severity=2.34, time=474.50.
# (pid=1240) /mnt/c/Users/llave/Documents/GitHub/flow/flow/core/kernel/vehicle/traci.py:957: UserWarning: API change now handles duration as floating point seconds
# (pid=1240)   veh_id, int(target_lane), 100000)

# %% [markdown]
# ## 5. Visualization and Analysis
# Tutorial 04 explains some methods of visualization here used.
#
# python plot_ray_results.py ray_results/construction_traffic/YOUR_EXPERIMENT progress.csv episode_mean_reward
#
# Returns the following plot of the mean reward at each episode over the training this environment for some time.
#
#
# <img src="img/episode_reward_mean.png">
#
# <center>**Figure 3.** The mean reward per episode of the training. </center>

# %% [markdown]
# It would be interesting to compare the mean speeds of the human vehicles on the highway (as in the plot in the previous part of the tutorial) once the RL agents are trained.<br>
# We use visualizer_rllib.py, which runs a simulation using the trained environment, and modify it to return us a similiar csv file as before, with the mean speeds of the vehicles.<br>
# We can thus compare the mean speed at each time step of the human cars on the highway before the consturction zone in a simulation with no RL agents and in a simulation with the trained RL agents.<br>
#
# Our goal was to train the RL agents to improve the mean speed of the human vehicles through this obstacle on the highway. In my training, I found a slight improvment of the flow, though not as consistent and as definite as I would've liked: there is room to improve.

# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

currentDir = '/mnt/c/users/llave/Documents/GitHub/flow_osuphysics/lucalavezzo/'
fname_sim= currentDir+'tutorial/meanSpeeds_sim.csv'
fname_trained = currentDir+'tutorial/meanSpeeds_trained.csv'

def import_data(fname):
    
    fields = []
    rows = []
    
    # reading csv file 
    with open(fname, 'r') as csvfile: 
        
        # creating a csv reader object 
        csvreader = csv.reader(csvfile) 

        # extracting field names through first row 
        fields = next(csvreader) 

        # extracting each data row one by one 
        for row in csvreader: 
            rows.append(float(row[0]))
    
    return fields, rows

sim_fields, sim_rows = import_data(fname_sim)
trained_fields, trained_rows = import_data(fname_trained)

figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plt.plot(sim_rows,label="Simulation without RL agents")
plt.plot(trained_rows,label="Simulation with trained RL agents")
plt.ylabel("Mean Speed of Human Vehicles")
plt.xlabel("Time step")
plt.legend()
plt.grid()
plt.show()
